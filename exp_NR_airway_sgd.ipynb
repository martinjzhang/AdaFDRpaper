# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from util import *
from prim_fdr import *
from data_loader import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## loading airway data
p,x = load_airway(verbose=True)

## testing the BH method
n_rej,t_rej=bh(p,alpha=0.1,verbose=True)
#print('FDP: %s \n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))

## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,verbose=True)
#print('FDP: %s\n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))
# Out:
# ## airway data ##
# # hypothesis: 33469
# p=0.000153542287814, x=6.56329425437
# p=0.0655868795554, x=6.25440153322
# p=0.793765241592, x=5.4687478236
# p=0.735407241539, x=4.05928083764
# p=0.578223628721, x=-1.14539457803
#
#
# ### bh summary ###
# # rejections: 4079
# rejection threshold: 0.0121801247322
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-504e02ea5822> in <module>()
#       7
#       8 ## testing the Storey BH method
# ----> 9 n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,verbose=True)
#      10 #print('FDP: %s\n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))
#
# ~/NeuralFDR2/util.py in storey_bh(p, alpha, lamb, n_sample, verbose)
#      22 def storey_bh(p,alpha=0.05,lamb=0.6,n_sample=None,verbose=False):
#      23     if n_sample: n_sample = p.shape[0]
# ---> 24     pi0_hat  = np.sum(p>lamb)/n_sample/(1-lamb)
#      25     alpha   /= pi0_hat
#      26     p_sort = sorted(p)
#
# TypeError: unsupported operand type(s) for /: 'int' and 'NoneType'

# %%
np.min(x)

# %%
np.max(x)

# %% [markdown]
# ### Testing ###

# %%
## testing the initialization 
temp_x = (x - np.min(x)) / (np.max(x)-np.min(x))
w,a,mu,sigma = ML_init(p,temp_x,3,alpha=0.1,n_itr=100,h=None,verbose=True)

# plt.figure()
# temp=np.linspace(0,1,101)
# plt.hist(x[h==1],bins=50,weights=1/np.sum(h==1)*50*np.ones([np.sum(h==1)]))
# temp = np.linspace(0,1,101)
# plt.plot(temp,f_all(temp,a,mu,sigma,w))
# plt.show()
# Out:
# ### ML initialization starts ###
# ## Learned parameters: ##
# Slope: w=0.012269174064, a=2.4023388671875
# Bump 0: w=0.261387066246, mu=[ 0.44691896], sigma=[ 0.08553053]
# Bump 1: w=0.344801599996, mu=[ 0.65523815], sigma=[ 0.07519836]
# Bump 2: w=0.381542159694, mu=[ 0.5813623], sigma=[ 0.06082121]

# %%
## test prim_fdr
n_rej,t=PrimFDR_SGD(p,temp_x,3,alpha=0.1,h=None,n_itr=1000,verbose=True)

print("### Summary ###")
print("method: perim_test_1d")
print("# rejections: %s"%str(n_rej))
print("FDP: %s"%str( np.sum((h==0)*(p<t))/np.sum(p<t)))
print("### End Summary ###")
# Out:
# ### Parameters
# n_itr=1000, n_samp=33469, lambda0=82.1009654652, lambda1=100.0
# ### ML initialization starts ###
# ## Learned parameters: ##
# Slope: w=0.012269174064, a=2.4023388671875
# Bump 0: w=0.261387066246, mu=[ 0.44691896], sigma=[ 0.08553053]
# Bump 1: w=0.344801599996, mu=[ 0.65523815], sigma=[ 0.07519836]
# Bump 2: w=0.381542159694, mu=[ 0.5813623], sigma=[ 0.06082121]
#
#
# ## # of discovery: 5966
# ### initialization value ###
# Slope: a=[ 2.40233898], b=[-10.35600567]
# Bump 0: w=-4.32612, mu=[ 0.44691896], sigma=[ 0.01463094]
# Bump 1: w=-3.92041, mu=[ 0.65523815], sigma=[ 0.01130959]
# Bump 2: w=-3.60697, mu=[ 0.58136231], sigma=[ 0.00739844]
#
#
# ### iteration 0 ###
# mean t:  0.0256319
# mean discovery:  0.26570875
# loss1:  [-0.24389395]
# loss2:  [ 0.12424719]
# n_rej:  1062835
# Estimated FDP: [ 0.10509431]
# FDP: 0.0
# Slope: a=[ 2.40183902], b=[-10.35650539]
# Bump 0: w=-4.32662, mu=[ 0.44641897], sigma=[ 0.01463094]
# Bump 1: w=-3.92091, mu=[ 0.65573817], sigma=[ 0.01130959]
# Bump 2: w=-3.60747, mu=[ 0.58086228], sigma=[ 0.00739844]
# ### iteration 200 ###
# mean t:  0.0246004
# mean discovery:  0.28626325
# loss1:  [-0.25816268]
# loss2:  [ 0.]
# n_rej:  1145053
# Estimated FDP: [ 0.09529034]
# FDP: 0.0
# Slope: a=[ 2.40625238], b=[-10.35134602]
# Bump 0: w=-4.31891, mu=[ 0.43814814], sigma=[ 0.01463094]
# Bump 1: w=-3.92093, mu=[ 0.66390103], sigma=[ 0.01130959]
# Bump 2: w=-3.61016, mu=[ 0.57153946], sigma=[ 0.00739844]
# ### iteration 400 ###
# mean t:  0.0245975
# mean discovery:  0.26756875
# loss1:  [-0.24324539]
# loss2:  [ 0.02729222]
# n_rej:  1070275
# Estimated FDP: [ 0.10112201]
# FDP: 0.0
# Slope: a=[ 2.41956449], b=[-10.33713913]
# Bump 0: w=-4.30171, mu=[ 0.4349705], sigma=[ 0.01463094]
# Bump 1: w=-3.91298, mu=[ 0.66645801], sigma=[ 0.01130959]
# Bump 2: w=-3.60601, mu=[ 0.56934375], sigma=[ 0.00739844]
# ### iteration 600 ###
# mean t:  0.024675
# mean discovery:  0.2803285
# loss1:  [-0.25439027]
# loss2:  [ 0.]
# n_rej:  1121314
# Estimated FDP: [ 0.09699655]
# FDP: 0.0
# Slope: a=[ 2.4316206], b=[-10.32420826]
# Bump 0: w=-4.28566, mu=[ 0.43010291], sigma=[ 0.01463094]
# Bump 1: w=-3.90622, mu=[ 0.67002118], sigma=[ 0.01130959]
# Bump 2: w=-3.60332, mu=[ 0.56623107], sigma=[ 0.00739844]
# ### iteration 800 ###
# mean t:  0.0242026
# mean discovery:  0.28994025
# loss1:  [-0.26100475]
# loss2:  [ 0.]
# n_rej:  1159761
# Estimated FDP: [ 0.09272861]
# FDP: 0.0
# Slope: a=[ 2.44778538], b=[-10.30712318]
# Bump 0: w=-4.26535, mu=[ 0.4286705], sigma=[ 0.01463094]
# Bump 1: w=-3.89547, mu=[ 0.66959339], sigma=[ 0.01130959]
# Bump 2: w=-3.59669, mu=[ 0.56721616], sigma=[ 0.00739844]
