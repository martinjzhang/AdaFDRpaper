# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from util import *
from prim_fdr import *
from data_loader import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## generating a 1d toy data 
# p,x,h=toy_data_1d(n_sample=100000,vis=1)
# p,h,x=neuralfdr_generate_data_2D(job=0,data_vis=1) ## gaussian mixture
# p,h,x=neuralfdr_generate_data_2D(job=1,data_vis=1) ## linear trend 
p,h,x=neuralfdr_generate_data_2D(job=2,data_vis=1) ## gaussian mixture + linear trend

## testing the BH method
n_rej,t_rej=bh(p,alpha=0.1,verbose=True)
print('FDP: %s \n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))

## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,verbose=True)
print('FDP: %s\n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))
# Out:
# ### bh summary ###
# # rejections: 15726
# rejection threshold: 0.0157258335093
#
#
# FDP: 0.0709016914664
#
# ### sbh summary ###
# # rejections: 19099
# rejection threshold: 0.0276396668996
# null estimate: 0.69095
#
#
# FDP: 0.0994816482538

# %% [markdown]
# ### Testing ###

# %%
## testing the initialization 
w,a,mu,sigma = ML_init(p,x,3,alpha=0.1,n_itr=100,h=h,verbose=True)

# plt.figure()
# temp=np.linspace(0,1,101)
# plt.hist(x[h==1],bins=50,weights=1/np.sum(h==1)*50*np.ones([np.sum(h==1)]))
# temp = np.linspace(0,1,101)
# plt.plot(temp,f_all(temp,a,mu,sigma,w))
# plt.show()
# Out:
# ### ML initialization starts ###
#
# ## Learned parameters: ##
# Slope: w=0.686407465542, a=[ 0.9376416  -0.42949707]
# Bump 0: w=0.136498323903, mu=[ 0.81574845  0.73854095], sigma=[ 0.09285315  0.11146091]
# Bump 1: w=0.153519947202, mu=[ 0.25730885  0.38865851], sigma=[ 0.10473719  0.11977248]
# Bump 2: w=0.0235742633522, mu=[ 0.54089265  0.35566079], sigma=[ 0.13526127  0.12702442]
#
#
# ## Testing Summary ##
# Num of alternatives: 31232.0
# Num of discovery: 20855
# Num of true discovery: 18836.0
# Actual FDP: 0.0968113162311

# %%
## test prim_fdr
n_rej,t=PrimFDR(p,x,3,alpha=0.1,n_itr=100,h=h,verbose=True)
print("### Summary ###")
print("method: perim_test_1d")
print("# rejections: %s"%str(n_rej))
print("FDP: %s"%str( np.sum((h==0)*(p<t))/np.sum(p<t)))
print("### End Summary ###")
# Out:
# ### Parameters
# n_itr=100, n_samp=100000, lambda0=63.5896341778, lambda1=100.0
# ### ML initialization starts ###
#
# ## Learned parameters: ##
# Slope: w=0.686407465542, a=[ 0.9376416  -0.42949707]
# Bump 0: w=0.136498323903, mu=[ 0.81574845  0.73854095], sigma=[ 0.09285315  0.11146091]
# Bump 1: w=0.153519947202, mu=[ 0.25730885  0.38865851], sigma=[ 0.10473719  0.11977248]
# Bump 2: w=0.0235742633522, mu=[ 0.54089265  0.35566079], sigma=[ 0.13526127  0.12702442]
#
#
# ## Summary before optimization ##
# ## Testing Summary ##
# Num of alternatives: 31232.0
# Num of discovery: 20844
# Num of true discovery: 18823.0
# Actual FDP: 0.0969583573211
#
#
# ### initialization value ###
# Slope: a=[ 0.93764162 -0.42949706], b=[-4.92842531]
# Bump 0: w=-3.51253, mu=[ 0.81574845  0.73854095], sigma=[ 0.01724342  0.02484707]
# Bump 1: w=-3.58737, mu=[ 0.25730884  0.38865852], sigma=[ 0.02193976  0.0286909 ]
# Bump 2: w=-5.77558, mu=[ 0.54089266  0.3556608 ], sigma=[ 0.03659122  0.03227041]
#
#
# exp: complete:  0.06741 seconds
# backprop: complete:  0.02805 seconds
# whole: complete:  0.11297 seconds
# ### iteration 0 ###
# mean t:  0.0141296
# mean discovery:  0.15696
# loss1:  [-0.13521597]
# loss2:  [ 0.0608041]
# n_rej:  15696
# Estimated FDP: [ 0.10449681]
# FDP: 0.0549821610601
# Slope: a=[ 0.93264163 -0.43449706], b=[-4.93342543]
# Bump 0: w=-3.51753, mu=[ 0.82074845  0.74354088], sigma=[ 0.01724342  0.02484707]
# Bump 1: w=-3.59237, mu=[ 0.25230896  0.38365877], sigma=[ 0.02193976  0.0286909 ]
# Bump 2: w=-5.78058, mu=[ 0.5358929   0.35066134], sigma=[ 0.03659122  0.03227041]
#
#
# exp: complete:  0.09952 seconds
# backprop: complete:  0.08065 seconds
# whole: complete:  0.19571 seconds
# exp: complete:  0.05269 seconds
# backprop: complete:  0.11647 seconds
# whole: complete:  0.18518 seconds
# exp: complete:  0.02467 seconds
# backprop: complete:  0.05704 seconds
# whole: complete:  0.10930 seconds
# exp: complete:  0.00618 seconds
# backprop: complete:  0.01881 seconds
# whole: complete:  0.03055 seconds
# exp: complete:  0.02958 seconds
# backprop: complete:  0.10071 seconds
# whole: complete:  0.15467 seconds
# exp: complete:  0.03076 seconds
# backprop: complete:  0.49338 seconds
# whole: complete:  0.55110 seconds
# exp: complete:  0.02746 seconds
# backprop: complete:  0.16741 seconds
# whole: complete:  0.21394 seconds
# exp: complete:  0.01620 seconds
# backprop: complete:  0.18112 seconds
# whole: complete:  0.20816 seconds
# exp: complete:  0.03599 seconds
# backprop: complete:  0.04387 seconds
# whole: complete:  0.09727 seconds
# exp: complete:  0.04493 seconds
# backprop: complete:  0.01214 seconds
# whole: complete:  0.08700 seconds
# exp: complete:  0.02662 seconds
# backprop: complete:  0.03568 seconds
# whole: complete:  0.07956 seconds
# exp: complete:  0.01182 seconds
# backprop: complete:  0.39965 seconds
# whole: complete:  0.43246 seconds
# exp: complete:  0.00644 seconds
# backprop: complete:  0.65110 seconds
# whole: complete:  0.66317 seconds
# exp: complete:  0.01359 seconds
# backprop: complete:  0.01803 seconds
# whole: complete:  0.05143 seconds
# exp: complete:  0.14682 seconds
# backprop: complete:  0.01225 seconds
# whole: complete:  0.18819 seconds
# exp: complete:  0.13958 seconds
# backprop: complete:  0.66046 seconds
# whole: complete:  0.83290 seconds
# exp: complete:  0.12795 seconds
# backprop: complete:  0.49081 seconds
# whole: complete:  0.64655 seconds
# exp: complete:  0.14267 seconds
# backprop: complete:  0.05329 seconds
# whole: complete:  0.23907 seconds
# exp: complete:  0.10045 seconds
# backprop: complete:  0.01195 seconds
# whole: complete:  0.12741 seconds
# exp: complete:  0.05342 seconds
# backprop: complete:  0.26289 seconds
# whole: complete:  0.33517 seconds
# ### iteration 20 ###
# mean t:  0.0123938
# mean discovery:  0.14975
# loss1:  [-0.12894736]
# loss2:  [ 0.]
# n_rej:  14975
# Estimated FDP: [ 0.09611502]
# FDP: 0.0503505843072
# Slope: a=[ 0.86784297 -0.49972978], b=[-4.99861336]
# Bump 0: w=-3.5798, mu=[ 0.88215649  0.78395289], sigma=[ 0.01724342  0.02484707]
# Bump 1: w=-3.656, mu=[ 0.27923292  0.37468645], sigma=[ 0.02193976  0.0286909 ]
# Bump 2: w=-5.84556, mu=[ 0.46058106  0.30318666], sigma=[ 0.03659122  0.03227041]
#
#
# exp: complete:  0.01891 seconds
# backprop: complete:  0.23495 seconds
# whole: complete:  0.26879 seconds
# exp: complete:  0.00658 seconds
# backprop: complete:  0.10913 seconds
# whole: complete:  0.12210 seconds
# exp: complete:  0.03893 seconds
# backprop: complete:  0.08324 seconds
# whole: complete:  0.14414 seconds
# exp: complete:  0.13253 seconds
# backprop: complete:  0.01042 seconds
# whole: complete:  0.17202 seconds
# exp: complete:  0.03283 seconds
# backprop: complete:  0.01586 seconds
# whole: complete:  0.06924 seconds
# exp: complete:  0.08653 seconds
# backprop: complete:  0.02738 seconds
# whole: complete:  0.13746 seconds
# exp: complete:  0.14229 seconds
# backprop: complete:  0.00885 seconds
# whole: complete:  0.18070 seconds
# exp: complete:  0.13247 seconds
# backprop: complete:  0.00894 seconds
# whole: complete:  0.17059 seconds
# exp: complete:  0.15472 seconds
# backprop: complete:  0.00885 seconds
# whole: complete:  0.17990 seconds
# exp: complete:  0.03670 seconds
# backprop: complete:  0.58132 seconds
# whole: complete:  0.63182 seconds
# exp: complete:  0.01916 seconds
# backprop: complete:  0.34706 seconds
# whole: complete:  0.39224 seconds
# exp: complete:  0.00647 seconds
# backprop: complete:  0.13258 seconds
# whole: complete:  0.14427 seconds
# exp: complete:  0.05058 seconds
# backprop: complete:  0.12004 seconds
# whole: complete:  0.21144 seconds
# exp: complete:  0.13372 seconds
# backprop: complete:  0.01082 seconds
# whole: complete:  0.16392 seconds
# exp: complete:  0.09187 seconds
# backprop: complete:  0.15272 seconds
# whole: complete:  0.28039 seconds
# exp: complete:  0.14250 seconds
# backprop: complete:  0.21347 seconds
# whole: complete:  0.38682 seconds
# exp: complete:  0.03788 seconds
# backprop: complete:  0.04261 seconds
# whole: complete:  0.10994 seconds
# exp: complete:  0.05265 seconds
# backprop: complete:  0.01215 seconds
# whole: complete:  0.08287 seconds
# exp: complete:  0.02932 seconds
# backprop: complete:  0.00906 seconds
# whole: complete:  0.04967 seconds
# exp: complete:  0.01357 seconds
# backprop: complete:  0.05612 seconds
# whole: complete:  0.08002 seconds
# ### iteration 40 ###
# mean t:  0.0124092
# mean discovery:  0.15012
# loss1:  [-0.12927964]
# loss2:  [ 0.]
# n_rej:  15012
# Estimated FDP: [ 0.09598748]
# FDP: 0.0505595523581
# Slope: a=[ 0.86642492 -0.50254637], b=[-5.00120449]
# Bump 0: w=-3.5735, mu=[ 0.86919063  0.74607223], sigma=[ 0.01724342  0.02484707]
# Bump 1: w=-3.65297, mu=[ 0.27474687  0.37911239], sigma=[ 0.02193976  0.0286909 ]
# Bump 2: w=-5.84693, mu=[ 0.42687634  0.34048969], sigma=[ 0.03659122  0.03227041]
#
#
# exp: complete:  0.04746 seconds
# backprop: complete:  0.02925 seconds
# whole: complete:  0.09970 seconds
# exp: complete:  0.02841 seconds
# backprop: complete:  0.62462 seconds
# whole: complete:  0.66984 seconds
# exp: complete:  0.00683 seconds
# backprop: complete:  0.04949 seconds
# whole: complete:  0.06904 seconds
# exp: complete:  0.13351 seconds
# backprop: complete:  0.01274 seconds
# whole: complete:  0.16624 seconds
# exp: complete:  0.09038 seconds
# backprop: complete:  0.01166 seconds
# whole: complete:  0.13265 seconds
# exp: complete:  0.09630 seconds
# backprop: complete:  0.23462 seconds
# whole: complete:  0.36322 seconds
# exp: complete:  0.00729 seconds
# backprop: complete:  0.47052 seconds
# whole: complete:  0.48478 seconds
# exp: complete:  0.01890 seconds
# backprop: complete:  0.01807 seconds
# whole: complete:  0.07185 seconds
# exp: complete:  0.14300 seconds
# backprop: complete:  0.12087 seconds
# whole: complete:  0.28454 seconds
# exp: complete:  0.02508 seconds
# backprop: complete:  0.01137 seconds
# whole: complete:  0.06488 seconds
# exp: complete:  0.02936 seconds
# backprop: complete:  0.06242 seconds
# whole: complete:  0.11536 seconds
# exp: complete:  0.10068 seconds
# backprop: complete:  0.01015 seconds
# whole: complete:  0.13799 seconds
# exp: complete:  0.05560 seconds
# backprop: complete:  0.00869 seconds
# whole: complete:  0.08137 seconds
# exp: complete:  0.01670 seconds
# backprop: complete:  0.12136 seconds
# whole: complete:  0.16609 seconds
# exp: complete:  0.00651 seconds
# backprop: complete:  0.25840 seconds
# whole: complete:  0.27033 seconds
# exp: complete:  0.00667 seconds
# backprop: complete:  0.05682 seconds
# whole: complete:  0.06872 seconds
# exp: complete:  0.02083 seconds
# backprop: complete:  0.01767 seconds
# whole: complete:  0.05728 seconds
# exp: complete:  0.00763 seconds
# backprop: complete:  0.19574 seconds
# whole: complete:  0.21326 seconds
# exp: complete:  0.04221 seconds
# backprop: complete:  0.00983 seconds
# whole: complete:  0.07633 seconds
# exp: complete:  0.01817 seconds
# backprop: complete:  0.01215 seconds
# whole: complete:  0.04559 seconds
# ### iteration 60 ###
# mean t:  0.0127317
# mean discovery:  0.15151
# loss1:  [-0.13055675]
# loss2:  [ 0.]
# n_rej:  15151
# Estimated FDP: [ 0.09751845]
# FDP: 0.051019734671
# Slope: a=[ 0.87802285 -0.49280819], b=[-4.99116516]
# Bump 0: w=-3.55072, mu=[ 0.84593379  0.72671431], sigma=[ 0.01724342  0.02484707]
# Bump 1: w=-3.63539, mu=[ 0.27507165  0.37824231], sigma=[ 0.02193976  0.0286909 ]
# Bump 2: w=-5.83464, mu=[ 0.39423665  0.37048003], sigma=[ 0.03659122  0.03227041]
#
#
# exp: complete:  0.00671 seconds
# backprop: complete:  0.01071 seconds
# whole: complete:  0.02449 seconds
# exp: complete:  0.05903 seconds
# backprop: complete:  0.03250 seconds
# whole: complete:  0.12786 seconds
# exp: complete:  0.00732 seconds
# backprop: complete:  0.03224 seconds
# whole: complete:  0.04490 seconds
# exp: complete:  0.00681 seconds
# backprop: complete:  0.03267 seconds
# whole: complete:  0.04536 seconds
# exp: complete:  0.00660 seconds
# backprop: complete:  0.01581 seconds
# whole: complete:  0.02784 seconds
# exp: complete:  0.00679 seconds
# backprop: complete:  0.02876 seconds
# whole: complete:  0.04727 seconds
# exp: complete:  0.00662 seconds
# backprop: complete:  0.03255 seconds
# whole: complete:  0.04466 seconds
# exp: complete:  0.00660 seconds
# backprop: complete:  0.06023 seconds
# whole: complete:  0.07365 seconds
# exp: complete:  0.03045 seconds
# backprop: complete:  0.12475 seconds
# whole: complete:  0.18831 seconds
# exp: complete:  0.08756 seconds
# backprop: complete:  0.16524 seconds
# whole: complete:  0.27478 seconds
# exp: complete:  0.03851 seconds
# backprop: complete:  0.02586 seconds
# whole: complete:  0.07767 seconds
# exp: complete:  0.02278 seconds
# backprop: complete:  0.01902 seconds
# whole: complete:  0.05408 seconds
# exp: complete:  0.00840 seconds
# backprop: complete:  0.01290 seconds
# whole: complete:  0.03298 seconds
# exp: complete:  0.16780 seconds
# backprop: complete:  0.00924 seconds
# whole: complete:  0.18887 seconds
# exp: complete:  0.14370 seconds
# backprop: complete:  0.01100 seconds
# whole: complete:  0.17902 seconds
# exp: complete:  0.01978 seconds
# backprop: complete:  0.02474 seconds
# whole: complete:  0.07129 seconds
# exp: complete:  0.02076 seconds
# backprop: complete:  0.02842 seconds
# whole: complete:  0.06425 seconds
# exp: complete:  0.00819 seconds
# backprop: complete:  0.02387 seconds
# whole: complete:  0.03803 seconds
# exp: complete:  0.02541 seconds
# backprop: complete:  0.16957 seconds
# whole: complete:  0.21927 seconds
# exp: complete:  0.01240 seconds
# backprop: complete:  0.24231 seconds
# whole: complete:  0.27529 seconds
# ### iteration 80 ###
# mean t:  0.0131181
# mean discovery:  0.1531
# loss1:  [-0.13199998]
# loss2:  [ 0.]
# n_rej:  15310
# Estimated FDP: [ 0.09937949]
# FDP: 0.0514696276943
# Slope: a=[ 0.89389443 -0.47917208], b=[-4.97719479]
# Bump 0: w=-3.52097, mu=[ 0.83091474  0.72951549], sigma=[ 0.01724342  0.02484707]
# Bump 1: w=-3.61263, mu=[ 0.27452239  0.377794  ], sigma=[ 0.02193976  0.0286909 ]
# Bump 2: w=-5.8176, mu=[ 0.36098582  0.37334523], sigma=[ 0.03659122  0.03227041]
#
#
# exp: complete:  0.05962 seconds
# backprop: complete:  0.59448 seconds
# whole: complete:  0.66815 seconds
# exp: complete:  0.02461 seconds
# backprop: complete:  0.06754 seconds
# whole: complete:  0.10589 seconds
# exp: complete:  0.00661 seconds
# backprop: complete:  0.06716 seconds
# whole: complete:  0.07974 seconds
# exp: complete:  0.00659 seconds
# backprop: complete:  0.03977 seconds
# whole: complete:  0.05158 seconds
# exp: complete:  0.00759 seconds
# backprop: complete:  0.00898 seconds
# whole: complete:  0.02793 seconds
# exp: complete:  0.02947 seconds
# backprop: complete:  0.01544 seconds
# whole: complete:  0.05875 seconds
# exp: complete:  0.01024 seconds
# backprop: complete:  0.41931 seconds
# whole: complete:  0.44403 seconds
# exp: complete:  0.15781 seconds
# backprop: complete:  0.01333 seconds
# whole: complete:  0.18378 seconds
# exp: complete:  0.02193 seconds
# backprop: complete:  0.01080 seconds
# whole: complete:  0.04539 seconds
# exp: complete:  0.08853 seconds
# backprop: complete:  0.01526 seconds
# whole: complete:  0.12221 seconds
# exp: complete:  0.02164 seconds
# backprop: complete:  0.30505 seconds
# whole: complete:  0.33673 seconds
# exp: complete:  0.14025 seconds
# backprop: complete:  0.15325 seconds
# whole: complete:  0.31691 seconds
# exp: complete:  0.09013 seconds
# backprop: complete:  0.01027 seconds
# whole: complete:  0.12523 seconds
# exp: complete:  0.00858 seconds
# backprop: complete:  0.01516 seconds
# whole: complete:  0.04446 seconds
# exp: complete:  0.05310 seconds
# backprop: complete:  0.00918 seconds
# whole: complete:  0.09134 seconds
# exp: complete:  0.14442 seconds
# backprop: complete:  0.01027 seconds
# whole: complete:  0.18359 seconds
# exp: complete:  0.02945 seconds
# backprop: complete:  0.01696 seconds
# whole: complete:  0.06862 seconds
# exp: complete:  0.04008 seconds
# backprop: complete:  0.02816 seconds
# whole: complete:  0.08338 seconds
# exp: complete:  0.02639 seconds
# backprop: complete:  0.12695 seconds
# whole: complete:  0.16668 seconds
# <matplotlib.figure.Figure at 0x7fdcfbad5fd0>
# ### Summary ###
# method: perim_test_1d
# # rejections: 21059
# FDP: 0.0979153805974
# ### End Summary ###
