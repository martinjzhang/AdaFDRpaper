# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from util import *
from prim_fdr import *
from data_loader import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Testing with the GTEx data

# %%
## loading GTEx data
p,x,n_full = load_GTEx_full(verbose=True)

## testing the BH method
n_rej,t_rej=bh(p,alpha=0.1,n_sample=n_full,verbose=True)

## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,n_sample=n_full,lamb=0.995,verbose=True)
# Out:
# ## Load GTEx full data ##
# # all hypothesis: 10623893
# # filtered hypothesis: 169301
# # p=0.00226011, x=[ 13.73583078   0.08957559   0.112     ]
# # p=0.00254028, x=[ 13.74614226   0.08957559   0.        ]
# # p=0.000610689, x=[ 13.74784609   0.08957559   0.        ]
# # p=0.00071358, x=[  1.37478546e+01   8.95755866e-02   1.20000000e-02]
# # p=0.000228687, x=[ 13.74820448   0.08957559   0.209     ]
#
#
# ## bh testing summary ##
# # n_rej = 29348
# # t_rej = 0.000276
#
#
# ## sbh summary ##
# # n_rej = 29689
# # t_rej = 0.000286
# # pi_0 estimate = 0.975

# %%
## test x_prep
_=x_prep(x,x_dim=None,verbose=True)

# %%
## test prim_fdr
n_rej,t=PrimFDR(p,x[:,0],5,alpha=0.1,h=None,n_itr=100,verbose=True)
# Out:
# ## PrimFDR_init starts
# # Learning null distribution
# !!! the model does not converge !!!
# # Learning alternative distribution
# # Test result with PrimFDR_init
# # Num of discovery: 34458
# ## PrimFDR_init finishes
#
# ## optimization paramter:
# # n_itr=100, n_samp=169301, lambda0=12746, lambda1=100
#
# ## optimization initialization:
# # Slope: a=[-0.8201611], b=[-7.90595675]
# # Bump 0: w=-8.63047, mu=[ 0.63562387], sigma=[ 0.00811433]
# # Bump 1: w=-8.41507, mu=[ 0.21958022], sigma=[ 0.01033295]
# # Bump 2: w=-7.89346, mu=[ 0.06650707], sigma=[ 0.00246385]
# # Bump 3: w=-12.7221, mu=[ 0.73972815], sigma=[ 0.00705748]
# # Bump 4: w=-8.62155, mu=[ 0.49828136], sigma=[ 0.01574849]
#
#
# ## iteration 0
# n_rej:  34459
# n_rej sig:  33978.1
# FD esti mirror: 3445
# FD esti mirror sig: 3498.84
# loss1:  [-0.20069608]
# loss2:  [ 0.05967505]
# Estimated FDP: [ 0.10297341]
# FDP: 0.0
# Slope: a=[-0.8251611], b=[-7.91095686]
# Bump 0: w=-8.63547, mu=[ 0.63062388], sigma=[ 0.00811433]
# Bump 1: w=-8.42007, mu=[ 0.21458024], sigma=[ 0.01033295]
# Bump 2: w=-7.89846, mu=[ 0.06150708], sigma=[ 0.00246385]
# Bump 3: w=-12.7271, mu=[ 0.73472834], sigma=[ 0.00705748]
# Bump 4: w=-8.62655, mu=[ 0.49328139], sigma=[ 0.01574849]
# /home/martin/NeuralFDR2/util.py:164: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-x))
# ## iteration 20
# n_rej:  33343
# n_rej sig:  32821.3
# FD esti mirror: 3158
# FD esti mirror sig: 3185.73
# loss1:  [-0.19386342]
# loss2:  [ 0.]
# Estimated FDP: [ 0.09706296]
# FDP: 0.0
# Slope: a=[-0.8802309], b=[-7.9646697]
# Bump 0: w=-8.68736, mu=[ 0.57428998], sigma=[ 0.00811433]
# Bump 1: w=-8.47121, mu=[ 0.16535053], sigma=[ 0.01033295]
# Bump 2: w=-7.94834, mu=[ 0.03467175], sigma=[ 0.00246385]
# Bump 3: w=-12.7811, mu=[ 0.67470771], sigma=[ 0.00705748]
# Bump 4: w=-8.67831, mu=[ 0.45575806], sigma=[ 0.01574849]
# ## iteration 40
# n_rej:  33560
# n_rej sig:  33029.4
# FD esti mirror: 3175
# FD esti mirror sig: 3226.53
# loss1:  [-0.19509302]
# loss2:  [ 0.]
# Estimated FDP: [ 0.09768642]
# FDP: 0.0
# Slope: a=[-0.87950194], b=[-7.9603653]
# Bump 0: w=-8.67896, mu=[ 0.56975269], sigma=[ 0.00811433]
# Bump 1: w=-8.46038, mu=[ 0.18745096], sigma=[ 0.01033295]
# Bump 2: w=-7.93375, mu=[ 0.06389511], sigma=[ 0.00246385]
# Bump 3: w=-12.7781, mu=[ 0.66393131], sigma=[ 0.00705748]
# Bump 4: w=-8.66867, mu=[ 0.47770405], sigma=[ 0.01574849]
# ## iteration 60
# n_rej:  33965
# n_rej sig:  33397.0
# FD esti mirror: 3260
# FD esti mirror sig: 3313.0
# loss1:  [-0.19726418]
# loss2:  [ 0.]
# Estimated FDP: [ 0.09920032]
# FDP: 0.0
# Slope: a=[-0.86835104], b=[-7.94456959]
# Bump 0: w=-8.65826, mu=[ 0.57400173], sigma=[ 0.00811433]
# Bump 1: w=-8.43554, mu=[ 0.22258206], sigma=[ 0.01033295]
# Bump 2: w=-7.90284, mu=[ 0.06463188], sigma=[ 0.00246385]
# Bump 3: w=-12.764, mu=[ 0.66163313], sigma=[ 0.00705748]
# Bump 4: w=-8.64568, mu=[ 0.50756931], sigma=[ 0.01574849]
# ## iteration 80
# n_rej:  34132
# n_rej sig:  33560.8
# FD esti mirror: 3311
# FD esti mirror sig: 3352.38
# loss1:  [-0.1982314]
# loss2:  [ 0.]
# Estimated FDP: [ 0.09988994]
# FDP: 0.0
# Slope: a=[-0.86609197], b=[-7.93712997]
# Bump 0: w=-8.64566, mu=[ 0.5766623], sigma=[ 0.00811433]
# Bump 1: w=-8.41765, mu=[ 0.22892801], sigma=[ 0.01033295]
# Bump 2: w=-7.87813, mu=[ 0.0560765], sigma=[ 0.00246385]
# Bump 3: w=-12.7558, mu=[ 0.65515661], sigma=[ 0.00705748]
# Bump 4: w=-8.63134, mu=[ 0.50588244], sigma=[ 0.01574849]
# # Num of discovery: 34817

# %%
## test prim_fdr
n_rej,t=PrimFDR(p,x,5,alpha=0.1,h=None,nr=10623893/p.shape[0],n_itr=100,verbose=True)
# Out:
# ## PrimFDR_init starts
# # Learning null distribution
# # Learning alternative distribution
# # Test result with PrimFDR_init
# # Num of discovery: 33738
# ## PrimFDR_init finishes
# ## Summary before optimization ##
# ## # of discovery: 32904
# ## Parameters
# n_itr=100, n_samp=169301, lambda0=10000.1600026, lambda1=200.0
# ### initialization value ###
# Slope: a=[-1.11315918  0.15646973  0.15646973], b=[-7.61363411]
# Bump 0: w=-8.0722, mu=[ 0.38140535  0.58303982  0.73181432], sigma=[ 0.04248868  0.01091963  0.03015689]
# Bump 1: w=-7.84226, mu=[ 0.31257057  0.63779581  0.37739146], sigma=[ 0.03942462  0.00860027  0.03480989]
# Bump 2: w=-8.68244, mu=[ 0.58965111  0.42845729  0.46587512], sigma=[ 0.01393348  0.03746306  0.06640829]
# Bump 3: w=-8.62256, mu=[ 0.48824856  0.36037108  0.80993479], sigma=[ 0.06197006  0.03007265  0.01500814]
# Bump 4: w=-7.83987, mu=[ 0.18401465  0.3407557   0.31507787], sigma=[ 0.00716864  0.02178183  0.01743615]
#
#
# ### iteration 0 ###
# mean t:  0.000379611
# FD esti t: 4032.94822364
# FD esti mirror: 3372
# FD esti mirror sig: 3455.43
# mean discovery:  0.199225048877
# loss1:  [-0.19518346]
# loss2:  [ 0.17832294]
# n_rej:  33729
# n_rej sig:  33044.8
# Estimated FDP: [ 0.12204503]
# FDP: 0.0
# Slope: a=[-1.11815917  0.15146974  0.15146974], b=[-7.61863422]
# Bump 0: w=-8.0772, mu=[ 0.38640478  0.57803988  0.73681426], sigma=[ 0.04248868  0.01091963  0.03015689]
# Bump 1: w=-7.84726, mu=[ 0.3175703   0.63279581  0.38239136], sigma=[ 0.03942462  0.00860027  0.03480989]
# Bump 2: w=-8.68744, mu=[ 0.58465111  0.4334572   0.47087505], sigma=[ 0.01393348  0.03746306  0.06640829]
# Bump 3: w=-8.62756, mu=[ 0.48324859  0.36537105  0.81493473], sigma=[ 0.06197006  0.03007265  0.01500814]
# Bump 4: w=-7.84487, mu=[ 0.17901468  0.3457537   0.32007781], sigma=[ 0.00716864  0.02178183  0.01743615]
# /home/martin/NeuralFDR2/util.py:164: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-x))
# ### iteration 20 ###
# mean t:  0.000325839
# FD esti t: 3461.68003609
# FD esti mirror: 2911
# FD esti mirror sig: 2972.75
# mean discovery:  0.189585412963
# loss1:  [-0.18356337]
# loss2:  [ 0.]
# n_rej:  32097
# n_rej sig:  31077.5
# Estimated FDP: [ 0.11138877]
# FDP: 0.0
# Slope: a=[-1.17972302  0.09059276  0.09074394], b=[-7.67953348]
# Bump 0: w=-8.13237, mu=[ 0.40114933  0.55001605  0.79743731], sigma=[ 0.04248868  0.01091963  0.03015689]
# Bump 1: w=-7.90653, mu=[ 0.30650532  0.60021985  0.44666985], sigma=[ 0.03942462  0.00860027  0.03480989]
# Bump 2: w=-8.74466, mu=[ 0.53678393  0.46652859  0.53510094], sigma=[ 0.01393348  0.03746306  0.06640829]
# Bump 3: w=-8.68564, mu=[ 0.42148003  0.42720568  0.8755393 ], sigma=[ 0.06197006  0.03007265  0.01500814]
# Bump 4: w=-7.90484, mu=[ 0.12146786  0.31128654  0.37490472], sigma=[ 0.00716864  0.02178183  0.01743615]
#
#
# ### iteration 40 ###
# mean t:  0.00032282
# FD esti t: 3429.60888915
# FD esti mirror: 2881
# FD esti mirror sig: 2947.32
# mean discovery:  0.189101068511
# loss1:  [-0.18299659]
# loss2:  [ 0.]
# n_rej:  32015
# n_rej sig:  30981.5
# Estimated FDP: [ 0.1106986]
# FDP: 0.0
# Slope: a=[-1.18487096  0.0873742   0.08799982], b=[-7.68266582]
# Bump 0: w=-8.11954, mu=[ 0.46388903  0.55440593  0.79641402], sigma=[ 0.04248868  0.01091963  0.03015689]
# Bump 1: w=-7.90497, mu=[ 0.34374979  0.60863727  0.45738247], sigma=[ 0.03942462  0.00860027  0.03480989]
# Bump 2: w=-8.73823, mu=[ 0.53815842  0.45817938  0.54622823], sigma=[ 0.01393348  0.03746306  0.06640829]
# Bump 3: w=-8.68283, mu=[ 0.41407806  0.4358649   0.87242579], sigma=[ 0.06197006  0.03007265  0.01500814]
# Bump 4: w=-7.90499, mu=[ 0.12483674  0.34198564  0.37440863], sigma=[ 0.00716864  0.02178183  0.01743615]
#
#
# ### iteration 60 ###
# mean t:  0.00032864
# FD esti t: 3491.43184954
# FD esti mirror: 2927
# FD esti mirror sig: 2998.76
# mean discovery:  0.19031192964
# loss1:  [-0.18443239]
# loss2:  [ 0.]
# n_rej:  32220
# n_rej sig:  31224.6
# Estimated FDP: [ 0.11181675]
# FDP: 0.0
# Slope: a=[-1.17997408  0.09485336  0.09611885], b=[-7.67505503]
# Bump 0: w=-8.09033, mu=[ 0.49981862  0.55208617  0.78412747], sigma=[ 0.04248868  0.01091963  0.03015689]
# Bump 1: w=-7.8907, mu=[ 0.38350531  0.62129056  0.45913339], sigma=[ 0.03942462  0.00860027  0.03480989]
# Bump 2: w=-8.71819, mu=[ 0.54762429  0.43884614  0.54837763], sigma=[ 0.01393348  0.03746306  0.06640829]
# Bump 3: w=-8.66738, mu=[ 0.4152073   0.43604681  0.858145  ], sigma=[ 0.06197006  0.03007265  0.01500814]
# Bump 4: w=-7.89304, mu=[ 0.14037256  0.36968753  0.3635233 ], sigma=[ 0.00716864  0.02178183  0.01743615]
#
#
# ### iteration 80 ###
# mean t:  0.000336965
# FD esti t: 3579.87962851
# FD esti mirror: 3007
# FD esti mirror sig: 3071.58
# mean discovery:  0.192001228581
# loss1:  [-0.18636951]
# loss2:  [ 0.]
# n_rej:  32506
# n_rej sig:  31552.5
# Estimated FDP: [ 0.11345771]
# FDP: 0.0
# Slope: a=[-1.1725297   0.10539053  0.10742282], b=[-7.66436625]
# Bump 0: w=-8.05387, mu=[ 0.50737959  0.54439449  0.77172083], sigma=[ 0.04248868  0.01091963  0.03015689]
# Bump 1: w=-7.87189, mu=[ 0.40935311  0.62869978  0.45841309], sigma=[ 0.03942462  0.00860027  0.03480989]
# Bump 2: w=-8.69298, mu=[ 0.55651492  0.4180811   0.54890001], sigma=[ 0.01393348  0.03746306  0.06640829]
# Bump 3: w=-8.64726, mu=[ 0.4174127   0.43550983  0.84674907], sigma=[ 0.06197006  0.03007265  0.01500814]
# Bump 4: w=-7.87643, mu=[ 0.15866607  0.37754437  0.35140371], sigma=[ 0.00716864  0.02178183  0.01743615]
# # Num of discovery: 34048
