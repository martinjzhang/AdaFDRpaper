# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
# from matplotlib import mlab
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
# from __future__ import 
import torch
from torch.autograd import Variable

## import self-written packages 
from module_test import *
from util import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
## generating a 1d toy data 
p,x,h=toy_data_1d(vis=1)

# %%
## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.2,vis=1)
# Out:
# ### Summary ###
# method: Storey BH
# # rejections: 1505
# rejection threshold: 0.0379525376053
# null estimate: 0.7915
# ### End Summary ###

# %%
## maybe we should use pytorch
def PrimFDR_1d(p,x,alpha=0.2,h=None):    
    torch.manual_seed(24)
    n_itr    = 20000
    L        = 2
    lambda0  = 100
    lambda1  = 10000
    loss_rec = np.zeros([n_itr],dtype=float)
 
    p     = Variable(torch.from_numpy(p).float(),requires_grad=False)
    x     = Variable(torch.from_numpy(x).float(),requires_grad=False)
    
    ## initialization    
    a     = Variable(torch.Tensor([-10]),requires_grad=True)
    b     = Variable(torch.Tensor([0]),requires_grad=True)
    w     = Variable(torch.zeros(L)-5,requires_grad=True)
    mu    = Variable(torch.rand(L)*2-1,requires_grad=True)
    sigma = Variable(torch.zeros(L)+0.1,requires_grad=True)
    
    optimizer = torch.optim.Adam([a,b,w,mu,sigma],lr=0.0001)
#     optimizer = torch.optim.Adam([a,b],lr=0.0005)
    optimizer.zero_grad()
    
    for l in range(n_itr):
        ## calculating the model
#         t = torch.exp(x*b+a)
        t = torch.exp(x*b+a)
        for i in range(L):
            t = t+torch.sigmoid(w[i])*torch.exp(-(x-mu[i])**2/sigma[i])
        #t = t.clamp(min=0)
        
        loss1 = -torch.mean(torch.sigmoid(lambda0*(t-p)))
        #loss2 = torch.exp(lambda1*(torch.mean(t)-alpha*torch.mean(torch.sigmoid(lambda0*(t-p)))))
        print(alpha*torch.mean(torch.sigmoid(lambda0*(t-p)))-torch.mean(t))
        loss2 = -torch.log(alpha*torch.mean(torch.sigmoid(lambda0*(t-p)))-torch.mean(t))
        loss  = loss1+loss2
        
        ## backprop
        loss.backward()
        optimizer.step()
        
        ## show the result 
        loss_rec[l] = loss.data.numpy()
        
        if l%2000==0:
            print('mean t: ', np.mean(t.data.numpy()))
            print('mean discovery: ', np.mean(t.data.numpy()>p.data.numpy()))
            print('loss1: ',loss1.data.numpy())
            print('loss2: ',loss2.data.numpy())
            print('n_rej: ',np.sum(t.data.numpy()>p.data.numpy()))
            print('Estimated FDP: %s'%str((torch.mean(t)/torch.mean(torch.sigmoid(lambda0*(t-p)))).data.numpy()))
            print('FDP: %s'%str( np.sum((h==0)*(p.data.numpy()<t.data.numpy()))/np.sum(p.data.numpy()<t.data.numpy())))
            print ('a: %s,b: %s'%(str(a.data.numpy()),str(b.data.numpy())))
            print ('w0: %s, mu0: %s, sigma0: %s'%(str(w.data.numpy()[0]),str(mu.data.numpy()[0]),str(sigma.data.numpy()[0])))
            print ('w1: %s, mu1: %s, sigma1: %s'%(str(w.data.numpy()[1]),str(mu.data.numpy()[1]),str(sigma.data.numpy()[1])))
            plt.figure()
            plot_t(t.data.numpy(),x.data.numpy())
            plt.show()
    
    
    plt.figure()
    plt.plot(loss_rec)
    plt.show()
    
    p = p.data.numpy()
    t = t.data.numpy()
    n_rej=np.sum(p<t)    
        
    return n_rej,t

# %%
n_rej,t=PrimFDR_1d(p,x,alpha=0.2,h=h)

print("### Summary ###")
print("method: perim_test_1d")
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2269
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2292
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2314
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2336
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2359
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2382
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2404
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2427
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2449
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2472
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2495
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2518
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2540
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2563
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2586
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2609
# [torch.FloatTensor of size 1]
# Variable containing:
# 1.00000e-03 *
#   8.2632
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2655
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2678
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2701
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2724
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2747
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2770
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2794
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2817
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2840
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2863
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2887
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2910
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2934
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2957
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.2981
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3004
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3028
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3051
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3075
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3099
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3122
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3146
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3170
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3194
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3218
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3241
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3265
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3289
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3313
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3338
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3362
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3386
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3410
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3434
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3459
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3483
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3507
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3532
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3556
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3581
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3605
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3630
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3655
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3679
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3704
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3729
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3754
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3778
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3803
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3828
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3853
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3878
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3903
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3929
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3954
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.3979
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4004
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4030
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4055
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4080
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4106
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4131
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4157
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4183
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4208
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4234
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4260
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4286
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4311
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4337
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4363
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4389
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4416
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4442
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4468
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4494
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4520
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4547
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4573
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4600
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4626
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4653
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4680
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4706
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4733
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4760
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4787
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4814
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4841
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4868
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4895
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4922
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4949
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.4977
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5004
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5032
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5059
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5087
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5114
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5142
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5170
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5198
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5225
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5253
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5282
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5310
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5338
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5366
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5394
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5423
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5451
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5480
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5509
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5537
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5566
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5595
# [torch.FloatTensor of size 1]
# Variable containing:
# 1.00000e-03 *
#   8.5624
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5653
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5682
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5711
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5740
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5770
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5799
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5829
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5858
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5888
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5918
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5948
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.5978
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6008
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6038
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6068
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6098
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6129
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6159
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6190
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6221
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6251
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6282
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6313
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6344
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6376
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6407
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6438
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6470
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6502
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6533
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6565
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6597
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6629
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6662
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6694
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6726
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6759
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6792
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6825
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6858
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6891
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6924
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6958
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.6991
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7025
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7059
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7093
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7127
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7161
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7196
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7230
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7265
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7300
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7335
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7370
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7406
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7442
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7477
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7513
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7550
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7586
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7623
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7659
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7697
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7734
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7771
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7809
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7847
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7885
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7923
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.7962
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8001
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8040
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8080
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8119
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8159
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8200
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8240
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8281
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8322
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8364
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8406
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8448
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8490
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8533
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8577
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8620
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8664
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8709
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8754
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8799
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8845
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8892
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8938
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.8986
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9034
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9082
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9131
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9181
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9231
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9282
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9334
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9387
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9440
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9494
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9549
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9605
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9662
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9720
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9779
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9839
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9900
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   8.9963
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0027
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0093
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0161
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0230
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0301
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0375
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0451
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0530
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0612
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0698
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0788
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0883
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.0985
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.1095
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.1216
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.1351
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.1509
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.1703
# [torch.FloatTensor of size 1]
#
# Variable containing:
# 1.00000e-03 *
#   9.1973
# [torch.FloatTensor of size 1]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-51-726cc6be13b8> in <module>()
# ----> 1 n_rej,t=PrimFDR_1d(p,x,alpha=0.2,h=h)
#       2
#       3 print("### Summary ###")
#       4 print("method: perim_test_1d")
#       5 print("# rejections: %s"%str(n_rej))
#
# <ipython-input-50-882928055788> in PrimFDR_1d(p, x, alpha, h)
#      32         loss1 = -torch.mean(torch.sigmoid(lambda0*(t-p)))
#      33         #loss2 = torch.exp(lambda1*(torch.mean(t)-alpha*torch.mean(torch.sigmoid(lambda0*(t-p)))))
# ---> 34         print(alpha*torch.mean(torch.sigmoid(lambda0*(t-p)))-torch.mean(t))
#      35         loss2 = -torch.log(alpha*torch.mean(torch.sigmoid(lambda0*(t-p)))-torch.mean(t))
#      36         loss  = loss1+loss2
#
# RuntimeError: value cannot be converted to type double without overflow: inf

# %%
## 
print(np.sum(p<0.05))
print(np.mean((p<0.01)*(h==0)))
# Out:
# 1694
# 0.0091

# %%
def test_t(x):
#     return 0.01+0.1*x    
    return 0.01

# %%
t=test_t(x)
print(np.mean(t))
print(np.mean((p<t)*(h==0)))
# Out:
# 0.01
# 0.0091

# %%
t
# Out:
# 0.01
