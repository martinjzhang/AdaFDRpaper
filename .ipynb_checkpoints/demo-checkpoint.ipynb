# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from module_test import *
from util import *
from prim_fdr import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
## generating a 1d toy data 
p,x,h=toy_data_1d(n_sample=100000,vis=1)
# Out:
# ### Summary ###
# # null: 85600, # alt: 14400:, null proportion: 0.856

# %%
## testing the BH method
n_rej,t_rej=bh(p,alpha=0.1,vis=1)
print('FDP: %s \n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))

## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,vis=1)
print('FDP: %s\n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))

plt.figure(figsize=[16,5])
plot_data_1d(p,x,h,n_pt=10000)
plt.plot([0,1],[t_rej,t_rej])
plt.ylim([0,10*t_rej])
plt.legend()
plt.show()
# Out:
# ### Summary ###
# method: BH
# # rejections: 2829
# rejection threshold: 0.00282551680216
# ### End Summary ###
# FDP: 0.0855425945564
#
# ### Summary ###
# method: Storey BH
# # rejections: 3258
# rejection threshold: 0.00377852616633
# null estimate: 0.861225
# ### End Summary ###
# FDP: 0.0991405770411

# %% [markdown]
# ### Some derivations for the implementation of ML\_init\_1d ###
# The slope function can be written as
# \begin{equation}
# f(x;a) = \frac{a}{e^a-1} e^{ax}.
# \end{equation}
# Then the likihood function, with sample weight, can be written as
# \begin{equation}
# l(x;a) = \sum_{i=1}^n w_i \left( ax_i + \log \frac{a}{e^a-1} \right) = a \sum_i w_i x_i + \sum_i w_i \log \frac{a}{e^a-1}.
# \end{equation}
# We add a regularization factor to have
# \begin{equation}
# l(x;a) = \sum_{i=1}^n w_i \left( ax_i + \log \frac{a}{e^a-1} + 0.005 a^2\right) = a \sum_i w_i x_i + \sum_i w_i \left( \log \frac{a}{e^a-1} + 0.005a^2 \right).
# \end{equation}
# Hence the maximum likelihood estimate satisfies
# \begin{equation}
# \frac{\log \frac{e^{\hat{a}}-1}{\hat{a}}+0.005\hat{a}^2 }{\hat{a}} = \frac{\sum_i w_i x_i}{\sum_i w_i}
# \end{equation}

# %% [markdown]
# ### Some technical consideration of the slope function ###

# %%
temp=np.linspace(-30,30,200)
c=[0.005,0.01,0.05]
plt.figure(figsize=[16,5])
for i in range(3):
    plt.subplot('13'+str(i+1))
    plt.plot(temp,(np.log((np.exp(temp)-1)/temp)+c[i]*temp**2)/temp)
    plt.ylim([0,1])
    plt.title('c = %s'%str(c[i]))
plt.show()

# %%
## testing the initialization 
w,a,mu,sigma = ML_init_1d(p,x,vis=1)

plt.figure()
temp=np.linspace(0,1,101)
plt.hist(x[h==1],bins=50,weights=1/np.sum(h==1)*50*np.ones([np.sum(h==1)]))
temp = np.linspace(0,1,101)
plt.plot(temp,f_all(temp,a,mu,sigma,w))
plt.show()
# Out:
# ### ML initialization starts ###
# ### iteration 0
# difference: 0.0786266486518
# 1107.12645336 1771.32730684 0.625026469746
# [ 0.33233158  0.27824354  0.38942488] 1.3282275390625 [ 0.25437381  0.78776553] [ 0.11697122  0.10207562]
# ### iteration 20
# difference: 0.00688489115093
# 1802.76558835 3043.6722765 0.592299506838
# [ 0.57104546  0.16385843  0.26509611] 1.0352880859374998 [ 0.20404085  0.80576679] [ 0.0474457   0.06157013]
# ### ML initialization ends ###

# %%
## test prim_fdr
n_rej,t=PrimFDR_1d(p,x,alpha=0.1,h=h,verbose=True)

print("### Summary ###")
print("method: perim_test_1d")
print("# rejections: %s"%str(n_rej))
print("FDP: %s"%str( np.sum((h==0)*(p<t))/np.sum(p<t)))
print("### End Summary ###")
# Out:
# n_itr:1000, lambda0:3539.17555626
# ### ML initialization starts ###
# ### ML initialization ends ###
#
# ## Summary before optimization ##
# ### Summary ###
# # rejections: 4180
# FDP: 0.101674641148
# ### End Summary ###
#
# ### initialization value
# a: [ 1.0352881],b: [-7.11684275]
# w0: -5.73673, mu0: 0.203158, sigma0: 0.00398008
# w1: -5.49269, mu1: 0.805808, sigma1: 0.00581687
#
# ### iteration 0 ###
# mean t:  0.00234222
# mean discovery:  0.02925
# loss1:  [-0.02906034]
# loss2:  [ 0.00355962]
# n_rej:  2925
# Estimated FDP: [ 0.08059864]
# FDP: 0.0659829059829
# a: [ 1.03518808],b: [-7.11694288]
# w0: -5.73683, mu0: 0.203058, sigma0: 0.00388008
# w1: -5.49279, mu1: 0.805909, sigma1: 0.00571687
# ### iteration 200 ###
# mean t:  0.00218457
# mean discovery:  0.02858
# loss1:  [-0.02827611]
# loss2:  [ 0.00161185]
# n_rej:  2858
# Estimated FDP: [ 0.07725862]
# FDP: 0.0647305808258
# a: [ 1.02388728],b: [-7.13021564]
# w0: -5.73456, mu0: 0.197311, sigma0: 0.00184844
# w1: -5.47516, mu1: 0.812889, sigma1: 0.00531597
# ### iteration 400 ###
# mean t:  0.00218415
# mean discovery:  0.02863
# loss1:  [-0.02830843]
# loss2:  [ 0.00155402]
# n_rej:  2863
# Estimated FDP: [ 0.07715554]
# FDP: 0.0646175340552
# a: [ 1.01063561],b: [-7.14552402]
# w0: -5.72641, mu0: 0.197393, sigma0: 0.00190738
# w1: -5.45572, mu1: 0.812367, sigma1: 0.00560343
# ### iteration 600 ###
# mean t:  0.00218387
# mean discovery:  0.02863
# loss1:  [-0.0283389]
# loss2:  [ 0.00150312]
# n_rej:  2863
# Estimated FDP: [ 0.07706257]
# FDP: 0.0642682500873
# a: [ 0.99753839],b: [-7.16083145]
# w0: -5.71596, mu0: 0.197487, sigma0: 0.00195789
# w1: -5.43643, mu1: 0.811879, sigma1: 0.00586913
# ### iteration 800 ###
# mean t:  0.00218382
# mean discovery:  0.02866
# loss1:  [-0.02836771]
# loss2:  [ 0.00145975]
# n_rej:  2866
# Estimated FDP: [ 0.07698267]
# FDP: 0.0631542219121
# a: [ 0.98505718],b: [-7.175776]
# w0: -5.70423, mu0: 0.197591, sigma0: 0.00199981
# w1: -5.41746, mu1: 0.811414, sigma1: 0.00610546
# ### Summary ###
# method: perim_test_1d
# # rejections: 4276
# FDP: 0.101730589336
# ### End Summary ###
