# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from util import *
from prim_fdr import *
from data_loader import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## loading airway data
p,x = load_airway(verbose=True)

## testing the BH method
n_rej,t_rej=bh(p,alpha=0.1,verbose=True)
#print('FDP: %s \n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))

## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,verbose=True)
# Out:
# ## airway data ##
# # hypothesis: 33469
# p=0.000153542287814, x=6.56329425437
# p=0.0655868795554, x=6.25440153322
# p=0.793765241592, x=5.4687478236
# p=0.735407241539, x=4.05928083764
# p=0.578223628721, x=-1.14539457803
#
#
# ## bh testing summary ##
# # n_rej = 4079
# # t_rej = 0.012180
#
#
# ## sbh summary ##
# # n_rej = 4079
# # t_rej = 0.012180
# # pi_0 estimate = 1.000

# %% [markdown]
# ### Testing PrimFDR_cv (3-fold validation)
#
# Baseline:
# Screen Shot 2018-02-13 at 10.43.14 PM![image.png](attachment:image.png)

# %%
_=PrimFDR_cv(p,x,5,alpha=0.1,n_itr=10000,h=None,verbose=True)
# Out:
# #time start: 0.0s
# #time input: 0.0005s
# ## testing fold 1: 0.0005s
# ## testing fold 2: 0.5737s
# ## testing fold 3: 1.1720s
# #time test: 1.7358s
# # total rejection: 6021 [1995, 2006, 2020]
# #time total: 2.0555s

# %%
n_rej,t,theta=PrimFDR(p,x,5,alpha=0.1,h=None,n_itr=10000,verbose=True)
# Out:
# ## PrimFDR_init starts
# # Learning null distribution
# Slope: w=0.771436920557, a=-1.3084912109375
# Bump 0: w=0.0978207033288, mu=[ 0.3781859], sigma=[ 0.10578879]
# Bump 1: w=0.125489073996, mu=[ 0.15548042], sigma=[ 0.06691559]
# Bump 2: w=0.00525330211803, mu=[ 0.53920275], sigma=[ 0.10641958]
# # Learning alternative distribution
# !!! the model does not converge !!!
# Slope: w=0.00215397480058, a=3.4764501953125
# Bump 0: w=0.343244811732, mu=[ 0.86664678], sigma=[ 0.05268262]
# Bump 1: w=0.289688109767, mu=[ 0.9624497], sigma=[ 0.02458364]
# Bump 2: w=0.3649131037, mu=[ 0.7093037], sigma=[ 0.09079001]
# # Test result with PrimFDR_init
# # Num of discovery: 6069
# ## PrimFDR_init finishes
#
# ## optimization paramter:
# # n_itr=100, n_samp=33469, lambda0=810, lambda1=100
#
# ## optimization initialization:
# # Slope: a=[ 3.4764502], b=[-11.55079365]
# # Bump 0: w=-2.2561, mu=[ 0.86664677], sigma=[ 0.00555092]
# # Bump 1: w=-1.66353, mu=[ 0.96244973], sigma=[ 0.00120871]
# # Bump 2: w=-2.73915, mu=[ 0.70930368], sigma=[ 0.01648565]
#
#
# ## iteration 0
# n_rej:  6082
# n_rej sig:  6074.51
# FD esti mirror: 608
# FD esti mirror sig: 619.984
# loss1:  [-0.18149649]
# loss2:  [ 0.03744736]
# Estimated FDP: [ 0.10206326]
# FDP: 0.0
# Slope: a=[ 3.47145081], b=[-11.55579281]
# Bump 0: w=-2.2611, mu=[ 0.87164676], sigma=[ 0.00555092]
# Bump 1: w=-1.66853, mu=[ 0.96744972], sigma=[ 0.00120871]
# Bump 2: w=-2.74415, mu=[ 0.71430355], sigma=[ 0.01648565]
# /home/martin/NeuralFDR2/util.py:166: RuntimeWarning: overflow encountered in exp
#   def sigmoid(x):
# ## iteration 20
# n_rej:  5884
# n_rej sig:  5881.97
# FD esti mirror: 540
# FD esti mirror sig: 550.938
# loss1:  [-0.17574383]
# loss2:  [ 0.]
# Estimated FDP: [ 0.09366558]
# FDP: 0.0
# Slope: a=[ 3.44603324], b=[-11.5820961]
# Bump 0: w=-2.28412, mu=[ 0.87714738], sigma=[ 0.00555092]
# Bump 1: w=-1.69405, mu=[ 0.99483418], sigma=[ 0.00120871]
# Bump 2: w=-2.76906, mu=[ 0.69932073], sigma=[ 0.01648565]
# ## iteration 40
# n_rej:  5911
# n_rej sig:  5908.43
# FD esti mirror: 550
# FD esti mirror sig: 558.257
# loss1:  [-0.1765344]
# loss2:  [ 0.]
# Estimated FDP: [ 0.09448486]
# FDP: 0.0
# Slope: a=[ 3.45227146], b=[-11.57761288]
# Bump 0: w=-2.27647, mu=[ 0.87719011], sigma=[ 0.00555092]
# Bump 1: w=-1.68884, mu=[ 0.99083203], sigma=[ 0.00120871]
# Bump 2: w=-2.76261, mu=[ 0.70206845], sigma=[ 0.01648565]
# ## iteration 60
# n_rej:  6016
# n_rej sig:  6013.77
# FD esti mirror: 594
# FD esti mirror sig: 600.426
# loss1:  [-0.17968172]
# loss2:  [ 0.]
# Estimated FDP: [ 0.09984197]
# FDP: 0.0
# Slope: a=[ 3.46822906], b=[-11.56376553]
# Bump 0: w=-2.25978, mu=[ 0.87465864], sigma=[ 0.00555092]
# Bump 1: w=-1.67383, mu=[ 0.9780122], sigma=[ 0.00120871]
# Bump 2: w=-2.74544, mu=[ 0.69785249], sigma=[ 0.01648565]
# ## iteration 80
# n_rej:  5977
# n_rej sig:  5976.01
# FD esti mirror: 581
# FD esti mirror sig: 593.39
# loss1:  [-0.17855352]
# loss2:  [ 0.]
# Estimated FDP: [ 0.09929539]
# FDP: 0.0
# Slope: a=[ 3.46411681], b=[-11.57003021]
# Bump 0: w=-2.2571, mu=[ 0.8890624], sigma=[ 0.00555092]
# Bump 1: w=-1.68375, mu=[ 0.97724324], sigma=[ 0.00120871]
# Bump 2: w=-2.74923, mu=[ 0.70789522], sigma=[ 0.01648565]
# # Num of discovery: 6000

# %%
_ = PrimFDR_init(p,x,20,alpha=0.1,n_itr=100,h=None,verbose=True)
# Out:
# ## PrimFDR_init starts
# # Learning null distribution
# ## initialization
# Slope: w=0.047619047619, a=-2.0898193359375004
# Bump 0: w=0.047619047619, mu=[ 0.20879901], sigma=[ 0.01177509]
# Bump 1: w=0.047619047619, mu=[ 0.63172947], sigma=[ 0.01948395]
# Bump 2: w=0.047619047619, mu=[ 0.02654354], sigma=[ 0.00326489]
# Bump 3: w=0.047619047619, mu=[ 0.34533896], sigma=[ 0.01561433]
# Bump 4: w=0.047619047619, mu=[ 0.48738902], sigma=[ 0.01899806]
# Bump 5: w=0.047619047619, mu=[ 0.06229559], sigma=[ 0.01002944]
# Bump 6: w=0.047619047619, mu=[ 0.26918876], sigma=[ 0.0129349]
# Bump 7: w=0.047619047619, mu=[ 0.1222652], sigma=[ 0.01092307]
# Bump 8: w=0.047619047619, mu=[ 0.6878831], sigma=[ 0.02462578]
# Bump 9: w=0.047619047619, mu=[ 0.43775421], sigma=[ 0.01795828]
# Bump 10: w=0.047619047619, mu=[ 0.5825264], sigma=[ 0.0179548]
# Bump 11: w=0.047619047619, mu=[ 0.14896484], sigma=[ 0.01135637]
# Bump 12: w=0.047619047619, mu=[ 0.09270029], sigma=[ 0.0103112]
# Bump 13: w=0.047619047619, mu=[ 0.39030104], sigma=[ 0.01782178]
# Bump 14: w=0.047619047619, mu=[ 0.00808706], sigma=[ 0.00646614]
# Bump 15: w=0.047619047619, mu=[ 0.75462047], sigma=[ 0.06974829]
# Bump 16: w=0.047619047619, mu=[ 0.1792278], sigma=[ 0.01172624]
# Bump 17: w=0.047619047619, mu=[ 0.23647774], sigma=[ 0.01242063]
# Bump 18: w=0.047619047619, mu=[ 0.53525529], sigma=[ 0.0187615]
# Bump 19: w=0.047619047619, mu=[ 0.30601543], sigma=[ 0.01375263]
#
#
# ## iteration 10 ##
# Slope: w=0.0203986380159, a=-0.8201611328125
# Bump 0: w=0.0499314090041, mu=[ 0.20853907], sigma=[ 0.01296648]
# Bump 1: w=0.0239784346802, mu=[ 0.62850714], sigma=[ 0.01970578]
# Bump 2: w=0.0706050643918, mu=[ 0.0279548], sigma=[ 0.00139299]
# Bump 3: w=0.0329816825508, mu=[ 0.34470123], sigma=[ 0.01649405]
# Bump 4: w=0.0278373856366, mu=[ 0.48809945], sigma=[ 0.02082582]
# Bump 5: w=0.109786760611, mu=[ 0.06173059], sigma=[ 0.00958777]
# Bump 6: w=0.0402170880073, mu=[ 0.26822858], sigma=[ 0.01364345]
# Bump 7: w=0.0705320575678, mu=[ 0.12166542], sigma=[ 0.01180888]
# Bump 8: w=0.0116262046923, mu=[ 0.67936398], sigma=[ 0.0242094]
# Bump 9: w=0.0240198715355, mu=[ 0.43723399], sigma=[ 0.02005299]
# Bump 10: w=0.0337857627327, mu=[ 0.5816917], sigma=[ 0.01838085]
# Bump 11: w=0.0609272823418, mu=[ 0.14816052], sigma=[ 0.01248324]
# Bump 12: w=0.0895961735797, mu=[ 0.09166891], sigma=[ 0.01085793]
# Bump 13: w=0.0282709002975, mu=[ 0.38938393], sigma=[ 0.0191022]
# Bump 14: w=0.129591937439, mu=[ 0.01020997], sigma=[ 0.00770783]
# Bump 15: w=0.00869520435022, mu=[ 0.70548706], sigma=[ 0.05245699]
# Bump 16: w=0.0554227700443, mu=[ 0.17897509], sigma=[ 0.01281843]
# Bump 17: w=0.0438636871928, mu=[ 0.23538055], sigma=[ 0.01366858]
# Bump 18: w=0.0326341570247, mu=[ 0.53561192], sigma=[ 0.0200493]
# Bump 19: w=0.0352975283036, mu=[ 0.30525975], sigma=[ 0.01461826]
# # Learning alternative distribution
# ## initialization
# Slope: w=0.047619047619, a=1.5235205078125
# Bump 0: w=0.047619047619, mu=[ 0.40314474], sigma=[ 0.01368267]
# Bump 1: w=0.047619047619, mu=[ 0.61397618], sigma=[ 0.00836129]
# Bump 2: w=0.047619047619, mu=[ 0.76345652], sigma=[ 0.01539045]
# Bump 3: w=0.047619047619, mu=[ 0.4966327], sigma=[ 0.0107352]
# Bump 4: w=0.047619047619, mu=[ 0.68214451], sigma=[ 0.00911422]
# Bump 5: w=0.047619047619, mu=[ 0.54920711], sigma=[ 0.00965115]
# Bump 6: w=0.047619047619, mu=[ 0.32433836], sigma=[ 0.01827369]
# Bump 7: w=0.047619047619, mu=[ 0.65724057], sigma=[ 0.00920478]
# Bump 8: w=0.047619047619, mu=[ 0.80791334], sigma=[ 0.01906659]
# Bump 9: w=0.047619047619, mu=[ 0.46870427], sigma=[ 0.01111318]
# Bump 10: w=0.047619047619, mu=[ 0.89267775], sigma=[ 0.03717472]
# Bump 11: w=0.047619047619, mu=[ 0.70440136], sigma=[ 0.00874872]
# Bump 12: w=0.047619047619, mu=[ 0.57192983], sigma=[ 0.00908167]
# Bump 13: w=0.047619047619, mu=[ 0.28008545], sigma=[ 0.02070314]
# Bump 14: w=0.047619047619, mu=[ 0.63464207], sigma=[ 0.00837306]
# Bump 15: w=0.047619047619, mu=[ 0.36091908], sigma=[ 0.01535864]
# Bump 16: w=0.047619047619, mu=[ 0.52459816], sigma=[ 0.01049259]
# Bump 17: w=0.047619047619, mu=[ 0.43779673], sigma=[ 0.01282505]
# Bump 18: w=0.047619047619, mu=[ 0.59181305], sigma=[ 0.00827717]
# Bump 19: w=0.047619047619, mu=[ 0.7321624], sigma=[ 0.01189014]
#
#
# ## iteration 10 ##
# Slope: w=0.0195613886203, a=1.2305810546874998
# Bump 0: w=0.0164907402593, mu=[ 0.40672428], sigma=[ 0.01402994]
# Bump 1: w=0.0339683853654, mu=[ 0.61413909], sigma=[ 0.00874548]
# Bump 2: w=0.103746890597, mu=[ 0.76368891], sigma=[ 0.01666138]
# Bump 3: w=0.0240942767527, mu=[ 0.49692404], sigma=[ 0.01115722]
# Bump 4: w=0.0504033564242, mu=[ 0.68238141], sigma=[ 0.00956487]
# Bump 5: w=0.0274880061634, mu=[ 0.54957227], sigma=[ 0.01023805]
# Bump 6: w=0.00412267762127, mu=[ 0.3320083], sigma=[ 0.01860921]
# Bump 7: w=0.0517187888843, mu=[ 0.65849681], sigma=[ 0.00940665]
# Bump 8: w=0.162634598152, mu=[ 0.81226341], sigma=[ 0.02067889]
# Bump 9: w=0.0222734445396, mu=[ 0.469027], sigma=[ 0.01170902]
# Bump 10: w=0.218279117253, mu=[ 0.89319416], sigma=[ 0.03787319]
# Bump 11: w=0.045817961314, mu=[ 0.70504303], sigma=[ 0.00947364]
# Bump 12: w=0.0241764050519, mu=[ 0.57122086], sigma=[ 0.01029714]
# Bump 13: w=0.00243687288203, mu=[ 0.28758494], sigma=[ 0.01382986]
# Bump 14: w=0.0359848440668, mu=[ 0.63528224], sigma=[ 0.00917407]
# Bump 15: w=0.00840236882585, mu=[ 0.36630987], sigma=[ 0.01627448]
# Bump 16: w=0.0245298719527, mu=[ 0.52408934], sigma=[ 0.01152359]
# Bump 17: w=0.0207361667523, mu=[ 0.43955663], sigma=[ 0.01370435]
# Bump 18: w=0.0267226960563, mu=[ 0.59258852], sigma=[ 0.00908835]
# Bump 19: w=0.0764111424653, mu=[ 0.73341095], sigma=[ 0.01285695]
# # Test result with PrimFDR_init
# # Num of discovery: 4283
# ## PrimFDR_init finishes

# %%
## test prim_fdr
n_rej,t=PrimFDR_v2(p,x,3,alpha=0.1,n_itr=100,h=None,verbose=True)
# Out:
# ## ML initialization starts ##
# ## initialization
# Slope: w=0.25, a=-3.2618115234375002
# Bump 0: w=0.25, mu=[ 0.06036162], sigma=[ 0.04580224]
# Bump 1: w=0.25, mu=[ 0.22527807], sigma=[ 0.08305443]
# Bump 2: w=0.25, mu=[ 0.53715195], sigma=[ 0.10449325]
#
#
# !!! the model does not converge !!!
# ## initialization
# Slope: w=0.25, a=0.8399951171875
# Bump 0: w=0.25, mu=[ 0.57833561], sigma=[ 0.06019189]
# Bump 1: w=0.25, mu=[ 0.42866776], sigma=[ 0.07795826]
# Bump 2: w=0.25, mu=[ 0.66785147], sigma=[ 0.07958438]
# ## Learned parameters for null population ##
# Slope: w=0.484847435213, a=-2.9688134765624996
# Bump 0: w=0.245900771506, mu=[ 0.05365628], sigma=[ 0.03669396]
# Bump 1: w=0.193009578511, mu=[ 0.19567093], sigma=[ 0.07490735]
# Bump 2: w=0.0762422147709, mu=[ 0.56203195], sigma=[ 0.06242815]
#
#
# ## Learned parameters for alternative population ##
# Slope: w=0.0122651666606, a=2.4023388671875
# Bump 0: w=0.381759152134, mu=[ 0.58139856], sigma=[ 0.06082503]
# Bump 1: w=0.261477989079, mu=[ 0.44695043], sigma=[ 0.08554126]
# Bump 2: w=0.344497692126, mu=[ 0.65527629], sigma=[ 0.07520017]
# /home/martin/NeuralFDR2/prim_fdr.py:101: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(bins[0:-1],p_alt/p_null,label='true_ratio')
# /home/martin/NeuralFDR2/prim_fdr.py:101: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(bins[0:-1],p_alt/p_null,label='true_ratio')
# # Num of discovery: 4681
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-7fd298fcd954> in <module>()
#       1 ## test prim_fdr
# ----> 2 n_rej,t=PrimFDR_v2(p,x,3,alpha=0.1,n_itr=100,h=None,verbose=True)
#
# TypeError: 'NoneType' object is not iterable

# %%
## testing the initialization 
w,a,mu,sigma = ML_init(p,x,3,alpha=0.1,n_itr=100,h=None,verbose=True)
# Out:
# ## ML initialization starts ##
# !!! the model does not converge !!!
# ## Learned parameters for null population ##
# Slope: w=0.484847435213, a=-2.9688134765624996
# Bump 0: w=0.245900771506, mu=[ 0.05365628], sigma=[ 0.03669396]
# Bump 1: w=0.193009578511, mu=[ 0.19567093], sigma=[ 0.07490735]
# Bump 2: w=0.0762422147709, mu=[ 0.56203195], sigma=[ 0.06242815]
# ## Learned parameters ##
# Slope: w=0.0388807125444, a=2.5976318359375004
# Bump 0: w=0.266895521483, mu=[ 0.60550922], sigma=[ 0.07317619]
# Bump 1: w=0.197833505564, mu=[ 0.45123629], sigma=[ 0.06899098]
# Bump 2: w=0.496390260409, mu=[ 0.69414052], sigma=[ 0.07358343]
#
#
# ## Testing Summary ##
# Num of discovery: 6037

# %%
## test prim_fdr
n_rej,t=PrimFDR(p,x,3,alpha=0.1,h=None,n_itr=5000,verbose=True)

print("### Summary ###")
print("method: perim_test_1d")
print("# rejections: %s"%str(n_rej))
print("FDP: %s"%str( np.sum((h==0)*(p<t))/np.sum(p<t)))
print("### End Summary ###")
# Out:
# ### Parameters
# n_itr=5000, n_samp=33469, lambda0=82.1009654652, lambda1=100.0
# ## ML initialization starts ##
# !!! the model does not converge !!!
# ## Learned parameters for null population ##
# Slope: w=0.484847435213, a=-2.9688134765624996
# Bump 0: w=0.245900771506, mu=[ 0.05365628], sigma=[ 0.03669396]
# Bump 1: w=0.193009578511, mu=[ 0.19567093], sigma=[ 0.07490735]
# Bump 2: w=0.0762422147709, mu=[ 0.56203195], sigma=[ 0.06242815]
# ## Learned parameters ##
# Slope: w=0.0388807125444, a=2.5976318359375004
# Bump 0: w=0.266895521483, mu=[ 0.60550922], sigma=[ 0.07317619]
# Bump 1: w=0.197833505564, mu=[ 0.45123629], sigma=[ 0.06899098]
# Bump 2: w=0.496390260409, mu=[ 0.69414052], sigma=[ 0.07358343]
#
#
# ## Testing Summary ##
# Num of discovery: 6037
# ## # of discovery: 6037
# ### initialization value ###
# Slope: a=[ 2.59763193], b=[-9.11409664]
# Bump 0: w=-3.92613, mu=[ 0.60550922], sigma=[ 0.01070951]
# Bump 1: w=-4.16666, mu=[ 0.45123628], sigma=[ 0.00951951]
# Bump 2: w=-3.31117, mu=[ 0.69414049], sigma=[ 0.01082904]
#
#
# ### iteration 0 ###
# mean t:  0.0126224
# mean discovery:  0.140249185814
# loss1:  [-0.12954663]
# loss2:  [ 0.]
# n_rej:  4694
# Estimated FDP: [ 0.0974354]
# FDP: 0.0
# Slope: a=[ 2.59813166], b=[-9.11359692]
# Bump 0: w=-3.92563, mu=[ 0.6050092], sigma=[ 0.01070951]
# Bump 1: w=-4.16616, mu=[ 0.45173627], sigma=[ 0.00951951]
# Bump 2: w=-3.31067, mu=[ 0.69364047], sigma=[ 0.01082904]
# ### iteration 1000 ###
# mean t:  0.0133334
# mean discovery:  0.142370551854
# loss1:  [-0.13335682]
# loss2:  [ 0.]
# n_rej:  4765
# Estimated FDP: [ 0.09998269]
# FDP: 0.0
# Slope: a=[ 2.60783672], b=[-9.13570118]
# Bump 0: w=-3.91273, mu=[ 0.54186076], sigma=[ 0.01070951]
# Bump 1: w=-4.14769, mu=[ 0.49245316], sigma=[ 0.00951951]
# Bump 2: w=-3.29887, mu=[ 0.69566715], sigma=[ 0.01082904]
# ### iteration 2000 ###
# mean t:  0.0133121
# mean discovery:  0.14204188951
# loss1:  [-0.13333337]
# loss2:  [ 0.]
# n_rej:  4754
# Estimated FDP: [ 0.09984108]
# FDP: 0.0
# Slope: a=[ 2.6121521], b=[-9.16415215]
# Bump 0: w=-3.90579, mu=[ 0.54048079], sigma=[ 0.01070951]
# Bump 1: w=-4.1399, mu=[ 0.49722728], sigma=[ 0.00951951]
# Bump 2: w=-3.2872, mu=[ 0.69928902], sigma=[ 0.01082904]
# ### iteration 3000 ###
# mean t:  0.0133104
# mean discovery:  0.14186261914
# loss1:  [-0.13335854]
# loss2:  [ 0.]
# n_rej:  4748
# Estimated FDP: [ 0.0998095]
# FDP: 0.0
# Slope: a=[ 2.61551237], b=[-9.1929388]
# Bump 0: w=-3.89916, mu=[ 0.54092896], sigma=[ 0.01070951]
# Bump 1: w=-4.13254, mu=[ 0.49860927], sigma=[ 0.00951951]
# Bump 2: w=-3.2761, mu=[ 0.70187247], sigma=[ 0.01082904]
# ### iteration 4000 ###
# mean t:  0.0133189
# mean discovery:  0.141892497535
# loss1:  [-0.13341039]
# loss2:  [ 0.]
# n_rej:  4749
# Estimated FDP: [ 0.09983424]
# FDP: 0.0
# Slope: a=[ 2.61781454], b=[-9.22216988]
# Bump 0: w=-3.89287, mu=[ 0.54207516], sigma=[ 0.01070951]
# Bump 1: w=-4.1256, mu=[ 0.49905059], sigma=[ 0.00951951]
# Bump 2: w=-3.26601, mu=[ 0.70387673], sigma=[ 0.01082904]
# ### Summary ###
# method: perim_test_1d
# # rejections: 6039
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-1cbb6f9d4333> in <module>()
#       5 print("method: perim_test_1d")
#       6 print("# rejections: %s"%str(n_rej))
# ----> 7 print("FDP: %s"%str( np.sum((h==0)*(p<t))/np.sum(p<t)))
#       8 print("### End Summary ###")
#
# NameError: name 'h' is not defined
