# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from util import *
from prim_fdr import *
from data_loader import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
## loading airway data
p,x = load_proteomics(verbose=True)

## testing the BH method
n_rej,t_rej=bh(p,alpha=0.1,verbose=True)
#print('FDP: %s \n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))

## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,verbose=True)
#print('FDP: %s\n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))
# Out:
# ## proteomics.csv ##
# # hypothesis: 2666
# p=9.75243810953e-06, x=1.09861228867
# p=0.0, x=3.04452243772
# p=0.0, x=2.83321334406
# p=0.0, x=2.63905732962
# p=0.0, x=0.69314718056
#
#
# ### bh summary ###
# # rejections: 244
# rejection threshold: 0.00900600150038
#
#
# ### sbh summary ###
# # rejections: 359
# rejection threshold: 0.0199849962491
# null estimate: 0.672355588897

# %% [markdown]
# ### Testing ###

# %%
## testing the initialization 
temp_x = (x - np.min(x)) / (np.max(x)-np.min(x))
w,a,mu,sigma = ML_init(p,temp_x,3,alpha=0.1,n_itr=100,h=None,verbose=True)

# plt.figure()
# temp=np.linspace(0,1,101)
# plt.hist(x[h==1],bins=50,weights=1/np.sum(h==1)*50*np.ones([np.sum(h==1)]))
# temp = np.linspace(0,1,101)
# plt.plot(temp,f_all(temp,a,mu,sigma,w))
# plt.show()
# Out:
# ### ML initialization starts ###
# ## Learned parameters: ##
# Slope: w=0.211307988158, a=-2.0898193359375004
# Bump 0: w=0.135762443483, mu=[ 0.24802526], sigma=[ 0.08783118]
# Bump 1: w=0.359221050212, mu=[ 0.62584861], sigma=[ 0.08957322]
# Bump 2: w=0.293708518147, mu=[ 0.42681505], sigma=[ 0.09948238]

# %%
## test prim_fdr
n_rej,t=PrimFDR(p,temp_x,3,alpha=0.1,h=None,n_itr=5000,verbose=True)

print("### Summary ###")
print("method: perim_test_1d")
print("# rejections: %s"%str(n_rej))
print("FDP: %s"%str( np.sum((h==0)*(p<t))/np.sum(p<t)))
print("### End Summary ###")
# Out:
# ### Parameters
# n_itr=5000, n_samp=2666, lambda0=111.037067888, lambda1=100.0
# ### ML initialization starts ###
# ## Learned parameters: ##
# Slope: w=0.211307988158, a=-2.0898193359375004
# Bump 0: w=0.135762443483, mu=[ 0.24802526], sigma=[ 0.08783118]
# Bump 1: w=0.359221050212, mu=[ 0.62584861], sigma=[ 0.08957322]
# Bump 2: w=0.293708518147, mu=[ 0.42681505], sigma=[ 0.09948238]
#
#
# ## # of discovery: 365
# ### initialization value ###
# Slope: a=[-2.08981943], b=[-5.65347672]
# Bump 0: w=-5.45162, mu=[ 0.24802527], sigma=[ 0.01542863]
# Bump 1: w=-4.49823, mu=[ 0.62584859], sigma=[ 0.01604672]
# Bump 2: w=-4.8045, mu=[ 0.42681506], sigma=[ 0.01979349]
#
#
# ### iteration 0 ###
# mean t:  0.00846863
# mean discovery:  0.0941485371343
# loss1:  [-0.08521941]
# loss2:  [ 0.]
# n_rej:  251
# Estimated FDP: [ 0.0993744]
# FDP: 0.0
# Slope: a=[-2.0888195], b=[-5.65247679]
# Bump 0: w=-5.45062, mu=[ 0.24902524], sigma=[ 0.01542863]
# Bump 1: w=-4.49723, mu=[ 0.6248486], sigma=[ 0.01604672]
# Bump 2: w=-4.8035, mu=[ 0.42781496], sigma=[ 0.01979349]
# ### iteration 1000 ###
# mean t:  0.00950518
# mean discovery:  0.101650412603
# loss1:  [-0.0953595]
# loss2:  [ 0.]
# n_rej:  271
# Estimated FDP: [ 0.09967729]
# FDP: 0.0
# Slope: a=[-1.93884778], b=[-5.5950036]
# Bump 0: w=-5.33014, mu=[ 0.47299454], sigma=[ 0.01542863]
# Bump 1: w=-4.06862, mu=[ 0.61309731], sigma=[ 0.01604672]
# Bump 2: w=-4.60807, mu=[ 0.53257805], sigma=[ 0.01979349]
# ### iteration 2000 ###
# mean t:  0.00971865
# mean discovery:  0.103150787697
# loss1:  [-0.09719495]
# loss2:  [ 0.]
# n_rej:  275
# Estimated FDP: [ 0.09999135]
# FDP: 0.0
# Slope: a=[-1.90591621], b=[-5.62302446]
# Bump 0: w=-5.2573, mu=[ 0.50009394], sigma=[ 0.01542863]
# Bump 1: w=-3.89875, mu=[ 0.63393509], sigma=[ 0.01604672]
# Bump 2: w=-4.51027, mu=[ 0.5569315], sigma=[ 0.01979349]
# ### iteration 3000 ###
# mean t:  0.00973168
# mean discovery:  0.103150787697
# loss1:  [-0.09761663]
# loss2:  [ 0.]
# n_rej:  275
# Estimated FDP: [ 0.09969284]
# FDP: 0.0
# Slope: a=[-1.91538489], b=[-5.68056488]
# Bump 0: w=-5.21536, mu=[ 0.50822991], sigma=[ 0.01542863]
# Bump 1: w=-3.81938, mu=[ 0.65045142], sigma=[ 0.01604672]
# Bump 2: w=-4.4591, mu=[ 0.55954874], sigma=[ 0.01979349]
# ### iteration 4000 ###
# mean t:  0.00978589
# mean discovery:  0.103900975244
# loss1:  [-0.09805816]
# loss2:  [ 0.]
# n_rej:  277
# Estimated FDP: [ 0.09979681]
# FDP: 0.0
# Slope: a=[-1.93491507], b=[-5.74354839]
# Bump 0: w=-5.18096, mu=[ 0.51142097], sigma=[ 0.01542863]
# Bump 1: w=-3.76465, mu=[ 0.66246229], sigma=[ 0.01604672]
# Bump 2: w=-4.42068, mu=[ 0.55272996], sigma=[ 0.01979349]
# ### Summary ###
# method: perim_test_1d
# # rejections: 389
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-970b019c9ca2> in <module>()
#       5 print("method: perim_test_1d")
#       6 print("# rejections: %s"%str(n_rej))
# ----> 7 print("FDP: %s"%str( np.sum((h==0)*(p<t))/np.sum(p<t)))
#       8 print("### End Summary ###")
#
# NameError: name 'h' is not defined
