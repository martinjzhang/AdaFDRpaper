# %%
import numpy as np
import adafdr.method as md
import adafdr.data_loader as dl
import matplotlib.pyplot as plt
import pandas as pd
import pickle
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

data_name = 'simu_data_sd'

# %% [markdown]
# ## Run methods on each simulation datasets
# This may take a while to run. The computed results are already stored in
# - Python methods: `./temp_result/res_ + data_name`
# - R methods: `./temp_result/res_r_ + data_name`
#
# where `data_name` is as defiend above. For those who do not
# want to run these again, they can directly move the figure generation
# section.
#
# For those who wish to run the code to reproduce the results,
# they need to specify the `data_path` below to be the path of
# `AdaFDRpaper_data` on their machine
#
# The Python methods are run by calling `analysis_batch.py` while
# R methods are run by calling `analysis_batch.R`. It is easier to
# run them using `.sh` script but we include them here for
# illustration purpose.

# %%
data_path = '/data3/martin/AdaFDRpaper_data'
input_folder = data_path + '/' + data_name

# %%
# Python methods
# %run analysis_batch.py -i $input_folder -d $data_name
# Out:
# input_folder: /data3/martin/AdaFDRpaper_data/simu_data_sd
# output_folder: ./temp_result/res_simu_data_sd
# alpha_list: [0.05, 0.1, 0.15, 0.2]
# # Processing data_5 with alpha=0.05
# # Processing data_5 with alpha=0.10
# # Processing data_5 with alpha=0.15
# # Processing data_5 with alpha=0.20
# # Processing data_2 with alpha=0.05
# # Processing data_2 with alpha=0.10
# # Processing data_2 with alpha=0.15
# # Processing data_2 with alpha=0.20
# # Processing data_0 with alpha=0.05
# # Processing data_0 with alpha=0.10
# # Processing data_0 with alpha=0.15
# # Processing data_0 with alpha=0.20
# # Processing data_3 with alpha=0.05
# # Processing data_3 with alpha=0.10
# # Processing data_3 with alpha=0.15
# # Processing data_3 with alpha=0.20
# # Processing data_7 with alpha=0.05
# # Processing data_7 with alpha=0.10
# # Processing data_7 with alpha=0.15
# # Processing data_7 with alpha=0.20
# # Processing data_9 with alpha=0.05
# # Processing data_9 with alpha=0.10
# # Processing data_9 with alpha=0.15
# # Processing data_9 with alpha=0.20
# # Processing data_4 with alpha=0.05
# # Processing data_4 with alpha=0.10
# # Processing data_4 with alpha=0.15
# # Processing data_4 with alpha=0.20
# # Processing data_6 with alpha=0.05
# # Processing data_6 with alpha=0.10
# # Processing data_6 with alpha=0.15
# # Processing data_6 with alpha=0.20
# # Processing data_1 with alpha=0.05
# # Processing data_1 with alpha=0.10
# # Processing data_1 with alpha=0.15
# # Processing data_1 with alpha=0.20
# # Processing data_8 with alpha=0.05
# # Processing data_8 with alpha=0.10
# # Processing data_8 with alpha=0.15
# # Processing data_8 with alpha=0.20

# %%
# R methods
output_folder = './temp_result/res_r_' + data_name
if data_name in ['data_yeast', 'data_polyester', 'data_polyester_ui']:
    benchmark_bl = 'T'
else:
    benchmark_bl = 'F'

# %%
# %%bash -s "$input_folder" "$output_folder" "$benchmark_bl"
# Rscript analysis_batch.R $1 $2 $3
# Out:
# [1] "input_folder: /data3/martin/AdaFDRpaper_data/simu_data_sd"
# [1] "output_folder: ./temp_result/res_r_simu_data_sd"
# [1] "benchmark_bl: F"
# [1] "data_0"
# alpha = 0.82: FDPhat 0.82, Number of Rej. 25118
# alpha = 0.81: FDPhat 0.81, Number of Rej. 23695
# alpha = 0.8: FDPhat 0.8, Number of Rej. 22441
# alpha = 0.79: FDPhat 0.79, Number of Rej. 21441
# alpha = 0.78: FDPhat 0.78, Number of Rej. 20763
# alpha = 0.77: FDPhat 0.77, Number of Rej. 19260
# alpha = 0.76: FDPhat 0.76, Number of Rej. 18194
# alpha = 0.75: FDPhat 0.75, Number of Rej. 17263
# alpha = 0.74: FDPhat 0.74, Number of Rej. 16493
# alpha = 0.73: FDPhat 0.73, Number of Rej. 15540
# alpha = 0.72: FDPhat 0.72, Number of Rej. 14653
# alpha = 0.71: FDPhat 0.71, Number of Rej. 13930
# alpha = 0.7: FDPhat 0.7, Number of Rej. 13256
# alpha = 0.69: FDPhat 0.69, Number of Rej. 12464
# alpha = 0.68: FDPhat 0.68, Number of Rej. 11942
# alpha = 0.67: FDPhat 0.67, Number of Rej. 11438
# alpha = 0.66: FDPhat 0.66, Number of Rej. 10652
# alpha = 0.65: FDPhat 0.65, Number of Rej. 10239
# alpha = 0.64: FDPhat 0.64, Number of Rej. 9733
# alpha = 0.63: FDPhat 0.63, Number of Rej. 9532
# alpha = 0.62: FDPhat 0.62, Number of Rej. 9189
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 8957
# alpha = 0.6: FDPhat 0.6, Number of Rej. 8597
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 8286
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 7987
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 7728
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 7458
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 7247
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 7086
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 6883
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 6661
# alpha = 0.51: FDPhat 0.51, Number of Rej. 6510
# alpha = 0.5: FDPhat 0.5, Number of Rej. 6292
# alpha = 0.49: FDPhat 0.49, Number of Rej. 5949
# alpha = 0.48: FDPhat 0.48, Number of Rej. 5698
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 5499
# alpha = 0.46: FDPhat 0.46, Number of Rej. 5383
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 5181
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 5063
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 4895
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 4711
# alpha = 0.41: FDPhat 0.41, Number of Rej. 4576
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 4366
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 4246
# alpha = 0.38: FDPhat 0.38, Number of Rej. 4132
# alpha = 0.37: FDPhat 0.37, Number of Rej. 4049
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 3923
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 3836
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 3733
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 3619
# alpha = 0.32: FDPhat 0.32, Number of Rej. 3447
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 3322
# alpha = 0.3: FDPhat 0.3, Number of Rej. 3177
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 3050
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 2880
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 2768
# alpha = 0.26: FDPhat 0.2597, Number of Rej. 2672
# alpha = 0.25: FDPhat 0.2499, Number of Rej. 2573
# alpha = 0.24: FDPhat 0.2399, Number of Rej. 2505
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 2353
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 2168
# alpha = 0.21: FDPhat 0.2096, Number of Rej. 2104
# alpha = 0.2: FDPhat 0.2, Number of Rej. 2030
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 1902
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 1808
# alpha = 0.17: FDPhat 0.1698, Number of Rej. 1731
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1570
# alpha = 0.15: FDPhat 0.1496, Number of Rej. 1444
# alpha = 0.14: FDPhat 0.1395, Number of Rej. 1384
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 1224
# alpha = 0.12: FDPhat 0.1196, Number of Rej. 1162
# alpha = 0.11: FDPhat 0.1094, Number of Rej. 1106
# alpha = 0.1: FDPhat 0.0999, Number of Rej. 1041
# alpha = 0.09: FDPhat 0.0899, Number of Rej. 990
# alpha = 0.08: FDPhat 0.0796, Number of Rej. 917
# alpha = 0.07: FDPhat 0.0695, Number of Rej. 791
# alpha = 0.06: FDPhat 0.0592, Number of Rej. 760
# alpha = 0.05: FDPhat 0.0493, Number of Rej. 710
# alpha = 0.04: FDPhat 0.0399, Number of Rej. 627
# alpha = 0.03: FDPhat 0.0288, Number of Rej. 520
# alpha = 0.02: FDPhat 0.0176, Number of Rej. 398
# alpha = 0.01: FDPhat 0.0068, Number of Rej. 148
# Task completed!
# [1] "data_1"
# alpha = 0.76: FDPhat 0.76, Number of Rej. 25132
# alpha = 0.75: FDPhat 0.75, Number of Rej. 23418
# alpha = 0.74: FDPhat 0.74, Number of Rej. 22345
# alpha = 0.73: FDPhat 0.73, Number of Rej. 20762
# alpha = 0.72: FDPhat 0.72, Number of Rej. 19087
# alpha = 0.71: FDPhat 0.71, Number of Rej. 17189
# alpha = 0.7: FDPhat 0.7, Number of Rej. 16079
# alpha = 0.69: FDPhat 0.69, Number of Rej. 15135
# alpha = 0.68: FDPhat 0.68, Number of Rej. 13878
# alpha = 0.67: FDPhat 0.67, Number of Rej. 13175
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 12659
# alpha = 0.65: FDPhat 0.65, Number of Rej. 12128
# alpha = 0.64: FDPhat 0.64, Number of Rej. 11543
# alpha = 0.63: FDPhat 0.63, Number of Rej. 11040
# alpha = 0.62: FDPhat 0.62, Number of Rej. 10700
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 10221
# alpha = 0.6: FDPhat 0.6, Number of Rej. 9749
# alpha = 0.59: FDPhat 0.59, Number of Rej. 9434
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 9034
# alpha = 0.57: FDPhat 0.57, Number of Rej. 8646
# alpha = 0.56: FDPhat 0.56, Number of Rej. 8445
# alpha = 0.55: FDPhat 0.55, Number of Rej. 8211
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 7749
# alpha = 0.53: FDPhat 0.53, Number of Rej. 7523
# alpha = 0.52: FDPhat 0.52, Number of Rej. 7350
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 7141
# alpha = 0.5: FDPhat 0.5, Number of Rej. 6980
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 6746
# alpha = 0.48: FDPhat 0.48, Number of Rej. 6525
# alpha = 0.47: FDPhat 0.47, Number of Rej. 6362
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 6102
# alpha = 0.45: FDPhat 0.45, Number of Rej. 5916
# alpha = 0.44: FDPhat 0.44, Number of Rej. 5687
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 5572
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 5397
# alpha = 0.41: FDPhat 0.41, Number of Rej. 5188
# alpha = 0.4: FDPhat 0.4, Number of Rej. 4995
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 4817
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 4685
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 4529
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 4430
# alpha = 0.35: FDPhat 0.35, Number of Rej. 4332
# alpha = 0.34: FDPhat 0.34, Number of Rej. 4256
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 4066
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 3945
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 3727
# alpha = 0.3: FDPhat 0.3, Number of Rej. 3610
# alpha = 0.29: FDPhat 0.29, Number of Rej. 3445
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 3316
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 3197
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 3097
# alpha = 0.25: FDPhat 0.25, Number of Rej. 3032
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 2911
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 2840
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 2619
# alpha = 0.21: FDPhat 0.21, Number of Rej. 2548
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 2488
# alpha = 0.19: FDPhat 0.19, Number of Rej. 2379
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 2314
# alpha = 0.17: FDPhat 0.17, Number of Rej. 2171
# alpha = 0.16: FDPhat 0.16, Number of Rej. 2038
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 1963
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 1881
# alpha = 0.13: FDPhat 0.13, Number of Rej. 1785
# alpha = 0.12: FDPhat 0.12, Number of Rej. 1667
# alpha = 0.11: FDPhat 0.11, Number of Rej. 1564
# alpha = 0.1: FDPhat 0.0995, Number of Rej. 1508
# alpha = 0.09: FDPhat 0.0899, Number of Rej. 1335
# alpha = 0.08: FDPhat 0.0798, Number of Rej. 1291
# alpha = 0.07: FDPhat 0.0696, Number of Rej. 1063
# alpha = 0.06: FDPhat 0.06, Number of Rej. 867
# alpha = 0.05: FDPhat 0.0492, Number of Rej. 712
# alpha = 0.04: FDPhat 0.0398, Number of Rej. 603
# alpha = 0.03: FDPhat 0.0295, Number of Rej. 440
# alpha = 0.02: FDPhat 0.0197, Number of Rej. 203
# [1] "data_2"
# alpha = 0.8: FDPhat 0.8, Number of Rej. 24582
# alpha = 0.79: FDPhat 0.79, Number of Rej. 23281
# alpha = 0.78: FDPhat 0.78, Number of Rej. 21931
# alpha = 0.77: FDPhat 0.77, Number of Rej. 20652
# alpha = 0.76: FDPhat 0.76, Number of Rej. 19139
# alpha = 0.75: FDPhat 0.75, Number of Rej. 17985
# alpha = 0.74: FDPhat 0.74, Number of Rej. 16999
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 16230
# alpha = 0.72: FDPhat 0.72, Number of Rej. 15341
# alpha = 0.71: FDPhat 0.71, Number of Rej. 14346
# alpha = 0.7: FDPhat 0.7, Number of Rej. 13645
# alpha = 0.69: FDPhat 0.69, Number of Rej. 13008
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 12473
# alpha = 0.67: FDPhat 0.67, Number of Rej. 12062
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 11016
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 9906
# alpha = 0.64: FDPhat 0.64, Number of Rej. 9263
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 8866
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 8579
# alpha = 0.61: FDPhat 0.61, Number of Rej. 8164
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 7819
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 7549
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 7244
# alpha = 0.57: FDPhat 0.57, Number of Rej. 7053
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 6899
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 6669
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 6462
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 6295
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 6040
# alpha = 0.51: FDPhat 0.51, Number of Rej. 5875
# alpha = 0.5: FDPhat 0.5, Number of Rej. 5706
# alpha = 0.49: FDPhat 0.49, Number of Rej. 5594
# alpha = 0.48: FDPhat 0.48, Number of Rej. 5488
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 5327
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 5145
# alpha = 0.45: FDPhat 0.45, Number of Rej. 4898
# alpha = 0.44: FDPhat 0.44, Number of Rej. 4725
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 4558
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 4382
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 4255
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 4134
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 4052
# alpha = 0.38: FDPhat 0.38, Number of Rej. 3911
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 3782
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 3582
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 3422
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 3295
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 3192
# alpha = 0.32: FDPhat 0.3197, Number of Rej. 3087
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 2963
# alpha = 0.3: FDPhat 0.2998, Number of Rej. 2915
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 2742
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 2698
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 2633
# alpha = 0.26: FDPhat 0.26, Number of Rej. 2562
# alpha = 0.25: FDPhat 0.2497, Number of Rej. 2471
# alpha = 0.24: FDPhat 0.24, Number of Rej. 2417
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 2327
# alpha = 0.22: FDPhat 0.2197, Number of Rej. 2262
# alpha = 0.21: FDPhat 0.2096, Number of Rej. 2180
# alpha = 0.2: FDPhat 0.1996, Number of Rej. 2119
# alpha = 0.19: FDPhat 0.19, Number of Rej. 2074
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 2029
# alpha = 0.17: FDPhat 0.1698, Number of Rej. 1926
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1826
# alpha = 0.15: FDPhat 0.15, Number of Rej. 1647
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 1580
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 1528
# alpha = 0.12: FDPhat 0.1197, Number of Rej. 1412
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1303
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 1137
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 1074
# alpha = 0.08: FDPhat 0.0796, Number of Rej. 1005
# alpha = 0.07: FDPhat 0.0697, Number of Rej. 890
# alpha = 0.06: FDPhat 0.0598, Number of Rej. 786
# alpha = 0.05: FDPhat 0.0496, Number of Rej. 746
# alpha = 0.04: FDPhat 0.0396, Number of Rej. 681
# alpha = 0.03: FDPhat 0.0296, Number of Rej. 608
# alpha = 0.02: FDPhat 0.0196, Number of Rej. 409
# [1] "data_3"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 24415
# alpha = 0.8: FDPhat 0.8, Number of Rej. 23257
# alpha = 0.79: FDPhat 0.79, Number of Rej. 21905
# alpha = 0.78: FDPhat 0.78, Number of Rej. 20702
# alpha = 0.77: FDPhat 0.77, Number of Rej. 18656
# alpha = 0.76: FDPhat 0.76, Number of Rej. 17318
# alpha = 0.75: FDPhat 0.75, Number of Rej. 16382
# alpha = 0.74: FDPhat 0.74, Number of Rej. 15586
# alpha = 0.73: FDPhat 0.73, Number of Rej. 14976
# alpha = 0.72: FDPhat 0.72, Number of Rej. 14476
# alpha = 0.71: FDPhat 0.71, Number of Rej. 14017
# alpha = 0.7: FDPhat 0.7, Number of Rej. 13513
# alpha = 0.69: FDPhat 0.69, Number of Rej. 12905
# alpha = 0.68: FDPhat 0.68, Number of Rej. 12268
# alpha = 0.67: FDPhat 0.67, Number of Rej. 11772
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 11245
# alpha = 0.65: FDPhat 0.65, Number of Rej. 10553
# alpha = 0.64: FDPhat 0.64, Number of Rej. 10177
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 9763
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 9346
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 9073
# alpha = 0.6: FDPhat 0.6, Number of Rej. 8725
# alpha = 0.59: FDPhat 0.59, Number of Rej. 8419
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 8015
# alpha = 0.57: FDPhat 0.57, Number of Rej. 7737
# alpha = 0.56: FDPhat 0.56, Number of Rej. 7429
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 7263
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 6960
# alpha = 0.53: FDPhat 0.53, Number of Rej. 6774
# alpha = 0.52: FDPhat 0.52, Number of Rej. 6537
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 6350
# alpha = 0.5: FDPhat 0.5, Number of Rej. 6176
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 5911
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 5759
# alpha = 0.47: FDPhat 0.47, Number of Rej. 5600
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 5377
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 5174
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 5031
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 4882
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 4689
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 4550
# alpha = 0.4: FDPhat 0.4, Number of Rej. 4420
# alpha = 0.39: FDPhat 0.39, Number of Rej. 4321
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 4188
# alpha = 0.37: FDPhat 0.37, Number of Rej. 4111
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 4036
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 3884
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 3804
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 3725
# alpha = 0.32: FDPhat 0.32, Number of Rej. 3666
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 3572
# alpha = 0.3: FDPhat 0.2997, Number of Rej. 3473
# alpha = 0.29: FDPhat 0.29, Number of Rej. 3390
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 3267
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 3112
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 2979
# alpha = 0.25: FDPhat 0.25, Number of Rej. 2852
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 2773
# alpha = 0.23: FDPhat 0.23, Number of Rej. 2731
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 2651
# alpha = 0.21: FDPhat 0.21, Number of Rej. 2586
# alpha = 0.2: FDPhat 0.1999, Number of Rej. 2466
# alpha = 0.19: FDPhat 0.1896, Number of Rej. 2326
# alpha = 0.18: FDPhat 0.18, Number of Rej. 2245
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 2078
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 1934
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 1808
# alpha = 0.14: FDPhat 0.1397, Number of Rej. 1718
# alpha = 0.13: FDPhat 0.1297, Number of Rej. 1627
# alpha = 0.12: FDPhat 0.1197, Number of Rej. 1570
# alpha = 0.11: FDPhat 0.1099, Number of Rej. 1520
# alpha = 0.1: FDPhat 0.0995, Number of Rej. 1367
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1280
# alpha = 0.08: FDPhat 0.0797, Number of Rej. 1180
# alpha = 0.07: FDPhat 0.0697, Number of Rej. 1076
# alpha = 0.06: FDPhat 0.0598, Number of Rej. 986
# alpha = 0.05: FDPhat 0.0499, Number of Rej. 921
# alpha = 0.04: FDPhat 0.0395, Number of Rej. 759
# alpha = 0.03: FDPhat 0.0299, Number of Rej. 669
# alpha = 0.02: FDPhat 0.0182, Number of Rej. 385
# alpha = 0.01: FDPhat 0.0096, Number of Rej. 104
# Task completed!
# [1] "data_4"
# alpha = 0.79: FDPhat 0.79, Number of Rej. 23567
# alpha = 0.78: FDPhat 0.78, Number of Rej. 22218
# alpha = 0.77: FDPhat 0.77, Number of Rej. 19850
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 18392
# alpha = 0.75: FDPhat 0.75, Number of Rej. 17399
# alpha = 0.74: FDPhat 0.74, Number of Rej. 15846
# alpha = 0.73: FDPhat 0.73, Number of Rej. 14683
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 13354
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 12338
# alpha = 0.7: FDPhat 0.7, Number of Rej. 11652
# alpha = 0.69: FDPhat 0.69, Number of Rej. 10916
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 10385
# alpha = 0.67: FDPhat 0.67, Number of Rej. 9990
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 9569
# alpha = 0.65: FDPhat 0.65, Number of Rej. 9042
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 8679
# alpha = 0.63: FDPhat 0.63, Number of Rej. 8278
# alpha = 0.62: FDPhat 0.62, Number of Rej. 8055
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 7821
# alpha = 0.6: FDPhat 0.6, Number of Rej. 7575
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 7442
# alpha = 0.58: FDPhat 0.58, Number of Rej. 7195
# alpha = 0.57: FDPhat 0.57, Number of Rej. 6972
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 6731
# alpha = 0.55: FDPhat 0.55, Number of Rej. 6546
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 6312
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 6080
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 5905
# alpha = 0.51: FDPhat 0.51, Number of Rej. 5718
# alpha = 0.5: FDPhat 0.4999, Number of Rej. 5589
# alpha = 0.49: FDPhat 0.49, Number of Rej. 5423
# alpha = 0.48: FDPhat 0.48, Number of Rej. 5323
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 5123
# alpha = 0.46: FDPhat 0.46, Number of Rej. 4983
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 4857
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 4676
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 4592
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 4483
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 4347
# alpha = 0.4: FDPhat 0.4, Number of Rej. 4253
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 4135
# alpha = 0.38: FDPhat 0.38, Number of Rej. 4011
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 3905
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 3816
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 3684
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 3587
# alpha = 0.33: FDPhat 0.33, Number of Rej. 3485
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 3379
# alpha = 0.31: FDPhat 0.31, Number of Rej. 3252
# alpha = 0.3: FDPhat 0.3, Number of Rej. 3207
# alpha = 0.29: FDPhat 0.29, Number of Rej. 3114
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 3013
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 2912
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 2774
# alpha = 0.25: FDPhat 0.25, Number of Rej. 2664
# alpha = 0.24: FDPhat 0.2399, Number of Rej. 2580
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 2441
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 2377
# alpha = 0.21: FDPhat 0.21, Number of Rej. 2281
# alpha = 0.2: FDPhat 0.1997, Number of Rej. 2198
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 2134
# alpha = 0.18: FDPhat 0.1796, Number of Rej. 2077
# alpha = 0.17: FDPhat 0.17, Number of Rej. 1965
# alpha = 0.16: FDPhat 0.1597, Number of Rej. 1891
# alpha = 0.15: FDPhat 0.1497, Number of Rej. 1763
# alpha = 0.14: FDPhat 0.1397, Number of Rej. 1675
# alpha = 0.13: FDPhat 0.1297, Number of Rej. 1627
# alpha = 0.12: FDPhat 0.12, Number of Rej. 1542
# alpha = 0.11: FDPhat 0.1095, Number of Rej. 1434
# alpha = 0.1: FDPhat 0.0995, Number of Rej. 1277
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1103
# alpha = 0.08: FDPhat 0.0799, Number of Rej. 1064
# alpha = 0.07: FDPhat 0.0692, Number of Rej. 809
# alpha = 0.06: FDPhat 0.0593, Number of Rej. 674
# alpha = 0.05: FDPhat 0.0496, Number of Rej. 564
# alpha = 0.04: FDPhat 0.038, Number of Rej. 368
# alpha = 0.03: FDPhat 0.0275, Number of Rej. 363
# alpha = 0.02: FDPhat 0.0175, Number of Rej. 229
# alpha = 0.01: FDPhat 0.0059, Number of Rej. 169
# Task completed!
# [1] "data_5"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 24040
# alpha = 0.8: FDPhat 0.8, Number of Rej. 23104
# alpha = 0.79: FDPhat 0.79, Number of Rej. 21805
# alpha = 0.78: FDPhat 0.78, Number of Rej. 20652
# alpha = 0.77: FDPhat 0.77, Number of Rej. 19324
# alpha = 0.76: FDPhat 0.76, Number of Rej. 18316
# alpha = 0.75: FDPhat 0.75, Number of Rej. 17514
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 16439
# alpha = 0.73: FDPhat 0.73, Number of Rej. 14837
# alpha = 0.72: FDPhat 0.72, Number of Rej. 14328
# alpha = 0.71: FDPhat 0.71, Number of Rej. 13743
# alpha = 0.7: FDPhat 0.7, Number of Rej. 13325
# alpha = 0.69: FDPhat 0.69, Number of Rej. 12945
# alpha = 0.68: FDPhat 0.68, Number of Rej. 12421
# alpha = 0.67: FDPhat 0.67, Number of Rej. 11874
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 11553
# alpha = 0.65: FDPhat 0.65, Number of Rej. 11088
# alpha = 0.64: FDPhat 0.64, Number of Rej. 10538
# alpha = 0.63: FDPhat 0.63, Number of Rej. 9854
# alpha = 0.62: FDPhat 0.62, Number of Rej. 9360
# alpha = 0.61: FDPhat 0.61, Number of Rej. 9135
# alpha = 0.6: FDPhat 0.6, Number of Rej. 8810
# alpha = 0.59: FDPhat 0.59, Number of Rej. 8409
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 8160
# alpha = 0.57: FDPhat 0.57, Number of Rej. 7902
# alpha = 0.56: FDPhat 0.56, Number of Rej. 7711
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 7508
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 7338
# alpha = 0.53: FDPhat 0.53, Number of Rej. 7187
# alpha = 0.52: FDPhat 0.52, Number of Rej. 6952
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 6733
# alpha = 0.5: FDPhat 0.5, Number of Rej. 6564
# alpha = 0.49: FDPhat 0.49, Number of Rej. 6321
# alpha = 0.48: FDPhat 0.48, Number of Rej. 6194
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 5957
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 5834
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 5650
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 5501
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 5438
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 5235
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 5038
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 4886
# alpha = 0.39: FDPhat 0.39, Number of Rej. 4636
# alpha = 0.38: FDPhat 0.38, Number of Rej. 4529
# alpha = 0.37: FDPhat 0.37, Number of Rej. 4360
# alpha = 0.36: FDPhat 0.36, Number of Rej. 4175
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 4038
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 3911
# alpha = 0.33: FDPhat 0.33, Number of Rej. 3770
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 3602
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 3524
# alpha = 0.3: FDPhat 0.3, Number of Rej. 3457
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 3357
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 3184
# alpha = 0.27: FDPhat 0.27, Number of Rej. 3030
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 2940
# alpha = 0.25: FDPhat 0.2497, Number of Rej. 2859
# alpha = 0.24: FDPhat 0.2397, Number of Rej. 2703
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 2610
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 2519
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 2465
# alpha = 0.2: FDPhat 0.1997, Number of Rej. 2369
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 2281
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 2157
# alpha = 0.17: FDPhat 0.1698, Number of Rej. 2102
# alpha = 0.16: FDPhat 0.16, Number of Rej. 1969
# alpha = 0.15: FDPhat 0.15, Number of Rej. 1900
# alpha = 0.14: FDPhat 0.14, Number of Rej. 1772
# alpha = 0.13: FDPhat 0.1298, Number of Rej. 1649
# alpha = 0.12: FDPhat 0.1194, Number of Rej. 1566
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1440
# alpha = 0.1: FDPhat 0.0993, Number of Rej. 1390
# alpha = 0.09: FDPhat 0.0893, Number of Rej. 1288
# alpha = 0.08: FDPhat 0.0793, Number of Rej. 1135
# alpha = 0.07: FDPhat 0.0695, Number of Rej. 1050
# alpha = 0.06: FDPhat 0.0591, Number of Rej. 964
# alpha = 0.05: FDPhat 0.0496, Number of Rej. 766
# alpha = 0.04: FDPhat 0.0389, Number of Rej. 617
# alpha = 0.03: FDPhat 0.0289, Number of Rej. 450
# alpha = 0.02: FDPhat 0.0159, Number of Rej. 126
# alpha = 0.01: FDPhat 0.0088, Number of Rej. 114
# Task completed!
# [1] "data_6"
# alpha = 0.79: FDPhat 0.79, Number of Rej. 24601
# alpha = 0.78: FDPhat 0.78, Number of Rej. 22142
# alpha = 0.77: FDPhat 0.77, Number of Rej. 20795
# alpha = 0.76: FDPhat 0.76, Number of Rej. 18550
# alpha = 0.75: FDPhat 0.75, Number of Rej. 17487
# alpha = 0.74: FDPhat 0.74, Number of Rej. 16559
# alpha = 0.73: FDPhat 0.73, Number of Rej. 15768
# alpha = 0.72: FDPhat 0.72, Number of Rej. 14541
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 13928
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 13434
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 12694
# alpha = 0.68: FDPhat 0.68, Number of Rej. 12228
# alpha = 0.67: FDPhat 0.67, Number of Rej. 11521
# alpha = 0.66: FDPhat 0.66, Number of Rej. 11090
# alpha = 0.65: FDPhat 0.65, Number of Rej. 10151
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 9592
# alpha = 0.63: FDPhat 0.63, Number of Rej. 9051
# alpha = 0.62: FDPhat 0.62, Number of Rej. 8510
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 8144
# alpha = 0.6: FDPhat 0.6, Number of Rej. 7762
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 7630
# alpha = 0.58: FDPhat 0.58, Number of Rej. 7366
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 7152
# alpha = 0.56: FDPhat 0.56, Number of Rej. 6918
# alpha = 0.55: FDPhat 0.55, Number of Rej. 6653
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 6392
# alpha = 0.53: FDPhat 0.53, Number of Rej. 6155
# alpha = 0.52: FDPhat 0.52, Number of Rej. 5985
# alpha = 0.51: FDPhat 0.51, Number of Rej. 5720
# alpha = 0.5: FDPhat 0.5, Number of Rej. 5620
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 5468
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 5332
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 5187
# alpha = 0.46: FDPhat 0.46, Number of Rej. 5020
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 4852
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 4646
# alpha = 0.43: FDPhat 0.43, Number of Rej. 4514
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 4401
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 4330
# alpha = 0.4: FDPhat 0.4, Number of Rej. 4210
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 4109
# alpha = 0.38: FDPhat 0.38, Number of Rej. 4008
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 3879
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 3779
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 3681
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 3558
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 3486
# alpha = 0.32: FDPhat 0.3197, Number of Rej. 3406
# alpha = 0.31: FDPhat 0.31, Number of Rej. 3294
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 3204
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 3106
# alpha = 0.28: FDPhat 0.28, Number of Rej. 3000
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 2857
# alpha = 0.26: FDPhat 0.2597, Number of Rej. 2715
# alpha = 0.25: FDPhat 0.25, Number of Rej. 2632
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 2548
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 2467
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 2407
# alpha = 0.21: FDPhat 0.2096, Number of Rej. 2342
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 2212
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 2128
# alpha = 0.18: FDPhat 0.18, Number of Rej. 2067
# alpha = 0.17: FDPhat 0.1697, Number of Rej. 1909
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1745
# alpha = 0.15: FDPhat 0.15, Number of Rej. 1640
# alpha = 0.14: FDPhat 0.1394, Number of Rej. 1535
# alpha = 0.13: FDPhat 0.13, Number of Rej. 1477
# alpha = 0.12: FDPhat 0.1195, Number of Rej. 1381
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1313
# alpha = 0.1: FDPhat 0.0997, Number of Rej. 1194
# alpha = 0.09: FDPhat 0.0897, Number of Rej. 1171
# alpha = 0.08: FDPhat 0.0794, Number of Rej. 1058
# alpha = 0.07: FDPhat 0.0691, Number of Rej. 999
# alpha = 0.06: FDPhat 0.06, Number of Rej. 884
# alpha = 0.05: FDPhat 0.0488, Number of Rej. 717
# alpha = 0.04: FDPhat 0.0392, Number of Rej. 561
# alpha = 0.03: FDPhat 0.0299, Number of Rej. 501
# alpha = 0.02: FDPhat 0.0198, Number of Rej. 454
# alpha = 0.01: FDPhat 0.009, Number of Rej. 332
# Task completed!
# [1] "data_7"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 23647
# alpha = 0.8: FDPhat 0.8, Number of Rej. 21820
# alpha = 0.79: FDPhat 0.79, Number of Rej. 20086
# alpha = 0.78: FDPhat 0.78, Number of Rej. 19000
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 17870
# alpha = 0.76: FDPhat 0.76, Number of Rej. 16753
# alpha = 0.75: FDPhat 0.75, Number of Rej. 15821
# alpha = 0.74: FDPhat 0.74, Number of Rej. 14175
# alpha = 0.73: FDPhat 0.73, Number of Rej. 13105
# alpha = 0.72: FDPhat 0.72, Number of Rej. 12402
# alpha = 0.71: FDPhat 0.71, Number of Rej. 11961
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 11241
# alpha = 0.69: FDPhat 0.69, Number of Rej. 10821
# alpha = 0.68: FDPhat 0.68, Number of Rej. 10396
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 9834
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 9378
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 8907
# alpha = 0.64: FDPhat 0.64, Number of Rej. 8624
# alpha = 0.63: FDPhat 0.63, Number of Rej. 8486
# alpha = 0.62: FDPhat 0.62, Number of Rej. 8273
# alpha = 0.61: FDPhat 0.61, Number of Rej. 8030
# alpha = 0.6: FDPhat 0.6, Number of Rej. 7642
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 7467
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 7224
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 6914
# alpha = 0.56: FDPhat 0.56, Number of Rej. 6752
# alpha = 0.55: FDPhat 0.55, Number of Rej. 6553
# alpha = 0.54: FDPhat 0.54, Number of Rej. 6330
# alpha = 0.53: FDPhat 0.53, Number of Rej. 6159
# alpha = 0.52: FDPhat 0.52, Number of Rej. 5902
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 5741
# alpha = 0.5: FDPhat 0.4999, Number of Rej. 5467
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 5306
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 5151
# alpha = 0.47: FDPhat 0.47, Number of Rej. 5013
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 4895
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 4753
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 4654
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 4503
# alpha = 0.42: FDPhat 0.42, Number of Rej. 4362
# alpha = 0.41: FDPhat 0.41, Number of Rej. 4232
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 4089
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 4006
# alpha = 0.38: FDPhat 0.38, Number of Rej. 3950
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 3882
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 3738
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 3654
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 3551
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 3441
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 3345
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 3277
# alpha = 0.3: FDPhat 0.2997, Number of Rej. 3166
# alpha = 0.29: FDPhat 0.29, Number of Rej. 3045
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 2898
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 2749
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 2651
# alpha = 0.25: FDPhat 0.25, Number of Rej. 2548
# alpha = 0.24: FDPhat 0.2397, Number of Rej. 2491
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 2441
# alpha = 0.22: FDPhat 0.22, Number of Rej. 2364
# alpha = 0.21: FDPhat 0.2098, Number of Rej. 2293
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 2217
# alpha = 0.19: FDPhat 0.19, Number of Rej. 2074
# alpha = 0.18: FDPhat 0.18, Number of Rej. 1939
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 1835
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 1727
# alpha = 0.15: FDPhat 0.1497, Number of Rej. 1630
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 1523
# alpha = 0.13: FDPhat 0.1295, Number of Rej. 1444
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 1327
# alpha = 0.11: FDPhat 0.1094, Number of Rej. 1115
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 1064
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 984
# alpha = 0.08: FDPhat 0.0796, Number of Rej. 955
# alpha = 0.07: FDPhat 0.0699, Number of Rej. 887
# alpha = 0.06: FDPhat 0.06, Number of Rej. 750
# alpha = 0.05: FDPhat 0.0498, Number of Rej. 642
# alpha = 0.04: FDPhat 0.0395, Number of Rej. 608
# alpha = 0.03: FDPhat 0.0285, Number of Rej. 492
# alpha = 0.02: FDPhat 0.0195, Number of Rej. 308
# [1] "data_8"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 23974
# alpha = 0.8: FDPhat 0.8, Number of Rej. 22729
# alpha = 0.79: FDPhat 0.79, Number of Rej. 21227
# alpha = 0.78: FDPhat 0.78, Number of Rej. 19639
# alpha = 0.77: FDPhat 0.77, Number of Rej. 18696
# alpha = 0.76: FDPhat 0.76, Number of Rej. 17852
# alpha = 0.75: FDPhat 0.75, Number of Rej. 17173
# alpha = 0.74: FDPhat 0.74, Number of Rej. 16507
# alpha = 0.73: FDPhat 0.73, Number of Rej. 16011
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 14929
# alpha = 0.71: FDPhat 0.71, Number of Rej. 13917
# alpha = 0.7: FDPhat 0.7, Number of Rej. 13326
# alpha = 0.69: FDPhat 0.69, Number of Rej. 12682
# alpha = 0.68: FDPhat 0.68, Number of Rej. 12056
# alpha = 0.67: FDPhat 0.67, Number of Rej. 11569
# alpha = 0.66: FDPhat 0.66, Number of Rej. 11029
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 10441
# alpha = 0.64: FDPhat 0.64, Number of Rej. 9999
# alpha = 0.63: FDPhat 0.63, Number of Rej. 9497
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 9133
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 8788
# alpha = 0.6: FDPhat 0.6, Number of Rej. 8520
# alpha = 0.59: FDPhat 0.59, Number of Rej. 8297
# alpha = 0.58: FDPhat 0.58, Number of Rej. 7983
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 7814
# alpha = 0.56: FDPhat 0.56, Number of Rej. 7393
# alpha = 0.55: FDPhat 0.55, Number of Rej. 7231
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 7020
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 6788
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 6611
# alpha = 0.51: FDPhat 0.51, Number of Rej. 6324
# alpha = 0.5: FDPhat 0.5, Number of Rej. 6114
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 5899
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 5756
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 5656
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 5564
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 5422
# alpha = 0.44: FDPhat 0.44, Number of Rej. 5223
# alpha = 0.43: FDPhat 0.43, Number of Rej. 5035
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 4918
# alpha = 0.41: FDPhat 0.41, Number of Rej. 4737
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 4667
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 4483
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 4317
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 4221
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 4098
# alpha = 0.35: FDPhat 0.35, Number of Rej. 3960
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 3820
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 3747
# alpha = 0.32: FDPhat 0.32, Number of Rej. 3550
# alpha = 0.31: FDPhat 0.31, Number of Rej. 3407
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 3251
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 3108
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 3005
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 2866
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 2775
# alpha = 0.25: FDPhat 0.2499, Number of Rej. 2697
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 2573
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 2486
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 2377
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 2275
# alpha = 0.2: FDPhat 0.1999, Number of Rej. 2221
# alpha = 0.19: FDPhat 0.19, Number of Rej. 2058
# alpha = 0.18: FDPhat 0.18, Number of Rej. 2006
# alpha = 0.17: FDPhat 0.1698, Number of Rej. 1944
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 1840
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 1803
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 1717
# alpha = 0.13: FDPhat 0.1298, Number of Rej. 1641
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 1528
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1367
# alpha = 0.1: FDPhat 0.0995, Number of Rej. 1256
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1103
# alpha = 0.08: FDPhat 0.0793, Number of Rej. 1047
# alpha = 0.07: FDPhat 0.0698, Number of Rej. 974
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 839
# alpha = 0.05: FDPhat 0.0493, Number of Rej. 750
# alpha = 0.04: FDPhat 0.039, Number of Rej. 616
# alpha = 0.03: FDPhat 0.0297, Number of Rej. 572
# alpha = 0.02: FDPhat 0.0197, Number of Rej. 458
# alpha = 0.01: FDPhat 0.0071, Number of Rej. 141
# Task completed!
# [1] "data_9"
# alpha = 0.83: FDPhat 0.83, Number of Rej. 24133
# alpha = 0.82: FDPhat 0.82, Number of Rej. 22669
# alpha = 0.81: FDPhat 0.81, Number of Rej. 21307
# alpha = 0.8: FDPhat 0.8, Number of Rej. 20250
# alpha = 0.79: FDPhat 0.79, Number of Rej. 19179
# alpha = 0.78: FDPhat 0.78, Number of Rej. 18196
# alpha = 0.77: FDPhat 0.77, Number of Rej. 17179
# alpha = 0.76: FDPhat 0.76, Number of Rej. 16141
# alpha = 0.75: FDPhat 0.75, Number of Rej. 15330
# alpha = 0.74: FDPhat 0.74, Number of Rej. 14491
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 13675
# alpha = 0.72: FDPhat 0.72, Number of Rej. 12760
# alpha = 0.71: FDPhat 0.71, Number of Rej. 12068
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 11694
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 11194
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 10154
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 9550
# alpha = 0.66: FDPhat 0.66, Number of Rej. 9114
# alpha = 0.65: FDPhat 0.65, Number of Rej. 8779
# alpha = 0.64: FDPhat 0.64, Number of Rej. 8572
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 8377
# alpha = 0.62: FDPhat 0.62, Number of Rej. 8070
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 7727
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 7514
# alpha = 0.59: FDPhat 0.59, Number of Rej. 7270
# alpha = 0.58: FDPhat 0.58, Number of Rej. 7054
# alpha = 0.57: FDPhat 0.57, Number of Rej. 6862
# alpha = 0.56: FDPhat 0.56, Number of Rej. 6654
# alpha = 0.55: FDPhat 0.55, Number of Rej. 6480
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 6184
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 6013
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 5774
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 5581
# alpha = 0.5: FDPhat 0.5, Number of Rej. 5450
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 5330
# alpha = 0.48: FDPhat 0.48, Number of Rej. 5219
# alpha = 0.47: FDPhat 0.47, Number of Rej. 5015
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 4871
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 4779
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 4640
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 4466
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 4334
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 4211
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 4126
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 4019
# alpha = 0.38: FDPhat 0.3798, Number of Rej. 3921
# alpha = 0.37: FDPhat 0.37, Number of Rej. 3811
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 3670
# alpha = 0.35: FDPhat 0.35, Number of Rej. 3540
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 3476
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 3395
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 3276
# alpha = 0.31: FDPhat 0.31, Number of Rej. 3200
# alpha = 0.3: FDPhat 0.3, Number of Rej. 3087
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 2950
# alpha = 0.28: FDPhat 0.28, Number of Rej. 2904
# alpha = 0.27: FDPhat 0.27, Number of Rej. 2815
# alpha = 0.26: FDPhat 0.2597, Number of Rej. 2722
# alpha = 0.25: FDPhat 0.25, Number of Rej. 2592
# alpha = 0.24: FDPhat 0.2399, Number of Rej. 2505
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 2368
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 2243
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 2120
# alpha = 0.2: FDPhat 0.1999, Number of Rej. 2041
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 1961
# alpha = 0.18: FDPhat 0.18, Number of Rej. 1900
# alpha = 0.17: FDPhat 0.1696, Number of Rej. 1851
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 1784
# alpha = 0.15: FDPhat 0.1495, Number of Rej. 1733
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 1666
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 1578
# alpha = 0.12: FDPhat 0.1194, Number of Rej. 1541
# alpha = 0.11: FDPhat 0.1098, Number of Rej. 1439
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 1336
# alpha = 0.09: FDPhat 0.0899, Number of Rej. 1223
# alpha = 0.08: FDPhat 0.08, Number of Rej. 1113
# alpha = 0.07: FDPhat 0.0692, Number of Rej. 954
# alpha = 0.06: FDPhat 0.0597, Number of Rej. 888
# alpha = 0.05: FDPhat 0.0497, Number of Rej. 724
# alpha = 0.04: FDPhat 0.039, Number of Rej. 590
# alpha = 0.03: FDPhat 0.0295, Number of Rej. 543
# alpha = 0.02: FDPhat 0.0175, Number of Rej. 286
# alpha = 0.01: FDPhat 0.0088, Number of Rej. 226
# Task completed!
# Loading required package: nlme
# This is mgcv 1.8-24. For overview type 'help("mgcv-package")'.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.

# %% [markdown]
# ## Figure generation
# ### Collect the results from the saved file

# %%
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
summary_stats = {}
# Python methods
result_path_py = './temp_result/res_' + data_name + '/result.pickle'
with open(result_path_py, 'rb') as fil:
    result_py = pickle.load(fil)
for method in result_py.keys():
    if len(result_py[method])>0:
        summary_stats[method] = {}
        summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
        summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    else:
        continue
    for fdp,power,alpha,dname in result_py[method]:
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# R methods
result_path_r = './temp_result/res_r_' + data_name
r_method_list = ['ihw', 'adapt', 'bl']
for method in r_method_list:
    res_df = pd.read_table(result_path_r + '/res_' + method, delimiter=',') 
    summary_stats[method] = {}
    summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
    summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    for i in range(res_df.shape[0]):
        fdp,power,alpha,dname = res_df.iloc[i]
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# Delete when there is no result
method_list = list(summary_stats.keys())
for method in method_list:
    if np.sum(summary_stats[method]['Power']) == 0:
        del summary_stats[method]

# %% [markdown]
# ### Generate the FDP and power plot

# %%
marker_list = ['o', 'v', 'p', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C4', 'C3', 'C0', 'C5', 'C8']
method_list = ['adafdr-fast', 'adafdr', 'bl', 'adapt', 'ihw', 'sbh', 'bh']
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
# FDP
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['FDP'], axis=0)
        y_err = np.std(summary_stats[method]['FDP'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
axis_min = min(x_min, y_min)
axis_max = max(x_max, y_max)
plt.plot([axis_min, axis_max], [axis_min, axis_max], linestyle='--', color='k')
plt.legend(loc=2, fontsize=12)
plt.ylabel('FDP', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
# Power 
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['Power'], axis=0)
        y_err = np.std(summary_stats[method]['Power'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
plt.legend(loc=2, fontsize=12)
plt.ylabel('power', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
