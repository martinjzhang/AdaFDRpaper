# %%
import numpy as np
import adafdr.method as md
import adafdr.data_loader as dl
import matplotlib.pyplot as plt
import pandas as pd
import pickle
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

data_name = 'simu_data_adapt'

# %% [markdown]
# ## Run methods on each simulation datasets
# This may take a while to run. The computed results are already stored in
# - Python methods: `./temp_result/res_ + data_name`
# - R methods: `./temp_result/res_r_ + data_name`
#
# where `data_name` is as defiend above. For those who do not
# want to run these again, they can directly move the figure generation
# section.
#
# For those who wish to run the code to reproduce the results,
# they need to specify the `data_path` below to be the path of
# `AdaFDRpaper_data` on their machine
#
# The Python methods are run by calling `analysis_batch.py` while
# R methods are run by calling `analysis_batch.R`. It is easier to
# run them using `.sh` script but we include them here for
# illustration purpose.

# %%
data_path = '/data3/martin/AdaFDRpaper_data'
input_folder = data_path + '/' + data_name

# %%
# Python methods
# %run analysis_batch.py -i $input_folder -d $data_name
# Out:
# input_folder: /data3/martin/AdaFDRpaper_data/simu_data_adapt
# output_folder: ./temp_result/res_simu_data_adapt
# alpha_list: [0.05, 0.1, 0.15, 0.2]
# # Processing data_5 with alpha=0.05
# # Processing data_5 with alpha=0.10
# # Processing data_5 with alpha=0.15
# # Processing data_5 with alpha=0.20
# # Processing data_2 with alpha=0.05
# # Processing data_2 with alpha=0.10
# # Processing data_2 with alpha=0.15
# # Processing data_2 with alpha=0.20
# # Processing data_0 with alpha=0.05
# # Processing data_0 with alpha=0.10
# # Processing data_0 with alpha=0.15
# # Processing data_0 with alpha=0.20
# # Processing data_3 with alpha=0.05
# # Processing data_3 with alpha=0.10
# # Processing data_3 with alpha=0.15
# # Processing data_3 with alpha=0.20
# # Processing data_7 with alpha=0.05
# # Processing data_7 with alpha=0.10
# # Processing data_7 with alpha=0.15
# # Processing data_7 with alpha=0.20
# # Processing data_9 with alpha=0.05
# # Processing data_9 with alpha=0.10
# # Processing data_9 with alpha=0.15
# # Processing data_9 with alpha=0.20
# # Processing data_4 with alpha=0.05
# # Processing data_4 with alpha=0.10
# # Processing data_4 with alpha=0.15
# # Processing data_4 with alpha=0.20
# # Processing data_6 with alpha=0.05
# # Processing data_6 with alpha=0.10
# # Processing data_6 with alpha=0.15
# # Processing data_6 with alpha=0.20
# # Processing data_1 with alpha=0.05
# # Processing data_1 with alpha=0.10
# # Processing data_1 with alpha=0.15
# # Processing data_1 with alpha=0.20
# # Processing data_8 with alpha=0.05
# # Processing data_8 with alpha=0.10
# # Processing data_8 with alpha=0.15
# # Processing data_8 with alpha=0.20

# %%
# R methods
output_folder = './temp_result/res_r_' + data_name
if data_name in ['data_yeast', 'data_polyester', 'data_polyester_ui']:
    benchmark_bl = 'T'
else:
    benchmark_bl = 'F'

# %%
# %%bash -s "$input_folder" "$output_folder" "$benchmark_bl"
# Rscript analysis_batch.R $1 $2 $3
# Out:
# [1] "input_folder: /data3/martin/AdaFDRpaper_data/simu_data_adapt"
# [1] "output_folder: ./temp_result/res_r_simu_data_adapt"
# [1] "benchmark_bl: F"
# [1] "data_0"
# alpha = 0.89: FDPhat 0.8898, Number of Rej. 1189
# alpha = 0.88: FDPhat 0.8795, Number of Rej. 1154
# alpha = 0.87: FDPhat 0.8698, Number of Rej. 1137
# alpha = 0.86: FDPhat 0.8592, Number of Rej. 1108
# alpha = 0.85: FDPhat 0.8498, Number of Rej. 952
# alpha = 0.84: FDPhat 0.8399, Number of Rej. 862
# alpha = 0.83: FDPhat 0.829, Number of Rej. 854
# alpha = 0.82: FDPhat 0.8199, Number of Rej. 744
# alpha = 0.81: FDPhat 0.8087, Number of Rej. 732
# alpha = 0.8: FDPhat 0.8, Number of Rej. 670
# alpha = 0.79: FDPhat 0.7897, Number of Rej. 623
# alpha = 0.78: FDPhat 0.7795, Number of Rej. 594
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 591
# alpha = 0.76: FDPhat 0.7598, Number of Rej. 587
# alpha = 0.75: FDPhat 0.7491, Number of Rej. 586
# alpha = 0.74: FDPhat 0.7396, Number of Rej. 576
# alpha = 0.73: FDPhat 0.7293, Number of Rej. 569
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 564
# alpha = 0.71: FDPhat 0.7098, Number of Rej. 541
# alpha = 0.7: FDPhat 0.6987, Number of Rej. 521
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 516
# alpha = 0.68: FDPhat 0.6783, Number of Rej. 488
# alpha = 0.67: FDPhat 0.6688, Number of Rej. 477
# alpha = 0.66: FDPhat 0.6597, Number of Rej. 476
# alpha = 0.65: FDPhat 0.6483, Number of Rej. 435
# alpha = 0.64: FDPhat 0.639, Number of Rej. 421
# alpha = 0.63: FDPhat 0.6288, Number of Rej. 396
# alpha = 0.62: FDPhat 0.6186, Number of Rej. 388
# alpha = 0.61: FDPhat 0.6094, Number of Rej. 384
# alpha = 0.6: FDPhat 0.5995, Number of Rej. 382
# alpha = 0.59: FDPhat 0.5892, Number of Rej. 370
# alpha = 0.58: FDPhat 0.5784, Number of Rej. 370
# alpha = 0.57: FDPhat 0.5682, Number of Rej. 359
# alpha = 0.56: FDPhat 0.56, Number of Rej. 350
# alpha = 0.55: FDPhat 0.5481, Number of Rej. 343
# alpha = 0.54: FDPhat 0.537, Number of Rej. 324
# alpha = 0.53: FDPhat 0.5294, Number of Rej. 323
# alpha = 0.52: FDPhat 0.5171, Number of Rej. 321
# alpha = 0.51: FDPhat 0.5096, Number of Rej. 312
# alpha = 0.5: FDPhat 0.5, Number of Rej. 296
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 296
# alpha = 0.48: FDPhat 0.4793, Number of Rej. 290
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 281
# alpha = 0.46: FDPhat 0.4585, Number of Rej. 277
# alpha = 0.45: FDPhat 0.4493, Number of Rej. 276
# alpha = 0.44: FDPhat 0.438, Number of Rej. 258
# alpha = 0.43: FDPhat 0.4291, Number of Rej. 254
# alpha = 0.42: FDPhat 0.4167, Number of Rej. 252
# alpha = 0.41: FDPhat 0.4087, Number of Rej. 252
# alpha = 0.4: FDPhat 0.3991, Number of Rej. 233
# alpha = 0.39: FDPhat 0.3886, Number of Rej. 229
# alpha = 0.38: FDPhat 0.3778, Number of Rej. 225
# alpha = 0.37: FDPhat 0.3694, Number of Rej. 222
# alpha = 0.36: FDPhat 0.3559, Number of Rej. 222
# alpha = 0.35: FDPhat 0.3484, Number of Rej. 221
# alpha = 0.34: FDPhat 0.338, Number of Rej. 213
# alpha = 0.33: FDPhat 0.3255, Number of Rej. 212
# alpha = 0.32: FDPhat 0.316, Number of Rej. 212
# alpha = 0.31: FDPhat 0.3095, Number of Rej. 210
# alpha = 0.3: FDPhat 0.3, Number of Rej. 210
# alpha = 0.29: FDPhat 0.2871, Number of Rej. 209
# alpha = 0.28: FDPhat 0.2775, Number of Rej. 209
# alpha = 0.27: FDPhat 0.2692, Number of Rej. 208
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 204
# alpha = 0.25: FDPhat 0.2488, Number of Rej. 201
# alpha = 0.24: FDPhat 0.2381, Number of Rej. 189
# alpha = 0.23: FDPhat 0.2295, Number of Rej. 183
# alpha = 0.22: FDPhat 0.2191, Number of Rej. 178
# alpha = 0.21: FDPhat 0.2069, Number of Rej. 174
# alpha = 0.2: FDPhat 0.1977, Number of Rej. 172
# alpha = 0.19: FDPhat 0.1871, Number of Rej. 171
# alpha = 0.18: FDPhat 0.1786, Number of Rej. 168
# alpha = 0.17: FDPhat 0.1687, Number of Rej. 166
# alpha = 0.16: FDPhat 0.1585, Number of Rej. 164
# alpha = 0.15: FDPhat 0.1467, Number of Rej. 150
# alpha = 0.14: FDPhat 0.1361, Number of Rej. 147
# alpha = 0.13: FDPhat 0.1293, Number of Rej. 147
# alpha = 0.12: FDPhat 0.1156, Number of Rej. 147
# alpha = 0.11: FDPhat 0.1096, Number of Rej. 146
# alpha = 0.1: FDPhat 0.0993, Number of Rej. 141
# alpha = 0.09: FDPhat 0.0882, Number of Rej. 136
# alpha = 0.08: FDPhat 0.0727, Number of Rej. 110
# alpha = 0.07: FDPhat 0.0636, Number of Rej. 110
# alpha = 0.06: FDPhat 0.0577, Number of Rej. 104
# alpha = 0.05: FDPhat 0.05, Number of Rej. 100
# alpha = 0.04: FDPhat 0.0385, Number of Rej. 78
# alpha = 0.03: FDPhat 0.0208, Number of Rej. 48
# [1] "data_1"
# alpha = 0.91: FDPhat 0.9099, Number of Rej. 1121
# alpha = 0.9: FDPhat 0.8994, Number of Rej. 1083
# alpha = 0.89: FDPhat 0.8896, Number of Rej. 996
# alpha = 0.88: FDPhat 0.8791, Number of Rej. 984
# alpha = 0.87: FDPhat 0.8694, Number of Rej. 911
# alpha = 0.86: FDPhat 0.8597, Number of Rej. 884
# alpha = 0.85: FDPhat 0.8495, Number of Rej. 844
# alpha = 0.84: FDPhat 0.839, Number of Rej. 708
# alpha = 0.83: FDPhat 0.8298, Number of Rej. 705
# alpha = 0.82: FDPhat 0.8194, Number of Rej. 681
# alpha = 0.81: FDPhat 0.8091, Number of Rej. 660
# alpha = 0.8: FDPhat 0.7988, Number of Rej. 641
# alpha = 0.79: FDPhat 0.7886, Number of Rej. 629
# alpha = 0.78: FDPhat 0.7788, Number of Rej. 624
# alpha = 0.77: FDPhat 0.7684, Number of Rej. 583
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 579
# alpha = 0.75: FDPhat 0.7495, Number of Rej. 555
# alpha = 0.74: FDPhat 0.7383, Number of Rej. 535
# alpha = 0.73: FDPhat 0.7287, Number of Rej. 527
# alpha = 0.72: FDPhat 0.719, Number of Rej. 484
# alpha = 0.71: FDPhat 0.7098, Number of Rej. 479
# alpha = 0.7: FDPhat 0.7, Number of Rej. 470
# alpha = 0.69: FDPhat 0.6881, Number of Rej. 452
# alpha = 0.68: FDPhat 0.68, Number of Rej. 450
# alpha = 0.67: FDPhat 0.6689, Number of Rej. 447
# alpha = 0.66: FDPhat 0.659, Number of Rej. 434
# alpha = 0.65: FDPhat 0.6486, Number of Rej. 424
# alpha = 0.64: FDPhat 0.6396, Number of Rej. 419
# alpha = 0.63: FDPhat 0.6292, Number of Rej. 418
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 413
# alpha = 0.61: FDPhat 0.6092, Number of Rej. 412
# alpha = 0.6: FDPhat 0.598, Number of Rej. 398
# alpha = 0.59: FDPhat 0.5876, Number of Rej. 388
# alpha = 0.58: FDPhat 0.5788, Number of Rej. 387
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 372
# alpha = 0.56: FDPhat 0.5583, Number of Rej. 369
# alpha = 0.55: FDPhat 0.5489, Number of Rej. 368
# alpha = 0.54: FDPhat 0.5376, Number of Rej. 346
# alpha = 0.53: FDPhat 0.5291, Number of Rej. 344
# alpha = 0.52: FDPhat 0.5175, Number of Rej. 342
# alpha = 0.51: FDPhat 0.5089, Number of Rej. 336
# alpha = 0.5: FDPhat 0.4985, Number of Rej. 335
# alpha = 0.49: FDPhat 0.4879, Number of Rej. 330
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 323
# alpha = 0.47: FDPhat 0.4671, Number of Rej. 319
# alpha = 0.46: FDPhat 0.4577, Number of Rej. 284
# alpha = 0.45: FDPhat 0.4472, Number of Rej. 284
# alpha = 0.44: FDPhat 0.4388, Number of Rej. 278
# alpha = 0.43: FDPhat 0.4281, Number of Rej. 278
# alpha = 0.42: FDPhat 0.4167, Number of Rej. 276
# alpha = 0.41: FDPhat 0.4088, Number of Rej. 274
# alpha = 0.4: FDPhat 0.397, Number of Rej. 267
# alpha = 0.39: FDPhat 0.3878, Number of Rej. 263
# alpha = 0.38: FDPhat 0.3798, Number of Rej. 258
# alpha = 0.37: FDPhat 0.3696, Number of Rej. 257
# alpha = 0.36: FDPhat 0.3594, Number of Rej. 256
# alpha = 0.35: FDPhat 0.3477, Number of Rej. 256
# alpha = 0.34: FDPhat 0.3373, Number of Rej. 255
# alpha = 0.33: FDPhat 0.3293, Number of Rej. 246
# alpha = 0.32: FDPhat 0.3172, Number of Rej. 227
# alpha = 0.31: FDPhat 0.3067, Number of Rej. 225
# alpha = 0.3: FDPhat 0.3, Number of Rej. 220
# alpha = 0.29: FDPhat 0.2864, Number of Rej. 220
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 218
# alpha = 0.27: FDPhat 0.2676, Number of Rej. 213
# alpha = 0.26: FDPhat 0.2594, Number of Rej. 212
# alpha = 0.25: FDPhat 0.25, Number of Rej. 212
# alpha = 0.24: FDPhat 0.2392, Number of Rej. 209
# alpha = 0.23: FDPhat 0.2266, Number of Rej. 203
# alpha = 0.22: FDPhat 0.2161, Number of Rej. 199
# alpha = 0.21: FDPhat 0.2071, Number of Rej. 198
# alpha = 0.2: FDPhat 0.197, Number of Rej. 198
# alpha = 0.19: FDPhat 0.1865, Number of Rej. 193
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 189
# alpha = 0.17: FDPhat 0.1667, Number of Rej. 186
# alpha = 0.16: FDPhat 0.1585, Number of Rej. 183
# alpha = 0.15: FDPhat 0.1477, Number of Rej. 176
# alpha = 0.14: FDPhat 0.1387, Number of Rej. 173
# alpha = 0.13: FDPhat 0.1272, Number of Rej. 173
# alpha = 0.12: FDPhat 0.1176, Number of Rej. 170
# alpha = 0.11: FDPhat 0.1071, Number of Rej. 168
# alpha = 0.1: FDPhat 0.097, Number of Rej. 165
# alpha = 0.09: FDPhat 0.0859, Number of Rej. 163
# alpha = 0.08: FDPhat 0.0784, Number of Rej. 153
# alpha = 0.07: FDPhat 0.0667, Number of Rej. 150
# alpha = 0.06: FDPhat 0.0559, Number of Rej. 143
# alpha = 0.05: FDPhat 0.0455, Number of Rej. 132
# alpha = 0.04: FDPhat 0.0379, Number of Rej. 132
# alpha = 0.03: FDPhat 0.0261, Number of Rej. 115
# alpha = 0.02: FDPhat 0.0114, Number of Rej. 88
# [1] "data_2"
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 1242
# alpha = 0.78: FDPhat 0.7792, Number of Rej. 1223
# alpha = 0.77: FDPhat 0.7698, Number of Rej. 1134
# alpha = 0.76: FDPhat 0.7593, Number of Rej. 1072
# alpha = 0.75: FDPhat 0.7492, Number of Rej. 929
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 919
# alpha = 0.73: FDPhat 0.73, Number of Rej. 874
# alpha = 0.72: FDPhat 0.7198, Number of Rej. 746
# alpha = 0.71: FDPhat 0.7098, Number of Rej. 734
# alpha = 0.7: FDPhat 0.6994, Number of Rej. 712
# alpha = 0.69: FDPhat 0.69, Number of Rej. 687
# alpha = 0.68: FDPhat 0.6798, Number of Rej. 662
# alpha = 0.67: FDPhat 0.6694, Number of Rej. 602
# alpha = 0.66: FDPhat 0.6589, Number of Rej. 598
# alpha = 0.65: FDPhat 0.6496, Number of Rej. 568
# alpha = 0.64: FDPhat 0.6398, Number of Rej. 558
# alpha = 0.63: FDPhat 0.63, Number of Rej. 554
# alpha = 0.62: FDPhat 0.6189, Number of Rej. 551
# alpha = 0.61: FDPhat 0.6097, Number of Rej. 538
# alpha = 0.6: FDPhat 0.6, Number of Rej. 535
# alpha = 0.59: FDPhat 0.5895, Number of Rej. 514
# alpha = 0.58: FDPhat 0.5786, Number of Rej. 496
# alpha = 0.57: FDPhat 0.5697, Number of Rej. 488
# alpha = 0.56: FDPhat 0.5584, Number of Rej. 471
# alpha = 0.55: FDPhat 0.5482, Number of Rej. 467
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 402
# alpha = 0.53: FDPhat 0.5291, Number of Rej. 378
# alpha = 0.52: FDPhat 0.52, Number of Rej. 375
# alpha = 0.51: FDPhat 0.5089, Number of Rej. 338
# alpha = 0.5: FDPhat 0.5, Number of Rej. 336
# alpha = 0.49: FDPhat 0.4896, Number of Rej. 335
# alpha = 0.48: FDPhat 0.4792, Number of Rej. 313
# alpha = 0.47: FDPhat 0.4684, Number of Rej. 301
# alpha = 0.46: FDPhat 0.46, Number of Rej. 300
# alpha = 0.45: FDPhat 0.4478, Number of Rej. 297
# alpha = 0.44: FDPhat 0.4392, Number of Rej. 296
# alpha = 0.43: FDPhat 0.4266, Number of Rej. 293
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 293
# alpha = 0.41: FDPhat 0.4091, Number of Rej. 286
# alpha = 0.4: FDPhat 0.4, Number of Rej. 280
# alpha = 0.39: FDPhat 0.3891, Number of Rej. 275
# alpha = 0.38: FDPhat 0.3769, Number of Rej. 268
# alpha = 0.37: FDPhat 0.3694, Number of Rej. 268
# alpha = 0.36: FDPhat 0.3571, Number of Rej. 266
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 263
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 256
# alpha = 0.33: FDPhat 0.3281, Number of Rej. 256
# alpha = 0.32: FDPhat 0.32, Number of Rej. 250
# alpha = 0.31: FDPhat 0.3077, Number of Rej. 247
# alpha = 0.3: FDPhat 0.2967, Number of Rej. 246
# alpha = 0.29: FDPhat 0.2886, Number of Rej. 246
# alpha = 0.28: FDPhat 0.2787, Number of Rej. 244
# alpha = 0.27: FDPhat 0.2692, Number of Rej. 234
# alpha = 0.26: FDPhat 0.2575, Number of Rej. 233
# alpha = 0.25: FDPhat 0.2478, Number of Rej. 230
# alpha = 0.24: FDPhat 0.24, Number of Rej. 225
# alpha = 0.23: FDPhat 0.2269, Number of Rej. 216
# alpha = 0.22: FDPhat 0.2176, Number of Rej. 216
# alpha = 0.21: FDPhat 0.2067, Number of Rej. 208
# alpha = 0.2: FDPhat 0.199, Number of Rej. 206
# alpha = 0.19: FDPhat 0.19, Number of Rej. 200
# alpha = 0.18: FDPhat 0.1777, Number of Rej. 197
# alpha = 0.17: FDPhat 0.1684, Number of Rej. 196
# alpha = 0.16: FDPhat 0.1582, Number of Rej. 196
# alpha = 0.15: FDPhat 0.1474, Number of Rej. 190
# alpha = 0.14: FDPhat 0.1366, Number of Rej. 183
# alpha = 0.13: FDPhat 0.1272, Number of Rej. 173
# alpha = 0.12: FDPhat 0.1163, Number of Rej. 172
# alpha = 0.11: FDPhat 0.1059, Number of Rej. 170
# alpha = 0.1: FDPhat 0.0958, Number of Rej. 167
# alpha = 0.09: FDPhat 0.0864, Number of Rej. 162
# alpha = 0.08: FDPhat 0.075, Number of Rej. 160
# alpha = 0.07: FDPhat 0.0641, Number of Rej. 156
# alpha = 0.06: FDPhat 0.0581, Number of Rej. 155
# alpha = 0.05: FDPhat 0.0467, Number of Rej. 150
# alpha = 0.04: FDPhat 0.0336, Number of Rej. 149
# alpha = 0.03: FDPhat 0.0276, Number of Rej. 145
# alpha = 0.02: FDPhat 0.016, Number of Rej. 125
# [1] "data_3"
# alpha = 0.86: FDPhat 0.8599, Number of Rej. 1192
# alpha = 0.85: FDPhat 0.85, Number of Rej. 1133
# alpha = 0.84: FDPhat 0.8398, Number of Rej. 1086
# alpha = 0.83: FDPhat 0.8294, Number of Rej. 1067
# alpha = 0.82: FDPhat 0.8191, Number of Rej. 984
# alpha = 0.81: FDPhat 0.8098, Number of Rej. 894
# alpha = 0.8: FDPhat 0.7991, Number of Rej. 891
# alpha = 0.79: FDPhat 0.7897, Number of Rej. 889
# alpha = 0.78: FDPhat 0.7791, Number of Rej. 869
# alpha = 0.77: FDPhat 0.769, Number of Rej. 827
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 812
# alpha = 0.75: FDPhat 0.75, Number of Rej. 800
# alpha = 0.74: FDPhat 0.7394, Number of Rej. 779
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 770
# alpha = 0.72: FDPhat 0.7196, Number of Rej. 749
# alpha = 0.71: FDPhat 0.7097, Number of Rej. 720
# alpha = 0.7: FDPhat 0.7, Number of Rej. 660
# alpha = 0.69: FDPhat 0.6888, Number of Rej. 588
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 578
# alpha = 0.67: FDPhat 0.6697, Number of Rej. 542
# alpha = 0.66: FDPhat 0.6589, Number of Rej. 516
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 497
# alpha = 0.64: FDPhat 0.6396, Number of Rej. 480
# alpha = 0.63: FDPhat 0.6287, Number of Rej. 474
# alpha = 0.62: FDPhat 0.6197, Number of Rej. 468
# alpha = 0.61: FDPhat 0.6086, Number of Rej. 442
# alpha = 0.6: FDPhat 0.6, Number of Rej. 440
# alpha = 0.59: FDPhat 0.5888, Number of Rej. 428
# alpha = 0.58: FDPhat 0.5795, Number of Rej. 390
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 365
# alpha = 0.56: FDPhat 0.5572, Number of Rej. 341
# alpha = 0.55: FDPhat 0.549, Number of Rej. 337
# alpha = 0.54: FDPhat 0.5392, Number of Rej. 319
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 319
# alpha = 0.52: FDPhat 0.5177, Number of Rej. 311
# alpha = 0.51: FDPhat 0.5083, Number of Rej. 303
# alpha = 0.5: FDPhat 0.5, Number of Rej. 302
# alpha = 0.49: FDPhat 0.4883, Number of Rej. 299
# alpha = 0.48: FDPhat 0.4775, Number of Rej. 289
# alpha = 0.47: FDPhat 0.4669, Number of Rej. 287
# alpha = 0.46: FDPhat 0.458, Number of Rej. 286
# alpha = 0.45: FDPhat 0.448, Number of Rej. 279
# alpha = 0.44: FDPhat 0.4388, Number of Rej. 278
# alpha = 0.43: FDPhat 0.4275, Number of Rej. 276
# alpha = 0.42: FDPhat 0.4197, Number of Rej. 274
# alpha = 0.41: FDPhat 0.4096, Number of Rej. 271
# alpha = 0.4: FDPhat 0.3985, Number of Rej. 271
# alpha = 0.39: FDPhat 0.3866, Number of Rej. 269
# alpha = 0.38: FDPhat 0.3792, Number of Rej. 269
# alpha = 0.37: FDPhat 0.3688, Number of Rej. 263
# alpha = 0.36: FDPhat 0.3594, Number of Rej. 256
# alpha = 0.35: FDPhat 0.3492, Number of Rej. 252
# alpha = 0.34: FDPhat 0.3373, Number of Rej. 252
# alpha = 0.33: FDPhat 0.3294, Number of Rej. 252
# alpha = 0.32: FDPhat 0.3171, Number of Rej. 246
# alpha = 0.31: FDPhat 0.308, Number of Rej. 237
# alpha = 0.3: FDPhat 0.2982, Number of Rej. 228
# alpha = 0.29: FDPhat 0.2889, Number of Rej. 225
# alpha = 0.28: FDPhat 0.28, Number of Rej. 225
# alpha = 0.27: FDPhat 0.2661, Number of Rej. 218
# alpha = 0.26: FDPhat 0.2593, Number of Rej. 216
# alpha = 0.25: FDPhat 0.2488, Number of Rej. 213
# alpha = 0.24: FDPhat 0.239, Number of Rej. 205
# alpha = 0.23: FDPhat 0.23, Number of Rej. 200
# alpha = 0.22: FDPhat 0.2172, Number of Rej. 198
# alpha = 0.21: FDPhat 0.2092, Number of Rej. 196
# alpha = 0.2: FDPhat 0.2, Number of Rej. 185
# alpha = 0.19: FDPhat 0.1878, Number of Rej. 181
# alpha = 0.18: FDPhat 0.1768, Number of Rej. 181
# alpha = 0.17: FDPhat 0.1676, Number of Rej. 179
# alpha = 0.16: FDPhat 0.1582, Number of Rej. 177
# alpha = 0.15: FDPhat 0.1494, Number of Rej. 174
# alpha = 0.14: FDPhat 0.1361, Number of Rej. 169
# alpha = 0.13: FDPhat 0.125, Number of Rej. 168
# alpha = 0.12: FDPhat 0.119, Number of Rej. 168
# alpha = 0.11: FDPhat 0.1084, Number of Rej. 166
# alpha = 0.1: FDPhat 0.0982, Number of Rej. 163
# alpha = 0.09: FDPhat 0.0859, Number of Rej. 163
# alpha = 0.08: FDPhat 0.075, Number of Rej. 160
# alpha = 0.07: FDPhat 0.0649, Number of Rej. 154
# alpha = 0.06: FDPhat 0.0584, Number of Rej. 154
# alpha = 0.05: FDPhat 0.0464, Number of Rej. 151
# alpha = 0.04: FDPhat 0.0362, Number of Rej. 138
# alpha = 0.03: FDPhat 0.0238, Number of Rej. 126
# alpha = 0.02: FDPhat 0.0167, Number of Rej. 120
# [1] "data_4"
# alpha = 0.87: FDPhat 0.8693, Number of Rej. 1201
# alpha = 0.86: FDPhat 0.8598, Number of Rej. 1163
# alpha = 0.85: FDPhat 0.8492, Number of Rej. 988
# alpha = 0.84: FDPhat 0.8396, Number of Rej. 979
# alpha = 0.83: FDPhat 0.8295, Number of Rej. 921
# alpha = 0.82: FDPhat 0.8199, Number of Rej. 794
# alpha = 0.81: FDPhat 0.8093, Number of Rej. 792
# alpha = 0.8: FDPhat 0.7995, Number of Rej. 788
# alpha = 0.79: FDPhat 0.7898, Number of Rej. 747
# alpha = 0.78: FDPhat 0.7787, Number of Rej. 741
# alpha = 0.77: FDPhat 0.7688, Number of Rej. 731
# alpha = 0.76: FDPhat 0.7597, Number of Rej. 720
# alpha = 0.75: FDPhat 0.7489, Number of Rej. 681
# alpha = 0.74: FDPhat 0.7392, Number of Rej. 671
# alpha = 0.73: FDPhat 0.7297, Number of Rej. 666
# alpha = 0.72: FDPhat 0.7193, Number of Rej. 659
# alpha = 0.71: FDPhat 0.7098, Number of Rej. 641
# alpha = 0.7: FDPhat 0.6987, Number of Rej. 541
# alpha = 0.69: FDPhat 0.689, Number of Rej. 537
# alpha = 0.68: FDPhat 0.6788, Number of Rej. 520
# alpha = 0.67: FDPhat 0.6693, Number of Rej. 511
# alpha = 0.66: FDPhat 0.6588, Number of Rej. 507
# alpha = 0.65: FDPhat 0.6494, Number of Rej. 502
# alpha = 0.64: FDPhat 0.6396, Number of Rej. 480
# alpha = 0.63: FDPhat 0.628, Number of Rej. 457
# alpha = 0.62: FDPhat 0.6195, Number of Rej. 452
# alpha = 0.61: FDPhat 0.6094, Number of Rej. 448
# alpha = 0.6: FDPhat 0.5995, Number of Rej. 422
# alpha = 0.59: FDPhat 0.5888, Number of Rej. 411
# alpha = 0.58: FDPhat 0.5796, Number of Rej. 402
# alpha = 0.57: FDPhat 0.5685, Number of Rej. 394
# alpha = 0.56: FDPhat 0.5575, Number of Rej. 391
# alpha = 0.55: FDPhat 0.5483, Number of Rej. 383
# alpha = 0.54: FDPhat 0.5385, Number of Rej. 364
# alpha = 0.53: FDPhat 0.5281, Number of Rej. 356
# alpha = 0.52: FDPhat 0.52, Number of Rej. 350
# alpha = 0.51: FDPhat 0.5078, Number of Rej. 321
# alpha = 0.5: FDPhat 0.5, Number of Rej. 316
# alpha = 0.49: FDPhat 0.4873, Number of Rej. 316
# alpha = 0.48: FDPhat 0.479, Number of Rej. 309
# alpha = 0.47: FDPhat 0.4694, Number of Rej. 294
# alpha = 0.46: FDPhat 0.4596, Number of Rej. 285
# alpha = 0.45: FDPhat 0.4491, Number of Rej. 285
# alpha = 0.44: FDPhat 0.4386, Number of Rej. 285
# alpha = 0.43: FDPhat 0.4286, Number of Rej. 280
# alpha = 0.42: FDPhat 0.4182, Number of Rej. 275
# alpha = 0.41: FDPhat 0.4067, Number of Rej. 268
# alpha = 0.4: FDPhat 0.3992, Number of Rej. 263
# alpha = 0.39: FDPhat 0.3878, Number of Rej. 263
# alpha = 0.38: FDPhat 0.3765, Number of Rej. 255
# alpha = 0.37: FDPhat 0.3676, Number of Rej. 253
# alpha = 0.36: FDPhat 0.3571, Number of Rej. 252
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 243
# alpha = 0.34: FDPhat 0.3374, Number of Rej. 243
# alpha = 0.33: FDPhat 0.3278, Number of Rej. 241
# alpha = 0.32: FDPhat 0.319, Number of Rej. 232
# alpha = 0.31: FDPhat 0.3057, Number of Rej. 229
# alpha = 0.3: FDPhat 0.2978, Number of Rej. 225
# alpha = 0.29: FDPhat 0.2877, Number of Rej. 219
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 218
# alpha = 0.27: FDPhat 0.2685, Number of Rej. 216
# alpha = 0.26: FDPhat 0.257, Number of Rej. 214
# alpha = 0.25: FDPhat 0.25, Number of Rej. 212
# alpha = 0.24: FDPhat 0.2392, Number of Rej. 209
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 209
# alpha = 0.22: FDPhat 0.2194, Number of Rej. 196
# alpha = 0.21: FDPhat 0.2074, Number of Rej. 188
# alpha = 0.2: FDPhat 0.2, Number of Rej. 185
# alpha = 0.19: FDPhat 0.1868, Number of Rej. 182
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 178
# alpha = 0.17: FDPhat 0.1685, Number of Rej. 178
# alpha = 0.16: FDPhat 0.1561, Number of Rej. 173
# alpha = 0.15: FDPhat 0.1445, Number of Rej. 173
# alpha = 0.14: FDPhat 0.1395, Number of Rej. 172
# alpha = 0.13: FDPhat 0.1279, Number of Rej. 172
# alpha = 0.12: FDPhat 0.1166, Number of Rej. 163
# alpha = 0.11: FDPhat 0.1043, Number of Rej. 163
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 161
# alpha = 0.09: FDPhat 0.0892, Number of Rej. 157
# alpha = 0.08: FDPhat 0.0779, Number of Rej. 154
# alpha = 0.07: FDPhat 0.0658, Number of Rej. 152
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 151
# alpha = 0.05: FDPhat 0.0451, Number of Rej. 133
# alpha = 0.04: FDPhat 0.0379, Number of Rej. 132
# alpha = 0.03: FDPhat 0.0234, Number of Rej. 128
# alpha = 0.02: FDPhat 0.0168, Number of Rej. 119
# alpha = 0.01: FDPhat 0.0097, Number of Rej. 103
# Task completed!
# [1] "data_5"
# alpha = 0.79: FDPhat 0.79, Number of Rej. 1257
# alpha = 0.78: FDPhat 0.7796, Number of Rej. 1234
# alpha = 0.77: FDPhat 0.7694, Number of Rej. 1210
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 1108
# alpha = 0.75: FDPhat 0.75, Number of Rej. 980
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 819
# alpha = 0.73: FDPhat 0.7291, Number of Rej. 801
# alpha = 0.72: FDPhat 0.7196, Number of Rej. 781
# alpha = 0.71: FDPhat 0.7097, Number of Rej. 775
# alpha = 0.7: FDPhat 0.6993, Number of Rej. 745
# alpha = 0.69: FDPhat 0.69, Number of Rej. 729
# alpha = 0.68: FDPhat 0.68, Number of Rej. 725
# alpha = 0.67: FDPhat 0.6697, Number of Rej. 669
# alpha = 0.66: FDPhat 0.6596, Number of Rej. 658
# alpha = 0.65: FDPhat 0.6495, Number of Rej. 639
# alpha = 0.64: FDPhat 0.6395, Number of Rej. 613
# alpha = 0.63: FDPhat 0.63, Number of Rej. 600
# alpha = 0.62: FDPhat 0.6194, Number of Rej. 599
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 564
# alpha = 0.6: FDPhat 0.6, Number of Rej. 560
# alpha = 0.59: FDPhat 0.5897, Number of Rej. 546
# alpha = 0.58: FDPhat 0.5797, Number of Rej. 533
# alpha = 0.57: FDPhat 0.5684, Number of Rej. 512
# alpha = 0.56: FDPhat 0.5597, Number of Rej. 511
# alpha = 0.55: FDPhat 0.5495, Number of Rej. 495
# alpha = 0.54: FDPhat 0.5393, Number of Rej. 484
# alpha = 0.53: FDPhat 0.5281, Number of Rej. 462
# alpha = 0.52: FDPhat 0.5187, Number of Rej. 455
# alpha = 0.51: FDPhat 0.5078, Number of Rej. 449
# alpha = 0.5: FDPhat 0.4988, Number of Rej. 431
# alpha = 0.49: FDPhat 0.4895, Number of Rej. 429
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 423
# alpha = 0.47: FDPhat 0.4681, Number of Rej. 408
# alpha = 0.46: FDPhat 0.4594, Number of Rej. 394
# alpha = 0.45: FDPhat 0.4491, Number of Rej. 383
# alpha = 0.44: FDPhat 0.4371, Number of Rej. 334
# alpha = 0.43: FDPhat 0.4277, Number of Rej. 332
# alpha = 0.42: FDPhat 0.4195, Number of Rej. 329
# alpha = 0.41: FDPhat 0.4087, Number of Rej. 323
# alpha = 0.4: FDPhat 0.3994, Number of Rej. 323
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 318
# alpha = 0.38: FDPhat 0.3785, Number of Rej. 317
# alpha = 0.37: FDPhat 0.3672, Number of Rej. 305
# alpha = 0.36: FDPhat 0.3586, Number of Rej. 304
# alpha = 0.35: FDPhat 0.3488, Number of Rej. 301
# alpha = 0.34: FDPhat 0.3379, Number of Rej. 293
# alpha = 0.33: FDPhat 0.3276, Number of Rej. 290
# alpha = 0.32: FDPhat 0.3169, Number of Rej. 284
# alpha = 0.31: FDPhat 0.3091, Number of Rej. 275
# alpha = 0.3: FDPhat 0.2989, Number of Rej. 261
# alpha = 0.29: FDPhat 0.2879, Number of Rej. 257
# alpha = 0.28: FDPhat 0.2773, Number of Rej. 256
# alpha = 0.27: FDPhat 0.2688, Number of Rej. 253
# alpha = 0.26: FDPhat 0.2574, Number of Rej. 237
# alpha = 0.25: FDPhat 0.2489, Number of Rej. 237
# alpha = 0.24: FDPhat 0.2373, Number of Rej. 236
# alpha = 0.23: FDPhat 0.2287, Number of Rej. 223
# alpha = 0.22: FDPhat 0.2172, Number of Rej. 221
# alpha = 0.21: FDPhat 0.2095, Number of Rej. 210
# alpha = 0.2: FDPhat 0.2, Number of Rej. 210
# alpha = 0.19: FDPhat 0.1875, Number of Rej. 208
# alpha = 0.18: FDPhat 0.1759, Number of Rej. 199
# alpha = 0.17: FDPhat 0.1667, Number of Rej. 192
# alpha = 0.16: FDPhat 0.1593, Number of Rej. 182
# alpha = 0.15: FDPhat 0.1492, Number of Rej. 181
# alpha = 0.14: FDPhat 0.1389, Number of Rej. 180
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 177
# alpha = 0.12: FDPhat 0.1173, Number of Rej. 162
# alpha = 0.11: FDPhat 0.1074, Number of Rej. 149
# alpha = 0.1: FDPhat 0.0979, Number of Rej. 143
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 123
# alpha = 0.08: FDPhat 0.0769, Number of Rej. 117
# alpha = 0.07: FDPhat 0.0696, Number of Rej. 115
# alpha = 0.06: FDPhat 0.0541, Number of Rej. 111
# alpha = 0.05: FDPhat 0.0463, Number of Rej. 108
# alpha = 0.04: FDPhat 0.0385, Number of Rej. 104
# alpha = 0.03: FDPhat 0.0267, Number of Rej. 75
# alpha = 0.02: FDPhat 0.0143, Number of Rej. 70
# [1] "data_6"
# alpha = 0.9: FDPhat 0.8998, Number of Rej. 1188
# alpha = 0.89: FDPhat 0.8893, Number of Rej. 1156
# alpha = 0.88: FDPhat 0.8792, Number of Rej. 1151
# alpha = 0.87: FDPhat 0.8698, Number of Rej. 1114
# alpha = 0.86: FDPhat 0.8599, Number of Rej. 1099
# alpha = 0.85: FDPhat 0.8499, Number of Rej. 933
# alpha = 0.84: FDPhat 0.8389, Number of Rej. 863
# alpha = 0.83: FDPhat 0.8289, Number of Rej. 859
# alpha = 0.82: FDPhat 0.8194, Number of Rej. 847
# alpha = 0.81: FDPhat 0.8095, Number of Rej. 840
# alpha = 0.8: FDPhat 0.7993, Number of Rej. 822
# alpha = 0.79: FDPhat 0.7892, Number of Rej. 688
# alpha = 0.78: FDPhat 0.7797, Number of Rej. 681
# alpha = 0.77: FDPhat 0.7696, Number of Rej. 677
# alpha = 0.76: FDPhat 0.7596, Number of Rej. 653
# alpha = 0.75: FDPhat 0.7496, Number of Rej. 603
# alpha = 0.74: FDPhat 0.7398, Number of Rej. 538
# alpha = 0.73: FDPhat 0.7298, Number of Rej. 507
# alpha = 0.72: FDPhat 0.7188, Number of Rej. 505
# alpha = 0.71: FDPhat 0.7089, Number of Rej. 481
# alpha = 0.7: FDPhat 0.6998, Number of Rej. 453
# alpha = 0.69: FDPhat 0.6885, Number of Rej. 443
# alpha = 0.68: FDPhat 0.678, Number of Rej. 441
# alpha = 0.67: FDPhat 0.669, Number of Rej. 426
# alpha = 0.66: FDPhat 0.6588, Number of Rej. 425
# alpha = 0.65: FDPhat 0.6488, Number of Rej. 410
# alpha = 0.64: FDPhat 0.639, Number of Rej. 410
# alpha = 0.63: FDPhat 0.6297, Number of Rej. 397
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 384
# alpha = 0.61: FDPhat 0.6092, Number of Rej. 371
# alpha = 0.6: FDPhat 0.6, Number of Rej. 365
# alpha = 0.59: FDPhat 0.5895, Number of Rej. 363
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 357
# alpha = 0.57: FDPhat 0.5686, Number of Rej. 357
# alpha = 0.56: FDPhat 0.5581, Number of Rej. 353
# alpha = 0.55: FDPhat 0.5489, Number of Rej. 348
# alpha = 0.54: FDPhat 0.5391, Number of Rej. 345
# alpha = 0.53: FDPhat 0.5284, Number of Rej. 335
# alpha = 0.52: FDPhat 0.5181, Number of Rej. 332
# alpha = 0.51: FDPhat 0.5094, Number of Rej. 320
# alpha = 0.5: FDPhat 0.5, Number of Rej. 310
# alpha = 0.49: FDPhat 0.4887, Number of Rej. 309
# alpha = 0.48: FDPhat 0.479, Number of Rej. 309
# alpha = 0.47: FDPhat 0.4673, Number of Rej. 306
# alpha = 0.46: FDPhat 0.46, Number of Rej. 300
# alpha = 0.45: FDPhat 0.45, Number of Rej. 300
# alpha = 0.44: FDPhat 0.4377, Number of Rej. 297
# alpha = 0.43: FDPhat 0.427, Number of Rej. 274
# alpha = 0.42: FDPhat 0.4164, Number of Rej. 269
# alpha = 0.41: FDPhat 0.4082, Number of Rej. 267
# alpha = 0.4: FDPhat 0.4, Number of Rej. 260
# alpha = 0.39: FDPhat 0.3885, Number of Rej. 260
# alpha = 0.38: FDPhat 0.3794, Number of Rej. 253
# alpha = 0.37: FDPhat 0.3665, Number of Rej. 251
# alpha = 0.36: FDPhat 0.3586, Number of Rej. 251
# alpha = 0.35: FDPhat 0.3494, Number of Rej. 249
# alpha = 0.34: FDPhat 0.3361, Number of Rej. 244
# alpha = 0.33: FDPhat 0.3278, Number of Rej. 241
# alpha = 0.32: FDPhat 0.318, Number of Rej. 239
# alpha = 0.31: FDPhat 0.3077, Number of Rej. 234
# alpha = 0.3: FDPhat 0.3, Number of Rej. 230
# alpha = 0.29: FDPhat 0.2877, Number of Rej. 219
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 218
# alpha = 0.27: FDPhat 0.2661, Number of Rej. 218
# alpha = 0.26: FDPhat 0.2581, Number of Rej. 217
# alpha = 0.25: FDPhat 0.25, Number of Rej. 216
# alpha = 0.24: FDPhat 0.2361, Number of Rej. 216
# alpha = 0.23: FDPhat 0.2286, Number of Rej. 210
# alpha = 0.22: FDPhat 0.2174, Number of Rej. 207
# alpha = 0.21: FDPhat 0.2077, Number of Rej. 207
# alpha = 0.2: FDPhat 0.197, Number of Rej. 203
# alpha = 0.19: FDPhat 0.1865, Number of Rej. 193
# alpha = 0.18: FDPhat 0.178, Number of Rej. 191
# alpha = 0.17: FDPhat 0.1693, Number of Rej. 189
# alpha = 0.16: FDPhat 0.1582, Number of Rej. 177
# alpha = 0.15: FDPhat 0.1471, Number of Rej. 170
# alpha = 0.14: FDPhat 0.1353, Number of Rej. 170
# alpha = 0.13: FDPhat 0.1288, Number of Rej. 163
# alpha = 0.12: FDPhat 0.1154, Number of Rej. 156
# alpha = 0.11: FDPhat 0.109, Number of Rej. 156
# alpha = 0.1: FDPhat 0.0974, Number of Rej. 154
# alpha = 0.09: FDPhat 0.085, Number of Rej. 153
# alpha = 0.08: FDPhat 0.08, Number of Rej. 150
# alpha = 0.07: FDPhat 0.069, Number of Rej. 145
# alpha = 0.06: FDPhat 0.0571, Number of Rej. 140
# alpha = 0.05: FDPhat 0.0441, Number of Rej. 136
# alpha = 0.04: FDPhat 0.0379, Number of Rej. 132
# alpha = 0.03: FDPhat 0.0229, Number of Rej. 131
# alpha = 0.02: FDPhat 0.0156, Number of Rej. 128
# alpha = 0.01: FDPhat 0.0079, Number of Rej. 127
# Task completed!
# [1] "data_7"
# alpha = 0.86: FDPhat 0.8594, Number of Rej. 1017
# alpha = 0.85: FDPhat 0.8493, Number of Rej. 1002
# alpha = 0.84: FDPhat 0.8396, Number of Rej. 960
# alpha = 0.83: FDPhat 0.8292, Number of Rej. 931
# alpha = 0.82: FDPhat 0.8197, Number of Rej. 832
# alpha = 0.81: FDPhat 0.8099, Number of Rej. 810
# alpha = 0.8: FDPhat 0.7994, Number of Rej. 698
# alpha = 0.79: FDPhat 0.7898, Number of Rej. 666
# alpha = 0.78: FDPhat 0.7797, Number of Rej. 640
# alpha = 0.77: FDPhat 0.77, Number of Rej. 613
# alpha = 0.76: FDPhat 0.759, Number of Rej. 556
# alpha = 0.75: FDPhat 0.7495, Number of Rej. 527
# alpha = 0.74: FDPhat 0.74, Number of Rej. 523
# alpha = 0.73: FDPhat 0.7292, Number of Rej. 517
# alpha = 0.72: FDPhat 0.7197, Number of Rej. 503
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 486
# alpha = 0.7: FDPhat 0.6996, Number of Rej. 486
# alpha = 0.69: FDPhat 0.6885, Number of Rej. 443
# alpha = 0.68: FDPhat 0.6795, Number of Rej. 390
# alpha = 0.67: FDPhat 0.6694, Number of Rej. 360
# alpha = 0.66: FDPhat 0.6583, Number of Rej. 357
# alpha = 0.65: FDPhat 0.6476, Number of Rej. 349
# alpha = 0.64: FDPhat 0.639, Number of Rej. 349
# alpha = 0.63: FDPhat 0.6282, Number of Rej. 347
# alpha = 0.62: FDPhat 0.6192, Number of Rej. 344
# alpha = 0.61: FDPhat 0.61, Number of Rej. 341
# alpha = 0.6: FDPhat 0.6, Number of Rej. 340
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 334
# alpha = 0.58: FDPhat 0.5789, Number of Rej. 323
# alpha = 0.57: FDPhat 0.5683, Number of Rej. 322
# alpha = 0.56: FDPhat 0.5575, Number of Rej. 287
# alpha = 0.55: FDPhat 0.547, Number of Rej. 287
# alpha = 0.54: FDPhat 0.5385, Number of Rej. 286
# alpha = 0.53: FDPhat 0.5284, Number of Rej. 282
# alpha = 0.52: FDPhat 0.5184, Number of Rej. 272
# alpha = 0.51: FDPhat 0.5094, Number of Rej. 267
# alpha = 0.5: FDPhat 0.4981, Number of Rej. 267
# alpha = 0.49: FDPhat 0.4869, Number of Rej. 267
# alpha = 0.48: FDPhat 0.4794, Number of Rej. 267
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 266
# alpha = 0.46: FDPhat 0.4586, Number of Rej. 266
# alpha = 0.45: FDPhat 0.4496, Number of Rej. 258
# alpha = 0.44: FDPhat 0.4365, Number of Rej. 252
# alpha = 0.43: FDPhat 0.428, Number of Rej. 250
# alpha = 0.42: FDPhat 0.4194, Number of Rej. 248
# alpha = 0.41: FDPhat 0.4073, Number of Rej. 248
# alpha = 0.4: FDPhat 0.4, Number of Rej. 240
# alpha = 0.39: FDPhat 0.3891, Number of Rej. 239
# alpha = 0.38: FDPhat 0.3782, Number of Rej. 238
# alpha = 0.37: FDPhat 0.366, Number of Rej. 235
# alpha = 0.36: FDPhat 0.3574, Number of Rej. 235
# alpha = 0.35: FDPhat 0.3491, Number of Rej. 232
# alpha = 0.34: FDPhat 0.3377, Number of Rej. 231
# alpha = 0.33: FDPhat 0.326, Number of Rej. 227
# alpha = 0.32: FDPhat 0.3186, Number of Rej. 226
# alpha = 0.31: FDPhat 0.3091, Number of Rej. 220
# alpha = 0.3: FDPhat 0.3, Number of Rej. 220
# alpha = 0.29: FDPhat 0.289, Number of Rej. 218
# alpha = 0.28: FDPhat 0.2765, Number of Rej. 217
# alpha = 0.27: FDPhat 0.2685, Number of Rej. 216
# alpha = 0.26: FDPhat 0.257, Number of Rej. 214
# alpha = 0.25: FDPhat 0.2477, Number of Rej. 214
# alpha = 0.24: FDPhat 0.2394, Number of Rej. 213
# alpha = 0.23: FDPhat 0.2282, Number of Rej. 206
# alpha = 0.22: FDPhat 0.2184, Number of Rej. 206
# alpha = 0.21: FDPhat 0.2087, Number of Rej. 206
# alpha = 0.2: FDPhat 0.2, Number of Rej. 205
# alpha = 0.19: FDPhat 0.1863, Number of Rej. 204
# alpha = 0.18: FDPhat 0.1765, Number of Rej. 204
# alpha = 0.17: FDPhat 0.1675, Number of Rej. 203
# alpha = 0.16: FDPhat 0.1576, Number of Rej. 203
# alpha = 0.15: FDPhat 0.1478, Number of Rej. 203
# alpha = 0.14: FDPhat 0.1386, Number of Rej. 202
# alpha = 0.13: FDPhat 0.1287, Number of Rej. 202
# alpha = 0.12: FDPhat 0.1173, Number of Rej. 196
# alpha = 0.11: FDPhat 0.1075, Number of Rej. 186
# alpha = 0.1: FDPhat 0.0978, Number of Rej. 184
# alpha = 0.09: FDPhat 0.0879, Number of Rej. 182
# alpha = 0.08: FDPhat 0.0782, Number of Rej. 179
# alpha = 0.07: FDPhat 0.0682, Number of Rej. 176
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 168
# alpha = 0.05: FDPhat 0.0491, Number of Rej. 163
# alpha = 0.04: FDPhat 0.0385, Number of Rej. 156
# alpha = 0.03: FDPhat 0.0263, Number of Rej. 152
# alpha = 0.02: FDPhat 0.0152, Number of Rej. 132
# alpha = 0.01: FDPhat 0.0088, Number of Rej. 113
# Task completed!
# [1] "data_8"
# alpha = 0.84: FDPhat 0.8398, Number of Rej. 1230
# alpha = 0.83: FDPhat 0.83, Number of Rej. 1200
# alpha = 0.82: FDPhat 0.8197, Number of Rej. 1087
# alpha = 0.81: FDPhat 0.8092, Number of Rej. 1022
# alpha = 0.8: FDPhat 0.7996, Number of Rej. 958
# alpha = 0.79: FDPhat 0.7894, Number of Rej. 831
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 786
# alpha = 0.77: FDPhat 0.7696, Number of Rej. 777
# alpha = 0.76: FDPhat 0.7588, Number of Rej. 738
# alpha = 0.75: FDPhat 0.7496, Number of Rej. 707
# alpha = 0.74: FDPhat 0.7393, Number of Rej. 679
# alpha = 0.73: FDPhat 0.7285, Number of Rej. 652
# alpha = 0.72: FDPhat 0.7197, Number of Rej. 635
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 624
# alpha = 0.7: FDPhat 0.6992, Number of Rej. 605
# alpha = 0.69: FDPhat 0.6887, Number of Rej. 604
# alpha = 0.68: FDPhat 0.6791, Number of Rej. 561
# alpha = 0.67: FDPhat 0.6698, Number of Rej. 536
# alpha = 0.66: FDPhat 0.6584, Number of Rej. 524
# alpha = 0.65: FDPhat 0.6489, Number of Rej. 507
# alpha = 0.64: FDPhat 0.64, Number of Rej. 500
# alpha = 0.63: FDPhat 0.6289, Number of Rej. 485
# alpha = 0.62: FDPhat 0.6195, Number of Rej. 481
# alpha = 0.61: FDPhat 0.6097, Number of Rej. 433
# alpha = 0.6: FDPhat 0.6, Number of Rej. 405
# alpha = 0.59: FDPhat 0.5891, Number of Rej. 404
# alpha = 0.58: FDPhat 0.5777, Number of Rej. 367
# alpha = 0.57: FDPhat 0.5686, Number of Rej. 357
# alpha = 0.56: FDPhat 0.56, Number of Rej. 350
# alpha = 0.55: FDPhat 0.5478, Number of Rej. 345
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 339
# alpha = 0.53: FDPhat 0.5276, Number of Rej. 326
# alpha = 0.52: FDPhat 0.5171, Number of Rej. 321
# alpha = 0.51: FDPhat 0.5095, Number of Rej. 316
# alpha = 0.5: FDPhat 0.4984, Number of Rej. 315
# alpha = 0.49: FDPhat 0.487, Number of Rej. 308
# alpha = 0.48: FDPhat 0.48, Number of Rej. 300
# alpha = 0.47: FDPhat 0.4694, Number of Rej. 294
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 287
# alpha = 0.45: FDPhat 0.4495, Number of Rej. 287
# alpha = 0.44: FDPhat 0.439, Number of Rej. 287
# alpha = 0.43: FDPhat 0.4296, Number of Rej. 284
# alpha = 0.42: FDPhat 0.4176, Number of Rej. 273
# alpha = 0.41: FDPhat 0.4081, Number of Rej. 272
# alpha = 0.4: FDPhat 0.3971, Number of Rej. 272
# alpha = 0.39: FDPhat 0.3889, Number of Rej. 270
# alpha = 0.38: FDPhat 0.3778, Number of Rej. 270
# alpha = 0.37: FDPhat 0.368, Number of Rej. 269
# alpha = 0.36: FDPhat 0.3582, Number of Rej. 268
# alpha = 0.35: FDPhat 0.3483, Number of Rej. 267
# alpha = 0.34: FDPhat 0.3371, Number of Rej. 264
# alpha = 0.33: FDPhat 0.3282, Number of Rej. 262
# alpha = 0.32: FDPhat 0.3175, Number of Rej. 252
# alpha = 0.31: FDPhat 0.308, Number of Rej. 250
# alpha = 0.3: FDPhat 0.2975, Number of Rej. 242
# alpha = 0.29: FDPhat 0.2887, Number of Rej. 239
# alpha = 0.28: FDPhat 0.2771, Number of Rej. 231
# alpha = 0.27: FDPhat 0.2687, Number of Rej. 227
# alpha = 0.26: FDPhat 0.2589, Number of Rej. 224
# alpha = 0.25: FDPhat 0.2477, Number of Rej. 222
# alpha = 0.24: FDPhat 0.2372, Number of Rej. 215
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 209
# alpha = 0.22: FDPhat 0.22, Number of Rej. 200
# alpha = 0.21: FDPhat 0.2092, Number of Rej. 196
# alpha = 0.2: FDPhat 0.199, Number of Rej. 196
# alpha = 0.19: FDPhat 0.1875, Number of Rej. 192
# alpha = 0.18: FDPhat 0.178, Number of Rej. 191
# alpha = 0.17: FDPhat 0.1685, Number of Rej. 178
# alpha = 0.16: FDPhat 0.16, Number of Rej. 175
# alpha = 0.15: FDPhat 0.1462, Number of Rej. 171
# alpha = 0.14: FDPhat 0.1377, Number of Rej. 167
# alpha = 0.13: FDPhat 0.1273, Number of Rej. 165
# alpha = 0.12: FDPhat 0.1173, Number of Rej. 162
# alpha = 0.11: FDPhat 0.109, Number of Rej. 156
# alpha = 0.1: FDPhat 0.0966, Number of Rej. 145
# alpha = 0.09: FDPhat 0.0862, Number of Rej. 116
# alpha = 0.08: FDPhat 0.0777, Number of Rej. 103
# alpha = 0.07: FDPhat 0.0693, Number of Rej. 101
# alpha = 0.06: FDPhat 0.0556, Number of Rej. 90
# alpha = 0.05: FDPhat 0.0494, Number of Rej. 81
# alpha = 0.04: FDPhat 0.0375, Number of Rej. 80
# alpha = 0.03: FDPhat 0.0263, Number of Rej. 76
# [1] "data_9"
# alpha = 0.87: FDPhat 0.87, Number of Rej. 1215
# alpha = 0.86: FDPhat 0.8594, Number of Rej. 1131
# alpha = 0.85: FDPhat 0.8498, Number of Rej. 1032
# alpha = 0.84: FDPhat 0.8399, Number of Rej. 1012
# alpha = 0.83: FDPhat 0.829, Number of Rej. 965
# alpha = 0.82: FDPhat 0.8198, Number of Rej. 899
# alpha = 0.81: FDPhat 0.8098, Number of Rej. 894
# alpha = 0.8: FDPhat 0.8, Number of Rej. 880
# alpha = 0.79: FDPhat 0.7894, Number of Rej. 812
# alpha = 0.78: FDPhat 0.7794, Number of Rej. 757
# alpha = 0.77: FDPhat 0.7689, Number of Rej. 740
# alpha = 0.76: FDPhat 0.7598, Number of Rej. 712
# alpha = 0.75: FDPhat 0.7493, Number of Rej. 686
# alpha = 0.74: FDPhat 0.7393, Number of Rej. 652
# alpha = 0.73: FDPhat 0.7295, Number of Rej. 584
# alpha = 0.72: FDPhat 0.7183, Number of Rej. 568
# alpha = 0.71: FDPhat 0.7082, Number of Rej. 538
# alpha = 0.7: FDPhat 0.6987, Number of Rej. 531
# alpha = 0.69: FDPhat 0.6889, Number of Rej. 524
# alpha = 0.68: FDPhat 0.6795, Number of Rej. 468
# alpha = 0.67: FDPhat 0.6688, Number of Rej. 465
# alpha = 0.66: FDPhat 0.6593, Number of Rej. 452
# alpha = 0.65: FDPhat 0.6493, Number of Rej. 422
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 411
# alpha = 0.63: FDPhat 0.6277, Number of Rej. 411
# alpha = 0.62: FDPhat 0.6182, Number of Rej. 406
# alpha = 0.61: FDPhat 0.6098, Number of Rej. 387
# alpha = 0.6: FDPhat 0.5995, Number of Rej. 372
# alpha = 0.59: FDPhat 0.5875, Number of Rej. 337
# alpha = 0.58: FDPhat 0.5774, Number of Rej. 336
# alpha = 0.57: FDPhat 0.5697, Number of Rej. 330
# alpha = 0.56: FDPhat 0.5594, Number of Rej. 320
# alpha = 0.55: FDPhat 0.5479, Number of Rej. 303
# alpha = 0.54: FDPhat 0.5397, Number of Rej. 302
# alpha = 0.53: FDPhat 0.53, Number of Rej. 300
# alpha = 0.52: FDPhat 0.5168, Number of Rej. 298
# alpha = 0.51: FDPhat 0.5068, Number of Rej. 296
# alpha = 0.5: FDPhat 0.5, Number of Rej. 292
# alpha = 0.49: FDPhat 0.4877, Number of Rej. 285
# alpha = 0.48: FDPhat 0.4789, Number of Rej. 284
# alpha = 0.47: FDPhat 0.4676, Number of Rej. 278
# alpha = 0.46: FDPhat 0.4586, Number of Rej. 266
# alpha = 0.45: FDPhat 0.4466, Number of Rej. 262
# alpha = 0.44: FDPhat 0.4389, Number of Rej. 262
# alpha = 0.43: FDPhat 0.4269, Number of Rej. 260
# alpha = 0.42: FDPhat 0.418, Number of Rej. 256
# alpha = 0.41: FDPhat 0.4076, Number of Rej. 238
# alpha = 0.4: FDPhat 0.3991, Number of Rej. 233
# alpha = 0.39: FDPhat 0.3896, Number of Rej. 231
# alpha = 0.38: FDPhat 0.3783, Number of Rej. 230
# alpha = 0.37: FDPhat 0.3684, Number of Rej. 228
# alpha = 0.36: FDPhat 0.3596, Number of Rej. 228
# alpha = 0.35: FDPhat 0.3468, Number of Rej. 222
# alpha = 0.34: FDPhat 0.3364, Number of Rej. 220
# alpha = 0.33: FDPhat 0.3271, Number of Rej. 214
# alpha = 0.32: FDPhat 0.319, Number of Rej. 210
# alpha = 0.31: FDPhat 0.3062, Number of Rej. 209
# alpha = 0.3: FDPhat 0.2995, Number of Rej. 207
# alpha = 0.29: FDPhat 0.2857, Number of Rej. 203
# alpha = 0.28: FDPhat 0.2786, Number of Rej. 201
# alpha = 0.27: FDPhat 0.2663, Number of Rej. 199
# alpha = 0.26: FDPhat 0.2589, Number of Rej. 197
# alpha = 0.25: FDPhat 0.25, Number of Rej. 196
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 196
# alpha = 0.23: FDPhat 0.2275, Number of Rej. 189
# alpha = 0.22: FDPhat 0.2169, Number of Rej. 189
# alpha = 0.21: FDPhat 0.2063, Number of Rej. 189
# alpha = 0.2: FDPhat 0.1958, Number of Rej. 189
# alpha = 0.19: FDPhat 0.1878, Number of Rej. 181
# alpha = 0.18: FDPhat 0.1778, Number of Rej. 180
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 177
# alpha = 0.16: FDPhat 0.1552, Number of Rej. 174
# alpha = 0.15: FDPhat 0.1494, Number of Rej. 174
# alpha = 0.14: FDPhat 0.1395, Number of Rej. 172
# alpha = 0.13: FDPhat 0.1243, Number of Rej. 169
# alpha = 0.12: FDPhat 0.119, Number of Rej. 168
# alpha = 0.11: FDPhat 0.1056, Number of Rej. 161
# alpha = 0.1: FDPhat 0.0949, Number of Rej. 158
# alpha = 0.09: FDPhat 0.0892, Number of Rej. 157
# alpha = 0.08: FDPhat 0.0774, Number of Rej. 155
# alpha = 0.07: FDPhat 0.0671, Number of Rej. 149
# alpha = 0.06: FDPhat 0.0593, Number of Rej. 135
# alpha = 0.05: FDPhat 0.0465, Number of Rej. 129
# alpha = 0.04: FDPhat 0.0328, Number of Rej. 122
# alpha = 0.03: FDPhat 0.0283, Number of Rej. 106
# Loading required package: nlme
# This is mgcv 1.8-24. For overview type 'help("mgcv-package")'.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.

# %% [markdown]
# ## Figure generation
# ### Collect the results from the saved file

# %%
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
summary_stats = {}
# Python methods
result_path_py = './temp_result/res_' + data_name + '/result.pickle'
with open(result_path_py, 'rb') as fil:
    result_py = pickle.load(fil)
for method in result_py.keys():
    if len(result_py[method])>0:
        summary_stats[method] = {}
        summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
        summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    else:
        continue
    for fdp,power,alpha,dname in result_py[method]:
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# R methods
result_path_r = './temp_result/res_r_' + data_name
r_method_list = ['ihw', 'adapt', 'bl']
for method in r_method_list:
    res_df = pd.read_table(result_path_r + '/res_' + method, delimiter=',') 
    summary_stats[method] = {}
    summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
    summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    for i in range(res_df.shape[0]):
        fdp,power,alpha,dname = res_df.iloc[i]
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# Delete when there is no result
method_list = list(summary_stats.keys())
for method in method_list:
    if np.sum(summary_stats[method]['Power']) == 0:
        del summary_stats[method]

# %% [markdown]
# ### Generate the FDP and power plot

# %%
marker_list = ['o', 'v', 'p', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C4', 'C3', 'C0', 'C5', 'C8']
method_list = ['adafdr-fast', 'adafdr', 'bl', 'adapt', 'ihw', 'sbh', 'bh']
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
# FDP
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['FDP'], axis=0)
        y_err = np.std(summary_stats[method]['FDP'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
axis_min = min(x_min, y_min)
axis_max = max(x_max, y_max)
plt.plot([axis_min, axis_max], [axis_min, axis_max], linestyle='--', color='k')
plt.legend(loc=2, fontsize=12)
plt.ylabel('FDP', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
# Power 
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['Power'], axis=0)
        y_err = np.std(summary_stats[method]['Power'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
plt.legend(loc=2, fontsize=12)
plt.ylabel('power', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
