# %%
import numpy as np
import adafdr.method as md
import adafdr.data_loader as dl
import matplotlib.pyplot as plt
import pandas as pd
import pickle
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

data_name = 'simu_1d_bump_slope'

# %% [markdown]
# ## Run methods on each simulation datasets
# This may take a while to run. The computed results are already stored in
# - Python methods: `./temp_result/res_ + data_name`
# - R methods: `./temp_result/res_r_ + data_name`
#
# where `data_name` is as defiend above. For those who do not
# want to run these again, they can directly move the figure generation
# section.
#
# For those who wish to run the code to reproduce the results,
# they need to specify the `data_path` below to be the path of
# `AdaFDRpaper_data` on their machine
#
# The Python methods are run by calling `analysis_batch.py` while
# R methods are run by calling `analysis_batch.R`. It is easier to
# run them using `.sh` script but we include them here for
# illustration purpose.

# %%
data_path = '/data3/martin/AdaFDRpaper_data'
input_folder = data_path + '/' + data_name

# %%
# Python methods
# %run analysis_batch.py -i $input_folder -d $data_name
# Out:
# input_folder: /data3/martin/AdaFDRpaper_data/simu_1d_bump_slope
# output_folder: ./temp_result/res_simu_1d_bump_slope
# alpha_list: [0.05, 0.1, 0.15, 0.2]
# # Processing data_5 with alpha=0.05
# # Processing data_5 with alpha=0.10
# # Processing data_5 with alpha=0.15
# # Processing data_5 with alpha=0.20
# # Processing data_2 with alpha=0.05
# # Processing data_2 with alpha=0.10
# # Processing data_2 with alpha=0.15
# # Processing data_2 with alpha=0.20
# # Processing data_0 with alpha=0.05
# # Processing data_0 with alpha=0.10
# # Processing data_0 with alpha=0.15
# # Processing data_0 with alpha=0.20
# # Processing data_3 with alpha=0.05
# # Processing data_3 with alpha=0.10
# # Processing data_3 with alpha=0.15
# # Processing data_3 with alpha=0.20
# # Processing data_7 with alpha=0.05
# # Processing data_7 with alpha=0.10
# # Processing data_7 with alpha=0.15
# # Processing data_7 with alpha=0.20
# # Processing data_9 with alpha=0.05
# # Processing data_9 with alpha=0.10
# # Processing data_9 with alpha=0.15
# # Processing data_9 with alpha=0.20
# # Processing data_4 with alpha=0.05
# # Processing data_4 with alpha=0.10
# # Processing data_4 with alpha=0.15
# # Processing data_4 with alpha=0.20
# # Processing data_6 with alpha=0.05
# # Processing data_6 with alpha=0.10
# # Processing data_6 with alpha=0.15
# # Processing data_6 with alpha=0.20
# # Processing data_1 with alpha=0.05
# # Processing data_1 with alpha=0.10
# # Processing data_1 with alpha=0.15
# # Processing data_1 with alpha=0.20
# # Processing data_8 with alpha=0.05
# # Processing data_8 with alpha=0.10
# # Processing data_8 with alpha=0.15
# # Processing data_8 with alpha=0.20

# %%
# R methods
output_folder = './temp_result/res_r_' + data_name
if data_name in ['data_yeast', 'data_polyester', 'data_polyester_ui']:
    benchmark_bl = 'T'
else:
    benchmark_bl = 'F'

# %%
# %%bash -s "$input_folder" "$output_folder" "$benchmark_bl"
# Rscript analysis_batch.R $1 $2 $3
# Out:
# [1] "input_folder: /data3/martin/AdaFDRpaper_data/simu_1d_bump_slope"
# [1] "output_folder: ./temp_result/res_r_simu_1d_bump_slope"
# [1] "benchmark_bl: F"
# [1] "data_0"
# alpha = 0.81: FDPhat 0.8099, Number of Rej. 9918
# alpha = 0.8: FDPhat 0.7999, Number of Rej. 9612
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 9054
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8709
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8330
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7883
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7668
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7361
# alpha = 0.73: FDPhat 0.73, Number of Rej. 7207
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 6934
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6608
# alpha = 0.7: FDPhat 0.7, Number of Rej. 6313
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5934
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 5632
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5025
# alpha = 0.66: FDPhat 0.66, Number of Rej. 4814
# alpha = 0.65: FDPhat 0.6498, Number of Rej. 4612
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4422
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 4157
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 3872
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 3791
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3672
# alpha = 0.59: FDPhat 0.59, Number of Rej. 3590
# alpha = 0.58: FDPhat 0.58, Number of Rej. 3507
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 3410
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3303
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 3143
# alpha = 0.54: FDPhat 0.5397, Number of Rej. 3070
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 2829
# alpha = 0.52: FDPhat 0.52, Number of Rej. 2656
# alpha = 0.51: FDPhat 0.5097, Number of Rej. 2570
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 2535
# alpha = 0.49: FDPhat 0.49, Number of Rej. 2439
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2348
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2322
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 2301
# alpha = 0.45: FDPhat 0.4497, Number of Rej. 2246
# alpha = 0.44: FDPhat 0.4396, Number of Rej. 2220
# alpha = 0.43: FDPhat 0.4297, Number of Rej. 2192
# alpha = 0.42: FDPhat 0.4197, Number of Rej. 2073
# alpha = 0.41: FDPhat 0.4098, Number of Rej. 2028
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 1963
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 1844
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 1823
# alpha = 0.37: FDPhat 0.3696, Number of Rej. 1802
# alpha = 0.36: FDPhat 0.36, Number of Rej. 1764
# alpha = 0.35: FDPhat 0.3496, Number of Rej. 1699
# alpha = 0.34: FDPhat 0.3397, Number of Rej. 1669
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 1634
# alpha = 0.32: FDPhat 0.3197, Number of Rej. 1589
# alpha = 0.31: FDPhat 0.3094, Number of Rej. 1558
# alpha = 0.3: FDPhat 0.2998, Number of Rej. 1541
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 1488
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 1451
# alpha = 0.27: FDPhat 0.2696, Number of Rej. 1387
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1347
# alpha = 0.25: FDPhat 0.2494, Number of Rej. 1307
# alpha = 0.24: FDPhat 0.2394, Number of Rej. 1274
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 1244
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 1161
# alpha = 0.21: FDPhat 0.2096, Number of Rej. 1145
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1095
# alpha = 0.19: FDPhat 0.1893, Number of Rej. 1062
# alpha = 0.18: FDPhat 0.1793, Number of Rej. 1032
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 983
# alpha = 0.16: FDPhat 0.159, Number of Rej. 956
# alpha = 0.15: FDPhat 0.1497, Number of Rej. 902
# alpha = 0.14: FDPhat 0.1389, Number of Rej. 857
# alpha = 0.13: FDPhat 0.1288, Number of Rej. 846
# alpha = 0.12: FDPhat 0.119, Number of Rej. 807
# alpha = 0.11: FDPhat 0.1089, Number of Rej. 771
# alpha = 0.1: FDPhat 0.0988, Number of Rej. 739
# alpha = 0.09: FDPhat 0.0897, Number of Rej. 691
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 629
# alpha = 0.07: FDPhat 0.0686, Number of Rej. 598
# alpha = 0.06: FDPhat 0.0587, Number of Rej. 545
# alpha = 0.05: FDPhat 0.0489, Number of Rej. 491
# alpha = 0.04: FDPhat 0.0389, Number of Rej. 463
# alpha = 0.03: FDPhat 0.0295, Number of Rej. 407
# alpha = 0.02: FDPhat 0.0178, Number of Rej. 338
# alpha = 0.01: FDPhat 0.0078, Number of Rej. 129
# Task completed!
# [1] "data_1"
# alpha = 0.8: FDPhat 0.7999, Number of Rej. 9831
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 9331
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8950
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8404
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7866
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 7441
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 7162
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 6735
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6435
# alpha = 0.71: FDPhat 0.71, Number of Rej. 6062
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5911
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5769
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 5638
# alpha = 0.67: FDPhat 0.67, Number of Rej. 5448
# alpha = 0.66: FDPhat 0.66, Number of Rej. 5314
# alpha = 0.65: FDPhat 0.65, Number of Rej. 5134
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4933
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 4679
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 4562
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 4355
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4180
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 4148
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3951
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3797
# alpha = 0.56: FDPhat 0.5597, Number of Rej. 3657
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3562
# alpha = 0.54: FDPhat 0.5397, Number of Rej. 3472
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 3411
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 3326
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 3176
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3130
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 3032
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2875
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2745
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2689
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2630
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2558
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2468
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2399
# alpha = 0.41: FDPhat 0.4098, Number of Rej. 2340
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2283
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 2212
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 2152
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 2106
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 2017
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 1975
# alpha = 0.34: FDPhat 0.34, Number of Rej. 1909
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 1843
# alpha = 0.32: FDPhat 0.3196, Number of Rej. 1799
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 1698
# alpha = 0.3: FDPhat 0.2996, Number of Rej. 1642
# alpha = 0.29: FDPhat 0.29, Number of Rej. 1576
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 1508
# alpha = 0.27: FDPhat 0.2694, Number of Rej. 1440
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 1389
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1360
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1293
# alpha = 0.23: FDPhat 0.23, Number of Rej. 1261
# alpha = 0.22: FDPhat 0.2195, Number of Rej. 1130
# alpha = 0.21: FDPhat 0.2093, Number of Rej. 1070
# alpha = 0.2: FDPhat 0.1994, Number of Rej. 1038
# alpha = 0.19: FDPhat 0.1892, Number of Rej. 1004
# alpha = 0.18: FDPhat 0.18, Number of Rej. 978
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 956
# alpha = 0.16: FDPhat 0.1595, Number of Rej. 947
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 928
# alpha = 0.14: FDPhat 0.1396, Number of Rej. 888
# alpha = 0.13: FDPhat 0.1294, Number of Rej. 850
# alpha = 0.12: FDPhat 0.1189, Number of Rej. 799
# alpha = 0.11: FDPhat 0.1099, Number of Rej. 755
# alpha = 0.1: FDPhat 0.0997, Number of Rej. 682
# alpha = 0.09: FDPhat 0.0892, Number of Rej. 639
# alpha = 0.08: FDPhat 0.0798, Number of Rej. 614
# alpha = 0.07: FDPhat 0.0691, Number of Rej. 579
# alpha = 0.06: FDPhat 0.0598, Number of Rej. 552
# alpha = 0.05: FDPhat 0.0493, Number of Rej. 487
# alpha = 0.04: FDPhat 0.0398, Number of Rej. 452
# alpha = 0.03: FDPhat 0.0284, Number of Rej. 388
# alpha = 0.02: FDPhat 0.0195, Number of Rej. 308
# alpha = 0.01: FDPhat 0.0093, Number of Rej. 216
# Task completed!
# [1] "data_2"
# alpha = 0.82: FDPhat 0.82, Number of Rej. 9622
# alpha = 0.81: FDPhat 0.81, Number of Rej. 8936
# alpha = 0.8: FDPhat 0.8, Number of Rej. 8489
# alpha = 0.79: FDPhat 0.79, Number of Rej. 8160
# alpha = 0.78: FDPhat 0.78, Number of Rej. 7821
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 7466
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 7146
# alpha = 0.75: FDPhat 0.75, Number of Rej. 6908
# alpha = 0.74: FDPhat 0.74, Number of Rej. 6700
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 6434
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6242
# alpha = 0.71: FDPhat 0.71, Number of Rej. 6100
# alpha = 0.7: FDPhat 0.6998, Number of Rej. 5797
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5595
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 5507
# alpha = 0.67: FDPhat 0.6698, Number of Rej. 5297
# alpha = 0.66: FDPhat 0.66, Number of Rej. 5123
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5042
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 4854
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 4702
# alpha = 0.62: FDPhat 0.62, Number of Rej. 4534
# alpha = 0.61: FDPhat 0.61, Number of Rej. 4438
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 4159
# alpha = 0.59: FDPhat 0.59, Number of Rej. 4085
# alpha = 0.58: FDPhat 0.58, Number of Rej. 3945
# alpha = 0.57: FDPhat 0.57, Number of Rej. 3865
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3650
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 3581
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3522
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3350
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 3280
# alpha = 0.51: FDPhat 0.51, Number of Rej. 3161
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3066
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 2958
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2844
# alpha = 0.47: FDPhat 0.47, Number of Rej. 2798
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2715
# alpha = 0.45: FDPhat 0.4497, Number of Rej. 2646
# alpha = 0.44: FDPhat 0.44, Number of Rej. 2582
# alpha = 0.43: FDPhat 0.4297, Number of Rej. 2427
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2372
# alpha = 0.41: FDPhat 0.4098, Number of Rej. 2311
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2268
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 2175
# alpha = 0.38: FDPhat 0.38, Number of Rej. 2129
# alpha = 0.37: FDPhat 0.3696, Number of Rej. 2075
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 1965
# alpha = 0.35: FDPhat 0.3496, Number of Rej. 1925
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 1836
# alpha = 0.33: FDPhat 0.33, Number of Rej. 1797
# alpha = 0.32: FDPhat 0.3196, Number of Rej. 1752
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 1682
# alpha = 0.3: FDPhat 0.2997, Number of Rej. 1635
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 1581
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 1526
# alpha = 0.27: FDPhat 0.2694, Number of Rej. 1496
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1455
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1424
# alpha = 0.24: FDPhat 0.2399, Number of Rej. 1313
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 1262
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1228
# alpha = 0.21: FDPhat 0.2094, Number of Rej. 1170
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1136
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 1091
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 984
# alpha = 0.17: FDPhat 0.1693, Number of Rej. 957
# alpha = 0.16: FDPhat 0.1594, Number of Rej. 922
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 894
# alpha = 0.14: FDPhat 0.1395, Number of Rej. 860
# alpha = 0.13: FDPhat 0.1293, Number of Rej. 812
# alpha = 0.12: FDPhat 0.1195, Number of Rej. 778
# alpha = 0.11: FDPhat 0.1095, Number of Rej. 758
# alpha = 0.1: FDPhat 0.0992, Number of Rej. 726
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 671
# alpha = 0.08: FDPhat 0.0797, Number of Rej. 627
# alpha = 0.07: FDPhat 0.0697, Number of Rej. 603
# alpha = 0.06: FDPhat 0.0593, Number of Rej. 573
# alpha = 0.05: FDPhat 0.0488, Number of Rej. 553
# alpha = 0.04: FDPhat 0.0393, Number of Rej. 509
# alpha = 0.03: FDPhat 0.0284, Number of Rej. 422
# alpha = 0.02: FDPhat 0.0189, Number of Rej. 317
# alpha = 0.01: FDPhat 0.0072, Number of Rej. 276
# Task completed!
# [1] "data_3"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 9924
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9020
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 8615
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 8223
# alpha = 0.77: FDPhat 0.77, Number of Rej. 7913
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 7630
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7460
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 7008
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6648
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6149
# alpha = 0.71: FDPhat 0.71, Number of Rej. 5941
# alpha = 0.7: FDPhat 0.7, Number of Rej. 5710
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5395
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5159
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 4977
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 4458
# alpha = 0.65: FDPhat 0.6498, Number of Rej. 4286
# alpha = 0.64: FDPhat 0.6398, Number of Rej. 3965
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 3839
# alpha = 0.62: FDPhat 0.62, Number of Rej. 3768
# alpha = 0.61: FDPhat 0.61, Number of Rej. 3600
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3412
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3302
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3149
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 3066
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 2938
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 2907
# alpha = 0.54: FDPhat 0.5397, Number of Rej. 2798
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 2729
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 2699
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2667
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 2577
# alpha = 0.49: FDPhat 0.4896, Number of Rej. 2502
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 2442
# alpha = 0.47: FDPhat 0.4696, Number of Rej. 2372
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2311
# alpha = 0.45: FDPhat 0.4496, Number of Rej. 2231
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2135
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2094
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2039
# alpha = 0.41: FDPhat 0.4096, Number of Rej. 1968
# alpha = 0.4: FDPhat 0.4, Number of Rej. 1940
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 1873
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 1817
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 1676
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 1612
# alpha = 0.35: FDPhat 0.35, Number of Rej. 1563
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 1536
# alpha = 0.33: FDPhat 0.33, Number of Rej. 1491
# alpha = 0.32: FDPhat 0.3197, Number of Rej. 1445
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 1369
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 1337
# alpha = 0.29: FDPhat 0.2894, Number of Rej. 1327
# alpha = 0.28: FDPhat 0.2797, Number of Rej. 1255
# alpha = 0.27: FDPhat 0.2696, Number of Rej. 1146
# alpha = 0.26: FDPhat 0.2596, Number of Rej. 1125
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 1065
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1034
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 1010
# alpha = 0.22: FDPhat 0.2191, Number of Rej. 986
# alpha = 0.21: FDPhat 0.2093, Number of Rej. 970
# alpha = 0.2: FDPhat 0.1996, Number of Rej. 932
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 896
# alpha = 0.18: FDPhat 0.1795, Number of Rej. 886
# alpha = 0.17: FDPhat 0.169, Number of Rej. 870
# alpha = 0.16: FDPhat 0.1596, Number of Rej. 846
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 807
# alpha = 0.14: FDPhat 0.1389, Number of Rej. 763
# alpha = 0.13: FDPhat 0.1292, Number of Rej. 751
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 743
# alpha = 0.11: FDPhat 0.1091, Number of Rej. 706
# alpha = 0.1: FDPhat 0.0999, Number of Rej. 671
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 579
# alpha = 0.08: FDPhat 0.0793, Number of Rej. 555
# alpha = 0.07: FDPhat 0.069, Number of Rej. 507
# alpha = 0.06: FDPhat 0.0599, Number of Rej. 451
# alpha = 0.05: FDPhat 0.0497, Number of Rej. 382
# alpha = 0.04: FDPhat 0.0378, Number of Rej. 370
# alpha = 0.03: FDPhat 0.0294, Number of Rej. 306
# alpha = 0.02: FDPhat 0.0199, Number of Rej. 201
# alpha = 0.01: FDPhat 0.0091, Number of Rej. 110
# Task completed!
# [1] "data_4"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 9445
# alpha = 0.8: FDPhat 0.8, Number of Rej. 8693
# alpha = 0.79: FDPhat 0.79, Number of Rej. 8294
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 7848
# alpha = 0.77: FDPhat 0.77, Number of Rej. 7360
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7241
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 7078
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6671
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 6327
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6085
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 5811
# alpha = 0.7: FDPhat 0.6998, Number of Rej. 5567
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5101
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 4936
# alpha = 0.67: FDPhat 0.6698, Number of Rej. 4664
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 4515
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 4347
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4250
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 4129
# alpha = 0.62: FDPhat 0.62, Number of Rej. 3876
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 3820
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3489
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3382
# alpha = 0.58: FDPhat 0.5797, Number of Rej. 3312
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 3222
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3087
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 2997
# alpha = 0.54: FDPhat 0.54, Number of Rej. 2889
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 2829
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2791
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2724
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 2681
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 2593
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 2559
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 2518
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2411
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2305
# alpha = 0.44: FDPhat 0.4396, Number of Rej. 2211
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2147
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2117
# alpha = 0.41: FDPhat 0.41, Number of Rej. 2061
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 2011
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 1942
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 1906
# alpha = 0.37: FDPhat 0.37, Number of Rej. 1857
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 1823
# alpha = 0.35: FDPhat 0.3497, Number of Rej. 1773
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 1743
# alpha = 0.33: FDPhat 0.33, Number of Rej. 1682
# alpha = 0.32: FDPhat 0.3196, Number of Rej. 1605
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 1575
# alpha = 0.3: FDPhat 0.2997, Number of Rej. 1505
# alpha = 0.29: FDPhat 0.29, Number of Rej. 1407
# alpha = 0.28: FDPhat 0.28, Number of Rej. 1318
# alpha = 0.27: FDPhat 0.27, Number of Rej. 1289
# alpha = 0.26: FDPhat 0.2593, Number of Rej. 1230
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1196
# alpha = 0.24: FDPhat 0.2395, Number of Rej. 1140
# alpha = 0.23: FDPhat 0.2293, Number of Rej. 1112
# alpha = 0.22: FDPhat 0.2193, Number of Rej. 1049
# alpha = 0.21: FDPhat 0.2091, Number of Rej. 1009
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 956
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 891
# alpha = 0.18: FDPhat 0.1791, Number of Rej. 860
# alpha = 0.17: FDPhat 0.1694, Number of Rej. 844
# alpha = 0.16: FDPhat 0.1595, Number of Rej. 809
# alpha = 0.15: FDPhat 0.1492, Number of Rej. 764
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 729
# alpha = 0.13: FDPhat 0.1294, Number of Rej. 680
# alpha = 0.12: FDPhat 0.1189, Number of Rej. 631
# alpha = 0.11: FDPhat 0.1093, Number of Rej. 613
# alpha = 0.1: FDPhat 0.0998, Number of Rej. 541
# alpha = 0.09: FDPhat 0.0895, Number of Rej. 503
# alpha = 0.08: FDPhat 0.0797, Number of Rej. 464
# alpha = 0.07: FDPhat 0.0689, Number of Rej. 421
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 386
# alpha = 0.05: FDPhat 0.0496, Number of Rej. 363
# alpha = 0.04: FDPhat 0.0385, Number of Rej. 312
# alpha = 0.03: FDPhat 0.0297, Number of Rej. 303
# alpha = 0.02: FDPhat 0.0197, Number of Rej. 254
# alpha = 0.01: FDPhat 0.0097, Number of Rej. 207
# Task completed!
# [1] "data_5"
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 9848
# alpha = 0.78: FDPhat 0.78, Number of Rej. 9280
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8607
# alpha = 0.76: FDPhat 0.76, Number of Rej. 8040
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7588
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7214
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 6752
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 6518
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6373
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5994
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5759
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 5592
# alpha = 0.67: FDPhat 0.67, Number of Rej. 5354
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 5208
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5041
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4919
# alpha = 0.63: FDPhat 0.63, Number of Rej. 4659
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 4523
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 4368
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4155
# alpha = 0.59: FDPhat 0.59, Number of Rej. 4012
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3904
# alpha = 0.57: FDPhat 0.57, Number of Rej. 3688
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3490
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3397
# alpha = 0.54: FDPhat 0.54, Number of Rej. 3239
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 3156
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 3107
# alpha = 0.51: FDPhat 0.51, Number of Rej. 3000
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 2805
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 2676
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2573
# alpha = 0.47: FDPhat 0.47, Number of Rej. 2466
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2422
# alpha = 0.45: FDPhat 0.45, Number of Rej. 2320
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2226
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2105
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2027
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 1982
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 1923
# alpha = 0.39: FDPhat 0.3896, Number of Rej. 1866
# alpha = 0.38: FDPhat 0.3795, Number of Rej. 1818
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 1736
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 1698
# alpha = 0.35: FDPhat 0.3496, Number of Rej. 1659
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 1637
# alpha = 0.33: FDPhat 0.33, Number of Rej. 1582
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 1510
# alpha = 0.31: FDPhat 0.3094, Number of Rej. 1432
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 1407
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 1343
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 1290
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 1268
# alpha = 0.26: FDPhat 0.2593, Number of Rej. 1234
# alpha = 0.25: FDPhat 0.2494, Number of Rej. 1163
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1121
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 1115
# alpha = 0.22: FDPhat 0.22, Number of Rej. 1100
# alpha = 0.21: FDPhat 0.2094, Number of Rej. 1065
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1001
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 975
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 951
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 918
# alpha = 0.16: FDPhat 0.16, Number of Rej. 894
# alpha = 0.15: FDPhat 0.1494, Number of Rej. 870
# alpha = 0.14: FDPhat 0.14, Number of Rej. 836
# alpha = 0.13: FDPhat 0.1295, Number of Rej. 780
# alpha = 0.12: FDPhat 0.1196, Number of Rej. 736
# alpha = 0.11: FDPhat 0.11, Number of Rej. 682
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 664
# alpha = 0.09: FDPhat 0.0889, Number of Rej. 630
# alpha = 0.08: FDPhat 0.0793, Number of Rej. 618
# alpha = 0.07: FDPhat 0.0697, Number of Rej. 588
# alpha = 0.06: FDPhat 0.0588, Number of Rej. 544
# alpha = 0.05: FDPhat 0.0497, Number of Rej. 523
# alpha = 0.04: FDPhat 0.0385, Number of Rej. 442
# alpha = 0.03: FDPhat 0.0281, Number of Rej. 392
# alpha = 0.02: FDPhat 0.0189, Number of Rej. 265
# alpha = 0.01: FDPhat 0.0073, Number of Rej. 137
# Task completed!
# [1] "data_6"
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 9793
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 9366
# alpha = 0.74: FDPhat 0.74, Number of Rej. 9141
# alpha = 0.73: FDPhat 0.73, Number of Rej. 8733
# alpha = 0.72: FDPhat 0.72, Number of Rej. 8220
# alpha = 0.71: FDPhat 0.71, Number of Rej. 7703
# alpha = 0.7: FDPhat 0.7, Number of Rej. 7350
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 7079
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 6780
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 6422
# alpha = 0.66: FDPhat 0.66, Number of Rej. 6135
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5901
# alpha = 0.64: FDPhat 0.64, Number of Rej. 5691
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 5339
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 5127
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 4848
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 4679
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 4593
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 4516
# alpha = 0.57: FDPhat 0.57, Number of Rej. 4223
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 4092
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3888
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3697
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3584
# alpha = 0.52: FDPhat 0.52, Number of Rej. 3452
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3328
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 3225
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 3029
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 2847
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2788
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2750
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2697
# alpha = 0.44: FDPhat 0.44, Number of Rej. 2625
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2491
# alpha = 0.42: FDPhat 0.4196, Number of Rej. 2464
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 2392
# alpha = 0.4: FDPhat 0.3997, Number of Rej. 2309
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 2221
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 2152
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 2079
# alpha = 0.36: FDPhat 0.3596, Number of Rej. 2044
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 1964
# alpha = 0.34: FDPhat 0.34, Number of Rej. 1903
# alpha = 0.33: FDPhat 0.3297, Number of Rej. 1826
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 1791
# alpha = 0.31: FDPhat 0.3095, Number of Rej. 1677
# alpha = 0.3: FDPhat 0.2995, Number of Rej. 1643
# alpha = 0.29: FDPhat 0.29, Number of Rej. 1600
# alpha = 0.28: FDPhat 0.2794, Number of Rej. 1514
# alpha = 0.27: FDPhat 0.2696, Number of Rej. 1480
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1459
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 1393
# alpha = 0.24: FDPhat 0.2394, Number of Rej. 1324
# alpha = 0.23: FDPhat 0.23, Number of Rej. 1274
# alpha = 0.22: FDPhat 0.2197, Number of Rej. 1238
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1191
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1091
# alpha = 0.19: FDPhat 0.1899, Number of Rej. 1032
# alpha = 0.18: FDPhat 0.179, Number of Rej. 983
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 944
# alpha = 0.16: FDPhat 0.1596, Number of Rej. 877
# alpha = 0.15: FDPhat 0.1495, Number of Rej. 823
# alpha = 0.14: FDPhat 0.1396, Number of Rej. 788
# alpha = 0.13: FDPhat 0.1293, Number of Rej. 735
# alpha = 0.12: FDPhat 0.1193, Number of Rej. 704
# alpha = 0.11: FDPhat 0.1089, Number of Rej. 661
# alpha = 0.1: FDPhat 0.0992, Number of Rej. 605
# alpha = 0.09: FDPhat 0.0897, Number of Rej. 591
# alpha = 0.08: FDPhat 0.0784, Number of Rej. 536
# alpha = 0.07: FDPhat 0.0685, Number of Rej. 511
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 470
# alpha = 0.05: FDPhat 0.0497, Number of Rej. 443
# alpha = 0.04: FDPhat 0.0388, Number of Rej. 387
# alpha = 0.03: FDPhat 0.03, Number of Rej. 367
# alpha = 0.02: FDPhat 0.0175, Number of Rej. 342
# [1] "data_7"
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9990
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9119
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8553
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8047
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7725
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 7326
# alpha = 0.74: FDPhat 0.74, Number of Rej. 6934
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6514
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 6319
# alpha = 0.71: FDPhat 0.71, Number of Rej. 5703
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5462
# alpha = 0.69: FDPhat 0.69, Number of Rej. 5325
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5184
# alpha = 0.67: FDPhat 0.6698, Number of Rej. 4870
# alpha = 0.66: FDPhat 0.66, Number of Rej. 4700
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 4576
# alpha = 0.64: FDPhat 0.6398, Number of Rej. 4387
# alpha = 0.63: FDPhat 0.63, Number of Rej. 4135
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 3967
# alpha = 0.61: FDPhat 0.61, Number of Rej. 3892
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 3768
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3675
# alpha = 0.58: FDPhat 0.58, Number of Rej. 3488
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3392
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3208
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3088
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3018
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 2867
# alpha = 0.52: FDPhat 0.52, Number of Rej. 2777
# alpha = 0.51: FDPhat 0.51, Number of Rej. 2710
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2616
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 2533
# alpha = 0.48: FDPhat 0.4796, Number of Rej. 2477
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 2431
# alpha = 0.46: FDPhat 0.4596, Number of Rej. 2376
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2296
# alpha = 0.44: FDPhat 0.4396, Number of Rej. 2243
# alpha = 0.43: FDPhat 0.4297, Number of Rej. 2199
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2046
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 1986
# alpha = 0.4: FDPhat 0.4, Number of Rej. 1955
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 1870
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 1849
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 1768
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 1740
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 1712
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 1668
# alpha = 0.33: FDPhat 0.3295, Number of Rej. 1642
# alpha = 0.32: FDPhat 0.32, Number of Rej. 1572
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 1530
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 1487
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 1463
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 1344
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 1267
# alpha = 0.26: FDPhat 0.2594, Number of Rej. 1245
# alpha = 0.25: FDPhat 0.2494, Number of Rej. 1207
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1096
# alpha = 0.23: FDPhat 0.2295, Number of Rej. 1059
# alpha = 0.22: FDPhat 0.2192, Number of Rej. 1040
# alpha = 0.21: FDPhat 0.2092, Number of Rej. 1023
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 986
# alpha = 0.19: FDPhat 0.1891, Number of Rej. 973
# alpha = 0.18: FDPhat 0.1791, Number of Rej. 927
# alpha = 0.17: FDPhat 0.17, Number of Rej. 906
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 851
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 834
# alpha = 0.14: FDPhat 0.1389, Number of Rej. 792
# alpha = 0.13: FDPhat 0.13, Number of Rej. 777
# alpha = 0.12: FDPhat 0.1197, Number of Rej. 735
# alpha = 0.11: FDPhat 0.11, Number of Rej. 691
# alpha = 0.1: FDPhat 0.0993, Number of Rej. 675
# alpha = 0.09: FDPhat 0.0892, Number of Rej. 628
# alpha = 0.08: FDPhat 0.08, Number of Rej. 600
# alpha = 0.07: FDPhat 0.0698, Number of Rej. 587
# alpha = 0.06: FDPhat 0.0586, Number of Rej. 529
# alpha = 0.05: FDPhat 0.0486, Number of Rej. 473
# alpha = 0.04: FDPhat 0.0381, Number of Rej. 394
# alpha = 0.03: FDPhat 0.0285, Number of Rej. 351
# alpha = 0.02: FDPhat 0.0192, Number of Rej. 313
# alpha = 0.01: FDPhat 0.0091, Number of Rej. 220
# Task completed!
# [1] "data_8"
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9247
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 8602
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8291
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7654
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7392
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6977
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 6746
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 6462
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6070
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5849
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5611
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5387
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5068
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 4731
# alpha = 0.65: FDPhat 0.6498, Number of Rej. 4603
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4472
# alpha = 0.63: FDPhat 0.63, Number of Rej. 4305
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 4188
# alpha = 0.61: FDPhat 0.61, Number of Rej. 4079
# alpha = 0.6: FDPhat 0.6, Number of Rej. 3920
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3806
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 3689
# alpha = 0.57: FDPhat 0.57, Number of Rej. 3609
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3539
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 3427
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3301
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3159
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 3003
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2871
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2762
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 2691
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2625
# alpha = 0.47: FDPhat 0.47, Number of Rej. 2598
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 2510
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2463
# alpha = 0.44: FDPhat 0.4397, Number of Rej. 2372
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2315
# alpha = 0.42: FDPhat 0.4196, Number of Rej. 2207
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2191
# alpha = 0.4: FDPhat 0.3996, Number of Rej. 2127
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 2049
# alpha = 0.38: FDPhat 0.3798, Number of Rej. 1988
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 1920
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 1879
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 1866
# alpha = 0.34: FDPhat 0.3397, Number of Rej. 1822
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 1770
# alpha = 0.32: FDPhat 0.3195, Number of Rej. 1690
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 1634
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 1577
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 1508
# alpha = 0.28: FDPhat 0.28, Number of Rej. 1425
# alpha = 0.27: FDPhat 0.2695, Number of Rej. 1410
# alpha = 0.26: FDPhat 0.2597, Number of Rej. 1367
# alpha = 0.25: FDPhat 0.2496, Number of Rej. 1342
# alpha = 0.24: FDPhat 0.2393, Number of Rej. 1304
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 1245
# alpha = 0.22: FDPhat 0.2197, Number of Rej. 1211
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1167
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1135
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 1086
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1067
# alpha = 0.17: FDPhat 0.1698, Number of Rej. 1001
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 976
# alpha = 0.15: FDPhat 0.1497, Number of Rej. 942
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 879
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 841
# alpha = 0.12: FDPhat 0.1199, Number of Rej. 826
# alpha = 0.11: FDPhat 0.1096, Number of Rej. 803
# alpha = 0.1: FDPhat 0.0997, Number of Rej. 752
# alpha = 0.09: FDPhat 0.0893, Number of Rej. 683
# alpha = 0.08: FDPhat 0.0796, Number of Rej. 603
# alpha = 0.07: FDPhat 0.0693, Number of Rej. 548
# alpha = 0.06: FDPhat 0.0586, Number of Rej. 512
# alpha = 0.05: FDPhat 0.049, Number of Rej. 469
# alpha = 0.04: FDPhat 0.0383, Number of Rej. 366
# alpha = 0.03: FDPhat 0.028, Number of Rej. 321
# alpha = 0.02: FDPhat 0.0176, Number of Rej. 227
# [1] "data_9"
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9850
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 8926
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 8541
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 8231
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7583
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7172
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6881
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6610
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6242
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 5973
# alpha = 0.7: FDPhat 0.7, Number of Rej. 5750
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5470
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 5301
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5041
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 4774
# alpha = 0.65: FDPhat 0.6498, Number of Rej. 4572
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 4479
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 4272
# alpha = 0.62: FDPhat 0.62, Number of Rej. 4097
# alpha = 0.61: FDPhat 0.61, Number of Rej. 3946
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 3816
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3621
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 3529
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 3452
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3337
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3246
# alpha = 0.54: FDPhat 0.54, Number of Rej. 3202
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 3156
# alpha = 0.52: FDPhat 0.52, Number of Rej. 3050
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2930
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2830
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 2805
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2721
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2654
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2587
# alpha = 0.45: FDPhat 0.45, Number of Rej. 2549
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2428
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2280
# alpha = 0.42: FDPhat 0.42, Number of Rej. 2205
# alpha = 0.41: FDPhat 0.41, Number of Rej. 2127
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2075
# alpha = 0.39: FDPhat 0.3896, Number of Rej. 2025
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 1969
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 1841
# alpha = 0.36: FDPhat 0.36, Number of Rej. 1814
# alpha = 0.35: FDPhat 0.3497, Number of Rej. 1787
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 1721
# alpha = 0.33: FDPhat 0.33, Number of Rej. 1691
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1651
# alpha = 0.31: FDPhat 0.3094, Number of Rej. 1629
# alpha = 0.3: FDPhat 0.2996, Number of Rej. 1602
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 1535
# alpha = 0.28: FDPhat 0.2797, Number of Rej. 1480
# alpha = 0.27: FDPhat 0.2695, Number of Rej. 1451
# alpha = 0.26: FDPhat 0.2595, Number of Rej. 1441
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1428
# alpha = 0.24: FDPhat 0.2399, Number of Rej. 1388
# alpha = 0.23: FDPhat 0.2295, Number of Rej. 1290
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1201
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1153
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1100
# alpha = 0.19: FDPhat 0.1895, Number of Rej. 1071
# alpha = 0.18: FDPhat 0.1794, Number of Rej. 1020
# alpha = 0.17: FDPhat 0.1694, Number of Rej. 927
# alpha = 0.16: FDPhat 0.1594, Number of Rej. 897
# alpha = 0.15: FDPhat 0.1494, Number of Rej. 857
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 815
# alpha = 0.13: FDPhat 0.1293, Number of Rej. 758
# alpha = 0.12: FDPhat 0.119, Number of Rej. 731
# alpha = 0.11: FDPhat 0.1091, Number of Rej. 724
# alpha = 0.1: FDPhat 0.0999, Number of Rej. 681
# alpha = 0.09: FDPhat 0.0892, Number of Rej. 650
# alpha = 0.08: FDPhat 0.0793, Number of Rej. 605
# alpha = 0.07: FDPhat 0.0697, Number of Rej. 531
# alpha = 0.06: FDPhat 0.0599, Number of Rej. 434
# alpha = 0.05: FDPhat 0.0499, Number of Rej. 381
# alpha = 0.04: FDPhat 0.0395, Number of Rej. 354
# alpha = 0.03: FDPhat 0.0272, Number of Rej. 257
# alpha = 0.02: FDPhat 0.0183, Number of Rej. 218
# alpha = 0.01: FDPhat 0.0095, Number of Rej. 211
# Task completed!
# Loading required package: nlme
# This is mgcv 1.8-24. For overview type 'help("mgcv-package")'.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.

# %% [markdown]
# ## Figure generation
# ### Collect the results from the saved file

# %%
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
summary_stats = {}
# Python methods
result_path_py = './temp_result/res_' + data_name + '/result.pickle'
with open(result_path_py, 'rb') as fil:
    result_py = pickle.load(fil)
for method in result_py.keys():
    if len(result_py[method])>0:
        summary_stats[method] = {}
        summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
        summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    else:
        continue
    for fdp,power,alpha,dname in result_py[method]:
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# R methods
result_path_r = './temp_result/res_r_' + data_name
r_method_list = ['ihw', 'adapt', 'bl']
for method in r_method_list:
    res_df = pd.read_table(result_path_r + '/res_' + method, delimiter=',') 
    summary_stats[method] = {}
    summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
    summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    for i in range(res_df.shape[0]):
        fdp,power,alpha,dname = res_df.iloc[i]
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# Delete when there is no result
method_list = list(summary_stats.keys())
for method in method_list:
    if np.sum(summary_stats[method]['Power']) == 0:
        del summary_stats[method]

# %% [markdown]
# ### Generate the FDP and power plot

# %%
marker_list = ['o', 'v', 'p', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C4', 'C3', 'C0', 'C5', 'C8']
method_list = ['adafdr-fast', 'adafdr', 'bl', 'adapt', 'ihw', 'sbh', 'bh']
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
# FDP
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['FDP'], axis=0)
        y_err = np.std(summary_stats[method]['FDP'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
axis_min = min(x_min, y_min)
axis_max = max(x_max, y_max)
plt.plot([axis_min, axis_max], [axis_min, axis_max], linestyle='--', color='k')
plt.legend(loc=2, fontsize=12)
plt.ylabel('FDP', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
# Power 
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['Power'], axis=0)
        y_err = np.std(summary_stats[method]['Power'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
plt.legend(loc=2, fontsize=12)
plt.ylabel('power', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
