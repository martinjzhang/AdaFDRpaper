# %%
import numpy as np
import adafdr.method as md
import adafdr.data_loader as dl
import matplotlib.pyplot as plt
import pandas as pd
import pickle
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

data_name = 'simu_data_wd'

# %% [markdown]
# ## Run methods on each simulation datasets
# This may take a while to run. The computed results are already stored in
# - Python methods: `./temp_result/res_ + data_name`
# - R methods: `./temp_result/res_r_ + data_name`
#
# where `data_name` is as defiend above. For those who do not
# want to run these again, they can directly move the figure generation
# section.
#
# For those who wish to run the code to reproduce the results,
# they need to specify the `data_path` below to be the path of
# `AdaFDRpaper_data` on their machine
#
# The Python methods are run by calling `analysis_batch.py` while
# R methods are run by calling `analysis_batch.R`. It is easier to
# run them using `.sh` script but we include them here for
# illustration purpose.

# %%
data_path = '/data3/martin/AdaFDRpaper_data'
input_folder = data_path + '/' + data_name

# %%
# Python methods
# %run analysis_batch.py -i $input_folder -d $data_name
# Out:
# input_folder: /data3/martin/AdaFDRpaper_data/simu_data_wd
# output_folder: ./temp_result/res_simu_data_wd
# alpha_list: [0.05, 0.1, 0.15, 0.2]
# # Processing data_5 with alpha=0.05
# # Processing data_5 with alpha=0.10
# # Processing data_5 with alpha=0.15
# # Processing data_5 with alpha=0.20
# # Processing data_2 with alpha=0.05
# # Processing data_2 with alpha=0.10
# # Processing data_2 with alpha=0.15
# # Processing data_2 with alpha=0.20
# # Processing data_0 with alpha=0.05
# # Processing data_0 with alpha=0.10
# # Processing data_0 with alpha=0.15
# # Processing data_0 with alpha=0.20
# # Processing data_3 with alpha=0.05
# # Processing data_3 with alpha=0.10
# # Processing data_3 with alpha=0.15
# # Processing data_3 with alpha=0.20
# # Processing data_7 with alpha=0.05
# # Processing data_7 with alpha=0.10
# # Processing data_7 with alpha=0.15
# # Processing data_7 with alpha=0.20
# # Processing data_9 with alpha=0.05
# # Processing data_9 with alpha=0.10
# # Processing data_9 with alpha=0.15
# # Processing data_9 with alpha=0.20
# # Processing data_4 with alpha=0.05
# # Processing data_4 with alpha=0.10
# # Processing data_4 with alpha=0.15
# # Processing data_4 with alpha=0.20
# # Processing data_6 with alpha=0.05
# # Processing data_6 with alpha=0.10
# # Processing data_6 with alpha=0.15
# # Processing data_6 with alpha=0.20
# # Processing data_1 with alpha=0.05
# # Processing data_1 with alpha=0.10
# # Processing data_1 with alpha=0.15
# # Processing data_1 with alpha=0.20
# # Processing data_8 with alpha=0.05
# # Processing data_8 with alpha=0.10
# # Processing data_8 with alpha=0.15
# # Processing data_8 with alpha=0.20

# %%
# R methods
output_folder = './temp_result/res_r_' + data_name
if data_name in ['data_yeast', 'data_polyester', 'data_polyester_ui']:
    benchmark_bl = 'T'
else:
    benchmark_bl = 'F'
# Out:
# [autoreload of adafdr.method failed: Traceback (most recent call last):
#   File "/home/martin/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 246, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/martin/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 369, in superreload
#     module = reload(module)
#   File "/home/martin/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/martin/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/martin/NeuralFDR2/adafdr/adafdr/method.py", line 646
#     if
#       ^
# SyntaxError: invalid syntax
# ]

# %%
# %%bash -s "$input_folder" "$output_folder" "$benchmark_bl"
# Rscript analysis_batch.R $1 $2 $3
# Out:
# [1] "input_folder: /data3/martin/AdaFDRpaper_data/simu_data_wd"
# [1] "output_folder: ./temp_result/res_r_simu_data_wd"
# [1] "benchmark_bl: F"
# [1] "data_0"
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9980
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9194
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 8782
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8504
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7941
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7656
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7176
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6681
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 5709
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 5333
# alpha = 0.7: FDPhat 0.6998, Number of Rej. 5177
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 4776
# alpha = 0.68: FDPhat 0.68, Number of Rej. 4553
# alpha = 0.67: FDPhat 0.6698, Number of Rej. 4428
# alpha = 0.66: FDPhat 0.66, Number of Rej. 4329
# alpha = 0.65: FDPhat 0.65, Number of Rej. 3940
# alpha = 0.64: FDPhat 0.6398, Number of Rej. 3848
# alpha = 0.63: FDPhat 0.63, Number of Rej. 3778
# alpha = 0.62: FDPhat 0.62, Number of Rej. 3647
# alpha = 0.61: FDPhat 0.61, Number of Rej. 3541
# alpha = 0.6: FDPhat 0.6, Number of Rej. 3390
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3287
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3204
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3013
# alpha = 0.56: FDPhat 0.5597, Number of Rej. 2914
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 2827
# alpha = 0.54: FDPhat 0.54, Number of Rej. 2763
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 2674
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 2624
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 2548
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2434
# alpha = 0.49: FDPhat 0.4896, Number of Rej. 2355
# alpha = 0.48: FDPhat 0.4797, Number of Rej. 2268
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 2163
# alpha = 0.46: FDPhat 0.4596, Number of Rej. 2093
# alpha = 0.45: FDPhat 0.45, Number of Rej. 2060
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 1971
# alpha = 0.43: FDPhat 0.4295, Number of Rej. 1893
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 1772
# alpha = 0.41: FDPhat 0.41, Number of Rej. 1722
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 1676
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 1644
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 1578
# alpha = 0.37: FDPhat 0.3696, Number of Rej. 1534
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 1428
# alpha = 0.35: FDPhat 0.3494, Number of Rej. 1345
# alpha = 0.34: FDPhat 0.3397, Number of Rej. 1307
# alpha = 0.33: FDPhat 0.3297, Number of Rej. 1286
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1260
# alpha = 0.31: FDPhat 0.3096, Number of Rej. 1224
# alpha = 0.3: FDPhat 0.2996, Number of Rej. 1155
# alpha = 0.29: FDPhat 0.2894, Number of Rej. 1078
# alpha = 0.28: FDPhat 0.2795, Number of Rej. 1034
# alpha = 0.27: FDPhat 0.2692, Number of Rej. 1003
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 974
# alpha = 0.25: FDPhat 0.2495, Number of Rej. 926
# alpha = 0.24: FDPhat 0.2395, Number of Rej. 906
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 884
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 847
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 829
# alpha = 0.2: FDPhat 0.1997, Number of Rej. 796
# alpha = 0.19: FDPhat 0.189, Number of Rej. 762
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 751
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 714
# alpha = 0.16: FDPhat 0.1589, Number of Rej. 686
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 661
# alpha = 0.14: FDPhat 0.1397, Number of Rej. 637
# alpha = 0.13: FDPhat 0.1291, Number of Rej. 604
# alpha = 0.12: FDPhat 0.1195, Number of Rej. 544
# alpha = 0.11: FDPhat 0.1096, Number of Rej. 502
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 473
# alpha = 0.09: FDPhat 0.09, Number of Rej. 400
# alpha = 0.08: FDPhat 0.08, Number of Rej. 350
# alpha = 0.07: FDPhat 0.0671, Number of Rej. 328
# alpha = 0.06: FDPhat 0.0597, Number of Rej. 318
# alpha = 0.05: FDPhat 0.0481, Number of Rej. 270
# alpha = 0.04: FDPhat 0.0398, Number of Rej. 251
# alpha = 0.03: FDPhat 0.029, Number of Rej. 138
# alpha = 0.02: FDPhat 0.0165, Number of Rej. 121
# [1] "data_1"
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9940
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 8901
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8400
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 7518
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7187
# alpha = 0.75: FDPhat 0.75, Number of Rej. 6875
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6585
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6092
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 5677
# alpha = 0.71: FDPhat 0.7098, Number of Rej. 5535
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5408
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5289
# alpha = 0.68: FDPhat 0.6798, Number of Rej. 4994
# alpha = 0.67: FDPhat 0.67, Number of Rej. 4806
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 4678
# alpha = 0.65: FDPhat 0.65, Number of Rej. 4560
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 4451
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 4075
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 3882
# alpha = 0.61: FDPhat 0.6098, Number of Rej. 3762
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 3686
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3592
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 3489
# alpha = 0.57: FDPhat 0.57, Number of Rej. 3409
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3371
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 3198
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3084
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 2993
# alpha = 0.52: FDPhat 0.52, Number of Rej. 2931
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 2809
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2758
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 2684
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 2557
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2479
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2419
# alpha = 0.45: FDPhat 0.45, Number of Rej. 2389
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2342
# alpha = 0.43: FDPhat 0.4296, Number of Rej. 2251
# alpha = 0.42: FDPhat 0.4197, Number of Rej. 2173
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2108
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2055
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 2022
# alpha = 0.38: FDPhat 0.3798, Number of Rej. 1959
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 1922
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 1873
# alpha = 0.35: FDPhat 0.3497, Number of Rej. 1836
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 1768
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 1707
# alpha = 0.32: FDPhat 0.3196, Number of Rej. 1630
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 1595
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 1574
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 1497
# alpha = 0.28: FDPhat 0.2797, Number of Rej. 1448
# alpha = 0.27: FDPhat 0.2698, Number of Rej. 1386
# alpha = 0.26: FDPhat 0.2593, Number of Rej. 1342
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1256
# alpha = 0.24: FDPhat 0.2393, Number of Rej. 1187
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 1150
# alpha = 0.22: FDPhat 0.2195, Number of Rej. 1107
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1086
# alpha = 0.2: FDPhat 0.1994, Number of Rej. 1008
# alpha = 0.19: FDPhat 0.1895, Number of Rej. 976
# alpha = 0.18: FDPhat 0.1794, Number of Rej. 931
# alpha = 0.17: FDPhat 0.1694, Number of Rej. 903
# alpha = 0.16: FDPhat 0.1594, Number of Rej. 828
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 767
# alpha = 0.14: FDPhat 0.139, Number of Rej. 712
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 662
# alpha = 0.12: FDPhat 0.1193, Number of Rej. 612
# alpha = 0.11: FDPhat 0.1088, Number of Rej. 579
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 542
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 481
# alpha = 0.08: FDPhat 0.0783, Number of Rej. 447
# alpha = 0.07: FDPhat 0.069, Number of Rej. 377
# alpha = 0.06: FDPhat 0.0568, Number of Rej. 264
# alpha = 0.05: FDPhat 0.05, Number of Rej. 220
# alpha = 0.04: FDPhat 0.04, Number of Rej. 200
# alpha = 0.03: FDPhat 0.0288, Number of Rej. 139
# [1] "data_2"
# alpha = 0.82: FDPhat 0.82, Number of Rej. 9921
# alpha = 0.81: FDPhat 0.8099, Number of Rej. 9212
# alpha = 0.8: FDPhat 0.7999, Number of Rej. 8722
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 8121
# alpha = 0.78: FDPhat 0.78, Number of Rej. 7626
# alpha = 0.77: FDPhat 0.77, Number of Rej. 7382
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 7122
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 6821
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6224
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 5669
# alpha = 0.72: FDPhat 0.72, Number of Rej. 5396
# alpha = 0.71: FDPhat 0.71, Number of Rej. 4962
# alpha = 0.7: FDPhat 0.6998, Number of Rej. 4697
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 4383
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 4189
# alpha = 0.67: FDPhat 0.67, Number of Rej. 4006
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 3783
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 3662
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 3593
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 3491
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 3306
# alpha = 0.61: FDPhat 0.6098, Number of Rej. 3239
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 3096
# alpha = 0.59: FDPhat 0.59, Number of Rej. 2968
# alpha = 0.58: FDPhat 0.58, Number of Rej. 2900
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 2722
# alpha = 0.56: FDPhat 0.56, Number of Rej. 2652
# alpha = 0.55: FDPhat 0.55, Number of Rej. 2582
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 2475
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 2423
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2387
# alpha = 0.51: FDPhat 0.5097, Number of Rej. 2319
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2242
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 2182
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2148
# alpha = 0.47: FDPhat 0.47, Number of Rej. 2049
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2021
# alpha = 0.45: FDPhat 0.4496, Number of Rej. 1975
# alpha = 0.44: FDPhat 0.4397, Number of Rej. 1924
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 1894
# alpha = 0.42: FDPhat 0.4197, Number of Rej. 1825
# alpha = 0.41: FDPhat 0.4095, Number of Rej. 1795
# alpha = 0.4: FDPhat 0.3995, Number of Rej. 1757
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 1711
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 1670
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 1630
# alpha = 0.36: FDPhat 0.3594, Number of Rej. 1558
# alpha = 0.35: FDPhat 0.3495, Number of Rej. 1528
# alpha = 0.34: FDPhat 0.34, Number of Rej. 1506
# alpha = 0.33: FDPhat 0.3296, Number of Rej. 1447
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 1413
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 1388
# alpha = 0.3: FDPhat 0.3, Number of Rej. 1350
# alpha = 0.29: FDPhat 0.2893, Number of Rej. 1331
# alpha = 0.28: FDPhat 0.2796, Number of Rej. 1302
# alpha = 0.27: FDPhat 0.2693, Number of Rej. 1192
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1147
# alpha = 0.25: FDPhat 0.2495, Number of Rej. 1094
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1080
# alpha = 0.23: FDPhat 0.2292, Number of Rej. 1021
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 960
# alpha = 0.21: FDPhat 0.2095, Number of Rej. 931
# alpha = 0.2: FDPhat 0.2, Number of Rej. 915
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 885
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 773
# alpha = 0.17: FDPhat 0.1694, Number of Rej. 732
# alpha = 0.16: FDPhat 0.16, Number of Rej. 675
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 614
# alpha = 0.14: FDPhat 0.1388, Number of Rej. 562
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 531
# alpha = 0.12: FDPhat 0.1192, Number of Rej. 453
# alpha = 0.11: FDPhat 0.1091, Number of Rej. 449
# alpha = 0.1: FDPhat 0.0995, Number of Rej. 392
# alpha = 0.09: FDPhat 0.0886, Number of Rej. 316
# alpha = 0.08: FDPhat 0.0778, Number of Rej. 270
# alpha = 0.07: FDPhat 0.0694, Number of Rej. 245
# alpha = 0.06: FDPhat 0.0543, Number of Rej. 92
# alpha = 0.05: FDPhat 0.0471, Number of Rej. 85
# [1] "data_3"
# alpha = 0.81: FDPhat 0.8099, Number of Rej. 9590
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9060
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 8705
# alpha = 0.78: FDPhat 0.78, Number of Rej. 7763
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 7220
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 6914
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 5757
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 5587
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 5268
# alpha = 0.72: FDPhat 0.7198, Number of Rej. 4947
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 4815
# alpha = 0.7: FDPhat 0.7, Number of Rej. 4410
# alpha = 0.69: FDPhat 0.69, Number of Rej. 4235
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 4096
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 3884
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 3802
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 3722
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 3605
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 3498
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 3344
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 3261
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3152
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 3052
# alpha = 0.58: FDPhat 0.58, Number of Rej. 2945
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 2890
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 2829
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 2684
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 2638
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 2542
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2518
# alpha = 0.51: FDPhat 0.51, Number of Rej. 2410
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 2315
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 2288
# alpha = 0.48: FDPhat 0.4797, Number of Rej. 2197
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 2129
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 2029
# alpha = 0.45: FDPhat 0.4497, Number of Rej. 1968
# alpha = 0.44: FDPhat 0.4397, Number of Rej. 1931
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 1873
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 1820
# alpha = 0.41: FDPhat 0.4095, Number of Rej. 1719
# alpha = 0.4: FDPhat 0.4, Number of Rej. 1660
# alpha = 0.39: FDPhat 0.3895, Number of Rej. 1597
# alpha = 0.38: FDPhat 0.3794, Number of Rej. 1534
# alpha = 0.37: FDPhat 0.3697, Number of Rej. 1520
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 1459
# alpha = 0.35: FDPhat 0.3496, Number of Rej. 1396
# alpha = 0.34: FDPhat 0.3395, Number of Rej. 1358
# alpha = 0.33: FDPhat 0.3295, Number of Rej. 1311
# alpha = 0.32: FDPhat 0.3193, Number of Rej. 1284
# alpha = 0.31: FDPhat 0.31, Number of Rej. 1226
# alpha = 0.3: FDPhat 0.2998, Number of Rej. 1201
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 1183
# alpha = 0.28: FDPhat 0.28, Number of Rej. 1143
# alpha = 0.27: FDPhat 0.2695, Number of Rej. 1102
# alpha = 0.26: FDPhat 0.2593, Number of Rej. 1076
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 1037
# alpha = 0.24: FDPhat 0.2396, Number of Rej. 1006
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 979
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 951
# alpha = 0.21: FDPhat 0.2096, Number of Rej. 916
# alpha = 0.2: FDPhat 0.1991, Number of Rej. 894
# alpha = 0.19: FDPhat 0.1895, Number of Rej. 876
# alpha = 0.18: FDPhat 0.1793, Number of Rej. 859
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 820
# alpha = 0.16: FDPhat 0.1596, Number of Rej. 727
# alpha = 0.15: FDPhat 0.1495, Number of Rej. 689
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 665
# alpha = 0.13: FDPhat 0.1297, Number of Rej. 617
# alpha = 0.12: FDPhat 0.1196, Number of Rej. 560
# alpha = 0.11: FDPhat 0.1093, Number of Rej. 503
# alpha = 0.1: FDPhat 0.0989, Number of Rej. 455
# alpha = 0.09: FDPhat 0.0884, Number of Rej. 430
# alpha = 0.08: FDPhat 0.0787, Number of Rej. 394
# alpha = 0.07: FDPhat 0.0682, Number of Rej. 381
# alpha = 0.06: FDPhat 0.0588, Number of Rej. 374
# alpha = 0.05: FDPhat 0.0484, Number of Rej. 351
# alpha = 0.04: FDPhat 0.0382, Number of Rej. 340
# alpha = 0.03: FDPhat 0.0276, Number of Rej. 326
# alpha = 0.02: FDPhat 0.0184, Number of Rej. 217
# [1] "data_4"
# alpha = 0.82: FDPhat 0.8199, Number of Rej. 9912
# alpha = 0.81: FDPhat 0.81, Number of Rej. 9336
# alpha = 0.8: FDPhat 0.8, Number of Rej. 8724
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 8012
# alpha = 0.78: FDPhat 0.78, Number of Rej. 7668
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 7276
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 6997
# alpha = 0.75: FDPhat 0.75, Number of Rej. 6732
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6214
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 5847
# alpha = 0.72: FDPhat 0.7198, Number of Rej. 5518
# alpha = 0.71: FDPhat 0.7098, Number of Rej. 5173
# alpha = 0.7: FDPhat 0.7, Number of Rej. 4783
# alpha = 0.69: FDPhat 0.6898, Number of Rej. 4633
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 4448
# alpha = 0.67: FDPhat 0.6698, Number of Rej. 4216
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 3964
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 3773
# alpha = 0.64: FDPhat 0.64, Number of Rej. 3658
# alpha = 0.63: FDPhat 0.63, Number of Rej. 3443
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 3372
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 3235
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3099
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3019
# alpha = 0.58: FDPhat 0.5797, Number of Rej. 2955
# alpha = 0.57: FDPhat 0.57, Number of Rej. 2865
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 2781
# alpha = 0.55: FDPhat 0.55, Number of Rej. 2651
# alpha = 0.54: FDPhat 0.5397, Number of Rej. 2559
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 2521
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 2476
# alpha = 0.51: FDPhat 0.51, Number of Rej. 2404
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2346
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 2303
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 2247
# alpha = 0.47: FDPhat 0.47, Number of Rej. 2200
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2161
# alpha = 0.45: FDPhat 0.45, Number of Rej. 2109
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2078
# alpha = 0.43: FDPhat 0.43, Number of Rej. 2021
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 1991
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 1943
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 1878
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 1837
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 1765
# alpha = 0.37: FDPhat 0.3697, Number of Rej. 1734
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 1670
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 1606
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 1571
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 1549
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1507
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 1449
# alpha = 0.3: FDPhat 0.2998, Number of Rej. 1401
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 1359
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 1329
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 1271
# alpha = 0.26: FDPhat 0.2594, Number of Rej. 1245
# alpha = 0.25: FDPhat 0.2494, Number of Rej. 1199
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1175
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 1123
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 1043
# alpha = 0.21: FDPhat 0.21, Number of Rej. 1005
# alpha = 0.2: FDPhat 0.2, Number of Rej. 965
# alpha = 0.19: FDPhat 0.1892, Number of Rej. 909
# alpha = 0.18: FDPhat 0.1796, Number of Rej. 835
# alpha = 0.17: FDPhat 0.1687, Number of Rej. 741
# alpha = 0.16: FDPhat 0.1596, Number of Rej. 708
# alpha = 0.15: FDPhat 0.1494, Number of Rej. 656
# alpha = 0.14: FDPhat 0.1392, Number of Rej. 618
# alpha = 0.13: FDPhat 0.1289, Number of Rej. 605
# alpha = 0.12: FDPhat 0.12, Number of Rej. 550
# alpha = 0.11: FDPhat 0.1098, Number of Rej. 492
# alpha = 0.1: FDPhat 0.0989, Number of Rej. 445
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 436
# alpha = 0.08: FDPhat 0.0787, Number of Rej. 432
# alpha = 0.07: FDPhat 0.0687, Number of Rej. 364
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 336
# alpha = 0.05: FDPhat 0.0485, Number of Rej. 309
# alpha = 0.04: FDPhat 0.0389, Number of Rej. 257
# alpha = 0.03: FDPhat 0.0299, Number of Rej. 234
# alpha = 0.02: FDPhat 0.02, Number of Rej. 100
# [1] "data_5"
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9565
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8621
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8043
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7366
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7076
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6548
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 6079
# alpha = 0.72: FDPhat 0.72, Number of Rej. 5614
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 5449
# alpha = 0.7: FDPhat 0.7, Number of Rej. 5200
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5073
# alpha = 0.68: FDPhat 0.68, Number of Rej. 4484
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 4374
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 4221
# alpha = 0.65: FDPhat 0.6498, Number of Rej. 4063
# alpha = 0.64: FDPhat 0.64, Number of Rej. 3958
# alpha = 0.63: FDPhat 0.63, Number of Rej. 3797
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 3728
# alpha = 0.61: FDPhat 0.61, Number of Rej. 3615
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3534
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3382
# alpha = 0.58: FDPhat 0.58, Number of Rej. 3276
# alpha = 0.57: FDPhat 0.5697, Number of Rej. 3170
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3087
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 3029
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 2886
# alpha = 0.53: FDPhat 0.53, Number of Rej. 2821
# alpha = 0.52: FDPhat 0.5197, Number of Rej. 2694
# alpha = 0.51: FDPhat 0.5096, Number of Rej. 2494
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2418
# alpha = 0.49: FDPhat 0.49, Number of Rej. 2339
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 2272
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2224
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2134
# alpha = 0.45: FDPhat 0.4495, Number of Rej. 2051
# alpha = 0.44: FDPhat 0.4395, Number of Rej. 2018
# alpha = 0.43: FDPhat 0.4296, Number of Rej. 1974
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 1946
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 1911
# alpha = 0.4: FDPhat 0.4, Number of Rej. 1855
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 1785
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 1753
# alpha = 0.37: FDPhat 0.3697, Number of Rej. 1658
# alpha = 0.36: FDPhat 0.3594, Number of Rej. 1622
# alpha = 0.35: FDPhat 0.3497, Number of Rej. 1564
# alpha = 0.34: FDPhat 0.3393, Number of Rej. 1497
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 1443
# alpha = 0.32: FDPhat 0.3197, Number of Rej. 1370
# alpha = 0.31: FDPhat 0.3094, Number of Rej. 1309
# alpha = 0.3: FDPhat 0.2994, Number of Rej. 1276
# alpha = 0.29: FDPhat 0.29, Number of Rej. 1245
# alpha = 0.28: FDPhat 0.2794, Number of Rej. 1217
# alpha = 0.27: FDPhat 0.2693, Number of Rej. 1192
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 1158
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 1129
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1080
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 1015
# alpha = 0.22: FDPhat 0.22, Number of Rej. 950
# alpha = 0.21: FDPhat 0.2092, Number of Rej. 932
# alpha = 0.2: FDPhat 0.2, Number of Rej. 895
# alpha = 0.19: FDPhat 0.1899, Number of Rej. 848
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 784
# alpha = 0.17: FDPhat 0.1689, Number of Rej. 746
# alpha = 0.16: FDPhat 0.1593, Number of Rej. 722
# alpha = 0.15: FDPhat 0.1491, Number of Rej. 711
# alpha = 0.14: FDPhat 0.1392, Number of Rej. 697
# alpha = 0.13: FDPhat 0.1293, Number of Rej. 665
# alpha = 0.12: FDPhat 0.1192, Number of Rej. 621
# alpha = 0.11: FDPhat 0.1092, Number of Rej. 586
# alpha = 0.1: FDPhat 0.0987, Number of Rej. 557
# alpha = 0.09: FDPhat 0.0888, Number of Rej. 507
# alpha = 0.08: FDPhat 0.0796, Number of Rej. 490
# alpha = 0.07: FDPhat 0.0697, Number of Rej. 416
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 369
# alpha = 0.05: FDPhat 0.0494, Number of Rej. 324
# alpha = 0.04: FDPhat 0.0387, Number of Rej. 284
# alpha = 0.03: FDPhat 0.0299, Number of Rej. 234
# alpha = 0.02: FDPhat 0.0186, Number of Rej. 215
# alpha = 0.01: FDPhat 0.0089, Number of Rej. 112
# Task completed!
# [1] "data_6"
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9527
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8890
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8539
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7804
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7464
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 7128
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 6693
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 6154
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 5804
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5162
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 4857
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 4643
# alpha = 0.67: FDPhat 0.67, Number of Rej. 4509
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 4211
# alpha = 0.65: FDPhat 0.65, Number of Rej. 4077
# alpha = 0.64: FDPhat 0.6398, Number of Rej. 3901
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 3694
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 3610
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 3502
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3427
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3365
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3221
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3148
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3038
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 2907
# alpha = 0.54: FDPhat 0.54, Number of Rej. 2863
# alpha = 0.53: FDPhat 0.53, Number of Rej. 2821
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2766
# alpha = 0.51: FDPhat 0.51, Number of Rej. 2708
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2626
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 2499
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2400
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2358
# alpha = 0.46: FDPhat 0.4596, Number of Rej. 2230
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2183
# alpha = 0.44: FDPhat 0.4396, Number of Rej. 2095
# alpha = 0.43: FDPhat 0.43, Number of Rej. 2063
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 1977
# alpha = 0.41: FDPhat 0.41, Number of Rej. 1922
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 1866
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 1804
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 1738
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 1660
# alpha = 0.36: FDPhat 0.3597, Number of Rej. 1593
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 1515
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 1481
# alpha = 0.33: FDPhat 0.3295, Number of Rej. 1405
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1332
# alpha = 0.31: FDPhat 0.3094, Number of Rej. 1309
# alpha = 0.3: FDPhat 0.2996, Number of Rej. 1255
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 1194
# alpha = 0.28: FDPhat 0.28, Number of Rej. 1150
# alpha = 0.27: FDPhat 0.2691, Number of Rej. 1085
# alpha = 0.26: FDPhat 0.2594, Number of Rej. 1037
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1012
# alpha = 0.24: FDPhat 0.2392, Number of Rej. 970
# alpha = 0.23: FDPhat 0.2294, Number of Rej. 946
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 919
# alpha = 0.21: FDPhat 0.2095, Number of Rej. 907
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 866
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 859
# alpha = 0.18: FDPhat 0.1795, Number of Rej. 808
# alpha = 0.17: FDPhat 0.1696, Number of Rej. 784
# alpha = 0.16: FDPhat 0.1593, Number of Rej. 678
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 667
# alpha = 0.14: FDPhat 0.1387, Number of Rej. 613
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 594
# alpha = 0.12: FDPhat 0.1191, Number of Rej. 571
# alpha = 0.11: FDPhat 0.1093, Number of Rej. 503
# alpha = 0.1: FDPhat 0.0987, Number of Rej. 456
# alpha = 0.09: FDPhat 0.0896, Number of Rej. 424
# alpha = 0.08: FDPhat 0.0783, Number of Rej. 332
# alpha = 0.07: FDPhat 0.0686, Number of Rej. 306
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 252
# alpha = 0.05: FDPhat 0.0468, Number of Rej. 235
# alpha = 0.04: FDPhat 0.0387, Number of Rej. 181
# alpha = 0.03: FDPhat 0.0294, Number of Rej. 102
# alpha = 0.02: FDPhat 0.02, Number of Rej. 50
# [1] "data_7"
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9928
# alpha = 0.78: FDPhat 0.78, Number of Rej. 9203
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8817
# alpha = 0.76: FDPhat 0.76, Number of Rej. 8129
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7455
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6914
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6540
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6292
# alpha = 0.71: FDPhat 0.71, Number of Rej. 5868
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5505
# alpha = 0.69: FDPhat 0.69, Number of Rej. 5187
# alpha = 0.68: FDPhat 0.68, Number of Rej. 4859
# alpha = 0.67: FDPhat 0.67, Number of Rej. 4524
# alpha = 0.66: FDPhat 0.66, Number of Rej. 4197
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 4033
# alpha = 0.64: FDPhat 0.6398, Number of Rej. 3873
# alpha = 0.63: FDPhat 0.6297, Number of Rej. 3746
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 3612
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 3476
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 3296
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3202
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3011
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 2925
# alpha = 0.56: FDPhat 0.56, Number of Rej. 2850
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 2778
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 2684
# alpha = 0.53: FDPhat 0.5297, Number of Rej. 2562
# alpha = 0.52: FDPhat 0.52, Number of Rej. 2527
# alpha = 0.51: FDPhat 0.5097, Number of Rej. 2466
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2344
# alpha = 0.49: FDPhat 0.4897, Number of Rej. 2279
# alpha = 0.48: FDPhat 0.4796, Number of Rej. 2160
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2094
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2024
# alpha = 0.45: FDPhat 0.45, Number of Rej. 1980
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 1914
# alpha = 0.43: FDPhat 0.4297, Number of Rej. 1878
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 1829
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 1771
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 1751
# alpha = 0.39: FDPhat 0.3896, Number of Rej. 1712
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 1662
# alpha = 0.37: FDPhat 0.3696, Number of Rej. 1629
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 1578
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 1509
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 1468
# alpha = 0.33: FDPhat 0.3293, Number of Rej. 1415
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1382
# alpha = 0.31: FDPhat 0.3095, Number of Rej. 1312
# alpha = 0.3: FDPhat 0.2995, Number of Rej. 1279
# alpha = 0.29: FDPhat 0.2896, Number of Rej. 1236
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 1204
# alpha = 0.27: FDPhat 0.2694, Number of Rej. 1136
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1124
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1048
# alpha = 0.24: FDPhat 0.2397, Number of Rej. 997
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 949
# alpha = 0.22: FDPhat 0.2192, Number of Rej. 917
# alpha = 0.21: FDPhat 0.2098, Number of Rej. 896
# alpha = 0.2: FDPhat 0.1995, Number of Rej. 852
# alpha = 0.19: FDPhat 0.19, Number of Rej. 816
# alpha = 0.18: FDPhat 0.1793, Number of Rej. 781
# alpha = 0.17: FDPhat 0.1698, Number of Rej. 736
# alpha = 0.16: FDPhat 0.16, Number of Rej. 725
# alpha = 0.15: FDPhat 0.1493, Number of Rej. 690
# alpha = 0.14: FDPhat 0.1388, Number of Rej. 634
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 571
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 526
# alpha = 0.11: FDPhat 0.1083, Number of Rej. 508
# alpha = 0.1: FDPhat 0.0984, Number of Rej. 447
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 369
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 352
# alpha = 0.07: FDPhat 0.0679, Number of Rej. 324
# alpha = 0.06: FDPhat 0.0571, Number of Rej. 280
# alpha = 0.05: FDPhat 0.0489, Number of Rej. 225
# alpha = 0.04: FDPhat 0.0361, Number of Rej. 166
# [1] "data_8"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 9820
# alpha = 0.8: FDPhat 0.7999, Number of Rej. 8826
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 8540
# alpha = 0.78: FDPhat 0.78, Number of Rej. 7999
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 7632
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7391
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 7117
# alpha = 0.74: FDPhat 0.74, Number of Rej. 6599
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6351
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 5902
# alpha = 0.71: FDPhat 0.71, Number of Rej. 5610
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5411
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5195
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5015
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 4793
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 4452
# alpha = 0.65: FDPhat 0.65, Number of Rej. 4251
# alpha = 0.64: FDPhat 0.6398, Number of Rej. 4037
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 3949
# alpha = 0.62: FDPhat 0.62, Number of Rej. 3663
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 3550
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3449
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 3359
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3180
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 3103
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 2961
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 2876
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 2758
# alpha = 0.53: FDPhat 0.5297, Number of Rej. 2696
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 2605
# alpha = 0.51: FDPhat 0.51, Number of Rej. 2457
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 2403
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 2348
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 2240
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 2212
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2135
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2067
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2023
# alpha = 0.43: FDPhat 0.43, Number of Rej. 1935
# alpha = 0.42: FDPhat 0.4197, Number of Rej. 1899
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 1803
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 1738
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 1668
# alpha = 0.38: FDPhat 0.38, Number of Rej. 1608
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 1455
# alpha = 0.36: FDPhat 0.3595, Number of Rej. 1402
# alpha = 0.35: FDPhat 0.3496, Number of Rej. 1353
# alpha = 0.34: FDPhat 0.3397, Number of Rej. 1310
# alpha = 0.33: FDPhat 0.3294, Number of Rej. 1287
# alpha = 0.32: FDPhat 0.3195, Number of Rej. 1252
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 1240
# alpha = 0.3: FDPhat 0.2997, Number of Rej. 1218
# alpha = 0.29: FDPhat 0.2895, Number of Rej. 1195
# alpha = 0.28: FDPhat 0.2793, Number of Rej. 1142
# alpha = 0.27: FDPhat 0.2696, Number of Rej. 1124
# alpha = 0.26: FDPhat 0.26, Number of Rej. 1077
# alpha = 0.25: FDPhat 0.2495, Number of Rej. 1046
# alpha = 0.24: FDPhat 0.2393, Number of Rej. 1007
# alpha = 0.23: FDPhat 0.23, Number of Rej. 987
# alpha = 0.22: FDPhat 0.2197, Number of Rej. 965
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 944
# alpha = 0.2: FDPhat 0.2, Number of Rej. 930
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 896
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 856
# alpha = 0.17: FDPhat 0.1696, Number of Rej. 849
# alpha = 0.16: FDPhat 0.1594, Number of Rej. 822
# alpha = 0.15: FDPhat 0.1495, Number of Rej. 776
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 744
# alpha = 0.13: FDPhat 0.1293, Number of Rej. 665
# alpha = 0.12: FDPhat 0.1197, Number of Rej. 635
# alpha = 0.11: FDPhat 0.1089, Number of Rej. 615
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 552
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 501
# alpha = 0.08: FDPhat 0.0789, Number of Rej. 456
# alpha = 0.07: FDPhat 0.0698, Number of Rej. 401
# alpha = 0.06: FDPhat 0.0593, Number of Rej. 354
# alpha = 0.05: FDPhat 0.0484, Number of Rej. 310
# alpha = 0.04: FDPhat 0.0386, Number of Rej. 259
# alpha = 0.03: FDPhat 0.0293, Number of Rej. 205
# alpha = 0.02: FDPhat 0.0199, Number of Rej. 151
# [1] "data_9"
# alpha = 0.8: FDPhat 0.7999, Number of Rej. 9481
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9056
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8736
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 8183
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7937
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 7569
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7384
# alpha = 0.73: FDPhat 0.73, Number of Rej. 7058
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6810
# alpha = 0.71: FDPhat 0.71, Number of Rej. 6593
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 6308
# alpha = 0.69: FDPhat 0.69, Number of Rej. 6054
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5731
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5484
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 5230
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5081
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 4835
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 4552
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 4329
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 4040
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3937
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3816
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 3705
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 3559
# alpha = 0.56: FDPhat 0.5597, Number of Rej. 3441
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3322
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3223
# alpha = 0.53: FDPhat 0.53, Number of Rej. 3119
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3089
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2885
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2838
# alpha = 0.49: FDPhat 0.4896, Number of Rej. 2751
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 2695
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 2616
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 2540
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2432
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2376
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2271
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2187
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2147
# alpha = 0.4: FDPhat 0.3997, Number of Rej. 2099
# alpha = 0.39: FDPhat 0.39, Number of Rej. 1995
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 1882
# alpha = 0.37: FDPhat 0.3696, Number of Rej. 1813
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 1709
# alpha = 0.35: FDPhat 0.3494, Number of Rej. 1617
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 1539
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 1492
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 1469
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 1437
# alpha = 0.3: FDPhat 0.2995, Number of Rej. 1419
# alpha = 0.29: FDPhat 0.2895, Number of Rej. 1361
# alpha = 0.28: FDPhat 0.2794, Number of Rej. 1328
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 1220
# alpha = 0.26: FDPhat 0.2592, Number of Rej. 1192
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1152
# alpha = 0.24: FDPhat 0.2396, Number of Rej. 1110
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 1058
# alpha = 0.22: FDPhat 0.2192, Number of Rej. 1040
# alpha = 0.21: FDPhat 0.2098, Number of Rej. 996
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 961
# alpha = 0.19: FDPhat 0.1892, Number of Rej. 930
# alpha = 0.18: FDPhat 0.1795, Number of Rej. 886
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 838
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 776
# alpha = 0.15: FDPhat 0.1493, Number of Rej. 750
# alpha = 0.14: FDPhat 0.1394, Number of Rej. 667
# alpha = 0.13: FDPhat 0.1294, Number of Rej. 626
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 601
# alpha = 0.11: FDPhat 0.1085, Number of Rej. 544
# alpha = 0.1: FDPhat 0.0983, Number of Rej. 529
# alpha = 0.09: FDPhat 0.0897, Number of Rej. 457
# alpha = 0.08: FDPhat 0.0794, Number of Rej. 378
# alpha = 0.07: FDPhat 0.068, Number of Rej. 338
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 285
# alpha = 0.05: FDPhat 0.0491, Number of Rej. 265
# alpha = 0.04: FDPhat 0.0398, Number of Rej. 176
# alpha = 0.03: FDPhat 0.024, Number of Rej. 125
# alpha = 0.02: FDPhat 0.0185, Number of Rej. 108
# Loading required package: nlme
# This is mgcv 1.8-24. For overview type 'help("mgcv-package")'.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.

# %% [markdown]
# ## Figure generation
# ### Collect the results from the saved file

# %%
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
summary_stats = {}
# Python methods
result_path_py = './temp_result/res_' + data_name + '/result.pickle'
with open(result_path_py, 'rb') as fil:
    result_py = pickle.load(fil)
for method in result_py.keys():
    if len(result_py[method])>0:
        summary_stats[method] = {}
        summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
        summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    else:
        continue
    for fdp,power,alpha,dname in result_py[method]:
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# R methods
result_path_r = './temp_result/res_r_' + data_name
r_method_list = ['ihw', 'adapt', 'bl']
for method in r_method_list:
    res_df = pd.read_table(result_path_r + '/res_' + method, delimiter=',') 
    summary_stats[method] = {}
    summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
    summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    for i in range(res_df.shape[0]):
        fdp,power,alpha,dname = res_df.iloc[i]
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# Delete when there is no result
method_list = list(summary_stats.keys())
for method in method_list:
    if np.sum(summary_stats[method]['Power']) == 0:
        del summary_stats[method]

# %% [markdown]
# ### Generate the FDP and power plot

# %%
marker_list = ['o', 'v', 'p', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C4', 'C3', 'C0', 'C5', 'C8']
method_list = ['adafdr-fast', 'adafdr', 'bl', 'adapt', 'ihw', 'sbh', 'bh']
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
# FDP
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['FDP'], axis=0)
        y_err = np.std(summary_stats[method]['FDP'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
axis_min = min(x_min, y_min)
axis_max = max(x_max, y_max)
plt.plot([axis_min, axis_max], [axis_min, axis_max], linestyle='--', color='k')
plt.legend(loc=2, fontsize=12)
plt.ylabel('FDP', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
# Power 
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['Power'], axis=0)
        y_err = np.std(summary_stats[method]['Power'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
plt.legend(loc=2, fontsize=12)
plt.ylabel('power', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
