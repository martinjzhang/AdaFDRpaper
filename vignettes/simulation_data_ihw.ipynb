# %%
import numpy as np
import adafdr.method as md
import adafdr.data_loader as dl
import matplotlib.pyplot as plt
import pandas as pd
import pickle
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

data_name = 'simu_data_ihw'

# %% [markdown]
# ## Run methods on each simulation datasets
# This may take a while to run. The computed results are already stored in
# - Python methods: `./temp_result/res_ + data_name`
# - R methods: `./temp_result/res_r_ + data_name`
#
# where `data_name` is as defiend above. For those who do not
# want to run these again, they can directly move the figure generation
# section.
#
# For those who wish to run the code to reproduce the results,
# they need to specify the `data_path` below to be the path of
# `AdaFDRpaper_data` on their machine
#
# The Python methods are run by calling `analysis_batch.py` while
# R methods are run by calling `analysis_batch.R`. It is easier to
# run them using `.sh` script but we include them here for
# illustration purpose.

# %%
data_path = '/data3/martin/AdaFDRpaper_data'
input_folder = data_path + '/' + data_name

# %%
# Python methods
# %run analysis_batch.py -i $input_folder -d $data_name
# Out:
# input_folder: /data3/martin/AdaFDRpaper_data/simu_data_ihw
# output_folder: ./temp_result/res_simu_data_ihw
# alpha_list: [0.05, 0.1, 0.15, 0.2]
# # Processing data_5 with alpha=0.05
# # Processing data_5 with alpha=0.10
# # Processing data_5 with alpha=0.15
# # Processing data_5 with alpha=0.20
# # Processing data_2 with alpha=0.05
# # Processing data_2 with alpha=0.10
# # Processing data_2 with alpha=0.15
# # Processing data_2 with alpha=0.20
# # Processing data_0 with alpha=0.05
# # Processing data_0 with alpha=0.10
# # Processing data_0 with alpha=0.15
# # Processing data_0 with alpha=0.20
# # Processing data_3 with alpha=0.05
# # Processing data_3 with alpha=0.10
# # Processing data_3 with alpha=0.15
# # Processing data_3 with alpha=0.20
# # Processing data_7 with alpha=0.05
# # Processing data_7 with alpha=0.10
# # Processing data_7 with alpha=0.15
# # Processing data_7 with alpha=0.20
# # Processing data_9 with alpha=0.05
# # Processing data_9 with alpha=0.10
# # Processing data_9 with alpha=0.15
# # Processing data_9 with alpha=0.20
# # Processing data_4 with alpha=0.05
# # Processing data_4 with alpha=0.10
# # Processing data_4 with alpha=0.15
# # Processing data_4 with alpha=0.20
# # Processing data_6 with alpha=0.05
# # Processing data_6 with alpha=0.10
# # Processing data_6 with alpha=0.15
# # Processing data_6 with alpha=0.20
# # Processing data_1 with alpha=0.05
# # Processing data_1 with alpha=0.10
# # Processing data_1 with alpha=0.15
# # Processing data_1 with alpha=0.20
# # Processing data_8 with alpha=0.05
# # Processing data_8 with alpha=0.10
# # Processing data_8 with alpha=0.15
# # Processing data_8 with alpha=0.20

# %%
# R methods
output_folder = './temp_result/res_r_' + data_name
if data_name in ['data_yeast', 'data_polyester', 'data_polyester_ui']:
    benchmark_bl = 'T'
else:
    benchmark_bl = 'F'

# %%
# %%bash -s "$input_folder" "$output_folder" "$benchmark_bl"
# Rscript analysis_batch.R $1 $2 $3
# Out:
# [1] "input_folder: /data3/martin/AdaFDRpaper_data/simu_data_ihw"
# [1] "output_folder: ./temp_result/res_r_simu_data_ihw"
# [1] "benchmark_bl: F"
# [1] "data_0"
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9879
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9400
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 8820
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8452
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 7980
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7724
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7588
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 7212
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6956
# alpha = 0.71: FDPhat 0.71, Number of Rej. 6730
# alpha = 0.7: FDPhat 0.7, Number of Rej. 6480
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 6301
# alpha = 0.68: FDPhat 0.68, Number of Rej. 6187
# alpha = 0.67: FDPhat 0.67, Number of Rej. 6003
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 5889
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5707
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 5549
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 5342
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 5154
# alpha = 0.61: FDPhat 0.61, Number of Rej. 5020
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4840
# alpha = 0.59: FDPhat 0.59, Number of Rej. 4734
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 4524
# alpha = 0.57: FDPhat 0.57, Number of Rej. 4372
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 4164
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 4065
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3857
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3691
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 3528
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3391
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3308
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 3203
# alpha = 0.48: FDPhat 0.48, Number of Rej. 3150
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 3060
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 3003
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2937
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2885
# alpha = 0.43: FDPhat 0.43, Number of Rej. 2835
# alpha = 0.42: FDPhat 0.42, Number of Rej. 2781
# alpha = 0.41: FDPhat 0.41, Number of Rej. 2761
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2713
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 2673
# alpha = 0.38: FDPhat 0.3798, Number of Rej. 2596
# alpha = 0.37: FDPhat 0.37, Number of Rej. 2500
# alpha = 0.36: FDPhat 0.3597, Number of Rej. 2452
# alpha = 0.35: FDPhat 0.35, Number of Rej. 2420
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 2376
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 2335
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 2283
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 2233
# alpha = 0.3: FDPhat 0.3, Number of Rej. 2210
# alpha = 0.29: FDPhat 0.2896, Number of Rej. 2179
# alpha = 0.28: FDPhat 0.28, Number of Rej. 2111
# alpha = 0.27: FDPhat 0.2698, Number of Rej. 2046
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 2009
# alpha = 0.25: FDPhat 0.2499, Number of Rej. 1941
# alpha = 0.24: FDPhat 0.2395, Number of Rej. 1929
# alpha = 0.23: FDPhat 0.23, Number of Rej. 1874
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1838
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 1774
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1745
# alpha = 0.19: FDPhat 0.1896, Number of Rej. 1709
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 1696
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 1658
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1626
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 1574
# alpha = 0.14: FDPhat 0.1394, Number of Rej. 1528
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 1505
# alpha = 0.12: FDPhat 0.1194, Number of Rej. 1483
# alpha = 0.11: FDPhat 0.1099, Number of Rej. 1456
# alpha = 0.1: FDPhat 0.0995, Number of Rej. 1397
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1370
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 1333
# alpha = 0.07: FDPhat 0.0694, Number of Rej. 1296
# alpha = 0.06: FDPhat 0.0597, Number of Rej. 1257
# alpha = 0.05: FDPhat 0.05, Number of Rej. 1180
# alpha = 0.04: FDPhat 0.0394, Number of Rej. 1143
# alpha = 0.03: FDPhat 0.0298, Number of Rej. 1108
# alpha = 0.02: FDPhat 0.0193, Number of Rej. 881
# alpha = 0.01: FDPhat 0.009, Number of Rej. 665
# Task completed!
# [1] "data_1"
# alpha = 0.8: FDPhat 0.7999, Number of Rej. 9882
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 9250
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8968
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8426
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7925
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 7741
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7411
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 7234
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 6947
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6704
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 6495
# alpha = 0.69: FDPhat 0.69, Number of Rej. 6338
# alpha = 0.68: FDPhat 0.68, Number of Rej. 6190
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5749
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 5657
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5544
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 5252
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 4975
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 4773
# alpha = 0.61: FDPhat 0.61, Number of Rej. 4643
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 4538
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 4440
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 4273
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 4155
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3975
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3933
# alpha = 0.54: FDPhat 0.54, Number of Rej. 3854
# alpha = 0.53: FDPhat 0.53, Number of Rej. 3738
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3670
# alpha = 0.51: FDPhat 0.51, Number of Rej. 3553
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3468
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 3376
# alpha = 0.48: FDPhat 0.48, Number of Rej. 3275
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 3208
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 3120
# alpha = 0.45: FDPhat 0.45, Number of Rej. 3038
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2964
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2903
# alpha = 0.42: FDPhat 0.42, Number of Rej. 2850
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 2790
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2743
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 2666
# alpha = 0.38: FDPhat 0.3798, Number of Rej. 2583
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 2539
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 2501
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 2447
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 2392
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 2347
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 2313
# alpha = 0.31: FDPhat 0.3096, Number of Rej. 2261
# alpha = 0.3: FDPhat 0.2997, Number of Rej. 2232
# alpha = 0.29: FDPhat 0.2896, Number of Rej. 2193
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 2134
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 2099
# alpha = 0.26: FDPhat 0.2596, Number of Rej. 2061
# alpha = 0.25: FDPhat 0.2499, Number of Rej. 2025
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1981
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 1947
# alpha = 0.22: FDPhat 0.2197, Number of Rej. 1921
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 1903
# alpha = 0.2: FDPhat 0.1997, Number of Rej. 1873
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 1828
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1795
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1754
# alpha = 0.16: FDPhat 0.1597, Number of Rej. 1734
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 1695
# alpha = 0.14: FDPhat 0.1396, Number of Rej. 1655
# alpha = 0.13: FDPhat 0.1298, Number of Rej. 1633
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 1594
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1540
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 1526
# alpha = 0.09: FDPhat 0.0897, Number of Rej. 1483
# alpha = 0.08: FDPhat 0.0796, Number of Rej. 1433
# alpha = 0.07: FDPhat 0.0693, Number of Rej. 1399
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 1359
# alpha = 0.05: FDPhat 0.0497, Number of Rej. 1288
# alpha = 0.04: FDPhat 0.0396, Number of Rej. 1187
# alpha = 0.03: FDPhat 0.0296, Number of Rej. 1116
# alpha = 0.02: FDPhat 0.0195, Number of Rej. 1026
# alpha = 0.01: FDPhat 0.0099, Number of Rej. 911
# Task completed!
# [1] "data_2"
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9489
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 9133
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8890
# alpha = 0.76: FDPhat 0.76, Number of Rej. 8607
# alpha = 0.75: FDPhat 0.75, Number of Rej. 8320
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7837
# alpha = 0.73: FDPhat 0.73, Number of Rej. 7659
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 7372
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 7167
# alpha = 0.7: FDPhat 0.7, Number of Rej. 6873
# alpha = 0.69: FDPhat 0.69, Number of Rej. 6612
# alpha = 0.68: FDPhat 0.68, Number of Rej. 6293
# alpha = 0.67: FDPhat 0.67, Number of Rej. 6087
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 5789
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5630
# alpha = 0.64: FDPhat 0.6398, Number of Rej. 5378
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 5204
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 5015
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 4689
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4562
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 4449
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 4318
# alpha = 0.57: FDPhat 0.57, Number of Rej. 4193
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 4071
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3973
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3853
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3763
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 3644
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 3533
# alpha = 0.5: FDPhat 0.4999, Number of Rej. 3473
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 3416
# alpha = 0.48: FDPhat 0.48, Number of Rej. 3369
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 3290
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 3227
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 3165
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 3083
# alpha = 0.43: FDPhat 0.4297, Number of Rej. 3039
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2953
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2879
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2823
# alpha = 0.39: FDPhat 0.39, Number of Rej. 2708
# alpha = 0.38: FDPhat 0.38, Number of Rej. 2579
# alpha = 0.37: FDPhat 0.3697, Number of Rej. 2505
# alpha = 0.36: FDPhat 0.3597, Number of Rej. 2469
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 2407
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 2385
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 2352
# alpha = 0.32: FDPhat 0.32, Number of Rej. 2269
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 2240
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 2194
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 2122
# alpha = 0.28: FDPhat 0.2796, Number of Rej. 2092
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 2064
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 2040
# alpha = 0.25: FDPhat 0.25, Number of Rej. 2016
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1989
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 1951
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1905
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1844
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1815
# alpha = 0.19: FDPhat 0.1896, Number of Rej. 1777
# alpha = 0.18: FDPhat 0.1797, Number of Rej. 1753
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1730
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 1690
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 1654
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 1630
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 1609
# alpha = 0.12: FDPhat 0.1199, Number of Rej. 1560
# alpha = 0.11: FDPhat 0.1095, Number of Rej. 1525
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 1486
# alpha = 0.09: FDPhat 0.0896, Number of Rej. 1451
# alpha = 0.08: FDPhat 0.08, Number of Rej. 1400
# alpha = 0.07: FDPhat 0.07, Number of Rej. 1358
# alpha = 0.06: FDPhat 0.0599, Number of Rej. 1303
# alpha = 0.05: FDPhat 0.05, Number of Rej. 1220
# alpha = 0.04: FDPhat 0.0398, Number of Rej. 1155
# alpha = 0.03: FDPhat 0.0299, Number of Rej. 1071
# alpha = 0.02: FDPhat 0.0199, Number of Rej. 904
# alpha = 0.01: FDPhat 0.0092, Number of Rej. 649
# Task completed!
# [1] "data_3"
# alpha = 0.78: FDPhat 0.78, Number of Rej. 9544
# alpha = 0.77: FDPhat 0.77, Number of Rej. 9091
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 8677
# alpha = 0.75: FDPhat 0.75, Number of Rej. 8311
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7957
# alpha = 0.73: FDPhat 0.73, Number of Rej. 7629
# alpha = 0.72: FDPhat 0.72, Number of Rej. 7214
# alpha = 0.71: FDPhat 0.71, Number of Rej. 6989
# alpha = 0.7: FDPhat 0.7, Number of Rej. 6896
# alpha = 0.69: FDPhat 0.69, Number of Rej. 6725
# alpha = 0.68: FDPhat 0.68, Number of Rej. 6337
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 6193
# alpha = 0.66: FDPhat 0.66, Number of Rej. 6020
# alpha = 0.65: FDPhat 0.65, Number of Rej. 5805
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 5543
# alpha = 0.63: FDPhat 0.63, Number of Rej. 5467
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 5329
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 5109
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4950
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 4771
# alpha = 0.58: FDPhat 0.58, Number of Rej. 4557
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 4394
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 4276
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 4175
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 4034
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3942
# alpha = 0.52: FDPhat 0.5197, Number of Rej. 3798
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3697
# alpha = 0.5: FDPhat 0.4999, Number of Rej. 3619
# alpha = 0.49: FDPhat 0.49, Number of Rej. 3492
# alpha = 0.48: FDPhat 0.48, Number of Rej. 3442
# alpha = 0.47: FDPhat 0.47, Number of Rej. 3366
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 3312
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 3261
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 3189
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 3082
# alpha = 0.42: FDPhat 0.42, Number of Rej. 3000
# alpha = 0.41: FDPhat 0.4098, Number of Rej. 2928
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2881
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 2845
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 2727
# alpha = 0.37: FDPhat 0.3697, Number of Rej. 2678
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 2626
# alpha = 0.35: FDPhat 0.35, Number of Rej. 2566
# alpha = 0.34: FDPhat 0.34, Number of Rej. 2518
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 2434
# alpha = 0.32: FDPhat 0.3197, Number of Rej. 2355
# alpha = 0.31: FDPhat 0.31, Number of Rej. 2297
# alpha = 0.3: FDPhat 0.2998, Number of Rej. 2248
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 2212
# alpha = 0.28: FDPhat 0.2797, Number of Rej. 2177
# alpha = 0.27: FDPhat 0.2696, Number of Rej. 2122
# alpha = 0.26: FDPhat 0.2597, Number of Rej. 2106
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 2046
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 2010
# alpha = 0.23: FDPhat 0.2295, Number of Rej. 1978
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1906
# alpha = 0.21: FDPhat 0.2098, Number of Rej. 1878
# alpha = 0.2: FDPhat 0.1999, Number of Rej. 1836
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 1797
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 1769
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1748
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1720
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 1668
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 1637
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 1609
# alpha = 0.12: FDPhat 0.1199, Number of Rej. 1576
# alpha = 0.11: FDPhat 0.1096, Number of Rej. 1551
# alpha = 0.1: FDPhat 0.0997, Number of Rej. 1505
# alpha = 0.09: FDPhat 0.0897, Number of Rej. 1482
# alpha = 0.08: FDPhat 0.0799, Number of Rej. 1414
# alpha = 0.07: FDPhat 0.0697, Number of Rej. 1378
# alpha = 0.06: FDPhat 0.0597, Number of Rej. 1324
# alpha = 0.05: FDPhat 0.0493, Number of Rej. 1278
# alpha = 0.04: FDPhat 0.0395, Number of Rej. 1190
# alpha = 0.03: FDPhat 0.0295, Number of Rej. 1120
# alpha = 0.02: FDPhat 0.02, Number of Rej. 952
# alpha = 0.01: FDPhat 0.0093, Number of Rej. 750
# Task completed!
# [1] "data_4"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 9672
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9203
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 8736
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8350
# alpha = 0.77: FDPhat 0.77, Number of Rej. 7994
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7508
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7083
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6933
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6696
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 6501
# alpha = 0.71: FDPhat 0.71, Number of Rej. 6286
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 6001
# alpha = 0.69: FDPhat 0.69, Number of Rej. 5835
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5709
# alpha = 0.67: FDPhat 0.67, Number of Rej. 5624
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 5410
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5284
# alpha = 0.64: FDPhat 0.64, Number of Rej. 5111
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 4950
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 4629
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 4391
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4277
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 4177
# alpha = 0.58: FDPhat 0.58, Number of Rej. 3926
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 3838
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3731
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 3629
# alpha = 0.54: FDPhat 0.5397, Number of Rej. 3561
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 3422
# alpha = 0.52: FDPhat 0.5197, Number of Rej. 3296
# alpha = 0.51: FDPhat 0.5097, Number of Rej. 3237
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3140
# alpha = 0.49: FDPhat 0.49, Number of Rej. 3041
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2969
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2911
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 2820
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2712
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2669
# alpha = 0.43: FDPhat 0.4297, Number of Rej. 2611
# alpha = 0.42: FDPhat 0.42, Number of Rej. 2562
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2515
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2465
# alpha = 0.39: FDPhat 0.3896, Number of Rej. 2433
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 2381
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 2342
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 2295
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 2272
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 2213
# alpha = 0.33: FDPhat 0.33, Number of Rej. 2185
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 2154
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 2130
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 2104
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 2078
# alpha = 0.28: FDPhat 0.2797, Number of Rej. 2059
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 2023
# alpha = 0.26: FDPhat 0.26, Number of Rej. 1977
# alpha = 0.25: FDPhat 0.2499, Number of Rej. 1957
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1927
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 1911
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1855
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 1807
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1777
# alpha = 0.19: FDPhat 0.19, Number of Rej. 1732
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1673
# alpha = 0.17: FDPhat 0.1698, Number of Rej. 1637
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1601
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 1575
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 1566
# alpha = 0.13: FDPhat 0.13, Number of Rej. 1508
# alpha = 0.12: FDPhat 0.1199, Number of Rej. 1501
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1467
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 1425
# alpha = 0.09: FDPhat 0.0896, Number of Rej. 1395
# alpha = 0.08: FDPhat 0.0797, Number of Rej. 1355
# alpha = 0.07: FDPhat 0.07, Number of Rej. 1272
# alpha = 0.06: FDPhat 0.0594, Number of Rej. 1229
# alpha = 0.05: FDPhat 0.0496, Number of Rej. 1149
# alpha = 0.04: FDPhat 0.0396, Number of Rej. 1111
# alpha = 0.03: FDPhat 0.0292, Number of Rej. 1028
# alpha = 0.02: FDPhat 0.0196, Number of Rej. 764
# alpha = 0.01: FDPhat 0.0089, Number of Rej. 561
# Task completed!
# [1] "data_5"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 9825
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9453
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 9005
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8594
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8217
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 7814
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7408
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 7282
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6918
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 6615
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6374
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 6162
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 6002
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 5792
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5638
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 5375
# alpha = 0.65: FDPhat 0.65, Number of Rej. 5074
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4966
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 4737
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 4637
# alpha = 0.61: FDPhat 0.6098, Number of Rej. 4521
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4367
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 4274
# alpha = 0.58: FDPhat 0.58, Number of Rej. 4176
# alpha = 0.57: FDPhat 0.57, Number of Rej. 4074
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3884
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 3749
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3573
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3480
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3441
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 3360
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3324
# alpha = 0.49: FDPhat 0.49, Number of Rej. 3249
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 3176
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 3125
# alpha = 0.46: FDPhat 0.46, Number of Rej. 3061
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2987
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2956
# alpha = 0.43: FDPhat 0.43, Number of Rej. 2907
# alpha = 0.42: FDPhat 0.42, Number of Rej. 2862
# alpha = 0.41: FDPhat 0.4098, Number of Rej. 2811
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2778
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 2720
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 2660
# alpha = 0.37: FDPhat 0.37, Number of Rej. 2638
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 2568
# alpha = 0.35: FDPhat 0.3497, Number of Rej. 2522
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 2492
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 2447
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 2382
# alpha = 0.31: FDPhat 0.31, Number of Rej. 2313
# alpha = 0.3: FDPhat 0.2996, Number of Rej. 2243
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 2175
# alpha = 0.28: FDPhat 0.2797, Number of Rej. 2145
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 2086
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 2047
# alpha = 0.25: FDPhat 0.2496, Number of Rej. 2003
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1971
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 1912
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1865
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1839
# alpha = 0.2: FDPhat 0.1999, Number of Rej. 1801
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 1760
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1723
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1677
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1651
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 1616
# alpha = 0.14: FDPhat 0.1394, Number of Rej. 1557
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 1528
# alpha = 0.12: FDPhat 0.1196, Number of Rej. 1472
# alpha = 0.11: FDPhat 0.1099, Number of Rej. 1428
# alpha = 0.1: FDPhat 0.0998, Number of Rej. 1403
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1381
# alpha = 0.08: FDPhat 0.0798, Number of Rej. 1329
# alpha = 0.07: FDPhat 0.0693, Number of Rej. 1269
# alpha = 0.06: FDPhat 0.0593, Number of Rej. 1197
# alpha = 0.05: FDPhat 0.05, Number of Rej. 1100
# alpha = 0.04: FDPhat 0.0394, Number of Rej. 964
# alpha = 0.03: FDPhat 0.0296, Number of Rej. 879
# alpha = 0.02: FDPhat 0.0196, Number of Rej. 816
# alpha = 0.01: FDPhat 0.01, Number of Rej. 602
# Task completed!
# [1] "data_6"
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9642
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 9078
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 8776
# alpha = 0.76: FDPhat 0.76, Number of Rej. 8437
# alpha = 0.75: FDPhat 0.75, Number of Rej. 8104
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 7956
# alpha = 0.73: FDPhat 0.73, Number of Rej. 7607
# alpha = 0.72: FDPhat 0.72, Number of Rej. 7364
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6915
# alpha = 0.7: FDPhat 0.7, Number of Rej. 6570
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 6386
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 5957
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5822
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 5642
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5275
# alpha = 0.64: FDPhat 0.64, Number of Rej. 5141
# alpha = 0.63: FDPhat 0.63, Number of Rej. 4986
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 4729
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 4614
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 4516
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 4403
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 4309
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 4177
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 4028
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3944
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3779
# alpha = 0.53: FDPhat 0.53, Number of Rej. 3617
# alpha = 0.52: FDPhat 0.5197, Number of Rej. 3473
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3428
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3320
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 3187
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 3086
# alpha = 0.47: FDPhat 0.47, Number of Rej. 3015
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 2942
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2899
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2867
# alpha = 0.43: FDPhat 0.4297, Number of Rej. 2816
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2732
# alpha = 0.41: FDPhat 0.4098, Number of Rej. 2645
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 2601
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 2547
# alpha = 0.38: FDPhat 0.38, Number of Rej. 2516
# alpha = 0.37: FDPhat 0.3697, Number of Rej. 2426
# alpha = 0.36: FDPhat 0.3596, Number of Rej. 2411
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 2373
# alpha = 0.34: FDPhat 0.3397, Number of Rej. 2358
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 2295
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 2267
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 2230
# alpha = 0.3: FDPhat 0.3, Number of Rej. 2187
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 2160
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 2108
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 2082
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 2043
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 2006
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1971
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 1956
# alpha = 0.22: FDPhat 0.22, Number of Rej. 1914
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1858
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1825
# alpha = 0.19: FDPhat 0.1899, Number of Rej. 1785
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 1741
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1683
# alpha = 0.16: FDPhat 0.1597, Number of Rej. 1653
# alpha = 0.15: FDPhat 0.1497, Number of Rej. 1617
# alpha = 0.14: FDPhat 0.1397, Number of Rej. 1582
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 1555
# alpha = 0.12: FDPhat 0.1199, Number of Rej. 1501
# alpha = 0.11: FDPhat 0.1095, Number of Rej. 1480
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 1438
# alpha = 0.09: FDPhat 0.0896, Number of Rej. 1406
# alpha = 0.08: FDPhat 0.0799, Number of Rej. 1340
# alpha = 0.07: FDPhat 0.0699, Number of Rej. 1302
# alpha = 0.06: FDPhat 0.06, Number of Rej. 1251
# alpha = 0.05: FDPhat 0.0497, Number of Rej. 1186
# alpha = 0.04: FDPhat 0.0394, Number of Rej. 1143
# alpha = 0.03: FDPhat 0.0294, Number of Rej. 1054
# alpha = 0.02: FDPhat 0.0193, Number of Rej. 882
# alpha = 0.01: FDPhat 0.0099, Number of Rej. 707
# Task completed!
# [1] "data_7"
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 9982
# alpha = 0.78: FDPhat 0.78, Number of Rej. 9217
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 8562
# alpha = 0.76: FDPhat 0.76, Number of Rej. 8241
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7896
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 7636
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 7339
# alpha = 0.72: FDPhat 0.72, Number of Rej. 7107
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6845
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 6648
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 6369
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 6023
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5846
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 5621
# alpha = 0.65: FDPhat 0.65, Number of Rej. 5434
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 5237
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 5084
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 4844
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 4788
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 4646
# alpha = 0.59: FDPhat 0.59, Number of Rej. 4534
# alpha = 0.58: FDPhat 0.58, Number of Rej. 4438
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 4290
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 4206
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 4103
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3999
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3848
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 3805
# alpha = 0.51: FDPhat 0.51, Number of Rej. 3718
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3640
# alpha = 0.49: FDPhat 0.49, Number of Rej. 3535
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 3428
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 3324
# alpha = 0.46: FDPhat 0.46, Number of Rej. 3261
# alpha = 0.45: FDPhat 0.45, Number of Rej. 3149
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 3010
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2929
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2870
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2808
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 2759
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 2710
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 2668
# alpha = 0.37: FDPhat 0.37, Number of Rej. 2576
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 2540
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 2469
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 2385
# alpha = 0.33: FDPhat 0.3296, Number of Rej. 2336
# alpha = 0.32: FDPhat 0.3197, Number of Rej. 2293
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 2253
# alpha = 0.3: FDPhat 0.2996, Number of Rej. 2216
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 2187
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 2133
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 2084
# alpha = 0.26: FDPhat 0.2595, Number of Rej. 2046
# alpha = 0.25: FDPhat 0.2496, Number of Rej. 1991
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1950
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 1920
# alpha = 0.22: FDPhat 0.2195, Number of Rej. 1895
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1844
# alpha = 0.2: FDPhat 0.1999, Number of Rej. 1811
# alpha = 0.19: FDPhat 0.1896, Number of Rej. 1772
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1729
# alpha = 0.17: FDPhat 0.1697, Number of Rej. 1691
# alpha = 0.16: FDPhat 0.1597, Number of Rej. 1666
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 1635
# alpha = 0.14: FDPhat 0.1395, Number of Rej. 1599
# alpha = 0.13: FDPhat 0.1295, Number of Rej. 1552
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 1527
# alpha = 0.11: FDPhat 0.1098, Number of Rej. 1475
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 1438
# alpha = 0.09: FDPhat 0.0895, Number of Rej. 1396
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 1358
# alpha = 0.07: FDPhat 0.07, Number of Rej. 1329
# alpha = 0.06: FDPhat 0.0598, Number of Rej. 1288
# alpha = 0.05: FDPhat 0.05, Number of Rej. 1200
# alpha = 0.04: FDPhat 0.0395, Number of Rej. 1139
# alpha = 0.03: FDPhat 0.03, Number of Rej. 1035
# alpha = 0.02: FDPhat 0.0195, Number of Rej. 921
# alpha = 0.01: FDPhat 0.0088, Number of Rej. 791
# Task completed!
# [1] "data_8"
# alpha = 0.81: FDPhat 0.8099, Number of Rej. 10022
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9574
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 9362
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 9102
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 8835
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 7888
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7612
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7380
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 7142
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6849
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6685
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 6374
# alpha = 0.69: FDPhat 0.69, Number of Rej. 6125
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5893
# alpha = 0.67: FDPhat 0.67, Number of Rej. 5654
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 5539
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5402
# alpha = 0.64: FDPhat 0.64, Number of Rej. 5225
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 5055
# alpha = 0.62: FDPhat 0.62, Number of Rej. 4934
# alpha = 0.61: FDPhat 0.61, Number of Rej. 4820
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4732
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 4543
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 4387
# alpha = 0.57: FDPhat 0.57, Number of Rej. 4302
# alpha = 0.56: FDPhat 0.56, Number of Rej. 4161
# alpha = 0.55: FDPhat 0.55, Number of Rej. 4102
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3968
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3801
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 3736
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3669
# alpha = 0.5: FDPhat 0.4999, Number of Rej. 3567
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 3466
# alpha = 0.48: FDPhat 0.48, Number of Rej. 3350
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 3269
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 3181
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 3128
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 3088
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 3033
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 3001
# alpha = 0.41: FDPhat 0.41, Number of Rej. 2910
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2853
# alpha = 0.39: FDPhat 0.39, Number of Rej. 2808
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 2715
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 2674
# alpha = 0.36: FDPhat 0.36, Number of Rej. 2592
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 2535
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 2486
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 2434
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 2379
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 2307
# alpha = 0.3: FDPhat 0.3, Number of Rej. 2260
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 2185
# alpha = 0.28: FDPhat 0.2796, Number of Rej. 2121
# alpha = 0.27: FDPhat 0.2698, Number of Rej. 2087
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 2059
# alpha = 0.25: FDPhat 0.25, Number of Rej. 2020
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1971
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 1949
# alpha = 0.22: FDPhat 0.2197, Number of Rej. 1903
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1872
# alpha = 0.2: FDPhat 0.1999, Number of Rej. 1846
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 1802
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1768
# alpha = 0.17: FDPhat 0.1697, Number of Rej. 1750
# alpha = 0.16: FDPhat 0.1595, Number of Rej. 1712
# alpha = 0.15: FDPhat 0.1496, Number of Rej. 1678
# alpha = 0.14: FDPhat 0.1397, Number of Rej. 1632
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 1613
# alpha = 0.12: FDPhat 0.1196, Number of Rej. 1564
# alpha = 0.11: FDPhat 0.1095, Number of Rej. 1544
# alpha = 0.1: FDPhat 0.0995, Number of Rej. 1477
# alpha = 0.09: FDPhat 0.0896, Number of Rej. 1418
# alpha = 0.08: FDPhat 0.0797, Number of Rej. 1380
# alpha = 0.07: FDPhat 0.0698, Number of Rej. 1333
# alpha = 0.06: FDPhat 0.06, Number of Rej. 1301
# alpha = 0.05: FDPhat 0.05, Number of Rej. 1261
# alpha = 0.04: FDPhat 0.0398, Number of Rej. 1181
# alpha = 0.03: FDPhat 0.0293, Number of Rej. 1057
# alpha = 0.02: FDPhat 0.0193, Number of Rej. 985
# alpha = 0.01: FDPhat 0.0098, Number of Rej. 305
# Task completed!
# [1] "data_9"
# alpha = 0.8: FDPhat 0.8, Number of Rej. 10064
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9694
# alpha = 0.78: FDPhat 0.78, Number of Rej. 9044
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8613
# alpha = 0.76: FDPhat 0.76, Number of Rej. 8220
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7799
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 7567
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 7402
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6950
# alpha = 0.71: FDPhat 0.71, Number of Rej. 6737
# alpha = 0.7: FDPhat 0.7, Number of Rej. 6469
# alpha = 0.69: FDPhat 0.69, Number of Rej. 6206
# alpha = 0.68: FDPhat 0.68, Number of Rej. 6056
# alpha = 0.67: FDPhat 0.6698, Number of Rej. 5697
# alpha = 0.66: FDPhat 0.66, Number of Rej. 5573
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5462
# alpha = 0.64: FDPhat 0.64, Number of Rej. 5355
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 5257
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 5072
# alpha = 0.61: FDPhat 0.6098, Number of Rej. 4877
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 4754
# alpha = 0.59: FDPhat 0.59, Number of Rej. 4680
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 4473
# alpha = 0.57: FDPhat 0.57, Number of Rej. 4337
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 4204
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 4065
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3973
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 3871
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 3805
# alpha = 0.51: FDPhat 0.5097, Number of Rej. 3645
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3518
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 3475
# alpha = 0.48: FDPhat 0.48, Number of Rej. 3421
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 3324
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 3205
# alpha = 0.45: FDPhat 0.45, Number of Rej. 3149
# alpha = 0.44: FDPhat 0.4397, Number of Rej. 3070
# alpha = 0.43: FDPhat 0.43, Number of Rej. 3000
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2958
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2862
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2771
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 2683
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 2614
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 2568
# alpha = 0.36: FDPhat 0.3597, Number of Rej. 2513
# alpha = 0.35: FDPhat 0.35, Number of Rej. 2443
# alpha = 0.34: FDPhat 0.3397, Number of Rej. 2390
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 2349
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 2282
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 2223
# alpha = 0.3: FDPhat 0.2998, Number of Rej. 2188
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 2130
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 2087
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 2047
# alpha = 0.26: FDPhat 0.26, Number of Rej. 2004
# alpha = 0.25: FDPhat 0.2499, Number of Rej. 1949
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1918
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 1880
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1838
# alpha = 0.21: FDPhat 0.21, Number of Rej. 1805
# alpha = 0.2: FDPhat 0.1997, Number of Rej. 1768
# alpha = 0.19: FDPhat 0.1895, Number of Rej. 1726
# alpha = 0.18: FDPhat 0.18, Number of Rej. 1700
# alpha = 0.17: FDPhat 0.1694, Number of Rej. 1682
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1614
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 1581
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 1551
# alpha = 0.13: FDPhat 0.13, Number of Rej. 1508
# alpha = 0.12: FDPhat 0.1197, Number of Rej. 1487
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1449
# alpha = 0.1: FDPhat 0.0997, Number of Rej. 1414
# alpha = 0.09: FDPhat 0.0897, Number of Rej. 1383
# alpha = 0.08: FDPhat 0.0794, Number of Rej. 1322
# alpha = 0.07: FDPhat 0.0698, Number of Rej. 1289
# alpha = 0.06: FDPhat 0.0598, Number of Rej. 1220
# alpha = 0.05: FDPhat 0.0498, Number of Rej. 1144
# alpha = 0.04: FDPhat 0.0396, Number of Rej. 1087
# alpha = 0.03: FDPhat 0.0298, Number of Rej. 973
# alpha = 0.02: FDPhat 0.0189, Number of Rej. 846
# alpha = 0.01: FDPhat 0.0098, Number of Rej. 716
# Task completed!
# Loading required package: nlme
# This is mgcv 1.8-24. For overview type 'help("mgcv-package")'.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# Warning messages:
# 1: Quick-TRANSfer stage steps exceeded maximum (= 1000000)
# 2: Quick-TRANSfer stage steps exceeded maximum (= 1000000)
# 3: Quick-TRANSfer stage steps exceeded maximum (= 1000000)
# 4: Quick-TRANSfer stage steps exceeded maximum (= 1000000)
# 5: Quick-TRANSfer stage steps exceeded maximum (= 1000000)
# 6: Quick-TRANSfer stage steps exceeded maximum (= 1000000)
# 7: Quick-TRANSfer stage steps exceeded maximum (= 1000000)
# 8: Quick-TRANSfer stage steps exceeded maximum (= 1000000)
# 9: Quick-TRANSfer stage steps exceeded maximum (= 1000000)
# 10: Quick-TRANSfer stage steps exceeded maximum (= 1000000)

# %% [markdown]
# ## Figure generation
# ### Collect the results from the saved file

# %%
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
summary_stats = {}
# Python methods
result_path_py = './temp_result/res_' + data_name + '/result.pickle'
with open(result_path_py, 'rb') as fil:
    result_py = pickle.load(fil)
for method in result_py.keys():
    if len(result_py[method])>0:
        summary_stats[method] = {}
        summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
        summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    else:
        continue
    for fdp,power,alpha,dname in result_py[method]:
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# R methods
result_path_r = './temp_result/res_r_' + data_name
r_method_list = ['ihw', 'adapt', 'bl']
for method in r_method_list:
    res_df = pd.read_table(result_path_r + '/res_' + method, delimiter=',') 
    summary_stats[method] = {}
    summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
    summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    for i in range(res_df.shape[0]):
        fdp,power,alpha,dname = res_df.iloc[i]
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# Delete when there is no result
method_list = list(summary_stats.keys())
for method in method_list:
    if np.sum(summary_stats[method]['Power']) == 0:
        del summary_stats[method]

# %% [markdown]
# ### Generate the FDP and power plot

# %%
marker_list = ['o', 'v', 'p', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C4', 'C3', 'C0', 'C5', 'C8']
method_list = ['adafdr-fast', 'adafdr', 'bl', 'adapt', 'ihw', 'sbh', 'bh']
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
# FDP
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['FDP'], axis=0)
        y_err = np.std(summary_stats[method]['FDP'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
axis_min = min(x_min, y_min)
axis_max = max(x_max, y_max)
plt.plot([axis_min, axis_max], [axis_min, axis_max], linestyle='--', color='k')
plt.legend(loc=2, fontsize=12)
plt.ylabel('FDP', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
# Power 
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['Power'], axis=0)
        y_err = np.std(summary_stats[method]['Power'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
plt.legend(loc=2, fontsize=12)
plt.ylabel('power', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
