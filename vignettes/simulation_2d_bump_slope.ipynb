# %%
import numpy as np
import adafdr.method as md
import adafdr.data_loader as dl
import matplotlib.pyplot as plt
import pandas as pd
import pickle
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

data_name = 'simu_2d_bump_slope'

# %% [markdown]
# ## Run methods on each simulation datasets
# This may take a while to run. The computed results are already stored in
# - Python methods: `./temp_result/res_ + data_name`
# - R methods: `./temp_result/res_r_ + data_name`
#
# where `data_name` is as defiend above. For those who do not
# want to run these again, they can directly move the figure generation
# section.
#
# For those who wish to run the code to reproduce the results,
# they need to specify the `data_path` below to be the path of
# `AdaFDRpaper_data` on their machine
#
# The Python methods are run by calling `analysis_batch.py` while
# R methods are run by calling `analysis_batch.R`. It is easier to
# run them using `.sh` script but we include them here for
# illustration purpose.

# %%
data_path = '/data3/martin/AdaFDRpaper_data'
input_folder = data_path + '/' + data_name

# %%
# Python methods
# %run analysis_batch.py -i $input_folder -d $data_name
# Out:
# input_folder: /data3/martin/AdaFDRpaper_data/simu_2d_bump_slope
# output_folder: ./temp_result/res_simu_2d_bump_slope
# alpha_list: [0.05, 0.1, 0.15, 0.2]
# # Processing data_5 with alpha=0.05
# # Processing data_5 with alpha=0.10
# # Processing data_5 with alpha=0.15
# # Processing data_5 with alpha=0.20
# # Processing data_2 with alpha=0.05
# # Processing data_2 with alpha=0.10
# # Processing data_2 with alpha=0.15
# # Processing data_2 with alpha=0.20
# # Processing data_0 with alpha=0.05
# # Processing data_0 with alpha=0.10
# # Processing data_0 with alpha=0.15
# # Processing data_0 with alpha=0.20
# # Processing data_3 with alpha=0.05
# # Processing data_3 with alpha=0.10
# # Processing data_3 with alpha=0.15
# # Processing data_3 with alpha=0.20
# # Processing data_7 with alpha=0.05
# # Processing data_7 with alpha=0.10
# # Processing data_7 with alpha=0.15
# # Processing data_7 with alpha=0.20
# # Processing data_9 with alpha=0.05
# # Processing data_9 with alpha=0.10
# # Processing data_9 with alpha=0.15
# # Processing data_9 with alpha=0.20
# # Processing data_4 with alpha=0.05
# # Processing data_4 with alpha=0.10
# # Processing data_4 with alpha=0.15
# # Processing data_4 with alpha=0.20
# # Processing data_6 with alpha=0.05
# # Processing data_6 with alpha=0.10
# # Processing data_6 with alpha=0.15
# # Processing data_6 with alpha=0.20
# # Processing data_1 with alpha=0.05
# # Processing data_1 with alpha=0.10
# # Processing data_1 with alpha=0.15
# # Processing data_1 with alpha=0.20
# # Processing data_8 with alpha=0.05
# # Processing data_8 with alpha=0.10
# # Processing data_8 with alpha=0.15
# # Processing data_8 with alpha=0.20

# %%
# R methods
output_folder = './temp_result/res_r_' + data_name
if data_name in ['data_yeast', 'data_polyester', 'data_polyester_ui']:
    benchmark_bl = 'T'
else:
    benchmark_bl = 'F'

# %%
# %%bash -s "$input_folder" "$output_folder" "$benchmark_bl"
# Rscript analysis_batch.R $1 $2 $3
# Out:
# [1] "input_folder: /data3/martin/AdaFDRpaper_data/simu_2d_bump_slope"
# [1] "output_folder: ./temp_result/res_r_simu_2d_bump_slope"
# [1] "benchmark_bl: F"
# [1] "data_0"
# alpha = 0.81: FDPhat 0.8099, Number of Rej. 9702
# alpha = 0.8: FDPhat 0.8, Number of Rej. 8999
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 8492
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8149
# alpha = 0.77: FDPhat 0.77, Number of Rej. 7686
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7075
# alpha = 0.75: FDPhat 0.75, Number of Rej. 6699
# alpha = 0.74: FDPhat 0.74, Number of Rej. 6300
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 6046
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 5872
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 5654
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5491
# alpha = 0.69: FDPhat 0.69, Number of Rej. 5148
# alpha = 0.68: FDPhat 0.68, Number of Rej. 4925
# alpha = 0.67: FDPhat 0.67, Number of Rej. 4712
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 4501
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 4153
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4005
# alpha = 0.63: FDPhat 0.63, Number of Rej. 3916
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 3822
# alpha = 0.61: FDPhat 0.61, Number of Rej. 3774
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3677
# alpha = 0.59: FDPhat 0.59, Number of Rej. 3563
# alpha = 0.58: FDPhat 0.58, Number of Rej. 3483
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3304
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3176
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3140
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3034
# alpha = 0.53: FDPhat 0.5297, Number of Rej. 2958
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2908
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2869
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 2773
# alpha = 0.49: FDPhat 0.49, Number of Rej. 2696
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 2586
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2526
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2434
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2312
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2233
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2203
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2117
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 2033
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2005
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 1981
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 1931
# alpha = 0.37: FDPhat 0.3697, Number of Rej. 1888
# alpha = 0.36: FDPhat 0.36, Number of Rej. 1839
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 1789
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 1743
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 1689
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1573
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 1501
# alpha = 0.3: FDPhat 0.2995, Number of Rej. 1469
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 1432
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 1383
# alpha = 0.27: FDPhat 0.2693, Number of Rej. 1344
# alpha = 0.26: FDPhat 0.2597, Number of Rej. 1217
# alpha = 0.25: FDPhat 0.2496, Number of Rej. 1178
# alpha = 0.24: FDPhat 0.2396, Number of Rej. 1152
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 1096
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 1084
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 1073
# alpha = 0.2: FDPhat 0.1992, Number of Rej. 1009
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 928
# alpha = 0.18: FDPhat 0.1795, Number of Rej. 919
# alpha = 0.17: FDPhat 0.17, Number of Rej. 853
# alpha = 0.16: FDPhat 0.1588, Number of Rej. 762
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 707
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 694
# alpha = 0.13: FDPhat 0.1297, Number of Rej. 640
# alpha = 0.12: FDPhat 0.1197, Number of Rej. 585
# alpha = 0.11: FDPhat 0.1087, Number of Rej. 552
# alpha = 0.1: FDPhat 0.0985, Number of Rej. 528
# alpha = 0.09: FDPhat 0.09, Number of Rej. 489
# alpha = 0.08: FDPhat 0.0797, Number of Rej. 477
# alpha = 0.07: FDPhat 0.0685, Number of Rej. 394
# alpha = 0.06: FDPhat 0.0576, Number of Rej. 330
# alpha = 0.05: FDPhat 0.0492, Number of Rej. 305
# alpha = 0.04: FDPhat 0.039, Number of Rej. 231
# alpha = 0.03: FDPhat 0.0282, Number of Rej. 213
# [1] "data_1"
# alpha = 0.81: FDPhat 0.8099, Number of Rej. 9843
# alpha = 0.8: FDPhat 0.7999, Number of Rej. 9522
# alpha = 0.79: FDPhat 0.79, Number of Rej. 9000
# alpha = 0.78: FDPhat 0.78, Number of Rej. 8685
# alpha = 0.77: FDPhat 0.77, Number of Rej. 8390
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7891
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7480
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 7137
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6873
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 6709
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6380
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 6072
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5860
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5581
# alpha = 0.67: FDPhat 0.67, Number of Rej. 5400
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 5257
# alpha = 0.65: FDPhat 0.65, Number of Rej. 5005
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4750
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 4598
# alpha = 0.62: FDPhat 0.62, Number of Rej. 4426
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 4225
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4097
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3882
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 3760
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3683
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3620
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 3512
# alpha = 0.54: FDPhat 0.54, Number of Rej. 3450
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3293
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3158
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2975
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2894
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 2784
# alpha = 0.48: FDPhat 0.4797, Number of Rej. 2708
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2641
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 2559
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2436
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2342
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2319
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2236
# alpha = 0.41: FDPhat 0.41, Number of Rej. 2166
# alpha = 0.4: FDPhat 0.3997, Number of Rej. 2114
# alpha = 0.39: FDPhat 0.3895, Number of Rej. 2046
# alpha = 0.38: FDPhat 0.38, Number of Rej. 2029
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 1968
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 1951
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 1884
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 1768
# alpha = 0.33: FDPhat 0.3297, Number of Rej. 1735
# alpha = 0.32: FDPhat 0.3196, Number of Rej. 1630
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 1610
# alpha = 0.3: FDPhat 0.3, Number of Rej. 1480
# alpha = 0.29: FDPhat 0.29, Number of Rej. 1445
# alpha = 0.28: FDPhat 0.2797, Number of Rej. 1412
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 1368
# alpha = 0.26: FDPhat 0.2595, Number of Rej. 1318
# alpha = 0.25: FDPhat 0.2494, Number of Rej. 1287
# alpha = 0.24: FDPhat 0.2397, Number of Rej. 1260
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 1180
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1137
# alpha = 0.21: FDPhat 0.2094, Number of Rej. 1108
# alpha = 0.2: FDPhat 0.1993, Number of Rej. 1069
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 1044
# alpha = 0.18: FDPhat 0.18, Number of Rej. 1000
# alpha = 0.17: FDPhat 0.1692, Number of Rej. 916
# alpha = 0.16: FDPhat 0.1593, Number of Rej. 885
# alpha = 0.15: FDPhat 0.1493, Number of Rej. 804
# alpha = 0.14: FDPhat 0.1396, Number of Rej. 709
# alpha = 0.13: FDPhat 0.1295, Number of Rej. 687
# alpha = 0.12: FDPhat 0.1193, Number of Rej. 637
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 629
# alpha = 0.1: FDPhat 0.0985, Number of Rej. 609
# alpha = 0.09: FDPhat 0.0892, Number of Rej. 583
# alpha = 0.08: FDPhat 0.0784, Number of Rej. 510
# alpha = 0.07: FDPhat 0.0691, Number of Rej. 492
# alpha = 0.06: FDPhat 0.0588, Number of Rej. 459
# alpha = 0.05: FDPhat 0.0494, Number of Rej. 445
# alpha = 0.04: FDPhat 0.038, Number of Rej. 342
# alpha = 0.03: FDPhat 0.0285, Number of Rej. 281
# alpha = 0.02: FDPhat 0.0167, Number of Rej. 180
# alpha = 0.01: FDPhat 0.0063, Number of Rej. 158
# Task completed!
# [1] "data_2"
# alpha = 0.81: FDPhat 0.8099, Number of Rej. 9676
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9010
# alpha = 0.79: FDPhat 0.79, Number of Rej. 8661
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 8305
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 7906
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7500
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7348
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7026
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6770
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6575
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6205
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5832
# alpha = 0.69: FDPhat 0.6898, Number of Rej. 5613
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 5498
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5107
# alpha = 0.66: FDPhat 0.66, Number of Rej. 4932
# alpha = 0.65: FDPhat 0.65, Number of Rej. 4774
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 4641
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 4474
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 4322
# alpha = 0.61: FDPhat 0.61, Number of Rej. 4228
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4100
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3923
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3844
# alpha = 0.57: FDPhat 0.57, Number of Rej. 3765
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3575
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 3461
# alpha = 0.54: FDPhat 0.54, Number of Rej. 3400
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3278
# alpha = 0.52: FDPhat 0.52, Number of Rej. 3177
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3081
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3006
# alpha = 0.49: FDPhat 0.4897, Number of Rej. 2902
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 2828
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 2735
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 2614
# alpha = 0.45: FDPhat 0.4497, Number of Rej. 2555
# alpha = 0.44: FDPhat 0.44, Number of Rej. 2466
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2406
# alpha = 0.42: FDPhat 0.4197, Number of Rej. 2340
# alpha = 0.41: FDPhat 0.4096, Number of Rej. 2273
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 2156
# alpha = 0.39: FDPhat 0.3896, Number of Rej. 2128
# alpha = 0.38: FDPhat 0.38, Number of Rej. 2050
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 1944
# alpha = 0.36: FDPhat 0.36, Number of Rej. 1850
# alpha = 0.35: FDPhat 0.3497, Number of Rej. 1793
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 1752
# alpha = 0.33: FDPhat 0.3296, Number of Rej. 1717
# alpha = 0.32: FDPhat 0.32, Number of Rej. 1672
# alpha = 0.31: FDPhat 0.3095, Number of Rej. 1609
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 1577
# alpha = 0.29: FDPhat 0.2894, Number of Rej. 1517
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 1447
# alpha = 0.27: FDPhat 0.2696, Number of Rej. 1365
# alpha = 0.26: FDPhat 0.2596, Number of Rej. 1329
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 1297
# alpha = 0.24: FDPhat 0.2396, Number of Rej. 1248
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 1197
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1174
# alpha = 0.21: FDPhat 0.2095, Number of Rej. 1131
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1071
# alpha = 0.19: FDPhat 0.1893, Number of Rej. 1025
# alpha = 0.18: FDPhat 0.1794, Number of Rej. 981
# alpha = 0.17: FDPhat 0.1693, Number of Rej. 939
# alpha = 0.16: FDPhat 0.1597, Number of Rej. 889
# alpha = 0.15: FDPhat 0.1494, Number of Rej. 803
# alpha = 0.14: FDPhat 0.1387, Number of Rej. 757
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 693
# alpha = 0.12: FDPhat 0.12, Number of Rej. 625
# alpha = 0.11: FDPhat 0.1095, Number of Rej. 612
# alpha = 0.1: FDPhat 0.0995, Number of Rej. 573
# alpha = 0.09: FDPhat 0.0886, Number of Rej. 542
# alpha = 0.08: FDPhat 0.0789, Number of Rej. 532
# alpha = 0.07: FDPhat 0.0684, Number of Rej. 497
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 453
# alpha = 0.05: FDPhat 0.0488, Number of Rej. 410
# alpha = 0.04: FDPhat 0.0386, Number of Rej. 363
# alpha = 0.03: FDPhat 0.0272, Number of Rej. 331
# alpha = 0.02: FDPhat 0.0175, Number of Rej. 286
# alpha = 0.01: FDPhat 0.0056, Number of Rej. 179
# Task completed!
# [1] "data_3"
# alpha = 0.82: FDPhat 0.82, Number of Rej. 9803
# alpha = 0.81: FDPhat 0.8099, Number of Rej. 9116
# alpha = 0.8: FDPhat 0.8, Number of Rej. 8703
# alpha = 0.79: FDPhat 0.79, Number of Rej. 8104
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 7875
# alpha = 0.77: FDPhat 0.77, Number of Rej. 7447
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 6986
# alpha = 0.75: FDPhat 0.75, Number of Rej. 6820
# alpha = 0.74: FDPhat 0.74, Number of Rej. 6422
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 6056
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 5798
# alpha = 0.71: FDPhat 0.71, Number of Rej. 5551
# alpha = 0.7: FDPhat 0.7, Number of Rej. 5266
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 4970
# alpha = 0.68: FDPhat 0.68, Number of Rej. 4740
# alpha = 0.67: FDPhat 0.6698, Number of Rej. 4616
# alpha = 0.66: FDPhat 0.66, Number of Rej. 4176
# alpha = 0.65: FDPhat 0.6498, Number of Rej. 4063
# alpha = 0.64: FDPhat 0.6398, Number of Rej. 3970
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 3666
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 3589
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 3453
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3264
# alpha = 0.59: FDPhat 0.59, Number of Rej. 3134
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 3063
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 2988
# alpha = 0.56: FDPhat 0.56, Number of Rej. 2900
# alpha = 0.55: FDPhat 0.55, Number of Rej. 2740
# alpha = 0.54: FDPhat 0.5397, Number of Rej. 2668
# alpha = 0.53: FDPhat 0.5297, Number of Rej. 2560
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2443
# alpha = 0.51: FDPhat 0.5097, Number of Rej. 2331
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2222
# alpha = 0.49: FDPhat 0.4897, Number of Rej. 2179
# alpha = 0.48: FDPhat 0.4797, Number of Rej. 2122
# alpha = 0.47: FDPhat 0.47, Number of Rej. 2047
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 1958
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 1887
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 1844
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 1770
# alpha = 0.42: FDPhat 0.4195, Number of Rej. 1733
# alpha = 0.41: FDPhat 0.4098, Number of Rej. 1657
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 1538
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 1460
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 1440
# alpha = 0.37: FDPhat 0.37, Number of Rej. 1400
# alpha = 0.36: FDPhat 0.3594, Number of Rej. 1369
# alpha = 0.35: FDPhat 0.3493, Number of Rej. 1337
# alpha = 0.34: FDPhat 0.3395, Number of Rej. 1302
# alpha = 0.33: FDPhat 0.3294, Number of Rej. 1278
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1229
# alpha = 0.31: FDPhat 0.3095, Number of Rej. 1176
# alpha = 0.3: FDPhat 0.3, Number of Rej. 1120
# alpha = 0.29: FDPhat 0.29, Number of Rej. 1045
# alpha = 0.28: FDPhat 0.2791, Number of Rej. 1014
# alpha = 0.27: FDPhat 0.2691, Number of Rej. 1007
# alpha = 0.26: FDPhat 0.2597, Number of Rej. 1001
# alpha = 0.25: FDPhat 0.2497, Number of Rej. 977
# alpha = 0.24: FDPhat 0.2392, Number of Rej. 928
# alpha = 0.23: FDPhat 0.2291, Number of Rej. 895
# alpha = 0.22: FDPhat 0.2197, Number of Rej. 865
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 848
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 806
# alpha = 0.19: FDPhat 0.1889, Number of Rej. 794
# alpha = 0.18: FDPhat 0.1794, Number of Rej. 758
# alpha = 0.17: FDPhat 0.1698, Number of Rej. 742
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 701
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 647
# alpha = 0.14: FDPhat 0.1391, Number of Rej. 611
# alpha = 0.13: FDPhat 0.1282, Number of Rej. 546
# alpha = 0.12: FDPhat 0.1199, Number of Rej. 517
# alpha = 0.11: FDPhat 0.11, Number of Rej. 491
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 462
# alpha = 0.09: FDPhat 0.0887, Number of Rej. 451
# alpha = 0.08: FDPhat 0.0794, Number of Rej. 441
# alpha = 0.07: FDPhat 0.069, Number of Rej. 406
# alpha = 0.06: FDPhat 0.0591, Number of Rej. 389
# alpha = 0.05: FDPhat 0.0482, Number of Rej. 353
# alpha = 0.04: FDPhat 0.0394, Number of Rej. 279
# alpha = 0.03: FDPhat 0.0271, Number of Rej. 258
# alpha = 0.02: FDPhat 0.0196, Number of Rej. 255
# [1] "data_4"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 9605
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9045
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 8705
# alpha = 0.78: FDPhat 0.78, Number of Rej. 7995
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 7772
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7266
# alpha = 0.75: FDPhat 0.75, Number of Rej. 6707
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6293
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6125
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 5822
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 5592
# alpha = 0.7: FDPhat 0.7, Number of Rej. 5143
# alpha = 0.69: FDPhat 0.69, Number of Rej. 4861
# alpha = 0.68: FDPhat 0.68, Number of Rej. 4778
# alpha = 0.67: FDPhat 0.6698, Number of Rej. 4504
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 4348
# alpha = 0.65: FDPhat 0.65, Number of Rej. 4260
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4022
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 3937
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 3837
# alpha = 0.61: FDPhat 0.61, Number of Rej. 3687
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 3496
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 3379
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3321
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3262
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3125
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 2907
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 2832
# alpha = 0.53: FDPhat 0.53, Number of Rej. 2736
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2668
# alpha = 0.51: FDPhat 0.5096, Number of Rej. 2647
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2536
# alpha = 0.49: FDPhat 0.49, Number of Rej. 2439
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 2384
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2322
# alpha = 0.46: FDPhat 0.4596, Number of Rej. 2226
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2174
# alpha = 0.44: FDPhat 0.4396, Number of Rej. 2145
# alpha = 0.43: FDPhat 0.4296, Number of Rej. 2109
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2051
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 1987
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 1953
# alpha = 0.39: FDPhat 0.3895, Number of Rej. 1887
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 1790
# alpha = 0.37: FDPhat 0.3695, Number of Rej. 1735
# alpha = 0.36: FDPhat 0.3596, Number of Rej. 1710
# alpha = 0.35: FDPhat 0.35, Number of Rej. 1680
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 1639
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 1564
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 1544
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 1482
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 1444
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 1404
# alpha = 0.28: FDPhat 0.2795, Number of Rej. 1349
# alpha = 0.27: FDPhat 0.27, Number of Rej. 1300
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1270
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1224
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1205
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 1166
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1105
# alpha = 0.21: FDPhat 0.2096, Number of Rej. 1078
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1030
# alpha = 0.19: FDPhat 0.1892, Number of Rej. 1004
# alpha = 0.18: FDPhat 0.1794, Number of Rej. 970
# alpha = 0.17: FDPhat 0.17, Number of Rej. 912
# alpha = 0.16: FDPhat 0.1593, Number of Rej. 854
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 814
# alpha = 0.14: FDPhat 0.1394, Number of Rej. 782
# alpha = 0.13: FDPhat 0.1295, Number of Rej. 780
# alpha = 0.12: FDPhat 0.1197, Number of Rej. 760
# alpha = 0.11: FDPhat 0.1099, Number of Rej. 728
# alpha = 0.1: FDPhat 0.0984, Number of Rej. 620
# alpha = 0.09: FDPhat 0.0895, Number of Rej. 581
# alpha = 0.08: FDPhat 0.0789, Number of Rej. 558
# alpha = 0.07: FDPhat 0.0696, Number of Rej. 546
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 454
# alpha = 0.05: FDPhat 0.0482, Number of Rej. 436
# alpha = 0.04: FDPhat 0.0394, Number of Rej. 381
# alpha = 0.03: FDPhat 0.0285, Number of Rej. 316
# alpha = 0.02: FDPhat 0.0183, Number of Rej. 219
# [1] "data_5"
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9390
# alpha = 0.79: FDPhat 0.79, Number of Rej. 8852
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 8296
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 8072
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7828
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 7530
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7265
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 7026
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6650
# alpha = 0.71: FDPhat 0.71, Number of Rej. 6410
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 6082
# alpha = 0.69: FDPhat 0.6898, Number of Rej. 5884
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 5724
# alpha = 0.67: FDPhat 0.67, Number of Rej. 5524
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 5227
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 5056
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 4887
# alpha = 0.63: FDPhat 0.63, Number of Rej. 4735
# alpha = 0.62: FDPhat 0.62, Number of Rej. 4589
# alpha = 0.61: FDPhat 0.61, Number of Rej. 4464
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4322
# alpha = 0.59: FDPhat 0.59, Number of Rej. 4229
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 4130
# alpha = 0.57: FDPhat 0.57, Number of Rej. 3988
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3850
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3720
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3609
# alpha = 0.53: FDPhat 0.53, Number of Rej. 3521
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3464
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 3278
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 3073
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 2940
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 2899
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 2819
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2702
# alpha = 0.45: FDPhat 0.4497, Number of Rej. 2504
# alpha = 0.44: FDPhat 0.44, Number of Rej. 2450
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2319
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2232
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 2170
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2033
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 1985
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 1911
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 1852
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 1817
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 1761
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 1701
# alpha = 0.33: FDPhat 0.3297, Number of Rej. 1674
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1623
# alpha = 0.31: FDPhat 0.31, Number of Rej. 1555
# alpha = 0.3: FDPhat 0.2995, Number of Rej. 1519
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 1459
# alpha = 0.28: FDPhat 0.2796, Number of Rej. 1420
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 1371
# alpha = 0.26: FDPhat 0.26, Number of Rej. 1327
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1244
# alpha = 0.24: FDPhat 0.2396, Number of Rej. 1206
# alpha = 0.23: FDPhat 0.2295, Number of Rej. 1146
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1069
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 1030
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 956
# alpha = 0.19: FDPhat 0.1896, Number of Rej. 902
# alpha = 0.18: FDPhat 0.1791, Number of Rej. 843
# alpha = 0.17: FDPhat 0.169, Number of Rej. 799
# alpha = 0.16: FDPhat 0.16, Number of Rej. 775
# alpha = 0.15: FDPhat 0.1492, Number of Rej. 764
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 737
# alpha = 0.13: FDPhat 0.1287, Number of Rej. 715
# alpha = 0.12: FDPhat 0.1192, Number of Rej. 688
# alpha = 0.11: FDPhat 0.1091, Number of Rej. 660
# alpha = 0.1: FDPhat 0.0998, Number of Rej. 581
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 512
# alpha = 0.08: FDPhat 0.0799, Number of Rej. 488
# alpha = 0.07: FDPhat 0.0687, Number of Rej. 451
# alpha = 0.06: FDPhat 0.0591, Number of Rej. 406
# alpha = 0.05: FDPhat 0.0499, Number of Rej. 361
# alpha = 0.04: FDPhat 0.0385, Number of Rej. 312
# alpha = 0.03: FDPhat 0.0293, Number of Rej. 239
# alpha = 0.02: FDPhat 0.02, Number of Rej. 200
# alpha = 0.01: FDPhat 0.0082, Number of Rej. 122
# Task completed!
# [1] "data_6"
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 9745
# alpha = 0.76: FDPhat 0.76, Number of Rej. 9124
# alpha = 0.75: FDPhat 0.75, Number of Rej. 8416
# alpha = 0.74: FDPhat 0.74, Number of Rej. 8053
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 7383
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6835
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6695
# alpha = 0.7: FDPhat 0.7, Number of Rej. 6403
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 6091
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5750
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5562
# alpha = 0.66: FDPhat 0.66, Number of Rej. 5370
# alpha = 0.65: FDPhat 0.65, Number of Rej. 5125
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4975
# alpha = 0.63: FDPhat 0.63, Number of Rej. 4808
# alpha = 0.62: FDPhat 0.62, Number of Rej. 4568
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 4301
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4165
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3875
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3694
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3597
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3488
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3426
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3242
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3059
# alpha = 0.52: FDPhat 0.52, Number of Rej. 2779
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2677
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2620
# alpha = 0.49: FDPhat 0.49, Number of Rej. 2545
# alpha = 0.48: FDPhat 0.4796, Number of Rej. 2479
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 2433
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 2412
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2343
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2264
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2196
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2136
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 2077
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2038
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 1939
# alpha = 0.38: FDPhat 0.3798, Number of Rej. 1888
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 1855
# alpha = 0.36: FDPhat 0.3597, Number of Rej. 1810
# alpha = 0.35: FDPhat 0.3497, Number of Rej. 1756
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 1707
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 1643
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1626
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 1594
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 1534
# alpha = 0.29: FDPhat 0.29, Number of Rej. 1500
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 1461
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 1335
# alpha = 0.26: FDPhat 0.2593, Number of Rej. 1284
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 1257
# alpha = 0.24: FDPhat 0.2399, Number of Rej. 1238
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 1201
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1128
# alpha = 0.21: FDPhat 0.2095, Number of Rej. 1093
# alpha = 0.2: FDPhat 0.1994, Number of Rej. 1048
# alpha = 0.19: FDPhat 0.1899, Number of Rej. 995
# alpha = 0.18: FDPhat 0.1793, Number of Rej. 976
# alpha = 0.17: FDPhat 0.1693, Number of Rej. 963
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 913
# alpha = 0.15: FDPhat 0.1492, Number of Rej. 878
# alpha = 0.14: FDPhat 0.14, Number of Rej. 850
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 810
# alpha = 0.12: FDPhat 0.12, Number of Rej. 725
# alpha = 0.11: FDPhat 0.1098, Number of Rej. 674
# alpha = 0.1: FDPhat 0.0988, Number of Rej. 658
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 615
# alpha = 0.08: FDPhat 0.0799, Number of Rej. 538
# alpha = 0.07: FDPhat 0.069, Number of Rej. 478
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 454
# alpha = 0.05: FDPhat 0.0482, Number of Rej. 394
# alpha = 0.04: FDPhat 0.0394, Number of Rej. 330
# alpha = 0.03: FDPhat 0.0294, Number of Rej. 272
# alpha = 0.02: FDPhat 0.0177, Number of Rej. 226
# alpha = 0.01: FDPhat 0.0088, Number of Rej. 114
# Task completed!
# [1] "data_7"
# alpha = 0.81: FDPhat 0.81, Number of Rej. 9925
# alpha = 0.8: FDPhat 0.8, Number of Rej. 9500
# alpha = 0.79: FDPhat 0.79, Number of Rej. 8714
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 8347
# alpha = 0.77: FDPhat 0.77, Number of Rej. 7769
# alpha = 0.76: FDPhat 0.76, Number of Rej. 7475
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7187
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 6741
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6484
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6246
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 5854
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 5574
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 5324
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5109
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 4929
# alpha = 0.66: FDPhat 0.66, Number of Rej. 4629
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 4404
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4333
# alpha = 0.63: FDPhat 0.63, Number of Rej. 4208
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 4053
# alpha = 0.61: FDPhat 0.6098, Number of Rej. 3926
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3834
# alpha = 0.59: FDPhat 0.59, Number of Rej. 3717
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3644
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3569
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3458
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3350
# alpha = 0.54: FDPhat 0.54, Number of Rej. 3215
# alpha = 0.53: FDPhat 0.5297, Number of Rej. 3096
# alpha = 0.52: FDPhat 0.5197, Number of Rej. 2942
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2916
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2866
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 2701
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 2640
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2562
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2495
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2370
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2314
# alpha = 0.43: FDPhat 0.43, Number of Rej. 2263
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2163
# alpha = 0.41: FDPhat 0.4096, Number of Rej. 2090
# alpha = 0.4: FDPhat 0.3996, Number of Rej. 2057
# alpha = 0.39: FDPhat 0.39, Number of Rej. 2031
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 1954
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 1893
# alpha = 0.36: FDPhat 0.36, Number of Rej. 1853
# alpha = 0.35: FDPhat 0.35, Number of Rej. 1783
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 1748
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 1704
# alpha = 0.32: FDPhat 0.3197, Number of Rej. 1642
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 1562
# alpha = 0.3: FDPhat 0.3, Number of Rej. 1530
# alpha = 0.29: FDPhat 0.2895, Number of Rej. 1482
# alpha = 0.28: FDPhat 0.2796, Number of Rej. 1420
# alpha = 0.27: FDPhat 0.27, Number of Rej. 1363
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 1339
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1276
# alpha = 0.24: FDPhat 0.2393, Number of Rej. 1216
# alpha = 0.23: FDPhat 0.2294, Number of Rej. 1190
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 1175
# alpha = 0.21: FDPhat 0.2091, Number of Rej. 1095
# alpha = 0.2: FDPhat 0.1996, Number of Rej. 1062
# alpha = 0.19: FDPhat 0.1893, Number of Rej. 1025
# alpha = 0.18: FDPhat 0.1797, Number of Rej. 985
# alpha = 0.17: FDPhat 0.17, Number of Rej. 959
# alpha = 0.16: FDPhat 0.1592, Number of Rej. 898
# alpha = 0.15: FDPhat 0.1492, Number of Rej. 858
# alpha = 0.14: FDPhat 0.1393, Number of Rej. 840
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 818
# alpha = 0.12: FDPhat 0.1195, Number of Rej. 778
# alpha = 0.11: FDPhat 0.1099, Number of Rej. 737
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 713
# alpha = 0.09: FDPhat 0.089, Number of Rej. 618
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 591
# alpha = 0.07: FDPhat 0.0695, Number of Rej. 561
# alpha = 0.06: FDPhat 0.0594, Number of Rej. 539
# alpha = 0.05: FDPhat 0.05, Number of Rej. 520
# alpha = 0.04: FDPhat 0.0399, Number of Rej. 426
# alpha = 0.03: FDPhat 0.0297, Number of Rej. 370
# alpha = 0.02: FDPhat 0.0197, Number of Rej. 355
# [1] "data_8"
# alpha = 0.78: FDPhat 0.78, Number of Rej. 9777
# alpha = 0.77: FDPhat 0.77, Number of Rej. 9091
# alpha = 0.76: FDPhat 0.76, Number of Rej. 8654
# alpha = 0.75: FDPhat 0.7499, Number of Rej. 8253
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 7870
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 7439
# alpha = 0.72: FDPhat 0.72, Number of Rej. 7185
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 6757
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 6444
# alpha = 0.69: FDPhat 0.69, Number of Rej. 6290
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 5985
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 5807
# alpha = 0.66: FDPhat 0.66, Number of Rej. 5467
# alpha = 0.65: FDPhat 0.65, Number of Rej. 5305
# alpha = 0.64: FDPhat 0.64, Number of Rej. 4908
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 4625
# alpha = 0.62: FDPhat 0.6199, Number of Rej. 4401
# alpha = 0.61: FDPhat 0.61, Number of Rej. 4192
# alpha = 0.6: FDPhat 0.6, Number of Rej. 4065
# alpha = 0.59: FDPhat 0.59, Number of Rej. 3890
# alpha = 0.58: FDPhat 0.5797, Number of Rej. 3812
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 3647
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3568
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3462
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3271
# alpha = 0.53: FDPhat 0.5297, Number of Rej. 3094
# alpha = 0.52: FDPhat 0.52, Number of Rej. 3002
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 2923
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2846
# alpha = 0.49: FDPhat 0.49, Number of Rej. 2747
# alpha = 0.48: FDPhat 0.4797, Number of Rej. 2641
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 2531
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 2468
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2365
# alpha = 0.44: FDPhat 0.44, Number of Rej. 2300
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2212
# alpha = 0.42: FDPhat 0.4196, Number of Rej. 2145
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 2109
# alpha = 0.4: FDPhat 0.3996, Number of Rej. 2052
# alpha = 0.39: FDPhat 0.39, Number of Rej. 1977
# alpha = 0.38: FDPhat 0.3795, Number of Rej. 1934
# alpha = 0.37: FDPhat 0.3695, Number of Rej. 1835
# alpha = 0.36: FDPhat 0.36, Number of Rej. 1814
# alpha = 0.35: FDPhat 0.35, Number of Rej. 1763
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 1674
# alpha = 0.33: FDPhat 0.3297, Number of Rej. 1638
# alpha = 0.32: FDPhat 0.32, Number of Rej. 1575
# alpha = 0.31: FDPhat 0.3096, Number of Rej. 1489
# alpha = 0.3: FDPhat 0.3, Number of Rej. 1420
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 1370
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 1344
# alpha = 0.27: FDPhat 0.2696, Number of Rej. 1276
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 1216
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1204
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1171
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 1141
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 1093
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 1068
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1046
# alpha = 0.19: FDPhat 0.1892, Number of Rej. 1020
# alpha = 0.18: FDPhat 0.1792, Number of Rej. 971
# alpha = 0.17: FDPhat 0.1693, Number of Rej. 933
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 870
# alpha = 0.15: FDPhat 0.1492, Number of Rej. 851
# alpha = 0.14: FDPhat 0.1389, Number of Rej. 792
# alpha = 0.13: FDPhat 0.129, Number of Rej. 744
# alpha = 0.12: FDPhat 0.119, Number of Rej. 706
# alpha = 0.11: FDPhat 0.11, Number of Rej. 673
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 644
# alpha = 0.09: FDPhat 0.0896, Number of Rej. 547
# alpha = 0.08: FDPhat 0.0798, Number of Rej. 489
# alpha = 0.07: FDPhat 0.0696, Number of Rej. 474
# alpha = 0.06: FDPhat 0.0583, Number of Rej. 446
# alpha = 0.05: FDPhat 0.0495, Number of Rej. 424
# alpha = 0.04: FDPhat 0.0386, Number of Rej. 311
# alpha = 0.03: FDPhat 0.028, Number of Rej. 286
# [1] "data_9"
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 10007
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 9533
# alpha = 0.77: FDPhat 0.77, Number of Rej. 9020
# alpha = 0.76: FDPhat 0.76, Number of Rej. 8411
# alpha = 0.75: FDPhat 0.75, Number of Rej. 7591
# alpha = 0.74: FDPhat 0.74, Number of Rej. 7142
# alpha = 0.73: FDPhat 0.73, Number of Rej. 6799
# alpha = 0.72: FDPhat 0.72, Number of Rej. 6385
# alpha = 0.71: FDPhat 0.71, Number of Rej. 6234
# alpha = 0.7: FDPhat 0.7, Number of Rej. 5980
# alpha = 0.69: FDPhat 0.69, Number of Rej. 5732
# alpha = 0.68: FDPhat 0.68, Number of Rej. 5534
# alpha = 0.67: FDPhat 0.67, Number of Rej. 5036
# alpha = 0.66: FDPhat 0.66, Number of Rej. 4894
# alpha = 0.65: FDPhat 0.65, Number of Rej. 4634
# alpha = 0.64: FDPhat 0.6398, Number of Rej. 4420
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 4291
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 4185
# alpha = 0.61: FDPhat 0.61, Number of Rej. 4005
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3902
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3741
# alpha = 0.58: FDPhat 0.58, Number of Rej. 3633
# alpha = 0.57: FDPhat 0.57, Number of Rej. 3523
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3355
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3164
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3047
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 2914
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2835
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2773
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2710
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 2607
# alpha = 0.48: FDPhat 0.4797, Number of Rej. 2556
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 2506
# alpha = 0.46: FDPhat 0.4596, Number of Rej. 2441
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2390
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2353
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2231
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2156
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2125
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 2076
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 2034
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 1973
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 1947
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 1906
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 1841
# alpha = 0.34: FDPhat 0.34, Number of Rej. 1800
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 1770
# alpha = 0.32: FDPhat 0.32, Number of Rej. 1722
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 1649
# alpha = 0.3: FDPhat 0.2997, Number of Rej. 1605
# alpha = 0.29: FDPhat 0.2894, Number of Rej. 1548
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 1490
# alpha = 0.27: FDPhat 0.2698, Number of Rej. 1401
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1347
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1296
# alpha = 0.24: FDPhat 0.2394, Number of Rej. 1278
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 1231
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1155
# alpha = 0.21: FDPhat 0.21, Number of Rej. 1100
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1065
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 1001
# alpha = 0.18: FDPhat 0.1795, Number of Rej. 975
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 936
# alpha = 0.16: FDPhat 0.1593, Number of Rej. 854
# alpha = 0.15: FDPhat 0.1493, Number of Rej. 817
# alpha = 0.14: FDPhat 0.1393, Number of Rej. 732
# alpha = 0.13: FDPhat 0.1293, Number of Rej. 719
# alpha = 0.12: FDPhat 0.1192, Number of Rej. 713
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 693
# alpha = 0.1: FDPhat 0.0984, Number of Rej. 620
# alpha = 0.09: FDPhat 0.0895, Number of Rej. 592
# alpha = 0.08: FDPhat 0.0791, Number of Rej. 569
# alpha = 0.07: FDPhat 0.0696, Number of Rej. 546
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 504
# alpha = 0.05: FDPhat 0.0491, Number of Rej. 468
# alpha = 0.04: FDPhat 0.0387, Number of Rej. 413
# alpha = 0.03: FDPhat 0.0271, Number of Rej. 295
# alpha = 0.02: FDPhat 0.0187, Number of Rej. 267
# Loading required package: nlme
# This is mgcv 1.8-24. For overview type 'help("mgcv-package")'.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.

# %% [markdown]
# ## Figure generation
# ### Collect the results from the saved file

# %%
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
summary_stats = {}
# Python methods
result_path_py = './temp_result/res_' + data_name + '/result.pickle'
with open(result_path_py, 'rb') as fil:
    result_py = pickle.load(fil)
for method in result_py.keys():
    if len(result_py[method])>0:
        summary_stats[method] = {}
        summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
        summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    else:
        continue
    for fdp,power,alpha,dname in result_py[method]:
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# R methods
result_path_r = './temp_result/res_r_' + data_name
r_method_list = ['ihw', 'adapt', 'bl']
for method in r_method_list:
    res_df = pd.read_table(result_path_r + '/res_' + method, delimiter=',') 
    summary_stats[method] = {}
    summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
    summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    for i in range(res_df.shape[0]):
        fdp,power,alpha,dname = res_df.iloc[i]
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# Delete when there is no result
method_list = list(summary_stats.keys())
for method in method_list:
    if np.sum(summary_stats[method]['Power']) == 0:
        del summary_stats[method]

# %% [markdown]
# ### Generate the FDP and power plot

# %%
marker_list = ['o', 'v', 'p', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C4', 'C3', 'C0', 'C5', 'C8']
method_list = ['adafdr-fast', 'adafdr', 'bl', 'adapt', 'ihw', 'sbh', 'bh']
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
# FDP
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['FDP'], axis=0)
        y_err = np.std(summary_stats[method]['FDP'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
axis_min = min(x_min, y_min)
axis_max = max(x_max, y_max)
plt.plot([axis_min, axis_max], [axis_min, axis_max], linestyle='--', color='k')
plt.legend(loc=2, fontsize=12)
plt.ylabel('FDP', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
# Power 
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['Power'], axis=0)
        y_err = np.std(summary_stats[method]['Power'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
plt.legend(loc=2, fontsize=12)
plt.ylabel('power', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
