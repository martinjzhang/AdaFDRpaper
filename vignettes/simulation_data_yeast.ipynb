# %%
import numpy as np
import adafdr.method as md
import adafdr.data_loader as dl
import matplotlib.pyplot as plt
import pandas as pd
import pickle
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

data_name = 'data_yeast'

# %% [markdown]
# ## Run methods on each simulation datasets
# This may take a while to run. The computed results are already stored in
# - Python methods: `./temp_result/res_ + data_name`
# - R methods: `./temp_result/res_r_ + data_name`
#
# where `data_name` is as defiend above. For those who do not
# want to run these again, they can directly move the figure generation
# section.
#
# For those who wish to run the code to reproduce the results,
# they need to specify the `data_path` below to be the path of
# `AdaFDRpaper_data` on their machine
#
# The Python methods are run by calling `analysis_batch.py` while
# R methods are run by calling `analysis_batch.R`. It is easier to
# run them using `.sh` script but we include them here for
# illustration purpose.

# %%
data_path = '/data3/martin/AdaFDRpaper_data'
input_folder = data_path + '/' + data_name

# %%
# Python methods
# %run analysis_batch.py -i $input_folder -d $data_name
# Out:
# input_folder: /data3/martin/AdaFDRpaper_data/data_yeast
# output_folder: ./temp_result/res_data_yeast
# alpha_list: [0.05, 0.1, 0.15, 0.2]
# # Processing data_5 with alpha=0.05
# # Processing data_5 with alpha=0.10
# # Processing data_5 with alpha=0.15
# # Processing data_5 with alpha=0.20
# # Processing data_2 with alpha=0.05
# # Processing data_2 with alpha=0.10
# # Processing data_2 with alpha=0.15
# # Processing data_2 with alpha=0.20
# # Processing data_0 with alpha=0.05
# # Processing data_0 with alpha=0.10
# # Processing data_0 with alpha=0.15
# # Processing data_0 with alpha=0.20
# # Processing data_3 with alpha=0.05
# # Processing data_3 with alpha=0.10
# # Processing data_3 with alpha=0.15
# # Processing data_3 with alpha=0.20
# # Processing data_7 with alpha=0.05
# # Processing data_7 with alpha=0.10
# # Processing data_7 with alpha=0.15
# # Processing data_7 with alpha=0.20
# # Processing data_9 with alpha=0.05
# # Processing data_9 with alpha=0.10
# # Processing data_9 with alpha=0.15
# # Processing data_9 with alpha=0.20
# # Processing data_4 with alpha=0.05
# # Processing data_4 with alpha=0.10
# # Processing data_4 with alpha=0.15
# # Processing data_4 with alpha=0.20
# # Processing data_6 with alpha=0.05
# # Processing data_6 with alpha=0.10
# # Processing data_6 with alpha=0.15
# # Processing data_6 with alpha=0.20
# # Processing data_1 with alpha=0.05
# # Processing data_1 with alpha=0.10
# # Processing data_1 with alpha=0.15
# # Processing data_1 with alpha=0.20
# # Processing data_8 with alpha=0.05
# # Processing data_8 with alpha=0.10
# # Processing data_8 with alpha=0.15
# # Processing data_8 with alpha=0.20

# %%
# R methods
output_folder = './temp_result/res_r_' + data_name
if data_name in ['data_yeast', 'data_polyester', 'data_polyester_ui']:
    benchmark_bl = 'T'
else:
    benchmark_bl = 'F'

# %%
# %%bash -s "$input_folder" "$output_folder" "$benchmark_bl"
# Rscript analysis_batch.R $1 $2 $3
# Out:
# [1] "input_folder: /data3/martin/AdaFDRpaper_data/data_yeast"
# [1] "output_folder: ./temp_result/res_r_data_yeast"
# [1] "benchmark_bl: T"
# [1] "data_0"
# alpha = 0.87: FDPhat 0.8699, Number of Rej. 3174
# alpha = 0.86: FDPhat 0.8599, Number of Rej. 3140
# alpha = 0.85: FDPhat 0.8497, Number of Rej. 3087
# alpha = 0.84: FDPhat 0.8398, Number of Rej. 3022
# alpha = 0.83: FDPhat 0.8298, Number of Rej. 2967
# alpha = 0.82: FDPhat 0.8199, Number of Rej. 2921
# alpha = 0.81: FDPhat 0.8097, Number of Rej. 2854
# alpha = 0.8: FDPhat 0.8, Number of Rej. 2815
# alpha = 0.79: FDPhat 0.7898, Number of Rej. 2773
# alpha = 0.78: FDPhat 0.7796, Number of Rej. 2741
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 2708
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 2653
# alpha = 0.75: FDPhat 0.7498, Number of Rej. 2622
# alpha = 0.74: FDPhat 0.7398, Number of Rej. 2598
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 2577
# alpha = 0.72: FDPhat 0.7199, Number of Rej. 2528
# alpha = 0.71: FDPhat 0.71, Number of Rej. 2486
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 2426
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 2393
# alpha = 0.68: FDPhat 0.68, Number of Rej. 2378
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 2348
# alpha = 0.66: FDPhat 0.66, Number of Rej. 2300
# alpha = 0.65: FDPhat 0.6496, Number of Rej. 2232
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 2194
# alpha = 0.63: FDPhat 0.6296, Number of Rej. 2168
# alpha = 0.62: FDPhat 0.6197, Number of Rej. 2127
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 2071
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 2034
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 2026
# alpha = 0.58: FDPhat 0.5796, Number of Rej. 1965
# alpha = 0.57: FDPhat 0.5697, Number of Rej. 1943
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 1888
# alpha = 0.55: FDPhat 0.55, Number of Rej. 1840
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 1806
# alpha = 0.53: FDPhat 0.5295, Number of Rej. 1798
# alpha = 0.52: FDPhat 0.5196, Number of Rej. 1788
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 1771
# alpha = 0.5: FDPhat 0.5, Number of Rej. 1760
# alpha = 0.49: FDPhat 0.4895, Number of Rej. 1718
# alpha = 0.48: FDPhat 0.48, Number of Rej. 1698
# alpha = 0.47: FDPhat 0.47, Number of Rej. 1681
# alpha = 0.46: FDPhat 0.4596, Number of Rej. 1658
# alpha = 0.45: FDPhat 0.4495, Number of Rej. 1642
# alpha = 0.44: FDPhat 0.4397, Number of Rej. 1617
# alpha = 0.43: FDPhat 0.4295, Number of Rej. 1602
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 1555
# alpha = 0.41: FDPhat 0.4095, Number of Rej. 1514
# alpha = 0.4: FDPhat 0.3996, Number of Rej. 1499
# alpha = 0.39: FDPhat 0.3895, Number of Rej. 1484
# alpha = 0.38: FDPhat 0.3793, Number of Rej. 1442
# alpha = 0.37: FDPhat 0.3693, Number of Rej. 1435
# alpha = 0.36: FDPhat 0.36, Number of Rej. 1414
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 1386
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 1374
# alpha = 0.33: FDPhat 0.3296, Number of Rej. 1344
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 1341
# alpha = 0.31: FDPhat 0.3093, Number of Rej. 1329
# alpha = 0.3: FDPhat 0.3, Number of Rej. 1320
# alpha = 0.29: FDPhat 0.2895, Number of Rej. 1309
# alpha = 0.28: FDPhat 0.2793, Number of Rej. 1278
# alpha = 0.27: FDPhat 0.2696, Number of Rej. 1261
# alpha = 0.26: FDPhat 0.2596, Number of Rej. 1256
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1244
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1222
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 1202
# alpha = 0.22: FDPhat 0.2194, Number of Rej. 1194
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 1178
# alpha = 0.2: FDPhat 0.1997, Number of Rej. 1157
# alpha = 0.19: FDPhat 0.1896, Number of Rej. 1139
# alpha = 0.18: FDPhat 0.1791, Number of Rej. 1122
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1095
# alpha = 0.16: FDPhat 0.1593, Number of Rej. 1067
# alpha = 0.15: FDPhat 0.1496, Number of Rej. 1056
# alpha = 0.14: FDPhat 0.1395, Number of Rej. 1032
# alpha = 0.13: FDPhat 0.1295, Number of Rej. 1019
# alpha = 0.12: FDPhat 0.12, Number of Rej. 1000
# alpha = 0.11: FDPhat 0.1091, Number of Rej. 981
# alpha = 0.1: FDPhat 0.0999, Number of Rej. 961
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 924
# alpha = 0.08: FDPhat 0.0798, Number of Rej. 890
# alpha = 0.07: FDPhat 0.0693, Number of Rej. 851
# alpha = 0.06: FDPhat 0.0599, Number of Rej. 818
# alpha = 0.05: FDPhat 0.049, Number of Rej. 796
# alpha = 0.04: FDPhat 0.0398, Number of Rej. 778
# alpha = 0.03: FDPhat 0.0295, Number of Rej. 746
# alpha = 0.02: FDPhat 0.02, Number of Rej. 700
# alpha = 0.01: FDPhat 0.0085, Number of Rej. 590
# Task completed!
# [1] "data_1"
# alpha = 0.73: FDPhat 0.73, Number of Rej. 3437
# alpha = 0.72: FDPhat 0.7197, Number of Rej. 3286
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 3192
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 3139
# alpha = 0.69: FDPhat 0.6898, Number of Rej. 3108
# alpha = 0.68: FDPhat 0.6797, Number of Rej. 3072
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 3014
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 2928
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 2888
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 2802
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 2772
# alpha = 0.62: FDPhat 0.62, Number of Rej. 2700
# alpha = 0.61: FDPhat 0.6098, Number of Rej. 2655
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 2607
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 2567
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 2483
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 2422
# alpha = 0.56: FDPhat 0.5597, Number of Rej. 2405
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 2333
# alpha = 0.54: FDPhat 0.5397, Number of Rej. 2266
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 2182
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2112
# alpha = 0.51: FDPhat 0.51, Number of Rej. 2055
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2038
# alpha = 0.49: FDPhat 0.49, Number of Rej. 1996
# alpha = 0.48: FDPhat 0.4796, Number of Rej. 1985
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 1948
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 1910
# alpha = 0.45: FDPhat 0.45, Number of Rej. 1900
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 1873
# alpha = 0.43: FDPhat 0.4295, Number of Rej. 1837
# alpha = 0.42: FDPhat 0.4196, Number of Rej. 1823
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 1789
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 1753
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 1724
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 1699
# alpha = 0.37: FDPhat 0.3696, Number of Rej. 1672
# alpha = 0.36: FDPhat 0.36, Number of Rej. 1653
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 1621
# alpha = 0.34: FDPhat 0.34, Number of Rej. 1556
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 1522
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1507
# alpha = 0.31: FDPhat 0.31, Number of Rej. 1497
# alpha = 0.3: FDPhat 0.2995, Number of Rej. 1466
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 1450
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 1422
# alpha = 0.27: FDPhat 0.2696, Number of Rej. 1391
# alpha = 0.26: FDPhat 0.26, Number of Rej. 1377
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1360
# alpha = 0.24: FDPhat 0.2395, Number of Rej. 1332
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 1323
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1301
# alpha = 0.21: FDPhat 0.2096, Number of Rej. 1298
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1280
# alpha = 0.19: FDPhat 0.1892, Number of Rej. 1263
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 1229
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1224
# alpha = 0.16: FDPhat 0.16, Number of Rej. 1219
# alpha = 0.15: FDPhat 0.1495, Number of Rej. 1197
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 1180
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 1157
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 1135
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1103
# alpha = 0.1: FDPhat 0.0998, Number of Rej. 1082
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1069
# alpha = 0.08: FDPhat 0.0799, Number of Rej. 1051
# alpha = 0.07: FDPhat 0.0695, Number of Rej. 1022
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 991
# alpha = 0.05: FDPhat 0.0495, Number of Rej. 969
# alpha = 0.04: FDPhat 0.0395, Number of Rej. 936
# alpha = 0.03: FDPhat 0.0295, Number of Rej. 882
# alpha = 0.02: FDPhat 0.0198, Number of Rej. 807
# alpha = 0.01: FDPhat 0.0093, Number of Rej. 752
# Task completed!
# [1] "data_2"
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3832
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3757
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3660
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3546
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3474
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 3333
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3274
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 3207
# alpha = 0.48: FDPhat 0.4797, Number of Rej. 3158
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 3060
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2985
# alpha = 0.45: FDPhat 0.4497, Number of Rej. 2924
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2880
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2813
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2792
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2740
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2668
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 2604
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 2534
# alpha = 0.37: FDPhat 0.37, Number of Rej. 2473
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 2423
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 2389
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 2333
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 2313
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 2258
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 2227
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 2194
# alpha = 0.29: FDPhat 0.29, Number of Rej. 2145
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 2091
# alpha = 0.27: FDPhat 0.2698, Number of Rej. 2057
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1982
# alpha = 0.25: FDPhat 0.2497, Number of Rej. 1942
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1889
# alpha = 0.23: FDPhat 0.23, Number of Rej. 1848
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1828
# alpha = 0.21: FDPhat 0.2096, Number of Rej. 1799
# alpha = 0.2: FDPhat 0.1997, Number of Rej. 1743
# alpha = 0.19: FDPhat 0.1896, Number of Rej. 1698
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1651
# alpha = 0.17: FDPhat 0.1698, Number of Rej. 1620
# alpha = 0.16: FDPhat 0.16, Number of Rej. 1594
# alpha = 0.15: FDPhat 0.1496, Number of Rej. 1564
# alpha = 0.14: FDPhat 0.1395, Number of Rej. 1541
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 1494
# alpha = 0.12: FDPhat 0.1199, Number of Rej. 1468
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1413
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 1385
# alpha = 0.09: FDPhat 0.0896, Number of Rej. 1340
# alpha = 0.08: FDPhat 0.0799, Number of Rej. 1302
# alpha = 0.07: FDPhat 0.0694, Number of Rej. 1253
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 1210
# alpha = 0.05: FDPhat 0.0498, Number of Rej. 1144
# alpha = 0.04: FDPhat 0.0392, Number of Rej. 1097
# alpha = 0.03: FDPhat 0.0297, Number of Rej. 1044
# alpha = 0.02: FDPhat 0.0197, Number of Rej. 963
# alpha = 0.01: FDPhat 0.0093, Number of Rej. 856
# Task completed!
# [1] "data_3"
# alpha = 0.83: FDPhat 0.83, Number of Rej. 3188
# alpha = 0.82: FDPhat 0.8197, Number of Rej. 3101
# alpha = 0.81: FDPhat 0.8099, Number of Rej. 3072
# alpha = 0.8: FDPhat 0.7998, Number of Rej. 3042
# alpha = 0.79: FDPhat 0.7898, Number of Rej. 3007
# alpha = 0.78: FDPhat 0.7798, Number of Rej. 2970
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 2934
# alpha = 0.76: FDPhat 0.7599, Number of Rej. 2891
# alpha = 0.75: FDPhat 0.75, Number of Rej. 2856
# alpha = 0.74: FDPhat 0.74, Number of Rej. 2800
# alpha = 0.73: FDPhat 0.7298, Number of Rej. 2750
# alpha = 0.72: FDPhat 0.72, Number of Rej. 2725
# alpha = 0.71: FDPhat 0.7098, Number of Rej. 2657
# alpha = 0.7: FDPhat 0.6997, Number of Rej. 2587
# alpha = 0.69: FDPhat 0.6899, Number of Rej. 2512
# alpha = 0.68: FDPhat 0.6797, Number of Rej. 2482
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 2439
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 2390
# alpha = 0.65: FDPhat 0.65, Number of Rej. 2337
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 2308
# alpha = 0.63: FDPhat 0.6297, Number of Rej. 2274
# alpha = 0.62: FDPhat 0.6196, Number of Rej. 2245
# alpha = 0.61: FDPhat 0.6098, Number of Rej. 2163
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 2144
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 2085
# alpha = 0.58: FDPhat 0.58, Number of Rej. 2050
# alpha = 0.57: FDPhat 0.5695, Number of Rej. 2014
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 1979
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 1948
# alpha = 0.54: FDPhat 0.5396, Number of Rej. 1931
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 1921
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 1858
# alpha = 0.51: FDPhat 0.5096, Number of Rej. 1829
# alpha = 0.5: FDPhat 0.5, Number of Rej. 1786
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 1772
# alpha = 0.48: FDPhat 0.4796, Number of Rej. 1737
# alpha = 0.47: FDPhat 0.47, Number of Rej. 1715
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 1679
# alpha = 0.45: FDPhat 0.4497, Number of Rej. 1659
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 1646
# alpha = 0.43: FDPhat 0.4295, Number of Rej. 1623
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 1586
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 1572
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 1558
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 1534
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 1525
# alpha = 0.37: FDPhat 0.3696, Number of Rej. 1507
# alpha = 0.36: FDPhat 0.3595, Number of Rej. 1491
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 1478
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 1446
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 1425
# alpha = 0.32: FDPhat 0.3194, Number of Rej. 1390
# alpha = 0.31: FDPhat 0.3095, Number of Rej. 1373
# alpha = 0.3: FDPhat 0.2997, Number of Rej. 1368
# alpha = 0.29: FDPhat 0.2895, Number of Rej. 1354
# alpha = 0.28: FDPhat 0.2793, Number of Rej. 1346
# alpha = 0.27: FDPhat 0.2693, Number of Rej. 1322
# alpha = 0.26: FDPhat 0.2594, Number of Rej. 1299
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 1289
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1275
# alpha = 0.23: FDPhat 0.2294, Number of Rej. 1260
# alpha = 0.22: FDPhat 0.22, Number of Rej. 1241
# alpha = 0.21: FDPhat 0.21, Number of Rej. 1224
# alpha = 0.2: FDPhat 0.1995, Number of Rej. 1198
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 1180
# alpha = 0.18: FDPhat 0.1795, Number of Rej. 1170
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1148
# alpha = 0.16: FDPhat 0.1593, Number of Rej. 1136
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 1121
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 1109
# alpha = 0.13: FDPhat 0.1297, Number of Rej. 1079
# alpha = 0.12: FDPhat 0.1192, Number of Rej. 1057
# alpha = 0.11: FDPhat 0.1093, Number of Rej. 1043
# alpha = 0.1: FDPhat 0.0995, Number of Rej. 1035
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 1018
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 981
# alpha = 0.07: FDPhat 0.0693, Number of Rej. 952
# alpha = 0.06: FDPhat 0.0597, Number of Rej. 922
# alpha = 0.05: FDPhat 0.0498, Number of Rej. 903
# alpha = 0.04: FDPhat 0.039, Number of Rej. 871
# alpha = 0.03: FDPhat 0.0289, Number of Rej. 830
# alpha = 0.02: FDPhat 0.02, Number of Rej. 802
# alpha = 0.01: FDPhat 0.0094, Number of Rej. 744
# Task completed!
# [1] "data_4"
# alpha = 1: FDPhat 1, Number of Rej. 2821
# alpha = 0.99: FDPhat 0.9899, Number of Rej. 2775
# alpha = 0.98: FDPhat 0.98, Number of Rej. 2748
# alpha = 0.97: FDPhat 0.97, Number of Rej. 2731
# alpha = 0.96: FDPhat 0.9597, Number of Rej. 2727
# alpha = 0.95: FDPhat 0.9499, Number of Rej. 2716
# alpha = 0.94: FDPhat 0.9397, Number of Rej. 2685
# alpha = 0.93: FDPhat 0.9299, Number of Rej. 2667
# alpha = 0.92: FDPhat 0.9198, Number of Rej. 2643
# alpha = 0.91: FDPhat 0.9097, Number of Rej. 2624
# alpha = 0.9: FDPhat 0.8997, Number of Rej. 2581
# alpha = 0.89: FDPhat 0.89, Number of Rej. 2563
# alpha = 0.88: FDPhat 0.8797, Number of Rej. 2543
# alpha = 0.87: FDPhat 0.87, Number of Rej. 2515
# alpha = 0.86: FDPhat 0.8599, Number of Rej. 2506
# alpha = 0.85: FDPhat 0.8497, Number of Rej. 2489
# alpha = 0.84: FDPhat 0.84, Number of Rej. 2462
# alpha = 0.83: FDPhat 0.83, Number of Rej. 2441
# alpha = 0.82: FDPhat 0.8198, Number of Rej. 2398
# alpha = 0.81: FDPhat 0.8096, Number of Rej. 2353
# alpha = 0.8: FDPhat 0.7997, Number of Rej. 2327
# alpha = 0.79: FDPhat 0.7898, Number of Rej. 2307
# alpha = 0.78: FDPhat 0.7798, Number of Rej. 2257
# alpha = 0.77: FDPhat 0.7696, Number of Rej. 2214
# alpha = 0.76: FDPhat 0.7597, Number of Rej. 2197
# alpha = 0.75: FDPhat 0.7496, Number of Rej. 2125
# alpha = 0.74: FDPhat 0.74, Number of Rej. 2073
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 2007
# alpha = 0.72: FDPhat 0.7198, Number of Rej. 1959
# alpha = 0.71: FDPhat 0.7099, Number of Rej. 1944
# alpha = 0.7: FDPhat 0.6998, Number of Rej. 1929
# alpha = 0.69: FDPhat 0.6896, Number of Rej. 1920
# alpha = 0.68: FDPhat 0.68, Number of Rej. 1881
# alpha = 0.67: FDPhat 0.6698, Number of Rej. 1835
# alpha = 0.66: FDPhat 0.6598, Number of Rej. 1784
# alpha = 0.65: FDPhat 0.6498, Number of Rej. 1759
# alpha = 0.64: FDPhat 0.6397, Number of Rej. 1740
# alpha = 0.63: FDPhat 0.6295, Number of Rej. 1714
# alpha = 0.62: FDPhat 0.6195, Number of Rej. 1703
# alpha = 0.61: FDPhat 0.6099, Number of Rej. 1679
# alpha = 0.6: FDPhat 0.6, Number of Rej. 1670
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 1658
# alpha = 0.58: FDPhat 0.5795, Number of Rej. 1641
# alpha = 0.57: FDPhat 0.5695, Number of Rej. 1612
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 1588
# alpha = 0.55: FDPhat 0.55, Number of Rej. 1571
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 1558
# alpha = 0.53: FDPhat 0.53, Number of Rej. 1551
# alpha = 0.52: FDPhat 0.5195, Number of Rej. 1536
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 1510
# alpha = 0.5: FDPhat 0.5, Number of Rej. 1486
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 1470
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 1461
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 1437
# alpha = 0.46: FDPhat 0.4595, Number of Rej. 1421
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 1416
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 1405
# alpha = 0.43: FDPhat 0.4295, Number of Rej. 1390
# alpha = 0.42: FDPhat 0.4197, Number of Rej. 1382
# alpha = 0.41: FDPhat 0.4098, Number of Rej. 1369
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 1353
# alpha = 0.39: FDPhat 0.3895, Number of Rej. 1348
# alpha = 0.38: FDPhat 0.3793, Number of Rej. 1326
# alpha = 0.37: FDPhat 0.3696, Number of Rej. 1315
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 1306
# alpha = 0.35: FDPhat 0.3493, Number of Rej. 1297
# alpha = 0.34: FDPhat 0.3393, Number of Rej. 1279
# alpha = 0.33: FDPhat 0.3297, Number of Rej. 1271
# alpha = 0.32: FDPhat 0.3193, Number of Rej. 1262
# alpha = 0.31: FDPhat 0.3095, Number of Rej. 1257
# alpha = 0.3: FDPhat 0.2998, Number of Rej. 1254
# alpha = 0.29: FDPhat 0.29, Number of Rej. 1245
# alpha = 0.28: FDPhat 0.2794, Number of Rej. 1235
# alpha = 0.27: FDPhat 0.2695, Number of Rej. 1232
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1220
# alpha = 0.25: FDPhat 0.2494, Number of Rej. 1211
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 1205
# alpha = 0.23: FDPhat 0.2295, Number of Rej. 1198
# alpha = 0.22: FDPhat 0.2193, Number of Rej. 1190
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1186
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1176
# alpha = 0.19: FDPhat 0.1892, Number of Rej. 1163
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 1146
# alpha = 0.17: FDPhat 0.1697, Number of Rej. 1137
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1126
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 1114
# alpha = 0.14: FDPhat 0.1394, Number of Rej. 1105
# alpha = 0.13: FDPhat 0.1292, Number of Rej. 1099
# alpha = 0.12: FDPhat 0.1199, Number of Rej. 1084
# alpha = 0.11: FDPhat 0.1093, Number of Rej. 1061
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 1056
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1047
# alpha = 0.08: FDPhat 0.0794, Number of Rej. 1020
# alpha = 0.07: FDPhat 0.0695, Number of Rej. 993
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 975
# alpha = 0.05: FDPhat 0.0494, Number of Rej. 972
# alpha = 0.04: FDPhat 0.0392, Number of Rej. 918
# alpha = 0.03: FDPhat 0.0296, Number of Rej. 877
# alpha = 0.02: FDPhat 0.019, Number of Rej. 841
# alpha = 0.01: FDPhat 0.0095, Number of Rej. 740
# Task completed!
# [1] "data_5"
# alpha = 0.9: FDPhat 0.8999, Number of Rej. 3077
# alpha = 0.89: FDPhat 0.89, Number of Rej. 3009
# alpha = 0.88: FDPhat 0.8799, Number of Rej. 2965
# alpha = 0.87: FDPhat 0.8698, Number of Rej. 2958
# alpha = 0.86: FDPhat 0.8597, Number of Rej. 2943
# alpha = 0.85: FDPhat 0.8497, Number of Rej. 2935
# alpha = 0.84: FDPhat 0.8399, Number of Rej. 2929
# alpha = 0.83: FDPhat 0.8299, Number of Rej. 2892
# alpha = 0.82: FDPhat 0.8199, Number of Rej. 2838
# alpha = 0.81: FDPhat 0.8098, Number of Rej. 2797
# alpha = 0.8: FDPhat 0.7999, Number of Rej. 2774
# alpha = 0.79: FDPhat 0.7899, Number of Rej. 2737
# alpha = 0.78: FDPhat 0.7799, Number of Rej. 2712
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 2690
# alpha = 0.76: FDPhat 0.7598, Number of Rej. 2673
# alpha = 0.75: FDPhat 0.7498, Number of Rej. 2634
# alpha = 0.74: FDPhat 0.7396, Number of Rej. 2604
# alpha = 0.73: FDPhat 0.7297, Number of Rej. 2556
# alpha = 0.72: FDPhat 0.72, Number of Rej. 2496
# alpha = 0.71: FDPhat 0.7097, Number of Rej. 2446
# alpha = 0.7: FDPhat 0.6998, Number of Rej. 2408
# alpha = 0.69: FDPhat 0.6898, Number of Rej. 2350
# alpha = 0.68: FDPhat 0.6797, Number of Rej. 2301
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 2236
# alpha = 0.66: FDPhat 0.6596, Number of Rej. 2183
# alpha = 0.65: FDPhat 0.6499, Number of Rej. 2111
# alpha = 0.64: FDPhat 0.64, Number of Rej. 2072
# alpha = 0.63: FDPhat 0.6299, Number of Rej. 2029
# alpha = 0.62: FDPhat 0.62, Number of Rej. 2000
# alpha = 0.61: FDPhat 0.6098, Number of Rej. 1958
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 1944
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 1892
# alpha = 0.58: FDPhat 0.5795, Number of Rej. 1867
# alpha = 0.57: FDPhat 0.5695, Number of Rej. 1842
# alpha = 0.56: FDPhat 0.5595, Number of Rej. 1816
# alpha = 0.55: FDPhat 0.55, Number of Rej. 1791
# alpha = 0.54: FDPhat 0.5395, Number of Rej. 1772
# alpha = 0.53: FDPhat 0.5296, Number of Rej. 1722
# alpha = 0.52: FDPhat 0.5197, Number of Rej. 1701
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 1687
# alpha = 0.5: FDPhat 0.5, Number of Rej. 1668
# alpha = 0.49: FDPhat 0.49, Number of Rej. 1643
# alpha = 0.48: FDPhat 0.4797, Number of Rej. 1624
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 1616
# alpha = 0.46: FDPhat 0.4594, Number of Rej. 1613
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 1603
# alpha = 0.44: FDPhat 0.4397, Number of Rej. 1585
# alpha = 0.43: FDPhat 0.4295, Number of Rej. 1567
# alpha = 0.42: FDPhat 0.4196, Number of Rej. 1549
# alpha = 0.41: FDPhat 0.4094, Number of Rej. 1539
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 1533
# alpha = 0.39: FDPhat 0.39, Number of Rej. 1518
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 1503
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 1487
# alpha = 0.36: FDPhat 0.3595, Number of Rej. 1452
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 1432
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 1421
# alpha = 0.33: FDPhat 0.3295, Number of Rej. 1399
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 1385
# alpha = 0.31: FDPhat 0.3095, Number of Rej. 1370
# alpha = 0.3: FDPhat 0.2996, Number of Rej. 1362
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 1343
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 1336
# alpha = 0.27: FDPhat 0.2693, Number of Rej. 1333
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 1316
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1304
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1300
# alpha = 0.23: FDPhat 0.2294, Number of Rej. 1277
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 1248
# alpha = 0.21: FDPhat 0.2095, Number of Rej. 1236
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1220
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 1202
# alpha = 0.18: FDPhat 0.1795, Number of Rej. 1181
# alpha = 0.17: FDPhat 0.1694, Number of Rej. 1169
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 1164
# alpha = 0.15: FDPhat 0.1497, Number of Rej. 1156
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 1130
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 1119
# alpha = 0.12: FDPhat 0.1194, Number of Rej. 1097
# alpha = 0.11: FDPhat 0.1098, Number of Rej. 1075
# alpha = 0.1: FDPhat 0.099, Number of Rej. 1050
# alpha = 0.09: FDPhat 0.0891, Number of Rej. 1032
# alpha = 0.08: FDPhat 0.0793, Number of Rej. 1021
# alpha = 0.07: FDPhat 0.0695, Number of Rej. 993
# alpha = 0.06: FDPhat 0.0594, Number of Rej. 959
# alpha = 0.05: FDPhat 0.0497, Number of Rej. 926
# alpha = 0.04: FDPhat 0.0395, Number of Rej. 911
# alpha = 0.03: FDPhat 0.0292, Number of Rej. 855
# alpha = 0.02: FDPhat 0.0197, Number of Rej. 812
# alpha = 0.01: FDPhat 0.0096, Number of Rej. 729
# Task completed!
# [1] "data_6"
# alpha = 0.79: FDPhat 0.79, Number of Rej. 3295
# alpha = 0.78: FDPhat 0.78, Number of Rej. 3200
# alpha = 0.77: FDPhat 0.7699, Number of Rej. 3125
# alpha = 0.76: FDPhat 0.7597, Number of Rej. 3038
# alpha = 0.75: FDPhat 0.7498, Number of Rej. 3018
# alpha = 0.74: FDPhat 0.7399, Number of Rej. 2976
# alpha = 0.73: FDPhat 0.7299, Number of Rej. 2936
# alpha = 0.72: FDPhat 0.72, Number of Rej. 2882
# alpha = 0.71: FDPhat 0.71, Number of Rej. 2855
# alpha = 0.7: FDPhat 0.7, Number of Rej. 2800
# alpha = 0.69: FDPhat 0.69, Number of Rej. 2774
# alpha = 0.68: FDPhat 0.6799, Number of Rej. 2743
# alpha = 0.67: FDPhat 0.6696, Number of Rej. 2697
# alpha = 0.66: FDPhat 0.6599, Number of Rej. 2605
# alpha = 0.65: FDPhat 0.6497, Number of Rej. 2578
# alpha = 0.64: FDPhat 0.6396, Number of Rej. 2553
# alpha = 0.63: FDPhat 0.6297, Number of Rej. 2501
# alpha = 0.62: FDPhat 0.6197, Number of Rej. 2456
# alpha = 0.61: FDPhat 0.6098, Number of Rej. 2427
# alpha = 0.6: FDPhat 0.5997, Number of Rej. 2371
# alpha = 0.59: FDPhat 0.5898, Number of Rej. 2345
# alpha = 0.58: FDPhat 0.58, Number of Rej. 2269
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 2188
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 2149
# alpha = 0.55: FDPhat 0.55, Number of Rej. 2120
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 2095
# alpha = 0.53: FDPhat 0.5297, Number of Rej. 2052
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2010
# alpha = 0.51: FDPhat 0.5096, Number of Rej. 1988
# alpha = 0.5: FDPhat 0.5, Number of Rej. 1962
# alpha = 0.49: FDPhat 0.4897, Number of Rej. 1948
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 1888
# alpha = 0.47: FDPhat 0.4696, Number of Rej. 1859
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 1829
# alpha = 0.45: FDPhat 0.4496, Number of Rej. 1806
# alpha = 0.44: FDPhat 0.4397, Number of Rej. 1790
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 1770
# alpha = 0.42: FDPhat 0.4196, Number of Rej. 1742
# alpha = 0.41: FDPhat 0.41, Number of Rej. 1727
# alpha = 0.4: FDPhat 0.3996, Number of Rej. 1704
# alpha = 0.39: FDPhat 0.3894, Number of Rej. 1687
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 1674
# alpha = 0.37: FDPhat 0.3697, Number of Rej. 1650
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 1617
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 1604
# alpha = 0.34: FDPhat 0.3395, Number of Rej. 1579
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 1561
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 1551
# alpha = 0.31: FDPhat 0.3096, Number of Rej. 1534
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 1504
# alpha = 0.29: FDPhat 0.2894, Number of Rej. 1496
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 1458
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 1446
# alpha = 0.26: FDPhat 0.26, Number of Rej. 1427
# alpha = 0.25: FDPhat 0.2495, Number of Rej. 1403
# alpha = 0.24: FDPhat 0.2397, Number of Rej. 1381
# alpha = 0.23: FDPhat 0.23, Number of Rej. 1361
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1342
# alpha = 0.21: FDPhat 0.21, Number of Rej. 1324
# alpha = 0.2: FDPhat 0.1994, Number of Rej. 1294
# alpha = 0.19: FDPhat 0.19, Number of Rej. 1274
# alpha = 0.18: FDPhat 0.1793, Number of Rej. 1266
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1254
# alpha = 0.16: FDPhat 0.16, Number of Rej. 1225
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 1202
# alpha = 0.14: FDPhat 0.1393, Number of Rej. 1177
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 1142
# alpha = 0.12: FDPhat 0.1197, Number of Rej. 1128
# alpha = 0.11: FDPhat 0.1099, Number of Rej. 1101
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 1077
# alpha = 0.09: FDPhat 0.0896, Number of Rej. 1060
# alpha = 0.08: FDPhat 0.0797, Number of Rej. 1042
# alpha = 0.07: FDPhat 0.0694, Number of Rej. 1008
# alpha = 0.06: FDPhat 0.0592, Number of Rej. 963
# alpha = 0.05: FDPhat 0.0499, Number of Rej. 922
# alpha = 0.04: FDPhat 0.0397, Number of Rej. 907
# alpha = 0.03: FDPhat 0.0292, Number of Rej. 855
# alpha = 0.02: FDPhat 0.019, Number of Rej. 791
# alpha = 0.01: FDPhat 0.0087, Number of Rej. 690
# Task completed!
# [1] "data_7"
# alpha = 0.6: FDPhat 0.5999, Number of Rej. 3722
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3621
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 3444
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3374
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3261
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3233
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3119
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3078
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3010
# alpha = 0.51: FDPhat 0.51, Number of Rej. 2910
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 2845
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 2731
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 2672
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 2633
# alpha = 0.46: FDPhat 0.4599, Number of Rej. 2542
# alpha = 0.45: FDPhat 0.4496, Number of Rej. 2511
# alpha = 0.44: FDPhat 0.44, Number of Rej. 2416
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2359
# alpha = 0.42: FDPhat 0.4196, Number of Rej. 2321
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 2253
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2205
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 2157
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 2110
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 2096
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 2040
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 1975
# alpha = 0.34: FDPhat 0.3395, Number of Rej. 1947
# alpha = 0.33: FDPhat 0.3297, Number of Rej. 1917
# alpha = 0.32: FDPhat 0.3197, Number of Rej. 1886
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 1830
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 1784
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 1702
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 1679
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 1649
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 1612
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1540
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1525
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 1505
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1496
# alpha = 0.21: FDPhat 0.2098, Number of Rej. 1468
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1440
# alpha = 0.19: FDPhat 0.1895, Number of Rej. 1393
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1384
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 1339
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1288
# alpha = 0.15: FDPhat 0.15, Number of Rej. 1267
# alpha = 0.14: FDPhat 0.1396, Number of Rej. 1239
# alpha = 0.13: FDPhat 0.1294, Number of Rej. 1206
# alpha = 0.12: FDPhat 0.12, Number of Rej. 1175
# alpha = 0.11: FDPhat 0.11, Number of Rej. 1164
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 1145
# alpha = 0.09: FDPhat 0.09, Number of Rej. 1100
# alpha = 0.08: FDPhat 0.0794, Number of Rej. 1083
# alpha = 0.07: FDPhat 0.0695, Number of Rej. 1036
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 990
# alpha = 0.05: FDPhat 0.049, Number of Rej. 979
# alpha = 0.04: FDPhat 0.0397, Number of Rej. 958
# alpha = 0.03: FDPhat 0.0292, Number of Rej. 855
# alpha = 0.02: FDPhat 0.0192, Number of Rej. 780
# alpha = 0.01: FDPhat 0.0098, Number of Rej. 715
# Task completed!
# [1] "data_8"
# alpha = 0.7: FDPhat 0.6999, Number of Rej. 3475
# alpha = 0.69: FDPhat 0.6898, Number of Rej. 3295
# alpha = 0.68: FDPhat 0.68, Number of Rej. 3212
# alpha = 0.67: FDPhat 0.6699, Number of Rej. 3138
# alpha = 0.66: FDPhat 0.66, Number of Rej. 3079
# alpha = 0.65: FDPhat 0.65, Number of Rej. 3031
# alpha = 0.64: FDPhat 0.6399, Number of Rej. 2971
# alpha = 0.63: FDPhat 0.6298, Number of Rej. 2947
# alpha = 0.62: FDPhat 0.6198, Number of Rej. 2912
# alpha = 0.61: FDPhat 0.6097, Number of Rej. 2816
# alpha = 0.6: FDPhat 0.5998, Number of Rej. 2786
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 2731
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 2713
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 2681
# alpha = 0.56: FDPhat 0.56, Number of Rej. 2600
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 2530
# alpha = 0.54: FDPhat 0.54, Number of Rej. 2515
# alpha = 0.53: FDPhat 0.53, Number of Rej. 2436
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 2383
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 2324
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2292
# alpha = 0.49: FDPhat 0.4896, Number of Rej. 2253
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 2184
# alpha = 0.47: FDPhat 0.4696, Number of Rej. 2138
# alpha = 0.46: FDPhat 0.4596, Number of Rej. 2102
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2065
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2012
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 1977
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 1960
# alpha = 0.41: FDPhat 0.41, Number of Rej. 1905
# alpha = 0.4: FDPhat 0.4, Number of Rej. 1865
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 1829
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 1812
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 1790
# alpha = 0.36: FDPhat 0.3598, Number of Rej. 1762
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 1721
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 1704
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 1667
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 1641
# alpha = 0.31: FDPhat 0.3095, Number of Rej. 1593
# alpha = 0.3: FDPhat 0.2997, Number of Rej. 1565
# alpha = 0.29: FDPhat 0.2894, Number of Rej. 1510
# alpha = 0.28: FDPhat 0.2797, Number of Rej. 1505
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 1486
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 1466
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1440
# alpha = 0.24: FDPhat 0.2399, Number of Rej. 1413
# alpha = 0.23: FDPhat 0.2295, Number of Rej. 1364
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 1348
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1339
# alpha = 0.2: FDPhat 0.1995, Number of Rej. 1308
# alpha = 0.19: FDPhat 0.1893, Number of Rej. 1284
# alpha = 0.18: FDPhat 0.1796, Number of Rej. 1264
# alpha = 0.17: FDPhat 0.1696, Number of Rej. 1232
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 1220
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 1195
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 1172
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 1132
# alpha = 0.12: FDPhat 0.1196, Number of Rej. 1104
# alpha = 0.11: FDPhat 0.1099, Number of Rej. 1092
# alpha = 0.1: FDPhat 0.0992, Number of Rej. 1058
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1025
# alpha = 0.08: FDPhat 0.0798, Number of Rej. 990
# alpha = 0.07: FDPhat 0.0693, Number of Rej. 953
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 925
# alpha = 0.05: FDPhat 0.0491, Number of Rej. 897
# alpha = 0.04: FDPhat 0.0394, Number of Rej. 864
# alpha = 0.03: FDPhat 0.0296, Number of Rej. 845
# alpha = 0.02: FDPhat 0.0191, Number of Rej. 734
# alpha = 0.01: FDPhat 0.0093, Number of Rej. 642
# Task completed!
# [1] "data_9"
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3797
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3699
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3511
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3402
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3340
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3242
# alpha = 0.52: FDPhat 0.52, Number of Rej. 3175
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 3064
# alpha = 0.5: FDPhat 0.5, Number of Rej. 2978
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 2913
# alpha = 0.48: FDPhat 0.4797, Number of Rej. 2877
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2843
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2800
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2723
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2685
# alpha = 0.43: FDPhat 0.4297, Number of Rej. 2623
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2511
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2447
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 2356
# alpha = 0.39: FDPhat 0.39, Number of Rej. 2290
# alpha = 0.38: FDPhat 0.38, Number of Rej. 2237
# alpha = 0.37: FDPhat 0.3697, Number of Rej. 2199
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 2159
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 2132
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 2082
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 2059
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 2035
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 1989
# alpha = 0.3: FDPhat 0.2996, Number of Rej. 1949
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 1911
# alpha = 0.28: FDPhat 0.2796, Number of Rej. 1878
# alpha = 0.27: FDPhat 0.2698, Number of Rej. 1835
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1782
# alpha = 0.25: FDPhat 0.2499, Number of Rej. 1749
# alpha = 0.24: FDPhat 0.2395, Number of Rej. 1716
# alpha = 0.23: FDPhat 0.2295, Number of Rej. 1686
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 1667
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1639
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1602
# alpha = 0.19: FDPhat 0.1897, Number of Rej. 1571
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1551
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 1522
# alpha = 0.16: FDPhat 0.1599, Number of Rej. 1482
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 1461
# alpha = 0.14: FDPhat 0.1397, Number of Rej. 1417
# alpha = 0.13: FDPhat 0.1297, Number of Rej. 1395
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 1369
# alpha = 0.11: FDPhat 0.1098, Number of Rej. 1330
# alpha = 0.1: FDPhat 0.0997, Number of Rej. 1294
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 1253
# alpha = 0.08: FDPhat 0.0798, Number of Rej. 1228
# alpha = 0.07: FDPhat 0.0693, Number of Rej. 1184
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 1124
# alpha = 0.05: FDPhat 0.05, Number of Rej. 1080
# alpha = 0.04: FDPhat 0.0396, Number of Rej. 1011
# alpha = 0.03: FDPhat 0.0293, Number of Rej. 991
# alpha = 0.02: FDPhat 0.0196, Number of Rej. 917
# alpha = 0.01: FDPhat 0.0097, Number of Rej. 827
# Task completed!
# Loading required package: nlme
# This is mgcv 1.8-24. For overview type 'help("mgcv-package")'.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.

# %% [markdown]
# ## Figure generation
# ### Collect the results from the saved file

# %%
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
summary_stats = {}
# Python methods
result_path_py = './temp_result/res_' + data_name + '/result.pickle'
with open(result_path_py, 'rb') as fil:
    result_py = pickle.load(fil)
for method in result_py.keys():
    if len(result_py[method])>0:
        summary_stats[method] = {}
        summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
        summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    else:
        continue
    for fdp,power,alpha,dname in result_py[method]:
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# R methods
result_path_r = './temp_result/res_r_' + data_name
r_method_list = ['ihw', 'adapt', 'bl']
for method in r_method_list:
    res_df = pd.read_table(result_path_r + '/res_' + method, delimiter=',') 
    summary_stats[method] = {}
    summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
    summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    for i in range(res_df.shape[0]):
        fdp,power,alpha,dname = res_df.iloc[i]
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# Delete when there is no result
method_list = list(summary_stats.keys())
for method in method_list:
    if np.sum(summary_stats[method]['Power']) == 0:
        del summary_stats[method]

# %% [markdown]
# ### Generate the FDP and power plot

# %%
marker_list = ['o', 'v', 'p', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C4', 'C3', 'C0', 'C5', 'C8']
method_list = ['adafdr-fast', 'adafdr', 'bl', 'adapt', 'ihw', 'sbh', 'bh']
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
# FDP
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['FDP'], axis=0)
        y_err = np.std(summary_stats[method]['FDP'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
axis_min = min(x_min, y_min)
axis_max = max(x_max, y_max)
plt.plot([axis_min, axis_max], [axis_min, axis_max], linestyle='--', color='k')
plt.legend(loc=2, fontsize=12)
plt.ylabel('FDP', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
# Power 
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['Power'], axis=0)
        y_err = np.std(summary_stats[method]['Power'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
plt.legend(loc=2, fontsize=12)
plt.ylabel('power', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
