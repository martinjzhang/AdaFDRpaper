# %%
import numpy as np
import adafdr.method as md
import adafdr.data_loader as dl
import matplotlib.pyplot as plt
import pandas as pd
import pickle
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

data_name = 'data_polyester_ui'

# %% [markdown]
# ## Run methods on each simulation datasets
# This may take a while to run. The computed results are already stored in
# - Python methods: `./temp_result/res_ + data_name`
# - R methods: `./temp_result/res_r_ + data_name`
#
# where `data_name` is as defiend above. For those who do not
# want to run these again, they can directly move the figure generation
# section.
#
# For those who wish to run the code to reproduce the results,
# they need to specify the `data_path` below to be the path of
# `AdaFDRpaper_data` on their machine
#
# The Python methods are run by calling `analysis_batch.py` while
# R methods are run by calling `analysis_batch.R`. It is easier to
# run them using `.sh` script but we include them here for
# illustration purpose.

# %%
data_path = '/data3/martin/AdaFDRpaper_data'
input_folder = data_path + '/' + data_name

# %%
# Python methods
# %run analysis_batch.py -i $input_folder -d $data_name
# Out:
# input_folder: /data3/martin/AdaFDRpaper_data/data_polyester_ui
# output_folder: ./temp_result/res_data_polyester_ui
# alpha_list: [0.05, 0.1, 0.15, 0.2]
# # Processing data_5 with alpha=0.05
# # Processing data_5 with alpha=0.10
# # Processing data_5 with alpha=0.15
# # Processing data_5 with alpha=0.20
# # Processing data_2 with alpha=0.05
# # Processing data_2 with alpha=0.10
# # Processing data_2 with alpha=0.15
# # Processing data_2 with alpha=0.20
# # Processing data_0 with alpha=0.05
# # Processing data_0 with alpha=0.10
# # Processing data_0 with alpha=0.15
# # Processing data_0 with alpha=0.20
# # Processing data_3 with alpha=0.05
# # Processing data_3 with alpha=0.10
# # Processing data_3 with alpha=0.15
# # Processing data_3 with alpha=0.20
# # Processing data_7 with alpha=0.05
# # Processing data_7 with alpha=0.10
# # Processing data_7 with alpha=0.15
# # Processing data_7 with alpha=0.20
# # Processing data_9 with alpha=0.05
# # Processing data_9 with alpha=0.10
# # Processing data_9 with alpha=0.15
# # Processing data_9 with alpha=0.20
# # Processing data_4 with alpha=0.05
# # Processing data_4 with alpha=0.10
# # Processing data_4 with alpha=0.15
# # Processing data_4 with alpha=0.20
# # Processing data_6 with alpha=0.05
# # Processing data_6 with alpha=0.10
# # Processing data_6 with alpha=0.15
# # Processing data_6 with alpha=0.20
# # Processing data_1 with alpha=0.05
# # Processing data_1 with alpha=0.10
# # Processing data_1 with alpha=0.15
# # Processing data_1 with alpha=0.20
# # Processing data_8 with alpha=0.05
# # Processing data_8 with alpha=0.10
# # Processing data_8 with alpha=0.15
# # Processing data_8 with alpha=0.20

# %%
# R methods
output_folder = './temp_result/res_r_' + data_name
if data_name in ['data_yeast', 'data_polyester', 'data_polyester_ui']:
    benchmark_bl = 'T'
else:
    benchmark_bl = 'F'

# %%
# %%bash -s "$input_folder" "$output_folder" "$benchmark_bl"
# Rscript analysis_batch.R $1 $2 $3
# Out:
# [1] "input_folder: /data3/martin/AdaFDRpaper_data/data_polyester_ui"
# [1] "output_folder: ./temp_result/res_r_data_polyester_ui"
# [1] "benchmark_bl: T"
# [1] "data_0"
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3704
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3599
# alpha = 0.55: FDPhat 0.5498, Number of Rej. 3401
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3382
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 3337
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3264
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3181
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3116
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 3030
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 2993
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 2943
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2880
# alpha = 0.45: FDPhat 0.45, Number of Rej. 2820
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2742
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2689
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2641
# alpha = 0.41: FDPhat 0.4096, Number of Rej. 2595
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2565
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 2542
# alpha = 0.38: FDPhat 0.38, Number of Rej. 2495
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 2444
# alpha = 0.36: FDPhat 0.3596, Number of Rej. 2411
# alpha = 0.35: FDPhat 0.3497, Number of Rej. 2376
# alpha = 0.34: FDPhat 0.34, Number of Rej. 2306
# alpha = 0.33: FDPhat 0.33, Number of Rej. 2270
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 2213
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 2173
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 2114
# alpha = 0.29: FDPhat 0.2895, Number of Rej. 2062
# alpha = 0.28: FDPhat 0.2798, Number of Rej. 2023
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 2006
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 1971
# alpha = 0.25: FDPhat 0.25, Number of Rej. 1956
# alpha = 0.24: FDPhat 0.2395, Number of Rej. 1933
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 1910
# alpha = 0.22: FDPhat 0.22, Number of Rej. 1900
# alpha = 0.21: FDPhat 0.2098, Number of Rej. 1873
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1852
# alpha = 0.19: FDPhat 0.1896, Number of Rej. 1825
# alpha = 0.18: FDPhat 0.18, Number of Rej. 1789
# alpha = 0.17: FDPhat 0.17, Number of Rej. 1759
# alpha = 0.16: FDPhat 0.1595, Number of Rej. 1737
# alpha = 0.15: FDPhat 0.15, Number of Rej. 1707
# alpha = 0.14: FDPhat 0.1397, Number of Rej. 1682
# alpha = 0.13: FDPhat 0.1297, Number of Rej. 1658
# alpha = 0.12: FDPhat 0.1194, Number of Rej. 1633
# alpha = 0.11: FDPhat 0.1098, Number of Rej. 1603
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 1559
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 1521
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 1484
# alpha = 0.07: FDPhat 0.0698, Number of Rej. 1448
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 1426
# alpha = 0.05: FDPhat 0.0497, Number of Rej. 1387
# alpha = 0.04: FDPhat 0.0398, Number of Rej. 1357
# alpha = 0.03: FDPhat 0.0294, Number of Rej. 1294
# alpha = 0.02: FDPhat 0.0198, Number of Rej. 1260
# alpha = 0.01: FDPhat 0.0098, Number of Rej. 1221
# Task completed!
# [1] "data_1"
# alpha = 0.59: FDPhat 0.59, Number of Rej. 3624
# alpha = 0.58: FDPhat 0.5798, Number of Rej. 3532
# alpha = 0.57: FDPhat 0.5697, Number of Rej. 3463
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3400
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3313
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3206
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 3173
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3141
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3116
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3064
# alpha = 0.49: FDPhat 0.49, Number of Rej. 2994
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2948
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 2902
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2859
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2828
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2760
# alpha = 0.43: FDPhat 0.4297, Number of Rej. 2667
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2639
# alpha = 0.41: FDPhat 0.41, Number of Rej. 2600
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2560
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 2520
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 2478
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 2455
# alpha = 0.36: FDPhat 0.3597, Number of Rej. 2424
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 2401
# alpha = 0.34: FDPhat 0.34, Number of Rej. 2356
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 2325
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 2292
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 2267
# alpha = 0.3: FDPhat 0.2998, Number of Rej. 2248
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 2187
# alpha = 0.28: FDPhat 0.28, Number of Rej. 2168
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 2132
# alpha = 0.26: FDPhat 0.26, Number of Rej. 2077
# alpha = 0.25: FDPhat 0.25, Number of Rej. 2060
# alpha = 0.24: FDPhat 0.2397, Number of Rej. 2040
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 2005
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1993
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 1979
# alpha = 0.2: FDPhat 0.2, Number of Rej. 1955
# alpha = 0.19: FDPhat 0.19, Number of Rej. 1916
# alpha = 0.18: FDPhat 0.1797, Number of Rej. 1875
# alpha = 0.17: FDPhat 0.17, Number of Rej. 1853
# alpha = 0.16: FDPhat 0.1597, Number of Rej. 1829
# alpha = 0.15: FDPhat 0.1497, Number of Rej. 1797
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 1767
# alpha = 0.13: FDPhat 0.1297, Number of Rej. 1750
# alpha = 0.12: FDPhat 0.1197, Number of Rej. 1713
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1686
# alpha = 0.1: FDPhat 0.0998, Number of Rej. 1653
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1637
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 1611
# alpha = 0.07: FDPhat 0.0695, Number of Rej. 1568
# alpha = 0.06: FDPhat 0.0598, Number of Rej. 1523
# alpha = 0.05: FDPhat 0.0496, Number of Rej. 1492
# alpha = 0.04: FDPhat 0.0396, Number of Rej. 1464
# alpha = 0.03: FDPhat 0.0299, Number of Rej. 1437
# alpha = 0.02: FDPhat 0.0194, Number of Rej. 1391
# alpha = 0.01: FDPhat 0.0097, Number of Rej. 1343
# Task completed!
# [1] "data_2"
# alpha = 0.58: FDPhat 0.58, Number of Rej. 3695
# alpha = 0.57: FDPhat 0.57, Number of Rej. 3579
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3495
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3433
# alpha = 0.54: FDPhat 0.54, Number of Rej. 3389
# alpha = 0.53: FDPhat 0.53, Number of Rej. 3351
# alpha = 0.52: FDPhat 0.5197, Number of Rej. 3294
# alpha = 0.51: FDPhat 0.5098, Number of Rej. 3262
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 3171
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 3117
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 3063
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 3008
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2930
# alpha = 0.45: FDPhat 0.4499, Number of Rej. 2894
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2869
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2792
# alpha = 0.42: FDPhat 0.4197, Number of Rej. 2740
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2691
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2650
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 2614
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 2507
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 2441
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 2398
# alpha = 0.35: FDPhat 0.3497, Number of Rej. 2356
# alpha = 0.34: FDPhat 0.3396, Number of Rej. 2270
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 2228
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 2189
# alpha = 0.31: FDPhat 0.3097, Number of Rej. 2170
# alpha = 0.3: FDPhat 0.3, Number of Rej. 2130
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 2084
# alpha = 0.28: FDPhat 0.28, Number of Rej. 2050
# alpha = 0.27: FDPhat 0.27, Number of Rej. 2030
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 2001
# alpha = 0.25: FDPhat 0.2496, Number of Rej. 1971
# alpha = 0.24: FDPhat 0.2399, Number of Rej. 1947
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 1897
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1878
# alpha = 0.21: FDPhat 0.2095, Number of Rej. 1852
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1812
# alpha = 0.19: FDPhat 0.1899, Number of Rej. 1801
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1768
# alpha = 0.17: FDPhat 0.1694, Number of Rej. 1741
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 1715
# alpha = 0.15: FDPhat 0.1496, Number of Rej. 1691
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 1660
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 1647
# alpha = 0.12: FDPhat 0.1194, Number of Rej. 1616
# alpha = 0.11: FDPhat 0.1098, Number of Rej. 1576
# alpha = 0.1: FDPhat 0.0997, Number of Rej. 1544
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1525
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 1497
# alpha = 0.07: FDPhat 0.0696, Number of Rej. 1466
# alpha = 0.06: FDPhat 0.0594, Number of Rej. 1414
# alpha = 0.05: FDPhat 0.0497, Number of Rej. 1387
# alpha = 0.04: FDPhat 0.0398, Number of Rej. 1356
# alpha = 0.03: FDPhat 0.03, Number of Rej. 1335
# alpha = 0.02: FDPhat 0.0193, Number of Rej. 1292
# alpha = 0.01: FDPhat 0.0097, Number of Rej. 1240
# Task completed!
# [1] "data_3"
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3660
# alpha = 0.54: FDPhat 0.54, Number of Rej. 3554
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3493
# alpha = 0.52: FDPhat 0.5198, Number of Rej. 3428
# alpha = 0.51: FDPhat 0.51, Number of Rej. 3404
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3336
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 3281
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 3184
# alpha = 0.47: FDPhat 0.4699, Number of Rej. 3103
# alpha = 0.46: FDPhat 0.46, Number of Rej. 3037
# alpha = 0.45: FDPhat 0.4497, Number of Rej. 2993
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2949
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2873
# alpha = 0.42: FDPhat 0.4199, Number of Rej. 2789
# alpha = 0.41: FDPhat 0.4099, Number of Rej. 2718
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 2669
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 2609
# alpha = 0.38: FDPhat 0.3797, Number of Rej. 2568
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 2526
# alpha = 0.36: FDPhat 0.36, Number of Rej. 2475
# alpha = 0.35: FDPhat 0.3497, Number of Rej. 2422
# alpha = 0.34: FDPhat 0.3397, Number of Rej. 2399
# alpha = 0.33: FDPhat 0.3296, Number of Rej. 2342
# alpha = 0.32: FDPhat 0.3196, Number of Rej. 2306
# alpha = 0.31: FDPhat 0.31, Number of Rej. 2271
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 2224
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 2202
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 2165
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 2145
# alpha = 0.26: FDPhat 0.2596, Number of Rej. 2099
# alpha = 0.25: FDPhat 0.2496, Number of Rej. 2079
# alpha = 0.24: FDPhat 0.2397, Number of Rej. 2040
# alpha = 0.23: FDPhat 0.2299, Number of Rej. 2010
# alpha = 0.22: FDPhat 0.22, Number of Rej. 1964
# alpha = 0.21: FDPhat 0.21, Number of Rej. 1924
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1912
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 1876
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 1835
# alpha = 0.17: FDPhat 0.1696, Number of Rej. 1810
# alpha = 0.16: FDPhat 0.16, Number of Rej. 1788
# alpha = 0.15: FDPhat 0.1495, Number of Rej. 1753
# alpha = 0.14: FDPhat 0.1397, Number of Rej. 1711
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 1678
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 1636
# alpha = 0.11: FDPhat 0.1095, Number of Rej. 1608
# alpha = 0.1: FDPhat 0.0997, Number of Rej. 1585
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1570
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 1534
# alpha = 0.07: FDPhat 0.0695, Number of Rej. 1511
# alpha = 0.06: FDPhat 0.0599, Number of Rej. 1452
# alpha = 0.05: FDPhat 0.0498, Number of Rej. 1405
# alpha = 0.04: FDPhat 0.0398, Number of Rej. 1332
# alpha = 0.03: FDPhat 0.0299, Number of Rej. 1306
# alpha = 0.02: FDPhat 0.0197, Number of Rej. 1268
# alpha = 0.01: FDPhat 0.0099, Number of Rej. 1215
# Task completed!
# [1] "data_4"
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3597
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3553
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3503
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3459
# alpha = 0.54: FDPhat 0.54, Number of Rej. 3402
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3329
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3293
# alpha = 0.51: FDPhat 0.5097, Number of Rej. 3231
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3128
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 3017
# alpha = 0.48: FDPhat 0.4798, Number of Rej. 2939
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 2878
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2835
# alpha = 0.45: FDPhat 0.4497, Number of Rej. 2802
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2733
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2696
# alpha = 0.42: FDPhat 0.4197, Number of Rej. 2623
# alpha = 0.41: FDPhat 0.41, Number of Rej. 2583
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2565
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 2517
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 2476
# alpha = 0.37: FDPhat 0.37, Number of Rej. 2411
# alpha = 0.36: FDPhat 0.3597, Number of Rej. 2374
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 2333
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 2286
# alpha = 0.33: FDPhat 0.3299, Number of Rej. 2249
# alpha = 0.32: FDPhat 0.32, Number of Rej. 2219
# alpha = 0.31: FDPhat 0.3099, Number of Rej. 2178
# alpha = 0.3: FDPhat 0.2997, Number of Rej. 2142
# alpha = 0.29: FDPhat 0.2898, Number of Rej. 2112
# alpha = 0.28: FDPhat 0.2796, Number of Rej. 2092
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 2065
# alpha = 0.26: FDPhat 0.2597, Number of Rej. 2033
# alpha = 0.25: FDPhat 0.25, Number of Rej. 2000
# alpha = 0.24: FDPhat 0.2399, Number of Rej. 1988
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 1955
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 1926
# alpha = 0.21: FDPhat 0.2098, Number of Rej. 1911
# alpha = 0.2: FDPhat 0.1999, Number of Rej. 1881
# alpha = 0.19: FDPhat 0.19, Number of Rej. 1858
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1834
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1813
# alpha = 0.16: FDPhat 0.1597, Number of Rej. 1772
# alpha = 0.15: FDPhat 0.1499, Number of Rej. 1728
# alpha = 0.14: FDPhat 0.1399, Number of Rej. 1708
# alpha = 0.13: FDPhat 0.1298, Number of Rej. 1672
# alpha = 0.12: FDPhat 0.12, Number of Rej. 1642
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1623
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 1587
# alpha = 0.09: FDPhat 0.0899, Number of Rej. 1569
# alpha = 0.08: FDPhat 0.0796, Number of Rej. 1521
# alpha = 0.07: FDPhat 0.0699, Number of Rej. 1503
# alpha = 0.06: FDPhat 0.0594, Number of Rej. 1464
# alpha = 0.05: FDPhat 0.0494, Number of Rej. 1437
# alpha = 0.04: FDPhat 0.0394, Number of Rej. 1421
# alpha = 0.03: FDPhat 0.0293, Number of Rej. 1398
# alpha = 0.02: FDPhat 0.0199, Number of Rej. 1357
# alpha = 0.01: FDPhat 0.0095, Number of Rej. 1262
# Task completed!
# [1] "data_5"
# alpha = 0.57: FDPhat 0.5699, Number of Rej. 3727
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3647
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3484
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3382
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 3301
# alpha = 0.52: FDPhat 0.52, Number of Rej. 3250
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3179
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 3067
# alpha = 0.49: FDPhat 0.49, Number of Rej. 3000
# alpha = 0.48: FDPhat 0.48, Number of Rej. 2950
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 2897
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 2823
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2757
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2692
# alpha = 0.43: FDPhat 0.4299, Number of Rej. 2626
# alpha = 0.42: FDPhat 0.4197, Number of Rej. 2590
# alpha = 0.41: FDPhat 0.4096, Number of Rej. 2556
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 2524
# alpha = 0.39: FDPhat 0.3897, Number of Rej. 2502
# alpha = 0.38: FDPhat 0.38, Number of Rej. 2450
# alpha = 0.37: FDPhat 0.3699, Number of Rej. 2425
# alpha = 0.36: FDPhat 0.3596, Number of Rej. 2397
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 2352
# alpha = 0.34: FDPhat 0.34, Number of Rej. 2315
# alpha = 0.33: FDPhat 0.33, Number of Rej. 2279
# alpha = 0.32: FDPhat 0.3197, Number of Rej. 2249
# alpha = 0.31: FDPhat 0.31, Number of Rej. 2213
# alpha = 0.3: FDPhat 0.3, Number of Rej. 2180
# alpha = 0.29: FDPhat 0.2897, Number of Rej. 2140
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 2115
# alpha = 0.27: FDPhat 0.2697, Number of Rej. 2091
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 2047
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 2018
# alpha = 0.24: FDPhat 0.24, Number of Rej. 1971
# alpha = 0.23: FDPhat 0.2296, Number of Rej. 1938
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1915
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 1903
# alpha = 0.2: FDPhat 0.1997, Number of Rej. 1863
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 1849
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1829
# alpha = 0.17: FDPhat 0.1695, Number of Rej. 1782
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 1746
# alpha = 0.15: FDPhat 0.1497, Number of Rej. 1723
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 1695
# alpha = 0.13: FDPhat 0.1298, Number of Rej. 1679
# alpha = 0.12: FDPhat 0.1195, Number of Rej. 1649
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1632
# alpha = 0.1: FDPhat 0.0994, Number of Rej. 1600
# alpha = 0.09: FDPhat 0.09, Number of Rej. 1567
# alpha = 0.08: FDPhat 0.0797, Number of Rej. 1544
# alpha = 0.07: FDPhat 0.0694, Number of Rej. 1499
# alpha = 0.06: FDPhat 0.0597, Number of Rej. 1475
# alpha = 0.05: FDPhat 0.0499, Number of Rej. 1443
# alpha = 0.04: FDPhat 0.0399, Number of Rej. 1404
# alpha = 0.03: FDPhat 0.0298, Number of Rej. 1375
# alpha = 0.02: FDPhat 0.0195, Number of Rej. 1331
# alpha = 0.01: FDPhat 0.01, Number of Rej. 1300
# Task completed!
# [1] "data_6"
# alpha = 0.59: FDPhat 0.5899, Number of Rej. 3667
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3611
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 3531
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3487
# alpha = 0.55: FDPhat 0.5497, Number of Rej. 3429
# alpha = 0.54: FDPhat 0.5398, Number of Rej. 3388
# alpha = 0.53: FDPhat 0.5299, Number of Rej. 3306
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3210
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3124
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3074
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 3023
# alpha = 0.48: FDPhat 0.4797, Number of Rej. 2952
# alpha = 0.47: FDPhat 0.4698, Number of Rej. 2867
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 2836
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2799
# alpha = 0.44: FDPhat 0.4399, Number of Rej. 2771
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2715
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2687
# alpha = 0.41: FDPhat 0.4098, Number of Rej. 2638
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2590
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 2522
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 2482
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 2450
# alpha = 0.36: FDPhat 0.36, Number of Rej. 2414
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 2361
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 2327
# alpha = 0.33: FDPhat 0.3297, Number of Rej. 2290
# alpha = 0.32: FDPhat 0.3199, Number of Rej. 2216
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 2195
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 2164
# alpha = 0.29: FDPhat 0.2899, Number of Rej. 2142
# alpha = 0.28: FDPhat 0.2797, Number of Rej. 2127
# alpha = 0.27: FDPhat 0.2698, Number of Rej. 2105
# alpha = 0.26: FDPhat 0.2599, Number of Rej. 2066
# alpha = 0.25: FDPhat 0.2499, Number of Rej. 2029
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 2002
# alpha = 0.23: FDPhat 0.2297, Number of Rej. 1972
# alpha = 0.22: FDPhat 0.22, Number of Rej. 1932
# alpha = 0.21: FDPhat 0.2096, Number of Rej. 1908
# alpha = 0.2: FDPhat 0.1997, Number of Rej. 1883
# alpha = 0.19: FDPhat 0.1898, Number of Rej. 1849
# alpha = 0.18: FDPhat 0.1796, Number of Rej. 1821
# alpha = 0.17: FDPhat 0.1696, Number of Rej. 1798
# alpha = 0.16: FDPhat 0.16, Number of Rej. 1769
# alpha = 0.15: FDPhat 0.1496, Number of Rej. 1751
# alpha = 0.14: FDPhat 0.1395, Number of Rej. 1728
# alpha = 0.13: FDPhat 0.1296, Number of Rej. 1697
# alpha = 0.12: FDPhat 0.1196, Number of Rej. 1672
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1631
# alpha = 0.1: FDPhat 0.0998, Number of Rej. 1593
# alpha = 0.09: FDPhat 0.0894, Number of Rej. 1566
# alpha = 0.08: FDPhat 0.0797, Number of Rej. 1519
# alpha = 0.07: FDPhat 0.0696, Number of Rej. 1452
# alpha = 0.06: FDPhat 0.0596, Number of Rej. 1427
# alpha = 0.05: FDPhat 0.0495, Number of Rej. 1374
# alpha = 0.04: FDPhat 0.0394, Number of Rej. 1344
# alpha = 0.03: FDPhat 0.0296, Number of Rej. 1282
# alpha = 0.02: FDPhat 0.0199, Number of Rej. 1209
# alpha = 0.01: FDPhat 0.0095, Number of Rej. 1154
# Task completed!
# [1] "data_7"
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3678
# alpha = 0.57: FDPhat 0.5698, Number of Rej. 3559
# alpha = 0.56: FDPhat 0.56, Number of Rej. 3500
# alpha = 0.55: FDPhat 0.55, Number of Rej. 3362
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3295
# alpha = 0.53: FDPhat 0.53, Number of Rej. 3253
# alpha = 0.52: FDPhat 0.5197, Number of Rej. 3217
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3169
# alpha = 0.5: FDPhat 0.4998, Number of Rej. 3143
# alpha = 0.49: FDPhat 0.4898, Number of Rej. 3081
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 2967
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 2934
# alpha = 0.46: FDPhat 0.46, Number of Rej. 2872
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2828
# alpha = 0.44: FDPhat 0.4398, Number of Rej. 2781
# alpha = 0.43: FDPhat 0.4297, Number of Rej. 2676
# alpha = 0.42: FDPhat 0.42, Number of Rej. 2612
# alpha = 0.41: FDPhat 0.41, Number of Rej. 2583
# alpha = 0.4: FDPhat 0.3999, Number of Rej. 2533
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 2496
# alpha = 0.38: FDPhat 0.3799, Number of Rej. 2448
# alpha = 0.37: FDPhat 0.3698, Number of Rej. 2407
# alpha = 0.36: FDPhat 0.3597, Number of Rej. 2374
# alpha = 0.35: FDPhat 0.35, Number of Rej. 2323
# alpha = 0.34: FDPhat 0.3398, Number of Rej. 2304
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 2286
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 2264
# alpha = 0.31: FDPhat 0.3098, Number of Rej. 2237
# alpha = 0.3: FDPhat 0.2996, Number of Rej. 2206
# alpha = 0.29: FDPhat 0.29, Number of Rej. 2176
# alpha = 0.28: FDPhat 0.28, Number of Rej. 2143
# alpha = 0.27: FDPhat 0.2698, Number of Rej. 2109
# alpha = 0.26: FDPhat 0.2598, Number of Rej. 2075
# alpha = 0.25: FDPhat 0.2498, Number of Rej. 2046
# alpha = 0.24: FDPhat 0.2398, Number of Rej. 2018
# alpha = 0.23: FDPhat 0.23, Number of Rej. 1996
# alpha = 0.22: FDPhat 0.2198, Number of Rej. 1947
# alpha = 0.21: FDPhat 0.2097, Number of Rej. 1922
# alpha = 0.2: FDPhat 0.1998, Number of Rej. 1892
# alpha = 0.19: FDPhat 0.1899, Number of Rej. 1843
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1823
# alpha = 0.17: FDPhat 0.1699, Number of Rej. 1789
# alpha = 0.16: FDPhat 0.1598, Number of Rej. 1771
# alpha = 0.15: FDPhat 0.1498, Number of Rej. 1736
# alpha = 0.14: FDPhat 0.1398, Number of Rej. 1688
# alpha = 0.13: FDPhat 0.1298, Number of Rej. 1656
# alpha = 0.12: FDPhat 0.1198, Number of Rej. 1619
# alpha = 0.11: FDPhat 0.1098, Number of Rej. 1603
# alpha = 0.1: FDPhat 0.0999, Number of Rej. 1581
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1548
# alpha = 0.08: FDPhat 0.0795, Number of Rej. 1534
# alpha = 0.07: FDPhat 0.0697, Number of Rej. 1506
# alpha = 0.06: FDPhat 0.0597, Number of Rej. 1475
# alpha = 0.05: FDPhat 0.0494, Number of Rej. 1436
# alpha = 0.04: FDPhat 0.0396, Number of Rej. 1388
# alpha = 0.03: FDPhat 0.0297, Number of Rej. 1279
# alpha = 0.02: FDPhat 0.0199, Number of Rej. 1208
# alpha = 0.01: FDPhat 0.0093, Number of Rej. 1177
# Task completed!
# [1] "data_8"
# alpha = 0.56: FDPhat 0.5599, Number of Rej. 3631
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3535
# alpha = 0.54: FDPhat 0.5399, Number of Rej. 3460
# alpha = 0.53: FDPhat 0.5298, Number of Rej. 3411
# alpha = 0.52: FDPhat 0.5199, Number of Rej. 3343
# alpha = 0.51: FDPhat 0.51, Number of Rej. 3304
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3202
# alpha = 0.49: FDPhat 0.4897, Number of Rej. 3102
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 3059
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 3023
# alpha = 0.46: FDPhat 0.4598, Number of Rej. 2971
# alpha = 0.45: FDPhat 0.45, Number of Rej. 2898
# alpha = 0.44: FDPhat 0.4397, Number of Rej. 2813
# alpha = 0.43: FDPhat 0.4298, Number of Rej. 2757
# alpha = 0.42: FDPhat 0.4198, Number of Rej. 2713
# alpha = 0.41: FDPhat 0.4098, Number of Rej. 2645
# alpha = 0.4: FDPhat 0.3998, Number of Rej. 2589
# alpha = 0.39: FDPhat 0.3899, Number of Rej. 2565
# alpha = 0.38: FDPhat 0.38, Number of Rej. 2529
# alpha = 0.37: FDPhat 0.37, Number of Rej. 2465
# alpha = 0.36: FDPhat 0.36, Number of Rej. 2425
# alpha = 0.35: FDPhat 0.3498, Number of Rej. 2390
# alpha = 0.34: FDPhat 0.3397, Number of Rej. 2361
# alpha = 0.33: FDPhat 0.3296, Number of Rej. 2312
# alpha = 0.32: FDPhat 0.3198, Number of Rej. 2267
# alpha = 0.31: FDPhat 0.31, Number of Rej. 2226
# alpha = 0.3: FDPhat 0.3, Number of Rej. 2200
# alpha = 0.29: FDPhat 0.29, Number of Rej. 2169
# alpha = 0.28: FDPhat 0.28, Number of Rej. 2093
# alpha = 0.27: FDPhat 0.2699, Number of Rej. 2071
# alpha = 0.26: FDPhat 0.2595, Number of Rej. 2046
# alpha = 0.25: FDPhat 0.25, Number of Rej. 2036
# alpha = 0.24: FDPhat 0.2396, Number of Rej. 1999
# alpha = 0.23: FDPhat 0.2298, Number of Rej. 1980
# alpha = 0.22: FDPhat 0.2199, Number of Rej. 1955
# alpha = 0.21: FDPhat 0.2096, Number of Rej. 1932
# alpha = 0.2: FDPhat 0.1999, Number of Rej. 1896
# alpha = 0.19: FDPhat 0.1896, Number of Rej. 1883
# alpha = 0.18: FDPhat 0.1799, Number of Rej. 1857
# alpha = 0.17: FDPhat 0.1697, Number of Rej. 1839
# alpha = 0.16: FDPhat 0.1596, Number of Rej. 1805
# alpha = 0.15: FDPhat 0.1496, Number of Rej. 1745
# alpha = 0.14: FDPhat 0.14, Number of Rej. 1722
# alpha = 0.13: FDPhat 0.1299, Number of Rej. 1686
# alpha = 0.12: FDPhat 0.1196, Number of Rej. 1664
# alpha = 0.11: FDPhat 0.1097, Number of Rej. 1632
# alpha = 0.1: FDPhat 0.0995, Number of Rej. 1598
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1559
# alpha = 0.08: FDPhat 0.08, Number of Rej. 1525
# alpha = 0.07: FDPhat 0.0696, Number of Rej. 1494
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 1446
# alpha = 0.05: FDPhat 0.0499, Number of Rej. 1383
# alpha = 0.04: FDPhat 0.04, Number of Rej. 1351
# alpha = 0.03: FDPhat 0.03, Number of Rej. 1300
# alpha = 0.02: FDPhat 0.0199, Number of Rej. 1256
# alpha = 0.01: FDPhat 0.0098, Number of Rej. 1225
# Task completed!
# [1] "data_9"
# alpha = 0.58: FDPhat 0.5799, Number of Rej. 3716
# alpha = 0.57: FDPhat 0.57, Number of Rej. 3593
# alpha = 0.56: FDPhat 0.5598, Number of Rej. 3521
# alpha = 0.55: FDPhat 0.5499, Number of Rej. 3457
# alpha = 0.54: FDPhat 0.54, Number of Rej. 3402
# alpha = 0.53: FDPhat 0.5297, Number of Rej. 3311
# alpha = 0.52: FDPhat 0.52, Number of Rej. 3229
# alpha = 0.51: FDPhat 0.5099, Number of Rej. 3187
# alpha = 0.5: FDPhat 0.5, Number of Rej. 3094
# alpha = 0.49: FDPhat 0.4899, Number of Rej. 3021
# alpha = 0.48: FDPhat 0.4799, Number of Rej. 2988
# alpha = 0.47: FDPhat 0.4697, Number of Rej. 2902
# alpha = 0.46: FDPhat 0.4597, Number of Rej. 2869
# alpha = 0.45: FDPhat 0.4498, Number of Rej. 2799
# alpha = 0.44: FDPhat 0.44, Number of Rej. 2757
# alpha = 0.43: FDPhat 0.43, Number of Rej. 2721
# alpha = 0.42: FDPhat 0.42, Number of Rej. 2686
# alpha = 0.41: FDPhat 0.4097, Number of Rej. 2636
# alpha = 0.4: FDPhat 0.4, Number of Rej. 2600
# alpha = 0.39: FDPhat 0.3898, Number of Rej. 2558
# alpha = 0.38: FDPhat 0.3796, Number of Rej. 2513
# alpha = 0.37: FDPhat 0.37, Number of Rej. 2473
# alpha = 0.36: FDPhat 0.3599, Number of Rej. 2437
# alpha = 0.35: FDPhat 0.3499, Number of Rej. 2412
# alpha = 0.34: FDPhat 0.3399, Number of Rej. 2380
# alpha = 0.33: FDPhat 0.3298, Number of Rej. 2356
# alpha = 0.32: FDPhat 0.32, Number of Rej. 2319
# alpha = 0.31: FDPhat 0.31, Number of Rej. 2255
# alpha = 0.3: FDPhat 0.2999, Number of Rej. 2234
# alpha = 0.29: FDPhat 0.2896, Number of Rej. 2210
# alpha = 0.28: FDPhat 0.2799, Number of Rej. 2172
# alpha = 0.27: FDPhat 0.2696, Number of Rej. 2107
# alpha = 0.26: FDPhat 0.2597, Number of Rej. 2079
# alpha = 0.25: FDPhat 0.2499, Number of Rej. 2053
# alpha = 0.24: FDPhat 0.24, Number of Rej. 2021
# alpha = 0.23: FDPhat 0.23, Number of Rej. 2000
# alpha = 0.22: FDPhat 0.2196, Number of Rej. 1972
# alpha = 0.21: FDPhat 0.2099, Number of Rej. 1949
# alpha = 0.2: FDPhat 0.1999, Number of Rej. 1906
# alpha = 0.19: FDPhat 0.1895, Number of Rej. 1863
# alpha = 0.18: FDPhat 0.1798, Number of Rej. 1846
# alpha = 0.17: FDPhat 0.1697, Number of Rej. 1809
# alpha = 0.16: FDPhat 0.16, Number of Rej. 1769
# alpha = 0.15: FDPhat 0.1496, Number of Rej. 1745
# alpha = 0.14: FDPhat 0.1395, Number of Rej. 1692
# alpha = 0.13: FDPhat 0.1295, Number of Rej. 1653
# alpha = 0.12: FDPhat 0.1196, Number of Rej. 1614
# alpha = 0.11: FDPhat 0.1096, Number of Rej. 1597
# alpha = 0.1: FDPhat 0.0996, Number of Rej. 1556
# alpha = 0.09: FDPhat 0.0898, Number of Rej. 1525
# alpha = 0.08: FDPhat 0.0799, Number of Rej. 1501
# alpha = 0.07: FDPhat 0.07, Number of Rej. 1458
# alpha = 0.06: FDPhat 0.0595, Number of Rej. 1428
# alpha = 0.05: FDPhat 0.0499, Number of Rej. 1383
# alpha = 0.04: FDPhat 0.04, Number of Rej. 1325
# alpha = 0.03: FDPhat 0.0298, Number of Rej. 1276
# alpha = 0.02: FDPhat 0.0197, Number of Rej. 1217
# alpha = 0.01: FDPhat 0.0093, Number of Rej. 1181
# Task completed!
# Loading required package: nlme
# This is mgcv 1.8-24. For overview type 'help("mgcv-package")'.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# We recommend that you supply (many) more than 1000 p-values for meaningful data-driven hypothesis weighting results.
# Warning message:
# Quick-TRANSfer stage steps exceeded maximum (= 320350)

# %% [markdown]
# ## Figure generation
# ### Collect the results from the saved file

# %%
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
summary_stats = {}
# Python methods
result_path_py = './temp_result/res_' + data_name + '/result.pickle'
with open(result_path_py, 'rb') as fil:
    result_py = pickle.load(fil)
for method in result_py.keys():
    if len(result_py[method])>0:
        summary_stats[method] = {}
        summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
        summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    else:
        continue
    for fdp,power,alpha,dname in result_py[method]:
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# R methods
result_path_r = './temp_result/res_r_' + data_name
r_method_list = ['ihw', 'adapt', 'bl']
for method in r_method_list:
    res_df = pd.read_table(result_path_r + '/res_' + method, delimiter=',') 
    summary_stats[method] = {}
    summary_stats[method]['FDP'] = np.zeros([n_data, len(alpha_list)])
    summary_stats[method]['Power'] = np.zeros([n_data, len(alpha_list)])
    for i in range(res_df.shape[0]):
        fdp,power,alpha,dname = res_df.iloc[i]
        summary_stats[method]['FDP'][int(dname[-1]), alpha_list.index(alpha)] = fdp
        summary_stats[method]['Power'][int(dname[-1]), alpha_list.index(alpha)] = power
# Delete when there is no result
method_list = list(summary_stats.keys())
for method in method_list:
    if np.sum(summary_stats[method]['Power']) == 0:
        del summary_stats[method]

# %% [markdown]
# ### Generate the FDP and power plot

# %%
marker_list = ['o', 'v', 'p', '^', '*', 'h', 'd']
color_list = ['C1', 'C2', 'C4', 'C3', 'C0', 'C5', 'C8']
method_list = ['adafdr-fast', 'adafdr', 'bl', 'adapt', 'ihw', 'sbh', 'bh']
alpha_list = [0.05, 0.1, 0.15, 0.2]
n_data = 10
# FDP
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['FDP'], axis=0)
        y_err = np.std(summary_stats[method]['FDP'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
axis_min = min(x_min, y_min)
axis_max = max(x_max, y_max)
plt.plot([axis_min, axis_max], [axis_min, axis_max], linestyle='--', color='k')
plt.legend(loc=2, fontsize=12)
plt.ylabel('FDP', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
# Power 
plt.figure(figsize = [6, 5])
for i_method,method in enumerate(method_list):
    if method in summary_stats.keys():
        y_val = np.mean(summary_stats[method]['Power'], axis=0)
        y_err = np.std(summary_stats[method]['Power'], axis=0) / np.sqrt(n_data) * 1.96
        plt.errorbar(alpha_list, y_val, yerr=y_err, label=method,\
                     capsize=4, elinewidth = 1.5, linewidth=1.5,\
                     color = color_list[i_method], marker = marker_list[i_method],\
                     markersize = 6, alpha=0.8)
plt.legend(loc=2, fontsize=12)
plt.ylabel('power', fontsize=16)
plt.xlabel('nominal FDR', fontsize=16)
plt.show()
