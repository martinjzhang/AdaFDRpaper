# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from util import *
from prim_fdr import *
from data_loader import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## loading airway data
p,x = load_airway(verbose=True)

## testing the BH method
n_rej,t_rej=bh(p,alpha=0.1,verbose=True)
#print('FDP: %s \n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))

## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,verbose=True)
#print('FDP: %s\n'%str( np.sum((h==0)*(p<t_rej)/np.sum(p<t_rej))))
# Out:
# ## airway data ##
# # hypothesis: 33469
# p=0.000153542287814, x=6.56329425437
# p=0.0655868795554, x=6.25440153322
# p=0.793765241592, x=5.4687478236
# p=0.735407241539, x=4.05928083764
# p=0.578223628721, x=-1.14539457803
#
#
# ### bh summary ###
# # rejections: 4079
# rejection threshold: 0.0121801247322
#
#
# ### sbh summary ###
# # rejections: 3863
# rejection threshold: 0.0094257394541
# null estimate: 1.22441662434

# %% [markdown]
# ### Testing PrimFDR_v2
#
# Baseline:
# Screen Shot 2018-02-13 at 10.43.14 PM![image.png](attachment:image.png)

# %%
PrimFDR_v2(p,x,1,alpha=0.1,n_itr=1000,h=None,verbose=True)
# Out:
# ## ML initialization starts ##
# ## Learned parameters for null population ##
# Slope: w=0.873866050008, a=-1.5038232421875
# Bump 0: w=0.126133949992, mu=[ 0.26919755], sigma=[ 0.11614004]
#
#
# ## Learned parameters for alternative population ##
# Slope: w=0.599086440635, a=3.8670361328125002
# Bump 0: w=0.400913559365, mu=[ 0.77430728], sigma=[ 0.10764312]
# ## Testing Summary ##
# Num of discovery: 5921

# %%
## testing the initialization 
w,a,mu,sigma = ML_init(p,x,3,alpha=0.1,n_itr=100,h=None,verbose=True)
# Out:
# ## ML initialization starts ##
# !!! the model does not converge !!!
# ## Learned parameters for null population ##
# Slope: w=0.484847435213, a=-2.9688134765624996
# Bump 0: w=0.245900771506, mu=[ 0.05365628], sigma=[ 0.03669396]
# Bump 1: w=0.193009578511, mu=[ 0.19567093], sigma=[ 0.07490735]
# Bump 2: w=0.0762422147709, mu=[ 0.56203195], sigma=[ 0.06242815]
# ## Learned parameters ##
# Slope: w=0.0388807125444, a=2.5976318359375004
# Bump 0: w=0.266895521483, mu=[ 0.60550922], sigma=[ 0.07317619]
# Bump 1: w=0.197833505564, mu=[ 0.45123629], sigma=[ 0.06899098]
# Bump 2: w=0.496390260409, mu=[ 0.69414052], sigma=[ 0.07358343]
#
#
# ## Testing Summary ##
# Num of discovery: 6037

# %%
## test prim_fdr
n_rej,t=PrimFDR(p,x,3,alpha=0.1,h=None,n_itr=5000,verbose=True)

print("### Summary ###")
print("method: perim_test_1d")
print("# rejections: %s"%str(n_rej))
print("FDP: %s"%str( np.sum((h==0)*(p<t))/np.sum(p<t)))
print("### End Summary ###")
# Out:
# ### Parameters
# n_itr=5000, n_samp=33469, lambda0=82.1009654652, lambda1=100.0
# ## ML initialization starts ##
# !!! the model does not converge !!!
# ## Learned parameters for null population ##
# Slope: w=0.484847435213, a=-2.9688134765624996
# Bump 0: w=0.245900771506, mu=[ 0.05365628], sigma=[ 0.03669396]
# Bump 1: w=0.193009578511, mu=[ 0.19567093], sigma=[ 0.07490735]
# Bump 2: w=0.0762422147709, mu=[ 0.56203195], sigma=[ 0.06242815]
# ## Learned parameters ##
# Slope: w=0.0388807125444, a=2.5976318359375004
# Bump 0: w=0.266895521483, mu=[ 0.60550922], sigma=[ 0.07317619]
# Bump 1: w=0.197833505564, mu=[ 0.45123629], sigma=[ 0.06899098]
# Bump 2: w=0.496390260409, mu=[ 0.69414052], sigma=[ 0.07358343]
#
#
# ## Testing Summary ##
# Num of discovery: 6037
# ## # of discovery: 6037
# ### initialization value ###
# Slope: a=[ 2.59763193], b=[-9.11409664]
# Bump 0: w=-3.92613, mu=[ 0.60550922], sigma=[ 0.01070951]
# Bump 1: w=-4.16666, mu=[ 0.45123628], sigma=[ 0.00951951]
# Bump 2: w=-3.31117, mu=[ 0.69414049], sigma=[ 0.01082904]
#
#
# ### iteration 0 ###
# mean t:  0.0126224
# mean discovery:  0.140249185814
# loss1:  [-0.12954663]
# loss2:  [ 0.]
# n_rej:  4694
# Estimated FDP: [ 0.0974354]
# FDP: 0.0
# Slope: a=[ 2.59813166], b=[-9.11359692]
# Bump 0: w=-3.92563, mu=[ 0.6050092], sigma=[ 0.01070951]
# Bump 1: w=-4.16616, mu=[ 0.45173627], sigma=[ 0.00951951]
# Bump 2: w=-3.31067, mu=[ 0.69364047], sigma=[ 0.01082904]
# ### iteration 1000 ###
# mean t:  0.0133334
# mean discovery:  0.142370551854
# loss1:  [-0.13335682]
# loss2:  [ 0.]
# n_rej:  4765
# Estimated FDP: [ 0.09998269]
# FDP: 0.0
# Slope: a=[ 2.60783672], b=[-9.13570118]
# Bump 0: w=-3.91273, mu=[ 0.54186076], sigma=[ 0.01070951]
# Bump 1: w=-4.14769, mu=[ 0.49245316], sigma=[ 0.00951951]
# Bump 2: w=-3.29887, mu=[ 0.69566715], sigma=[ 0.01082904]
# ### iteration 2000 ###
# mean t:  0.0133121
# mean discovery:  0.14204188951
# loss1:  [-0.13333337]
# loss2:  [ 0.]
# n_rej:  4754
# Estimated FDP: [ 0.09984108]
# FDP: 0.0
# Slope: a=[ 2.6121521], b=[-9.16415215]
# Bump 0: w=-3.90579, mu=[ 0.54048079], sigma=[ 0.01070951]
# Bump 1: w=-4.1399, mu=[ 0.49722728], sigma=[ 0.00951951]
# Bump 2: w=-3.2872, mu=[ 0.69928902], sigma=[ 0.01082904]
# ### iteration 3000 ###
# mean t:  0.0133104
# mean discovery:  0.14186261914
# loss1:  [-0.13335854]
# loss2:  [ 0.]
# n_rej:  4748
# Estimated FDP: [ 0.0998095]
# FDP: 0.0
# Slope: a=[ 2.61551237], b=[-9.1929388]
# Bump 0: w=-3.89916, mu=[ 0.54092896], sigma=[ 0.01070951]
# Bump 1: w=-4.13254, mu=[ 0.49860927], sigma=[ 0.00951951]
# Bump 2: w=-3.2761, mu=[ 0.70187247], sigma=[ 0.01082904]
# ### iteration 4000 ###
# mean t:  0.0133189
# mean discovery:  0.141892497535
# loss1:  [-0.13341039]
# loss2:  [ 0.]
# n_rej:  4749
# Estimated FDP: [ 0.09983424]
# FDP: 0.0
# Slope: a=[ 2.61781454], b=[-9.22216988]
# Bump 0: w=-3.89287, mu=[ 0.54207516], sigma=[ 0.01070951]
# Bump 1: w=-4.1256, mu=[ 0.49905059], sigma=[ 0.00951951]
# Bump 2: w=-3.26601, mu=[ 0.70387673], sigma=[ 0.01082904]
# ### Summary ###
# method: perim_test_1d
# # rejections: 6039
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-1cbb6f9d4333> in <module>()
#       5 print("method: perim_test_1d")
#       6 print("# rejections: %s"%str(n_rej))
# ----> 7 print("FDP: %s"%str( np.sum((h==0)*(p<t))/np.sum(p<t)))
#       8 print("### End Summary ###")
#
# NameError: name 'h' is not defined
