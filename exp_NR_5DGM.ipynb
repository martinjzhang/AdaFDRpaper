# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from util import *
from prim_fdr import *
from data_loader import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
p,h,x = load_5DGM(verbose=True)
# Out:
# /home/martin/NeuralFDR2/NeuralFDR2/data_loader.py:232: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
#   pi1 = ((mlab.bivariate_normal(x1, x2, 0.25, 0.25, -0.5, -0.2)+
# /home/martin/NeuralFDR2/NeuralFDR2/data_loader.py:233: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
#   mlab.bivariate_normal(x1, x2, 0.25, 0.25, 0.7, 0.5))/2).clip(max=1)
# /home/martin/NeuralFDR2/NeuralFDR2/data_loader.py:254: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
#   pi1_grid = ((mlab.bivariate_normal(X_grid, Y_grid, 0.25, 0.25, -0.5, -0.2)+
# /home/martin/NeuralFDR2/NeuralFDR2/data_loader.py:255: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
#   mlab.bivariate_normal(X_grid, Y_grid, 0.25, 0.25, 0.7, 0.5))/2).clip(max=1)

# %% [markdown]
# ### Testing
#
# Screen Shot 2018-03-02 at 12.10.50 AM![image.png](attachment:image.png)

# %%
n_rej,t,_=PrimFDR(p,x,5,alpha=0.1,h=None,n_itr=200,verbose=True)
# Out:
# ## PrimFDR_init starts
# # Learning null distribution
# ## initialization
# Slope: w=0.5, a=[-0.03883301 -0.13649902 -0.03883301 -0.03883301 -0.03883301]
# Bump 0: w=0.1, mu=[0.71984798 0.28327989 0.75344862 0.5043113  0.50060067], sigma=[0.17111688 0.17324702 0.15202807 0.28362702 0.28818239]
# Bump 1: w=0.1, mu=[0.72104329 0.28990533 0.25179273 0.50179046 0.49917642], sigma=[0.17220995 0.17684516 0.15433244 0.28472921 0.28738354]
# Bump 2: w=0.1, mu=[0.38962648 0.76560783 0.50662226 0.25257173 0.50254528], sigma=[0.25558624 0.15597428 0.28560149 0.15509254 0.28829877]
# Bump 3: w=0.1, mu=[0.22391394 0.15334253 0.4960364  0.49705493 0.49884899], sigma=[0.15387772 0.10263074 0.28343172 0.28836748 0.28917425]
# Bump 4: w=0.1, mu=[0.39558599 0.76807999 0.49537614 0.74794652 0.49991851], sigma=[0.25715795 0.15446561 0.28541052 0.15478599 0.28791742]
#
#
# Slope: w=0.9397596130621108, a=[-0.13649902  0.05882324 -0.03883301 -0.03883301 -0.03883301]
# ...

# %%
_=PrimFDR_cv(p,x,5,alpha=0.1,n_itr=10000,h=None,verbose=True)
# Out:
# #time start: 0.0s
# #time input: 0.0132s
# ## testing fold 1: 0.0133s
# pfdr_test start
# PrimFDR start
# gamma1 0.3729823750501847
# 0 1.0000000000000002 8422 2112 0.25077178817383045
# 0 0.5000000000000001 6441 1042 0.1617761217202298
# 0 0.25000000000000006 5057 536 0.1059916946806407
# 0 0.12500000000000003 3985 262 0.0657465495608532
# 0.06250000000000001 0.12500000000000003 4572 403 0.08814523184601925
# 0.09375000000000003 0.12500000000000003 4823 458 0.09496164213145346
# 0.10937500000000003 0.12500000000000003 4942 497 0.10056657223796034
# 0.10937500000000003 0.11718750000000003 4878 481 0.0986059860598606
# 0.11328125000000003 0.11718750000000003 4919 490 0.09961374263061598
# 0.11523437500000003 0.11718750000000003 4932 493 0.09995944849959448
# 0.11621093750000003 0.11718750000000003 4939 495 0.10022271714922049
# 0.11621093750000003 0.11669921875000003 4935 494 0.10010131712259372
# 0.11621093750000003 0.11645507812500003 4933 493 0.09993918508007298
# ...

# %%
n_rej,t,_=PrimFDR(p,x,5,alpha=0.1,h=None,n_itr=20000,verbose=True)
# Out:
# ## PrimFDR_init starts
# # Learning null distribution
# # Learning alternative distribution
# # Test result with PrimFDR_init
# # Num of discovery: 15541
# ## PrimFDR_init finishes
#
# ## optimization paramter:
# # n_itr=20000, n_samp=100000, lambda0=226, lambda1=100
#
# ## optimization initialization:
# # Slope: a=[ 1.13293457  1.23058105  0.05882324  0.05882324 -0.03883301], b=[-5.94591379]
# # Bump 0: w=-0.729559, mu=[ 0.83072633  0.74622214  0.69596279  0.50754923  0.70153838], sigma=[ 0.01583763  0.0209179   0.05864296  0.14973281  0.0640825 ]
# # Bump 1: w=-0.860925, mu=[ 0.25794011  0.39293268  0.73820341  0.48276147  0.50602984], sigma=[ 0.02407809  0.02533035  0.04810076  0.15424578  0.1593181 ]
# # Bump 2: w=-0.852923, mu=[ 0.8249439   0.74185699  0.22468804  0.48649761  0.64588666], sigma=[ 0.01601801  0.02140713  0.03586517  0.13998507  0.08213034]
# ...
