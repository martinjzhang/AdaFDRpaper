# %%
import matplotlib
matplotlib.use('Agg')
import logging
import os
import data_loader as dl
import prim_fdr as pf
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
output_folder = './results/ukbb'

# %%
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    
logging.basicConfig(level=logging.DEBUG,
    format='%(module)s:: %(message)s',
    filename=output_folder+'/result.log', filemode='w')
logger = logging.getLogger()

# %%
p,x,n_full,cate_name = dl.load_ukbb(verbose=True)
# Out:
# ## Load GTEx full data ##
# # all hypothesis: 847800
# # filtered hypothesis: 89577
# # p=0.99706, x=[19.  0.]
# # p=0.969224, x=[19.  0.]
# # p=0.952471, x=[1.9e+01 1.0e-03]
# # p=0.987448, x=[19.  0.]
# # p=0.98016, x=[19.  0.]

# %%
n_rej,t_rej=pf.bh(p,alpha=0.1,n_sample=n_full,verbose=True)
logger.info('## BH, n_rej=%d, t_rej=%0.5f'%(n_rej,t_rej))
n_rej,t_rej,pi0_hat=pf.storey_bh(p,alpha=0.1,n_sample=n_full,lamb=0.995,verbose=True)
logger.info('## SBH, n_rej=%d, t_rej=%0.5f'%(n_rej,t_rej))
# Out:
# ## bh testing summary ##
# # n_rej = 151
# # t_rej = 0.000018
#
#
# ## sbh summary ##
# # n_rej = 151
# # t_rej = 0.000018
# # pi_0 estimate = 1.000

# %%
n_rej,t,_=pf.PrimFDR(p,x,5,alpha=0.1,h=None,n_itr=1000,verbose=True,output_folder=output_folder,logger=logger)
logger.info('## PF, n_rej=%d'%(n_rej))
logger.info('## Total time: %0.1fs'%(time.time()-start_time))
# Out:
# ## PrimFDR_init starts
# # Learning null distribution
# ## initialization
# Slope: w=0.5, a=[-0.02357269  0.01915436]
# Bump 0: w=0.1, mu=[0.24231957 0.2315123 ], sigma=[0.15319278 0.14072885]
# Bump 1: w=0.1, mu=[0.25209094 0.73105257], sigma=[0.15455019 0.16126999]
# Bump 2: w=0.1, mu=[0.63290321 0.39272576], sigma=[0.13013564 0.12962039]
# Bump 3: w=0.1, mu=[0.88323366 0.15716884], sigma=[0.06892809 0.12598546]
# Bump 4: w=0.1, mu=[0.74446514 0.76350327], sigma=[0.15239675 0.14639994]
#
#
# Slope: w=0.7867283660905728, a=[-0.39592438  0.26937347]
# Bump 0: w=0.042263191224507654, mu=[0.40894198 0.22645081], sigma=[0.12635322 0.04571432]
# Bump 1: w=0.021969953779929243, mu=[0.3111984  0.61885957], sigma=[0.12942671 0.12984041]
# Bump 2: w=0.04539766367127189, mu=[0.67159634 0.37826604], sigma=[0.04780422 0.03659102]
# Bump 3: w=0.03964245797687269, mu=[0.83961462 0.08221648], sigma=[0.04340957 0.04514085]
# Bump 4: w=0.06399836725684566, mu=[0.71992498 0.70235403], sigma=[0.13903649 0.14563974]
#
#
# # Learning alternative distribution
# ## initialization
# Slope: w=0.5, a=[ 0.03136017 -0.00526031]
# Bump 0: w=0.1, mu=[0.81595899 0.75667869], sigma=[0.11173831 0.15315404]
# Bump 1: w=0.1, mu=[0.26225281 0.20588877], sigma=[0.15732771 0.12768615]
# Bump 2: w=0.1, mu=[0.76221418 0.27743745], sigma=[0.15414858 0.16774923]
# Bump 3: w=0.1, mu=[0.49015874 0.73221557], sigma=[0.12173998 0.16332836]
# Bump 4: w=0.1, mu=[0.17313609 0.69206392], sigma=[0.10803916 0.18370289]
#
#
# Slope: w=0.8831129996225294, a=[0.35481415 0.1839328 ]
# Bump 0: w=0.0026016505470365303, mu=[0.56995319 0.63636033], sigma=[0.15976221 0.16214655]
# Bump 1: w=0.047258270813188584, mu=[0.23439559 0.0994038 ], sigma=[0.13289092 0.05585169]
# Bump 2: w=0.0033959886179555313, mu=[0.5420624  0.51497053], sigma=[0.18313802 0.05027162]
# Bump 3: w=0.030435567518095015, mu=[0.41452131 0.72575301], sigma=[0.10134118 0.1449957 ]
# Bump 4: w=0.033195522881195025, mu=[0.14485637 0.39237542], sigma=[0.065835   0.17587076]
#
#
# # Test result with PrimFDR_init
# # Num of discovery: 207
#
#
# ## PrimFDR_init finishes
#
# ## optimization paramter:
# # n_itr=1000, n_samp=89577, lambda0=58822, lambda1=100
#
# [45.37107947 83.41934304]
# ## optimization initialization:
# # Slope: a=[0.35481414 0.1839328 ], b=[-10.689454]
# # Bump 0: w=-14.425291, mu=[0.5699532  0.63636035], sigma=[0.43176037 0.22797531]
# # Bump 1: w=-10.275851, mu=[0.2343956 0.0994038], sigma=[0.62402254 1.9214565 ]
# # Bump 2: w=-13.124336, mu=[0.5420624  0.51497054], sigma=[0.3285745 2.371688 ]
# # Bump 3: w=-11.398835, mu=[0.4145213 0.725753 ], sigma=[1.0730476  0.28509724]
# # Bump 4: w=-11.073736, mu=[0.14485638 0.3923754 ], sigma=[2.542595   0.19378313]
#
#
# ## iteration 0
# n_rej:  209
# n_rej sig:  203.01408
# FD esti mirror: 21
# FD esti mirror sig: 21.30231
# loss1:  -0.002266362
# loss2:  [0.00111512]
# Estimated FDP: 0.104920335
# FDP: 0.0
# Slope: a=[0.33481628 0.16393498], b=[-10.709453]
# Bump 0: w=-14.444854, mu=[0.58937436 0.6172638 ], sigma=[0.4513819  0.24771252]
# Bump 1: w=-10.295808, mu=[0.2143971  0.11940292], sigma=[0.64400256 1.941422  ]
# Bump 2: w=-13.143884, mu=[0.56202203 0.4949949 ], sigma=[0.3483823 2.3897967]
# Bump 3: w=-11.418811, mu=[0.39453655 0.7057586 ], sigma=[1.0929894  0.30508152]
# Bump 4: w=-11.093702, mu=[0.12486424 0.41234478], sigma=[2.5624354  0.21376334]
#
#
# ## iteration 200
# n_rej:  291
# n_rej sig:  280.79715
# FD esti mirror: 23
# FD esti mirror sig: 27.414032
# loss1:  -0.003134699
# loss2:  [0.]
# Estimated FDP: 0.097632624
# FDP: 0.0
# Slope: a=[0.3526381  0.20154253], b=[-10.7134905]
# Bump 0: w=-13.770946, mu=[0.6550785  0.48543346], sigma=[0.82021534 0.4901135 ]
# Bump 1: w=-9.026674, mu=[0.21162878 0.1186953 ], sigma=[0.06410743 3.1799233 ]
# Bump 2: w=-11.160864, mu=[0.4807411  0.40267938], sigma=[-0.00816733  2.232612  ]
# Bump 3: w=-9.225865, mu=[0.25956818 0.5598065 ], sigma=[1.7674516 0.620638 ]
# Bump 4: w=-8.807087, mu=[-0.01546933  0.47324026], sigma=[3.1514277  0.12181924]
#
#
# ## iteration 400
# n_rej:  314
# n_rej sig:  299.62158
# FD esti mirror: 26
# FD esti mirror sig: 29.854218
# loss1:  -0.0033448474
# loss2:  [0.]
# Estimated FDP: 0.09964121
# FDP: 0.0
# Slope: a=[0.4110203  0.24743772], b=[-10.692398]
# Bump 0: w=-13.416196, mu=[0.6567509 0.505734 ], sigma=[0.8972805 0.500571 ]
# Bump 1: w=-8.99213, mu=[0.3192349  0.13327792], sigma=[0.03633305 3.273518  ]
# Bump 2: w=-11.065966, mu=[0.48184216 0.3955001 ], sigma=[-0.03480965  2.290849  ]
# Bump 3: w=-9.03865, mu=[0.2714824 0.5635946], sigma=[1.9787081 0.5756843]
# Bump 4: w=-8.576199, mu=[-0.02397738  0.4650435 ], sigma=[3.2761657  0.14123148]
#
#
# ## iteration 600
# n_rej:  317
# n_rej sig:  301.45224
# FD esti mirror: 26
# FD esti mirror sig: 30.114084
# loss1:  -0.0033652843
# loss2:  [0.]
# Estimated FDP: 0.09989843
# FDP: 0.0
# Slope: a=[0.41624153 0.25208104], b=[-10.693213]
# Bump 0: w=-13.343845, mu=[0.65594965 0.5086799 ], sigma=[0.91754675 0.50279385]
# Bump 1: w=-8.986371, mu=[0.33002847 0.13420227], sigma=[0.03650993 3.2939918 ]
# Bump 2: w=-11.039902, mu=[0.48240703 0.39495578], sigma=[-0.0424976  2.309433 ]
# Bump 3: w=-9.0176115, mu=[0.27167726 0.5650823 ], sigma=[2.0136957 0.5762429]
# Bump 4: w=-8.532854, mu=[-0.02473808  0.46593857], sigma=[3.2976925 0.1403857]
#
#
# ## iteration 800
# n_rej:  317
# n_rej sig:  301.91504
# FD esti mirror: 26
# FD esti mirror sig: 30.186144
# loss1:  -0.003370451
# loss2:  [0.]
# Estimated FDP: 0.0999844
# FDP: 0.0
# Slope: a=[0.4173454  0.25309488], b=[-10.693263]
# Bump 0: w=-13.3296795, mu=[0.65587425 0.5095045 ], sigma=[0.9212776  0.50293976]
# Bump 1: w=-8.985004, mu=[0.33240622 0.13445921], sigma=[0.03647475 3.29795   ]
# Bump 2: w=-11.033364, mu=[0.48256186 0.39480415], sigma=[-0.04445267  2.3132696 ]
# Bump 3: w=-9.013699, mu=[0.27181047 0.56550264], sigma=[2.020037  0.5763281]
# Bump 4: w=-8.5239525, mu=[-0.0248071  0.466237 ], sigma=[3.301633   0.14011106]
#
#
# # Num of discovery: 203
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fad038481382> in <module>()
#       1 n_rej,t,_=pf.PrimFDR(p,x,5,alpha=0.1,h=None,n_itr=1000,verbose=True,output_folder=output_folder,logger=logger)
#       2 logger.info('## PF, n_rej=%d'%(n_rej))
# ----> 3 logger.info('## Total time: %0.1fs'%(time.time()-start_time))
#
# NameError: name 'start_time' is not defined

# %%
p,x,n_full,cate_name = dl.load_ukbb(verbose=True, use_other=True)
# Out:
# ## Load GTEx full data ##
# # all hypothesis: 847800
# # filtered hypothesis: 89577
# # p=0.99706, x=[19.        0.        0.255087  0.576189  0.182763  0.662377]
# # p=0.969224, x=[19.        0.        0.247647  0.596876  0.58193   0.391994]
# # p=0.952471, x=[1.90000e+01 1.00000e-03 8.06289e-01 1.96430e-01 5.83755e-01 9.27449e-01]
# # p=0.987448, x=[19.        0.        0.188702  0.511884  0.120008  0.819033]
# # p=0.98016, x=[19.        0.        0.221527  0.242656  0.373062  0.64991 ]

# %%
n_rej,t,_=pf.PrimFDR(p,x,5,alpha=0.1,h=None,n_itr=1000,verbose=True,output_folder=output_folder,logger=logger)
logger.info('## PF, n_rej=%d'%(n_rej))
# Out:
# ## PrimFDR_init starts
# # Learning null distribution
# ## initialization
# Slope: w=0.5, a=[-0.02204666  0.01762863  0.04814316 -0.00373428 -0.00983841  0.02983444]
# Bump 0: w=0.1, mu=[0.28910833 0.24972207 0.5110612  0.4903359  0.39989594 0.51141065], sigma=[0.18207121 0.14401748 0.29109368 0.28519838 0.23647513 0.29144674]
# Bump 1: w=0.1, mu=[0.82526247 0.28524524 0.52448764 0.49931979 0.4618855  0.50910866], sigma=[0.11287075 0.1956939  0.28750538 0.28402123 0.26188557 0.29437265]
# Bump 2: w=0.1, mu=[0.51303723 0.79001581 0.51262056 0.50123571 0.6599382  0.52548188], sigma=[0.27775775 0.1339224  0.28522877 0.28541205 0.17901876 0.28759786]
# Bump 3: w=0.1, mu=[0.48620569 0.7107622  0.49589543 0.48808617 0.21930773 0.48742306], sigma=[0.27495159 0.1782086  0.2880289  0.28402913 0.13555925 0.29301746]
# Bump 4: w=0.1, mu=[0.42540283 0.44587091 0.47622064 0.52545679 0.853829   0.47868646], sigma=[0.26670059 0.24477227 0.28380363 0.28509324 0.09214679 0.28331117]
#
#
# Slope: w=0.8744708217703712, a=[-0.10750443  0.05119461  0.05119461 -0.00678635 -0.02204666  0.02678299]
# Bump 0: w=0.025153169270322153, mu=[0.49008596 0.2338308  0.51724453 0.49128469 0.47665111 0.50956444], sigma=[0.05836342 0.04028626 1.         1.         0.24960372 1.        ]
# Bump 1: w=0.04075634904838252, mu=[0.67170111 0.37854955 0.50394157 0.50758542 0.49234866 0.49932598], sigma=[0.04679994 0.03535501 1.         1.         1.         1.        ]
# Bump 2: w=0.021680662928500218, mu=[0.50910001 0.71147129 0.50326124 0.50112735 0.62767638 0.51891157], sigma=[1.         0.13492366 1.         1.         0.16267214 1.        ]
# Bump 3: w=0.024125998605761832, mu=[0.50464457 0.66555478 0.49312622 0.49221729 0.26041833 0.49817805], sigma=[1.         0.14686613 1.         1.         0.122303   1.        ]
# Bump 4: w=0.013812998376662144, mu=[0.4843577  0.54176038 0.48825658 0.51366912 0.84250002 0.49858082], sigma=[1.         0.20155556 1.         1.         0.0587831  1.        ]
#
#
# # Learning alternative distribution
# ## initialization
# Slope: w=0.5, a=[ 0.03288589 -0.02815079 -0.08308792  0.00236984  0.00236984 -0.0434111 ]
# Bump 0: w=0.1, mu=[0.51376386 0.62431072 0.48098909 0.22988269 0.48599226 0.48690048], sigma=[0.27340265 0.22827292 0.29474349 0.14519075 0.27873667 0.29375233]
# Bump 1: w=0.1, mu=[0.512728   0.61856997 0.5054515  0.72741927 0.30181354 0.49433101], sigma=[0.28056231 0.22938536 0.28250975 0.16903308 0.18326997 0.28120968]
# Bump 2: w=0.1, mu=[0.87106608 0.10364905 0.49291498 0.48896464 0.49002194 0.5026647 ], sigma=[0.06989649 0.07069286 0.29189572 0.28700232 0.28605053 0.28970202]
# Bump 3: w=0.1, mu=[0.49993958 0.59006843 0.5106078  0.71692074 0.80828422 0.51229768], sigma=[0.27325344 0.24177949 0.2901265  0.18026988 0.12190413 0.28081655]
# Bump 4: w=0.1, mu=[0.2650312  0.1595198  0.50053735 0.48225617 0.49490819 0.50662513], sigma=[0.16002794 0.09569289 0.2845672  0.28420772 0.2823883  0.28585191]
#
#
# Slope: w=0.8572581342580025, a=[ 0.02983444  0.46619217 -0.09224411  0.01152573 -0.00983841 -0.05561935]
# Bump 0: w=0.016308810207145447, mu=[0.50763472 0.6030108  0.49361176 0.3268926  0.49576436 0.49527628], sigma=[1.         0.14004824 1.         0.15320826 1.         1.        ]
# Bump 1: w=0.007449600233497622, mu=[0.49463187 0.50690752 0.49444776 0.68756939 0.38169463 0.51613095], sigma=[1.         0.07711538 1.         0.13626496 0.15606037 1.        ]
# Bump 2: w=0.04895264548315059, mu=[0.83738862 0.08378987 0.49606589 0.4905011  0.48638635 0.5001306 ], sigma=[0.04849435 0.04602868 1.         1.         1.         1.        ]
# Bump 3: w=0.008571054931837295, mu=[0.49213737 0.52133929 0.51706083 0.71629959 0.74177457 0.51736631], sigma=[1.         0.13324763 1.         0.14912165 0.14324976 1.        ]
# Bump 4: w=0.061459754886366805, mu=[0.23742872 0.15040374 0.49886939 0.49180114 0.50778703 0.50222194], sigma=[0.13308787 0.07493007 1.         1.         1.         1.        ]
#
#
# # Test result with PrimFDR_init
# # Num of discovery: 235
#
#
# ## PrimFDR_init finishes
#
# ## optimization paramter:
# # n_itr=1000, n_samp=89577, lambda0=630476309, lambda1=100
#
# [48.46816252 92.55765985  0.5        14.34278059  9.27913712  0.5       ]
# ## optimization initialization:
# # Slope: a=[ 0.02983444  0.46619216 -0.09224411  0.01152573 -0.00983841 -0.05561936], b=[-10.392818]
# # Bump 0: w=-15.842263, mu=[0.5076347  0.6030108  0.49361175 0.32689258 0.49576434 0.49527627], sigma=[0.01031605 0.27542433 1.         1.4851567  0.05388432 1.        ]
# # Bump 1: w=-14.054415, mu=[0.4946319  0.5069075  0.49444777 0.6875694  0.38169464 0.5161309 ], sigma=[0.01031605 0.90839684 1.         1.8774496  2.2124686  1.        ]
# # Bump 2: w=-12.480042, mu=[0.83738863 0.08378987 0.49606588 0.4905011  0.48638636 0.5001306 ], sigma=[4.3866315  2.5497675  1.         0.03486075 0.05388432 1.        ]
# # Bump 3: w=-14.465599, mu=[0.49213737 0.5213393  0.5170608  0.7162996  0.74177456 0.5173663 ], sigma=[0.01031605 0.30425563 1.         1.5676723  2.6258783  1.        ]
# # Bump 4: w=-13.749366, mu=[0.23742872 0.15040374 0.4988694  0.49180114 0.50778705 0.50222194], sigma=[0.5824203  0.96215564 1.         0.03486075 0.05388432 1.        ]
#
#
# ## iteration 0
# n_rej:  219
# n_rej sig:  219.00017
# FD esti mirror: 22
# FD esti mirror sig: 22.000183
# loss1:  -0.002444824
# loss2:  [0.00011164]
# Estimated FDP: 0.10045662
# FDP: 0.0
# Slope: a=[ 0.02983444  0.46619216 -0.09224411  0.01152573 -0.00983841 -0.05561936], b=[-10.392818]
# Bump 0: w=-15.842263, mu=[0.5076347  0.6030108  0.49361175 0.32689258 0.49576434 0.49527627], sigma=[0.01031605 0.27542433 1.         1.4851567  0.05388432 1.        ]
# Bump 1: w=-14.054415, mu=[0.4946319  0.5069075  0.49444777 0.6875694  0.38169464 0.5161309 ], sigma=[0.01031605 0.90839684 1.         1.8774496  2.2124686  1.        ]
# Bump 2: w=-12.480042, mu=[0.83738863 0.08378987 0.49606588 0.4905011  0.48638636 0.5001306 ], sigma=[4.3866315  2.5497675  1.         0.03486075 0.05388432 1.        ]
# Bump 3: w=-14.465599, mu=[0.49213737 0.5213393  0.5170608  0.7162996  0.74177456 0.5173663 ], sigma=[0.01031605 0.30425563 1.         1.5676723  2.6258783  1.        ]
# Bump 4: w=-13.749366, mu=[0.23742872 0.15040374 0.4988694  0.49180114 0.50778705 0.50222194], sigma=[0.5824203  0.96215564 1.         0.03486075 0.05388432 1.        ]
#
#
# ## iteration 200
# n_rej:  219
# n_rej sig:  219.00017
# FD esti mirror: 22
# FD esti mirror sig: 22.000183
# loss1:  -0.002444824
# loss2:  [0.00011164]
# Estimated FDP: 0.10045662
# FDP: 0.0
# Slope: a=[ 0.02983444  0.46619216 -0.09224411  0.01152573 -0.00983841 -0.05561936], b=[-10.392818]
# Bump 0: w=-15.842263, mu=[0.5076347  0.6030108  0.49361175 0.32689258 0.49576434 0.49527627], sigma=[0.01031605 0.27542433 1.         1.4851567  0.05388432 1.        ]
# Bump 1: w=-14.054415, mu=[0.4946319  0.5069075  0.49444777 0.6875694  0.38169464 0.5161309 ], sigma=[0.01031605 0.90839684 1.         1.8774496  2.2124686  1.        ]
# Bump 2: w=-12.480042, mu=[0.83738863 0.08378987 0.49606588 0.4905011  0.48638636 0.5001306 ], sigma=[4.3866315  2.5497675  1.         0.03486075 0.05388432 1.        ]
# Bump 3: w=-14.465599, mu=[0.49213737 0.5213393  0.5170608  0.7162996  0.74177456 0.5173663 ], sigma=[0.01031605 0.30425563 1.         1.5676723  2.6258783  1.        ]
# Bump 4: w=-13.749366, mu=[0.23742872 0.15040374 0.4988694  0.49180114 0.50778705 0.50222194], sigma=[0.5824203  0.96215564 1.         0.03486075 0.05388432 1.        ]
#
#
# ## iteration 400
# n_rej:  219
# n_rej sig:  219.00017
# FD esti mirror: 22
# FD esti mirror sig: 22.000183
# loss1:  -0.002444824
# loss2:  [0.00011164]
# Estimated FDP: 0.10045662
# FDP: 0.0
# Slope: a=[ 0.02983444  0.46619216 -0.09224411  0.01152573 -0.00983841 -0.05561936], b=[-10.392818]
# Bump 0: w=-15.842263, mu=[0.5076347  0.6030108  0.49361175 0.32689258 0.49576434 0.49527627], sigma=[0.01031605 0.27542433 1.         1.4851567  0.05388432 1.        ]
# Bump 1: w=-14.054415, mu=[0.4946319  0.5069075  0.49444777 0.6875694  0.38169464 0.5161309 ], sigma=[0.01031605 0.90839684 1.         1.8774496  2.2124686  1.        ]
# Bump 2: w=-12.480042, mu=[0.83738863 0.08378987 0.49606588 0.4905011  0.48638636 0.5001306 ], sigma=[4.3866315  2.5497675  1.         0.03486075 0.05388432 1.        ]
# Bump 3: w=-14.465599, mu=[0.49213737 0.5213393  0.5170608  0.7162996  0.74177456 0.5173663 ], sigma=[0.01031605 0.30425563 1.         1.5676723  2.6258783  1.        ]
# Bump 4: w=-13.749366, mu=[0.23742872 0.15040374 0.4988694  0.49180114 0.50778705 0.50222194], sigma=[0.5824203  0.96215564 1.         0.03486075 0.05388432 1.        ]
# ## iteration 600
# n_rej:  219
# n_rej sig:  219.00017
# FD esti mirror: 22
# FD esti mirror sig: 22.000183
# loss1:  -0.002444824
# loss2:  [0.00011164]
# Estimated FDP: 0.10045662
# FDP: 0.0
# Slope: a=[ 0.02983444  0.46619216 -0.09224411  0.01152573 -0.00983841 -0.05561936], b=[-10.392818]
# Bump 0: w=-15.842263, mu=[0.5076347  0.6030108  0.49361175 0.32689258 0.49576434 0.49527627], sigma=[0.01031605 0.27542433 1.         1.4851567  0.05388432 1.        ]
# Bump 1: w=-14.054415, mu=[0.4946319  0.5069075  0.49444777 0.6875694  0.38169464 0.5161309 ], sigma=[0.01031605 0.90839684 1.         1.8774496  2.2124686  1.        ]
# Bump 2: w=-12.480042, mu=[0.83738863 0.08378987 0.49606588 0.4905011  0.48638636 0.5001306 ], sigma=[4.3866315  2.5497675  1.         0.03486075 0.05388432 1.        ]
# Bump 3: w=-14.465599, mu=[0.49213737 0.5213393  0.5170608  0.7162996  0.74177456 0.5173663 ], sigma=[0.01031605 0.30425563 1.         1.5676723  2.6258783  1.        ]
# Bump 4: w=-13.749366, mu=[0.23742872 0.15040374 0.4988694  0.49180114 0.50778705 0.50222194], sigma=[0.5824203  0.96215564 1.         0.03486075 0.05388432 1.        ]
#
#
# ## iteration 800
# n_rej:  219
# n_rej sig:  219.00017
# FD esti mirror: 22
# FD esti mirror sig: 22.000183
# loss1:  -0.002444824
# loss2:  [0.00011164]
# Estimated FDP: 0.10045662
# FDP: 0.0
# Slope: a=[ 0.02983444  0.46619216 -0.09224411  0.01152573 -0.00983841 -0.05561936], b=[-10.392818]
# Bump 0: w=-15.842263, mu=[0.5076347  0.6030108  0.49361175 0.32689258 0.49576434 0.49527627], sigma=[0.01031605 0.27542433 1.         1.4851567  0.05388432 1.        ]
# Bump 1: w=-14.054415, mu=[0.4946319  0.5069075  0.49444777 0.6875694  0.38169464 0.5161309 ], sigma=[0.01031605 0.90839684 1.         1.8774496  2.2124686  1.        ]
# Bump 2: w=-12.480042, mu=[0.83738863 0.08378987 0.49606588 0.4905011  0.48638636 0.5001306 ], sigma=[4.3866315  2.5497675  1.         0.03486075 0.05388432 1.        ]
# Bump 3: w=-14.465599, mu=[0.49213737 0.5213393  0.5170608  0.7162996  0.74177456 0.5173663 ], sigma=[0.01031605 0.30425563 1.         1.5676723  2.6258783  1.        ]
# Bump 4: w=-13.749366, mu=[0.23742872 0.15040374 0.4988694  0.49180114 0.50778705 0.50222194], sigma=[0.5824203  0.96215564 1.         0.03486075 0.05388432 1.        ]
#
#
# # Num of discovery: 273
