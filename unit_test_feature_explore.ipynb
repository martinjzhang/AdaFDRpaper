# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from util import *
from prim_fdr import *
from data_loader import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### GTEx: feature exploration

# %%
## loading GTEx data
p,x,n_full,cate_name = load_GTEx_full(verbose=True)

## testing the BH method
n_rej,t_rej=bh(p,alpha=0.1,n_sample=n_full,verbose=True)

## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,n_sample=n_full,lamb=0.995,verbose=True)
# Out:
# ## Load GTEx full data ##
# # all hypothesis: 10623893
# # filtered hypothesis: 169301
# # p=0.00226011, x=[13.73583078  0.08957559  0.112      16.        ]
# # p=0.00254028, x=[13.74614226  0.08957559  0.         16.        ]
# # p=0.000610689, x=[13.74784609  0.08957559  0.         16.        ]
# # p=0.00071358, x=[1.37478546e+01 8.95755866e-02 1.20000000e-02 1.60000000e+01]
# # p=0.000228687, x=[13.74820448  0.08957559  0.209      13.        ]
#
#
# ## bh testing summary ##
# # n_rej = 29348
# # t_rej = 0.000276
#
#
# ## sbh summary ##
# # n_rej = 29689
# # t_rej = 0.000286
# # pi_0 estimate = 0.975

# %%
feature_explore(p,x[:,3],alpha=0.1,qt_norm=False,feature_name=[],cate_name=[cate_name[3]])

# %%
feature_explore(p,x,alpha=0.1,qt_norm=True,feature_name=[],cate_name=cate_name)

# %%
feature_explore(p,x,alpha=0.1,qt_norm=True,feature_name=[],cate_name=cate_name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-fec9b76ce862> in <module>()
# ----> 1 feature_explore(p,x,alpha=0.1,qt_norm=True,feature_name=[],cate_name=cate_name)
#
# ~/NeuralFDR2/NeuralFDR2/prim_fdr.py in feature_explore(p, x, alpha, qt_norm, reorder, feature_name, cate_name)
#     160     else:
#     161         for i in range(min(4,d)):
# --> 162             feature_explore_1d(x_null[:,i],x_alt[:,i],bins,meta_feature[i],title=feature_name[i],cate_name=cate_name[i])
#     163
#     164 """
#
# ~/NeuralFDR2/NeuralFDR2/prim_fdr.py in feature_explore_1d(x_null, x_alt, bins, meta_info, title, cate_name)
#     109             p_null,p_alt = np.zeros([unique_val.shape[0]]),np.zeros([unique_val.shape[0]])
#     110             for i,key in enumerate(unique_null): p_null[unique_val==key] = cts_null[i]
# --> 111             for i,key in enumerate(unique_alt): p_alt[unique_val==key] = cts_alt[i]
#     112             n_bin = unique_val.shape[0]
#     113             p_null = (p_null+1)/np.sum(p_null+1)*n_bin
#
# KeyboardInterrupt:

# %% [markdown]
# ### airway: feature exploration

# %%
p,x = load_airway(verbose=False)
feature_explore(p,x,alpha=0.1,qt_norm=True,feature_name=[])

# %%
plt.figure()
plt.scatter(x,p,alpha=0.01)
plt.show()

# %% [markdown]
# ### mixture_fit_new
