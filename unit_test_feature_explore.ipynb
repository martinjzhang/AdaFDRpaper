# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import torch
from torch.autograd import Variable

## import self-written packages 
from util import *
from prim_fdr import *
from data_loader import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### GTEx: feature exploration

# %%
## loading GTEx data
p,x,n_full,cate_name = load_GTEx_full(verbose=True)

## testing the BH method
n_rej,t_rej=bh(p,alpha=0.1,n_sample=n_full,verbose=True)

## testing the Storey BH method
n_rej,t_rej,pi0_hat=storey_bh(p,alpha=0.1,n_sample=n_full,lamb=0.995,verbose=True)
# Out:
# ## Load GTEx full data ##
# # all hypothesis: 10623893
# # filtered hypothesis: 169301
# # p=0.00226011, x=[13.73583078  0.08957559  0.112      16.        ]
# # p=0.00254028, x=[13.74614226  0.08957559  0.         16.        ]
# # p=0.000610689, x=[13.74784609  0.08957559  0.         16.        ]
# # p=0.00071358, x=[1.37478546e+01 8.95755866e-02 1.20000000e-02 1.60000000e+01]
# # p=0.000228687, x=[13.74820448  0.08957559  0.209      13.        ]
#
#
# ## bh testing summary ##
# # n_rej = 29348
# # t_rej = 0.000276
#
#
# ## sbh summary ##
# # n_rej = 29689
# # t_rej = 0.000286
# # pi_0 estimate = 0.975

# %% [markdown]
# ## test feature_preprocess

# %%
x_,meta_info = feature_preprocess(x,p,return_metainfo=True,verbose=True)

# %%
feature_explore(p,x,alpha=0.1,qt_norm=False,vis_dim=[0,1,3],cate_name={3:cate_name[3]})

# %%
feature_explore(p,x,alpha=0.1,qt_norm=True,vis_dim=[0,1,3],cate_name={3:cate_name[3]})

# %%
feature_explore(p,x,alpha=0.1,qt_norm=True,vis_dim=[0,1,3],cate_name={3:cate_name[3]})

# %% [markdown]
# ### airway: feature exploration

# %%
p,x = load_airway(verbose=False)
feature_explore(p,x,alpha=0.1,qt_norm=False)

# %%
p,x = load_airway(verbose=False)
feature_explore(p,x,alpha=0.1,qt_norm=True)

# %%
plt.figure()
plt.scatter(x,p,alpha=0.01)
plt.show()

# %% [markdown]
# ### mixture_fit_new
