# %%
## import public packages
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.cluster import KMeans
from scipy.stats import norm
from scipy.stats import multivariate_normal
import time

## import self-written packages 
from nfdr2.util import *
import nfdr2.method as md
import nfdr2.data_loader as dl

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
p, x, n_full, cate_name, cis_name = dl.load_GTEx(if_impute=False)
# Out:
# load GTEx_small

# %%
md.feature_explore(p, x, alpha=0.1, n_full=n_full, vis_dim=[3], cate_name=cate_name,\
                   output_folder=None, h=None)

# %%
np.sum(p>0.99)/n_full*100
# Out:
# 0.9299899523348747

# %%
-np.log10(0.00882831)
# Out:
# 2.054122425292256

# %%
p, x, n_full, cate_name, cis_name = dl.load_GTEx('GTEx_small')

# %%
md.feature_explore(p, x, alpha=0.1, n_full=None, vis_dim=None,\
                   cate_name=cate_name, output_folder=None,\
                   title_list=None, h=None)

# %%
output_folder = '/data3/martin/gtex_data/GTEx_Analysis_v7_eQTL_all_associations'
fil = open(output_folder+'/GTEx_small.pickle','wb') 
pickle.dump(p[0:50000], fil)
pickle.dump(x[0:50000], fil)
pickle.dump(cis_name[0:50000], fil)
fil.close()

# %%
np.set_printoptions(precision=16,suppress=True)
md.feature_explore(p,x,vis_dim=[3],cate_name=cate_name,\
                   title_list = ['a', 'b', 'distance', 'chromatin'])
